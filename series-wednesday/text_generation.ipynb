# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                   transcript
# episode 1  Original release date: November 23, 2022 Wedne...
# episode 2  Original release date: November 23, 2022 Wedne...
# episode 3  Original release date: November 23, 2022 Wedne...
# episode 4  Original release date: November 23, 2022 Wedne...
# episode 5  Original release date: November 23, 2022 32 ye...
# episode 6  Original release date: November 23, 2022 Wedne...
# episode 7  Original release date: November 23, 2022 At Ma...
# episode 8  Original release date: November 23, 2022 Wedne...

# %%
# Extract only Brad Williams's text
ep_5_text = data.transcript.loc['episode 5']
ep_5_text[:200]
# Out:
# 'Original release date: November\xa023,\xa02022 32 years ago, Gomez is arrested on suspicion of killing Garrett Gates at Nevermore. At present time, the Addamses visit Wednesday for parents’ weekend at Never'

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ep_5_dict = markov_chain(ep_5_text)
ep_5_dict
# Out:
# {'Original': ['release'],
#  'release': ['date:', 'Gomez'],
#  'date:': ['November\xa023,\xa02022'],
#  'November\xa023,\xa02022': ['32'],
#  '32': ['years', 'years'],
#  'years': ['ago,', 'ago?', 'of', 'to', 'ago.'],
#  'ago,': ['Gomez'],
#  'Gomez': ['is', 'is', 'reveals', 'after', 'and', 'Addams.', 'kissing'],
#  'is': ['arrested',
#   'cut',
#   'guilty',
#   'on',
#   'expected',
#   'not',
#   'odd.',
#   'disappointing.',
#   'an',
#   'neither',
#   'exactly',
#   'over.',
#   'Bianca.',
#   'no',
#   'drying',
#   'gonna',
#   'a',
#   'about,',
#   'exactly',
#   'that',
#   'being',
#   'a',
#   'desperately',
#   'all',
#   'trying',
#   'all',
#   'about',
#   'the',
#   'Mother',
#   'a',
#   'a',
#   'that',
#   'over.'],
#  'arrested': ['on', 'for', 'for'],
#  'on': ['suspicion',
#   'car]',
#   'her',
#   'the',
#   'the',
#   'my',
#   'this',
#   'the',
#   'that',
#   'my',
#   'him.',
#   'a',
#   'the',
#   'the',
#   'that?',
#   'his',
#   'the',
#   'the',
#   'was',
#   'the',
#   'my',
#   'earth?'],
#  'suspicion': ['of'],
#  'of': ['killing',
#   'shapeshifting',
#   'affection.',
#   'a',
#   'murder…',
#   'teenage',
#   'our',
#   'you',
#   'our',
#   'his',
#   'an',
#   'this',
#   'us',
#   'humor',
#   'dishonesty',
#   'head-shrinking.',
#   'head-shrinking,',
#   'that',
#   'people',
#   'a',
#   'murdering',
#   'that.',
#   'their',
#   'their',
#   'myself',
#   'people,',
#   'the',
#   'it?',
#   'Garrett',
#   'law.',
#   'the',
#   'here.',
#   'sincerity.',
#   'his',
#   'emotion?',
#   'treachery',
#   'myself.',
#   'which',
#   'remorse',
#   'them',
#   'them’s',
#   'those.',
#   'your',
#   'the',
#   'a',
#   'any',
#   'when',
#   'truth.',
#   'the',
#   'you',
#   'soft',
#   'each',
#   'nightshade',
#   'nightshade',
#   'Ansel',
#   'our',
#   'who',
#   'great',
#   'you,',
#   'my',
#   'this',
#   'all'],
#  'killing': ['Garrett', 'Gates.'],
#  'Garrett': ['Gates',
#   'intended',
#   'Gates,',
#   'Gates.',
#   'Gates.',
#   'Gates.',
#   'was',
#   'was',
#   'Gates.',
#   'Gates’s',
#   'Gates,',
#   'was',
#   'was',
#   'died,',
#   'Gates',
#   'went',
#   'bragging'],
#  'Gates': ['at', 'was', 'wasn’t', 'hated'],
#  'at': ['Nevermore.',
#   'Nevermore.',
#   'Nevermore,',
#   'the',
#   'this.',
#   'my',
#   'you.',
#   'the',
#   'hand,',
#   'best.',
#   'Nevermore.',
#   'the',
#   'Pilgrim',
#   'me.',
#   'the',
#   'the',
#   'all.',
#   'such',
#   'that',
#   'Camp',
#   'least',
#   'all,'],
#  'Nevermore.': ['At', 'A', 'I', 'I', '[Sue]', 'He', 'I’m'],
#  'At': ['present', 'least', 'least'],
#  'present': ['time,'],
#  'time,': ['the'],
#  'the': ['Addamses',
#   'suspected',
#   'coroner',
#   'night.',
#   'entire',
#   'school.',
#   'fetid',
#   'best',
#   'unfortunate',
#   'mend',
#   'positive',
#   'mend?',
#   'reason',
#   'hospital.',
#   'past',
#   'little',
#   'target',
#   'dance.',
#   'Seychelles.',
#   'world.',
#   'lumberjack.',
#   'Solstice',
#   'weekend?',
#   'matter',
#   'culture',
#   'monster',
#   'ICU.',
#   'mend.',
#   'process.',
#   'results',
#   'wisdom',
#   'weekend.',
#   'lab.',
#   'DNA',
#   'ICU,',
#   'morgue.',
#   'family',
#   'results',
#   'scene.',
#   'local',
#   'best',
#   'music.',
#   'time',
#   'place.',
#   'place.',
#   'truth,',
#   'candy.',
#   'bowl?',
#   'full',
#   'judge',
#   'wrong',
#   'end',
#   'weekend',
#   'Hummers.',
#   'easiest',
#   'morgue.',
#   'body.',
#   'coroner’s',
#   'truth.',
#   'truth',
#   'murder',
#   'right',
#   'right',
#   'police?',
#   'oldest',
#   'night',
#   'Rave’N',
#   'school.',
#   'sword,',
#   'perfect',
#   'matter',
#   'overt',
#   'reason',
#   'hell',
#   'saber',
#   'District',
#   'timing',
#   'very',
#   'icing',
#   'cake.',
#   'monster’s',
#   'DNA',
#   'world',
#   'coroner.',
#   'security',
#   'morgue,',
#   'lens.',
#   'backyard.',
#   'whole',
#   'wrong',
#   'very',
#   'Balkan',
#   'moon',
#   'knot?',
#   'first',
#   'family',
#   'fish',
#   'crime…',
#   'truth',
#   'Poe',
#   'fencing',
#   'group',
#   'first',
#   'one',
#   'time',
#   'stairs,',
#   'way',
#   'mouth.',
#   'eyes',
#   'scream',
#   'door.',
#   'table.',
#   'blame',
#   'mouth.',
#   'morning.',
#   'long',
#   'law',
#   'punch',
#   'nightshade',
#   'entire',
#   'land',
#   'school',
#   'punch',
#   'kids',
#   'whole',
#   'autopsy',
#   'truth',
#   'peace.',
#   'only',
#   'sheriff',
#   'full',
#   'sheriff’s',
#   'treacherous',
#   'past',
#   'spectrum',
#   'world',
#   'proper',
#   'living.',
#   'school',
#   'pages',
#   'wonderful',
#   'next',
#   'talent',
#   'authorities.',
#   'situation',
#   'school',
#   'same,'],
#  'Addamses': ['visit'],
#  'visit': ['Wednesday'],
#  'Wednesday': ['for',
#   'confronts',
#   'that',
#   'and',
#   'to',
#   'to',
#   'away',
#   'around.'],
#  'for': ['parents’',
#   'the',
#   'outcasts.',
#   'our',
#   'acting',
#   'what',
#   'the',
#   'the',
#   'the',
#   'you',
#   'the',
#   'our',
#   'any',
#   'me',
#   'me…',
#   'us',
#   'the',
#   'keeping',
#   'all',
#   'the',
#   'you.',
#   'murdering.',
#   'interest.',
#   'your',
#   'being',
#   'ransom.',
#   'a',
#   'his',
#   'you.',
#   'lycanthropy',
#   'werewolves?',
#   'your',
#   'his',
#   'seeing',
#   'Nevermore.',
#   'you,',
#   'someone',
#   'that.',
#   'who',
#   'anything,'],
#  'parents’': ['weekend'],
#  'weekend': ['at', 'to', 'my'],
#  'A': ['family', 'man', 'siren', 'bullet,', 'huge', 'few'],
#  'family': ['therapy',
#   'togetherness',
#   'session',
#   'past',
#   'were',
#   'deserves',
#   'behind',
#   'reunion',
#   'over'],
#  'therapy': ['session', 'with', 'for'],
#  'session': ['is', 'this', 'is'],
#  'cut': ['short', 'deep.'],
#  'short': ['when', 'notice,'],
#  'when': ['Wednesday',
#   'he',
#   'we',
#   'I',
#   'she’s',
#   'prepared',
#   'I',
#   'they',
#   'you',
#   'you',
#   'I',
#   'I',
#   'we’re',
#   'I'],
#  'confronts': ['her'],
#  'her': ['parents',
#   'crystal',
#   'judge-y',
#   'face',
#   'mind.',
#   'sharp',
#   'therapist',
#   'daughter',
#   'scales.',
#   'laying',
#   'kindness',
#   'how',
#   'tabby',
#   'painting',
#   'secret,',
#   'before.',
#   'vengeance',
#   'too',
#   'viper’s'],
#  'parents': ['about', 'can', 'faced'],
#  'about': ['the',
#   'the',
#   'toxic',
#   'Wednesday',
#   'my',
#   'some',
#   'your',
#   'lately.',
#   'retirement.',
#   'an',
#   'boys.',
#   'to',
#   'justice',
#   'how',
#   'ruining',
#   'him',
#   'all'],
#  'suspected': ['murder.'],
#  'murder.': ['Meanwhile,', 'Ah,'],
#  'Meanwhile,': ['Sheriff'],
#  'Sheriff': ['Galpin', 'Walker,', 'Galpin'],
#  'Galpin': ['learns', 'concludes', 'feels'],
#  'learns': ['that'],
#  'that': ['the',
#   'Gomez',
#   'Gates',
#   'he',
#   'Garrett',
#   'took',
#   'stormy',
#   'Eugene',
#   'would',
#   'biting',
#   'I',
#   'duet',
#   'is',
#   'killed',
#   'might',
#   'kind',
#   'is',
#   'cave',
#   'creature.',
#   'claw.',
#   'need',
#   'helps',
#   'man’s',
#   'we',
#   'bed.',
#   'something',
#   'is',
#   'your',
#   'I',
#   'her',
#   'was',
#   'someone',
#   'all',
#   'happens,',
#   'I',
#   'be?',
#   'dance',
#   'broke',
#   'effect.',
#   'night',
#   'dance.',
#   'his',
#   'you',
#   'one',
#   'stings,',
#   'night.',
#   'to'],
#  'coroner': ['has', 'kills'],
#  'has': ['committed', 'been', 'not', 'been', 'his'],
#  'committed': ['suicide', 'the'],
#  'suicide': ['after', 'note'],
#  'after': ['admitting', 'admitting', 'this,'],
#  'admitting': ['to', 'to'],
#  'to': ['fabricating',
#   'Wednesday',
#   'killing',
#   'find',
#   'poison',
#   'his',
#   'release',
#   'covering',
#   'covering',
#   'evade',
#   'misguided',
#   'wonder…',
#   'tell',
#   'say,',
#   'see',
#   'see',
#   'learn',
#   'grow,',
#   'report',
#   'make',
#   'see',
#   'avoid',
#   'see',
#   'siren-song',
#   'the',
#   'embrace',
#   'speak',
#   'the',
#   'attend',
#   'side',
#   'stomach',
#   'go',
#   'therapy',
#   'sit',
#   'start?',
#   'bring',
#   'me.',
#   'be',
#   'debate',
#   'tell',
#   'excavate',
#   'this',
#   'fight,',
#   'come',
#   'me.',
#   'talk',
#   'come',
#   'do',
#   'see',
#   'ask',
#   'destroy',
#   'say',
#   'startle',
#   'finally',
#   'do',
#   'find',
#   'put',
#   'tell',
#   'distract',
#   'make',
#   'remain',
#   'an',
#   'explain?',
#   'a',
#   'catch',
#   'swim',
#   'flay',
#   'be',
#   'navigate',
#   'talk.',
#   'do',
#   'deliver',
#   'the',
#   'return',
#   'town.',
#   'pay',
#   'see',
#   'derail',
#   'test',
#   'throw',
#   'take',
#   'them?',
#   'an',
#   'get',
#   'know',
#   'be',
#   'send',
#   'conversion',
#   'wolf',
#   'be',
#   'him',
#   'a',
#   'find',
#   'be',
#   'be',
#   'your',
#   'be',
#   'protect',
#   'his',
#   'leave',
#   'your',
#   'protect',
#   'haunt',
#   'find',
#   'join?',
#   'spoil',
#   'serve',
#   'me,',
#   'me',
#   'be',
#   'kill',
#   'use',
#   'murder',
#   'spike',
#   'me',
#   'falsify',
#   'keep',
#   'me',
#   'be',
#   'control',
#   'be',
#   'madness.',
#   'help',
#   'thank',
#   'pick',
#   'wolf',
#   'do',
#   'lose.',
#   'be',
#   'blaze.',
#   'be',
#   'find',
#   'involve',
#   'that?',
#   'murder',
#   'rectify',
#   'cover',
#   'do',
#   'shield',
#   'Eugene.'],
#  'fabricating': ['Gates’s\xa0autopsy\xa0report.'],
#  'Gates’s\xa0autopsy\xa0report.': ['Galpin'],
#  'concludes': ['that'],
#  'guilty': ['and', 'about', 'man'],
#  'and': ['arrests',
#   'Morticia',
#   'arrested',
#   'exaggerated',
#   'they',
#   'to',
#   'is',
#   'make',
#   'youthful',
#   'the',
#   'I',
#   'denial',
#   'put',
#   'I',
#   'we',
#   'tag',
#   'talk',
#   'why',
#   'her',
#   'the',
#   'you',
#   'Janet.',
#   'registered',
#   'has',
#   'I',
#   'will',
#   'he',
#   'richest',
#   'I',
#   'hate,',
#   'independent.',
#   'prejudice.',
#   'he',
#   'I',
#   'she',
#   'finally',
#   'I',
#   'free',
#   'bigotry.',
#   'brave.',
#   'lock',
#   'Gomez',
#   'blue',
#   'focus.',
#   'spike',
#   'covered',
#   'Nevermore.',
#   'kill',
#   'Nevermore’s',
#   'unequivocal',
#   'even',
#   'my',
#   'not',
#   'help',
#   'MorningSong',
#   'he',
#   'he',
#   'Mayor',
#   'protect'],
#  'arrests': ['him.'],
#  'him.': ['In', 'He', 'Any', 'He', '[gasps]', '[low,'],
#  'In': ['prison,', 'fact,'],
#  'prison,': ['Gomez'],
#  'reveals': ['to', 'that'],
#  'was': ['killed',
#   'a',
#   'accused',
#   'created',
#   'filling',
#   'a',
#   'Garrett',
#   'never',
#   'so',
#   'so',
#   'legal',
#   'planning',
#   'obscured.',
#   'infatuated',
#   'furious',
#   'unstoppable.',
#   'a',
#   '12.',
#   'the',
#   'orphaned,',
#   'howling',
#   'a',
#   'to',
#   'started',
#   'the',
#   'terrifying.',
#   'even',
#   'like',
#   'staring',
#   'only',
#   'so…',
#   'so',
#   'foaming',
#   'right.',
#   'dying…',
#   'going',
#   'built',
#   'stolen',
#   'his',
#   'to',
#   'your',
#   'a',
#   'reminded',
#   'you.',
#   'not'],
#  'killed': ['by', 'Rowan', 'themselves', 'Joseph', 'by'],
#  'by': ['accident,',
#   'police',
#   'means',
#   'community,',
#   'jealousy',
#   '“we,”',
#   'an',
#   'rage.',
#   'a',
#   'the'],
#  'accident,': ['while'],
#  'while': ['Morticia'],
#  'Morticia': ['confesses', 'dig', 'Frump’s'],
#  'confesses': ['to'],
#  'Gates.': ['Wednesday', 'Garrett', 'You', 'You', 'Well,', 'I'],
#  'dig': ['up'],
#  'up': ['Gates’s',
#   'Gates’s',
#   'Rowan’s',
#   'there.',
#   'with',
#   'the',
#   'the',
#   'drowning.',
#   'to',
#   'the'],
#  'Gates’s': ['grave', 'motive.', 'family'],
#  'grave': ['to', 'earlier'],
#  'find': ['that', 'out', 'me?', 'out', 'the', 'out', 'her.', 'out.', 'out'],
#  'he': ['had',
#   'could',
#   'was',
#   'was',
#   'had',
#   'still',
#   'could',
#   'kept',
#   'felt',
#   'covered',
#   'started',
#   'says.',
#   'smooths',
#   'delivers',
#   'identified',
#   'used',
#   'looked',
#   'had',
#   'really',
#   'must',
#   'fully',
#   'agree',
#   'attempted'],
#  'had': ['been',
#   'a',
#   'the',
#   'accused',
#   'broken',
#   'made',
#   'a',
#   'a',
#   'been',
#   'the',
#   'done',
#   'our',
#   'here.'],
#  'been': ['lethally',
#   'to',
#   'hunted,',
#   'waxing?',
#   'eating',
#   'rocky',
#   'very',
#   'a',
#   'through',
#   'hard',
#   'coping?',
#   'torture',
#   'lying',
#   'there.',
#   'living',
#   'waiting',
#   'one',
#   'arrested',
#   'playing',
#   'more',
#   'a',
#   'trashed.'],
#  'lethally': ['poisoned'],
#  'poisoned': ['before'],
#  'before': ['he', 'her', 'my'],
#  'could': ['be',
#   'you',
#   'I?',
#   'talk',
#   'only',
#   'keep',
#   'you',
#   'have',
#   'tell',
#   'help'],
#  'be': ['killed,',
#   'so',
#   'most',
#   'your',
#   'honest,',
#   'right',
#   'addressed.',
#   'the',
#   'a',
#   'in',
#   'Wednesday.',
#   'okay,',
#   'kidding',
#   'used',
#   'appointed',
#   'strong',
#   'dramatic,',
#   'normal,',
#   'nice.',
#   'a',
#   'sent',
#   'the',
#   'falling',
#   'strong.',
#   'alone.',
#   'so',
#   'an',
#   'called',
#   'believed.',
#   'released',
#   'positive.',
#   'a',
#   'a',
#   'a'],
#  'killed,': ['but'],
#  'but': ['are', 'it’s', 'your', 'they', 'the', 'I', 'deadly,', 'her', 'he'],
#  'are': ['caught',
#   'you,',
#   'you\xa0accused',
#   'a',
#   'down,',
#   'starting',
#   'not',
#   'you',
#   'the',
#   'you',
#   'around',
#   'these?',
#   'camps',
#   'biting.',
#   'those',
#   'strong',
#   'more',
#   'out',
#   'the',
#   'you'],
#  'caught': ['by', 'her', 'in'],
#  'police': ['and'],
#  'night.': ['Later,', 'Excuse'],
#  'Later,': ['they'],
#  'they': ['confront',
#   'certainly',
#   'not,',
#   'are.',
#   'search',
#   'care',
#   'are',
#   'will',
#   'were',
#   'make',
#   'haven’t',
#   'tied',
#   'cleared',
#   'can',
#   'were'],
#  'confront': ['Mayor'],
#  'Mayor': ['Walker', 'Walker', 'Walker'],
#  'Walker': ['who', 'agrees', 'are'],
#  'who': ['reveals',
#   'or',
#   'wants',
#   'did',
#   'really',
#   'killed',
#   'we',
#   'gets',
#   'I'],
#  'intended': ['to'],
#  'poison': ['the', 'that', 'to'],
#  'entire': ['school', 'school.'],
#  'school': ['due', 'was', 'year', 'or', 'from'],
#  'due': ['to'],
#  'his': ['father’s',
#   'friend.',
#   'fingers?',
#   'digits.',
#   'brains',
#   'bidding.',
#   'kids.',
#   'name.',
#   'desk.',
#   'wife.',
#   'murderer.',
#   'family',
#   'only',
#   'confession',
#   'tells.',
#   'mustache.',
#   'signed',
#   'crime.',
#   'little',
#   'hands,',
#   'mind',
#   'oppression.',
#   'life.',
#   'pocket.',
#   'family',
#   'idea.',
#   'father',
#   'pocket.',
#   'mom',
#   'right'],
#  'father’s': ['hate', 'from'],
#  'hate': ['for'],
#  'outcasts.': ['Mayor'],
#  'agrees': ['to'],
#  'covering': ['up', 'up', 'up'],
#  'motive.': ['Back'],
#  'Back': ['at'],
#  'Nevermore,': ['Weems'],
#  'Weems': ['reluctantly'],
#  'reluctantly': ['admits'],
#  'admits': ['to'],
#  'Rowan’s': ['death', 'father'],
#  'death': ['by', 'if', 'trap.', 'allowed'],
#  'means': ['of', 'we', 'Garrett'],
#  'shapeshifting': ['in'],
#  'in': ['an',
#   'handcuffs,',
#   'a',
#   'the',
#   'the',
#   'on',
#   'the',
#   'over',
#   'the',
#   'it.',
#   'the',
#   'the',
#   'each',
#   'that',
#   'at',
#   'the',
#   'his',
#   'his',
#   'a',
#   'orange.',
#   'Jericho.',
#   'perfection.',
#   'a',
#   'the',
#   'it.',
#   'the',
#   'the',
#   'no',
#   'the',
#   'your',
#   'America.',
#   'order',
#   'lockup',
#   'the',
#   'his',
#   'charge',
#   'a',
#   'his',
#   'there.',
#   'her',
#   'your',
#   'the',
#   'his',
#   'an'],
#  'an': ['effort',
#   'open',
#   'attempted',
#   'innocent',
#   'eye',
#   'old',
#   'attorney.',
#   'outcast-hating',
#   'essay',
#   'early',
#   'ancestor',
#   'Addams',
#   'escape',
#   'innocent',
#   'unflattering'],
#  'effort': ['to'],
#  'evade': ['controversy'],
#  'controversy': ['at', 'and'],
#  'school.': ['*', 'Starting', 'Did', 'His', 'Thank'],
#  '*': ['*', '*', '[tense,'],
#  '[tense,': ['enigmatic'],
#  'enigmatic': ['music'],
#  'music': ['playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'continuing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'building]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'builds,',
#   'playing]',
#   'playing]',
#   'playing]',
#   'swells]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]',
#   'playing]'],
#  'playing]': ['[Wednesday]',
#   '…what',
#   '[quirkily',
#   'Ah,',
#   'Not',
#   'Yeah.',
#   'Son',
#   'Who',
#   'Recruitment',
#   '[Thing',
#   '[mysterious',
#   'First',
#   '[birds',
#   'So',
#   '[grunts]',
#   'Garrett',
#   'Addams!',
#   '[both',
#   'So',
#   'What',
#   '[Wednesday]',
#   '[wet',
#   '[Morticia',
#   'It’s',
#   'All',
#   '[bell',
#   'I’m',
#   'I',
#   'You',
#   '[jauntily'],
#  '[Wednesday]': ['How',
#   'On',
#   'If',
#   'We',
#   'That’s',
#   'Hello,',
#   'Don’t',
#   'Don’t'],
#  'How': ['well',
#   'are',
#   'have',
#   'could',
#   'could',
#   'did',
#   'can',
#   'many',
#   'to',
#   'the',
#   'are',
#   'ironic,',
#   'do',
#   'are'],
#  'well': ['do'],
#  'do': ['we',
#   'hear',
#   'his',
#   'with',
#   'you',
#   'without',
#   'taste',
#   'it.',
#   'we',
#   'you',
#   'it',
#   'you.',
#   'I',
#   'to'],
#  'we': ['really',
#   'missed',
#   'had,',
#   'did',
#   'both',
#   'can',
#   'should…',
#   'weren’t',
#   'can',
#   'please',
#   'don’t',
#   'got',
#   'both',
#   'have',
#   'have',
#   'have',
#   'are.',
#   'both',
#   'can’t'],
#  'really': ['know', 'happened', 'think', 'do', 'committed', 'died.'],
#  'know': ['our',
#   'what',
#   'Reggie,',
#   'the',
#   'how',
#   'what',
#   'what’s',
#   'who',
#   'them',
#   'they',
#   'what',
#   'that',
#   'they',
#   'Mother',
#   'why',
#   'we’ve',
#   'how',
#   'you'],
#  'our': ['parents?',
#   'lives,',
#   'children',
#   'students.',
#   'very',
#   'little',
#   'relationship',
#   'breath.',
#   'little',
#   'outing.',
#   'difficulties',
#   'mother-daughter',
#   'bloodline'],
#  'parents?': ['Take'],
#  'Take': ['my'],
#  'my': ['father.',
#   'plum-lipped',
#   'plague',
#   'family?',
#   'mom',
#   'little',
#   'every',
#   'crap?',
#   'plate',
#   'brother',
#   'parents',
#   'home.',
#   'proof.',
#   'eyes.',
#   'survival',
#   'father',
#   'father,',
#   'investigation?',
#   'game.',
#   'son!',
#   'job',
#   'complaint',
#   'disposition,',
#   'visions',
#   'son',
#   'own',
#   'life…',
#   'little',
#   'decision'],
#  'father.': ['I’ve', 'Could', 'He'],
#  'I’ve': ['always',
#   'never',
#   'been',
#   'always',
#   'got',
#   'been',
#   'been',
#   'never',
#   'seen',
#   'seen'],
#  'always': ['considered',
#   'filled',
#   'adored.',
#   'encouraged',
#   'been',
#   'thought',
#   'thought',
#   'here'],
#  'considered': ['him'],
#  'him': ['an',
#   'some',
#   'insane.',
#   'since',
#   'myself,',
#   'now?',
#   'alone!',
#   'of',
#   'stalking',
#   'mad'],
#  'open': ['book.', 'to'],
#  'book.': ['A'],
#  'man': ['given', 'who’s'],
#  'given': ['to'],
#  'misguided': ['schemes'],
#  'schemes': ['and'],
#  'exaggerated': ['displays'],
#  'displays': ['of'],
#  'affection.': ['But'],
#  'But': ['when',
#   'I’m',
#   'anything',
#   'his',
#   'then',
#   'mostly',
#   'I',
#   'how',
#   'you',
#   'no.',
#   'I’m',
#   'without',
#   'we’re',
#   'after',
#   'they'],
#  'a': ['student,',
#   'murder',
#   'sword,',
#   'dozen',
#   'safe',
#   'full',
#   'coma.',
#   'personal',
#   'touch',
#   'jerk',
#   'no-show',
#   'text',
#   'room',
#   'stately',
#   'dead',
#   'little',
#   'lab',
#   'family',
#   'big',
#   'bunch',
#   'bitch.',
#   'murderer',
#   'lot',
#   'good',
#   'decades-old',
#   'personal',
#   'damn',
#   'real',
#   'request.',
#   'higher',
#   'real',
#   'cruise',
#   'disappointment.',
#   'court',
#   'rose',
#   'grave',
#   'head',
#   'terrible',
#   'comforting',
#   'better',
#   'fencing',
#   'rattlesnake?',
#   'world',
#   'call',
#   'decades-old',
#   'guilty',
#   'shock,',
#   'distraction.',
#   'gift.',
#   'trial.',
#   'state',
#   'night',
#   'bet',
#   'catch.',
#   'Nightshade.',
#   'member?',
#   'competition,',
#   'competition,',
#   'trivial',
#   'rabid',
#   'souvenir',
#   'vision?',
#   'vial',
#   'stab',
#   'telltale',
#   'drunken',
#   'trial,',
#   'full',
#   'deal?',
#   'Dove.',
#   'darker',
#   'Raven.',
#   'witch',
#   'good',
#   'nail-biter.',
#   'murderer.',
#   'stranger',
#   'crystal',
#   'shape-shifter.',
#   'fascinating',
#   'soul,'],
#  'student,': ['he'],
#  'accused': ['of', 'of', 'his'],
#  'murder': ['that', 'of', 'case', 'the', 'you'],
#  'took': ['place', 'the'],
#  'place': ['right', 'was'],
#  'right': ['up', 'there.', 'now.', 'to', 'to', 'way', 'now.', 'mind.'],
#  'there.': ['Which', 'Dad.', '[Galpin]', 'When'],
#  'Which': ['leads', 'means', 'means'],
#  'leads': ['me'],
#  'me': ['to',
#   'here,',
#   'look',
#   'like',
#   'to',
#   'the',
#   'ask?',
#   'how',
#   'off',
#   'anything.',
#   'to',
#   'one',
#   'somewhere',
#   'of',
#   'you’re',
#   'in',
#   'that',
#   'a',
#   'for',
#   'for'],
#  'wonder…': ['[intense,'],
#  '[intense,': ['unsettling', 'sweeping'],
#  'unsettling': ['music'],
#  '…what': ['really'],
#  'happened': ['that', 'at', 'to'],
#  'stormy': ['night'],
#  'night': ['32', 'of', 'apart', 'together.', 'Garrett', 'to'],
#  'ago?': ['[screams]'],
#  '[screams]': ['[music'],
#  '[music': ['swells]', 'builds', 'builds,'],
#  'swells]': ['I', 'Tish,'],
#  'I': ['think',
#   'don’t',
#   'don’t',
#   'hope',
#   'left',
#   'realize',
#   'knew',
#   'should',
#   'give',
#   'thought',
#   'uncovered',
#   'haven’t',
#   'love',
#   'can',
#   'shouldn’t',
#   'got',
#   'started',
#   'made',
#   'guess',
#   'haven’t',
#   'guess',
#   'always',
#   'borrow',
#   'can',
#   'refuse',
#   'do',
#   'have',
#   'thought',
#   'want',
#   'don’t',
#   'mean,',
#   'never',
#   'think',
#   'refuse',
#   'go',
#   'wouldn’t',
#   'miss',
#   'haven’t',
#   'don’t',
#   'refuse?',
#   'finally',
#   'harvested',
#   'should',
#   'brought',
#   'should',
#   'just',
#   'got',
#   'always',
#   'got',
#   'am',
#   'haven’t',
#   'ask',
#   'have',
#   'help',
#   'caught',
#   'stepped',
#   'saw',
#   'saw',
#   'was',
#   'know',
#   'wasn’t',
#   'know',
#   'do.',
#   'understand',
#   'never',
#   'would',
#   'have',
#   'see',
#   'found',
#   'gave',
#   'should',
#   'brought',
#   'know,',
#   'thought',
#   'just',
#   'want',
#   'always',
#   'had',
#   'mean',
#   'rejected',
#   'was',
#   'win',
#   'join',
#   'could',
#   'rejected',
#   'saw',
#   'know',
#   'made',
#   'found',
#   'was',
#   'heard',
#   'realized',
#   'was',
#   'knew,',
#   'don’t',
#   'was',
#   'knew',
#   'borrowed',
#   'think',
#   'remember',
#   'resent',
#   'resent',
#   'lodged',
#   'left',
#   'know',
#   'touch',
#   'get',
#   'don’t',
#   'could',
#   'would,',
#   'don’t',
#   'pity',
#   'missed',
#   'missed',
#   'don’t.',
#   'hope',
#   'am.',
#   'know',
#   'knew',
#   'leafed',
#   'was',
#   'had',
#   'don’t',
#   'knew',
#   'did',
#   'tell',
#   'did',
#   'needed'],
#  'think': ['he', 'it’s', 'I', 'he’d', 'the'],
#  'sword,': ['and', 'my'],
#  'certainly': ['have', 'were,'],
#  'have': ['issues.',
#   'heard',
#   'worn',
#   'all',
#   'asked',
#   'spoken,',
#   'you',
#   'to',
#   'no',
#   'the',
#   'the',
#   'received',
#   'his',
#   'Garrett’s',
#   'to',
#   'to',
#   'to',
#   'here?',
#   'one',
#   'to.',
#   'an',
#   'a',
#   'that',
#   'been',
#   'prevented',
#   'no',
#   'a',
#   'become…',
#   'too',
#   'what',
#   'your'],
#  'issues.': ['I'],
#  'don’t': ['like',
#   'know',
#   'be',
#   'want',
#   'you',
#   'know',
#   'want',
#   'know',
#   'say…',
#   'know',
#   'want',
#   'want',
#   'know',
#   'hold',
#   'want'],
#  'like': ['to',
#   'a',
#   'that.',
#   'having',
#   'a',
#   'that?',
#   'they’re',
#   'chicken',
#   'I',
#   'you',
#   'not',
#   'me?'],
#  'tell': ['tales,', 'us', 'me', 'her.', 'me.', 'him.', 'a'],
#  'tales,': ['Sheriff'],
#  'Walker,': ['but'],
#  'it’s': ['all', 'easy', 'like', 'high', 'been', 'you.', 'decided.'],
#  'all': ['Morticia',
#   'his',
#   'to',
#   'right?',
#   'do.',
#   'he',
#   'about',
#   'these',
#   'came',
#   'some',
#   'a',
#   'I',
#   'textbook',
#   'those',
#   'the',
#   'this.',
#   'the'],
#  'Frump’s': ['fault.'],
#  'fault.': ['They'],
#  'They': ['were', 'certainly', 'bag', 'found', 'really', 'stuck'],
#  'were': ['fighting',
#   'the',
#   'they',
#   'dropped.',
#   'you',
#   'all',
#   'covering',
#   'the',
#   'an',
#   'her',
#   'never',
#   'so',
#   'sheriff,',
#   'in',
#   'worried',
#   'very',
#   'just',
#   'driving'],
#  'fighting': ['over', 'for'],
#  'over': ['her.', 'with.', '20', 'yet.', '200'],
#  'her.': ['Tish…',
#   '[music',
#   'Tyler,',
#   'She’ll',
#   '[dramatic',
#   'Why',
#   '[chilling',
#   'You’re'],
#  'Tish…': ['I'],
#  'what': ['to',
#   'they',
#   'happened',
#   'it’s',
#   'to',
#   'this',
#   'he',
#   'happened.',
#   'I’d',
#   'do',
#   'it',
#   'it',
#   'happened,',
#   'I'],
#  'say,': ['Gomez.'],
#  'Gomez.': ['Seeing', 'How'],
#  'Seeing': ['you'],
#  'you': ['in',
#   'more.',
#   'have',
#   'been',
#   'finally',
#   'look',
#   'in',
#   'so.',
#   'not',
#   'feeling',
#   'been',
#   'too,',
#   'skipped',
#   'apologize',
#   'to',
#   'misjudged',
#   'the',
#   'remember',
#   'all',
#   'been',
#   'right',
#   'refuse',
#   'take',
#   'thinking?',
#   'ambush',
#   'really',
#   'find',
#   'mean',
#   'take',
#   'to',
#   'siren’d',
#   'want',
#   'go',
#   'joined',
#   'got?',
#   'never',
#   'going',
#   'wolfed',
#   'say',
#   'in',
#   'cannot',
#   'in',
#   'call',
#   'for',
#   'feel',
#   'as',
#   'taught',
#   'get',
#   'find',
#   'failing',
#   'the',
#   'even',
#   'truly',
#   'a',
#   'to',
#   'want',
#   'know',
#   'claimed',
#   'captained',
#   'send',
#   'need',
#   'got',
#   'nearly',
#   'sure',
#   'don’t',
#   'two.',
#   'are',
#   'won’t',
#   'stabbed',
#   'two',
#   'have',
#   'see?',
#   'for',
#   'already',
#   'were',
#   'were',
#   'instruct',
#   'were',
#   'get',
#   'could',
#   'had',
#   'have',
#   'want?',
#   'didn’t',
#   'could',
#   'so',
#   'so',
#   'under',
#   'won’t',
#   'and',
#   'didn’t',
#   'need',
#   'participated',
#   'impersonate',
#   'became',
#   'did.',
#   'twice.',
#   'protecting'],
#  'handcuffs,': ['accused'],
#  'murder…': ['I’ve'],
#  'never': ['loved',
#   'change.',
#   'thought',
#   'my',
#   'change',
#   'know',
#   'believe',
#   'lose',
#   'live',
#   'forget',
#   'here.',
#   'seen'],
#  'loved': ['you'],
#  'more.': ['Cara', 'All', 'Our'],
#  'Cara': ['mia.'],
#  'mia.': ['All'],
#  'All': ['right,', 'right.', 'right.', 'right.', 'I', 'charges'],
#  'right,': ['that’s'],
#  'that’s': ['enough,', 'potpourri.', 'when', 'okay,'],
#  'enough,': ['Addams.'],
#  'Addams.': ['Let’s', 'How', 'And'],
#  'Let’s': ['go.', 'move', 'get', 'get', 'get', 'see'],
#  'go.': ['Let’s', '[bell', '[poignant,'],
#  'move': ['it'],
#  'it': ['out.',
#   'off.',
#   'went',
#   'would',
#   'hurt?',
#   'your',
#   'myself.',
#   'in',
#   'up,',
#   'is',
#   'should',
#   'four',
#   'up',
#   'wasn’t',
#   'from',
#   'up.',
#   'feels',
#   'on',
#   'takes',
#   'was',
#   'wouldn’t'],
#  'out.': ['Let’s', '[Enid', '[ticking]', '[sighs'],
#  'get': ['going.', 'this', 'down', 'in?', 'me', 'off', 'elected', 'these'],
#  'going.': ['[officer', 'Come', 'Not'],
#  '[officer': ['bangs'],
#  'bangs': ['on'],
#  'car]': ['[jauntily'],
#  '[jauntily': ['macabre', 'macabre'],
#  'macabre': ['music', 'outro'],
#  '[quirkily': ['dreary', 'dreary'],
#  'dreary': ['music', 'music'],
#  'Ah,': ['the', 'Nevermore.'],
#  'fetid': ['air'],
#  'air': ['of'],
#  'teenage': ['angst.'],
#  'angst.': ['These'],
#  'These': ['were', 'sessions', 'aren’t', 'are'],
#  'best': ['years', 'yet.', 'in', 'for'],
#  'lives,': ['were'],
#  'not,': ['Tish?', 'my'],
#  'Tish?': ['They'],
#  'were,': ['mi'],
#  'mi': ['cariño.'],
#  'cariño.': ['I'],
#  'hope': ['Wednesday’s', 'that', 'that'],
#  'Wednesday’s': ['happy', 'assimilation'],
#  'happy': ['to', 'to', 'you'],
#  'see': ['us.',
#   'us.',
#   'him?',
#   'you',
#   'the',
#   'more',
#   'through',
#   'is',
#   'that',
#   'if'],
#  'us.': ['I', '[Gomez]', 'We', 'Garrett’s', 'You'],
#  'left': ['a', 'for'],
#  'dozen': ['messages'],
#  'messages': ['on'],
#  'crystal': ['ball.', 'ball'],
#  'ball.': ['Still'],
#  'Still': ['no'],
#  'no': ['reply.', 'matter', 'way', 'idea.', 'need', 'time.', 'one', 'idea'],
#  'reply.': ['Fret'],
#  'Fret': ['not,'],
#  'plum-lipped': ['cupid.'],
#  'cupid.': ['I’m'],
#  'I’m': ['sure',
#   'happy',
#   'the',
#   'sorry',
#   'not',
#   'just…',
#   'not',
#   'not',
#   'being',
#   'sorry',
#   'about',
#   'gonna',
#   'sorry',
#   'always',
#   'not',
#   'meant',
#   'going',
#   'proud',
#   'only',
#   'curious'],
#  'sure': ['she’s', 'how', 'they', 'you'],
#  'she’s': ['dying', 'five?'],
#  'dying': ['to'],
#  '[Gomez]': ['Mmm.', 'Fortunately,'],
#  'Mmm.': ['[Pugsley]', 'I'],
#  '[Pugsley]': ['Come', 'What’ll', 'Dad!'],
#  'Come': ['on,', 'on.'],
#  'on,': ['let’s'],
#  'let’s': ['go.', 'focus'],
#  '[bell': ['tolls]', 'tolls]'],
#  'tolls]': ['Nevermore', 'So,'],
#  'Nevermore': ['was'],
#  'created': ['as'],
#  'as': ['a', 'cold-blooded', 'I', 'far', 'fatherhood', 'a', 'an', 'that'],
#  'safe': ['haven'],
#  'haven': ['for'],
#  'children': ['to'],
#  'learn': ['and'],
#  'grow,': ['no'],
#  'matter': ['who', 'at', 'of', 'much'],
#  'or': ['what', 'later', 'may', 'something,', 'future.', 'Rowan'],
#  'are.': ['[applause]', 'Given'],
#  '[applause]': ['I'],
#  'realize': ['most'],
#  'most': ['of', 'beneficial'],
#  'heard': ['about', 'of', 'the'],
#  'unfortunate': ['incident'],
#  'incident': ['involving'],
#  'involving': ['one'],
#  'one': ['of',
#   'kid',
#   'siren',
#   'suspect.',
#   'will',
#   'believed',
#   'of',
#   'in',
#   'of',
#   'would',
#   'who',
#   'way',
#   'last',
#   'of',
#   'day,',
#   'condition.'],
#  'students.': ['But'],
#  'report': ['that'],
#  'Eugene': ['is', 'in', 'hasn’t', 'loves', 'also'],
#  'mend': ['and'],
#  'expected': ['to'],
#  'make': ['a', 'this', 'you', 'sure', 'something', 'a', 'me', 'you'],
#  'full': ['recovery.', 'story.', 'of', 'support', 'and'],
#  'recovery.': ['So'],
#  'So': ['let’s', 'tell', 'are', 'as', 'you', 'you’re', 'go'],
#  'focus': ['on'],
#  'positive': ['and'],
#  'this': ['Parents’',
#   'weekend.',
#   'over',
#   'family',
#   'year?',
#   'morning.',
#   'for',
#   'in',
#   'for',
#   'school.',
#   'weekend.',
#   'is',
#   'school.',
#   'town.',
#   'is',
#   'is',
#   'is',
#   'weekend.',
#   'back',
#   'would',
#   'summer.',
#   'yearbook,',
#   'school'],
#  'Parents’': ['Weekend', 'Weekend'],
#  'Weekend': ['our', 'wasn’t'],
#  'very': ['best', 'open', 'boy', 'weekend', 'best', 'impressive', 'violent'],
#  'yet.': ['[Wednesday]', 'I’m', 'He’s'],
#  'On': ['the'],
#  'mend?': ['Try'],
#  'Try': ['in'],
#  'coma.': ['Have'],
#  'Have': ['you', 'you', 'you', 'it', 'you'],
#  'him?': ['You’re', 'Whoa.', '[students'],
#  'You’re': ['his', 'looking', 'just', 'not', 'under', 'both', 'a', 'a'],
#  'friend.': ['I’m', 'I'],
#  'reason': ['he’s', 'I'],
#  'he’s': ['in', 'on', 'got', 'confessed,', 'sentenced,'],
#  'hospital.': ['That'],
#  'That': ['is', 'way', 'place', 'is', 'didn’t', 'blue', 'makes'],
#  'not': ['your',
#   'been',
#   'yielded',
#   'a',
#   'to',
#   'that',
#   'comfortable',
#   'having',
#   'concern',
#   'your',
#   'hungry,',
#   'talking',
#   'have',
#   'kill',
#   'over',
#   'a',
#   'to',
#   'trained',
#   'going.',
#   'yours.',
#   'only',
#   'to',
#   'in'],
#  'your': ['fault,',
#   'feeble',
#   'dad’s',
#   'presence.',
#   'reaction,',
#   'parents',
#   'way,',
#   'father',
#   'secret?',
#   'stepfather.',
#   'way',
#   'friends.',
#   'goodbyes.',
#   'mother?',
#   'mother.',
#   'mother',
#   'mother',
#   'prime',
#   'cousin',
#   'fishing',
#   'favorite',
#   'legacy',
#   'shadow?',
#   'father’s',
#   'father',
#   'room',
#   'first',
#   'fun.',
#   'own.',
#   'implication.',
#   'job',
#   'visions',
#   'daughter',
#   'own',
#   'life,',
#   'dirty'],
#  'fault,': ['okay?'],
#  'okay?': ['The', 'What’s'],
#  'The': ['monster',
#   'bees',
#   'suicide',
#   'same',
#   'headstone',
#   'very',
#   'way',
#   'way',
#   'right',
#   'point',
#   'coroner',
#   'Nightshades',
#   'remarkable',
#   'night'],
#  'monster': ['hasn’t', 'that'],
#  'hasn’t': ['attacked', 'shown', 'been', 'had'],
#  'attacked': ['anyone'],
#  'anyone': ['in', 'can'],
#  'past': ['week.', 'with', 'or'],
#  'week.': ['Maybe', 'He'],
#  'Maybe': ['you', 'we', 'I', 'it'],
#  'finally': ['scared', 'make', 'make', 'going', 'be', 'accept'],
#  'scared': ['it'],
#  'off.': ['Or'],
#  'Or': ['maybe', 'teach'],
#  'maybe': ['it', 'we'],
#  'went': ['into', 'there'],
#  'into': ['hiding', 'Nevermore.', 'obsession,', 'the', 'me,', 'the', 'that'],
#  'hiding': ['to'],
#  'avoid': ['this'],
#  'weekend.': ['[Morticia]', 'I’m', 'No.', 'Oh,', 'I'],
#  '[Morticia]': ['Look',
#   'Nothing',
#   'Mmm.',
#   'By',
#   'Garrett!',
#   'It',
#   'Wednesday.',
#   'Mi'],
#  'Look': ['at'],
#  'this.': ['Some', 'I’m', 'I', 'I'],
#  'Some': ['things', 'of'],
#  'things': ['never'],
#  'change.': ['[quirky'],
#  '[quirky': ['music'],
#  'continuing]': ['I'],
#  'knew': ['I', 'our', 'that,', 'the', 'you', 'it.'],
#  'should': ['have', 'be', 'go.', 'run', 'be.'],
#  'worn': ['my'],
#  'plague': ['mask.'],
#  'mask.': ['Would'],
#  'Would': ['you'],
#  'look': ['at', 'at', 'human.', 'even'],
#  'family?': ['[howling]'],
#  '[howling]': ['Talk'],
#  'Talk': ['about'],
#  'toxic': ['pack'],
#  'pack': ['mentality.'],
#  'mentality.': ['I'],
#  'give': ['my', 'a', 'me'],
#  'mom': ['30', 'and', 'to'],
#  '30': ['seconds', 'years'],
#  'seconds': ['before'],
#  'judge-y': ['claws'],
#  'claws': ['come'],
#  'come': ['out.',
#   'on.',
#   'on.',
#   'here',
#   'home.',
#   'home,',
#   'as',
#   'here,',
#   'back',
#   'back'],
#  '[Enid': ['sighs]'],
#  'sighs]': ['Let’s', 'I'],
#  'with.': ['There'],
#  'There': ['she'],
#  'she': ['is.', 'hasn’t', 'was', 'wanted', 'was', 'couldn’t'],
#  'is.': ['Oh,'],
#  'Oh,': ['how', 'let', 'don’t', 'come', 'no', 'no.'],
#  'how': ['we',
#   'much',
#   'you',
#   'long',
#   'to',
#   'to',
#   'imperative',
#   'can',
#   'he',
#   'to',
#   'Sheriff'],
#  'missed': ['those', 'you', 'you'],
#  'those': ['accusing', 'dang', 'all', 'outcasts!'],
#  'accusing': ['eyes'],
#  'eyes': ['and', 'on', 'bore', 'of', 'didn’t'],
#  'youthful': ['sneer.'],
#  'sneer.': ['How'],
#  'you,': ['my',
#   'Dad.',
#   'Eugene.',
#   'dear.',
#   'Sheriff?',
#   'Wednesday.',
#   'I',
#   'kiddo.',
#   'Mother.'],
#  'little': ['rain',
#   'fella',
#   'walk',
#   'girl.',
#   'tormenta,',
#   'sister',
#   'jailbird',
#   'death'],
#  'rain': ['cloud?'],
#  'cloud?': ['I'],
#  'thought': ['Thing', 'that', 'I’d', 'they', 'we', 'I’d'],
#  'Thing': ['was'],
#  'filling': ['you'],
#  'every': ['move.'],
#  'move.': ['I'],
#  'uncovered': ['your'],
#  'feeble': ['subterfuge'],
#  'subterfuge': ['almost'],
#  'almost': ['immediately.'],
#  'immediately.': ['So,'],
#  'So,': ['how’s', 'who', 'your', 'it’s'],
#  'how’s': ['the', 'your'],
#  'fella': ['doing?'],
#  'doing?': ['Does'],
#  'Does': ['he'],
#  'still': ['have', 'worthy'],
#  'fingers?': ['Relax.'],
#  'Relax.': ['I'],
#  'haven’t': ['snapped', 'laid', 'come', 'made', 'defined', 'spent'],
#  'snapped': ['any'],
#  'any': ['of', 'sign', 'more.', 'wrongdoing.', 'boy'],
#  'digits.': ['Yet.'],
#  'Yet.': ['So'],
#  'us': ['everything.', 'better', 'too.', 'apart.', 'at', 'when', 'to'],
#  'everything.': ['Since'],
#  'Since': ['you’ve'],
#  'you’ve': ['abandoned', 'been', 'been', 'come'],
#  'abandoned': ['me'],
#  'here,': ['I’ve', 'so', 'Wednesday.'],
#  'hunted,': ['haunted…'],
#  'haunted…': ['and'],
#  'target': ['of'],
#  'attempted': ['murder.', 'to'],
#  'love': ['you', 'for'],
#  'so.': ['Enid.'],
#  'Enid.': ['Oh,', 'You'],
#  'let': ['me'],
#  'you.': ['One-one-thousand,',
#   'And',
#   'I',
#   'And',
#   'A',
#   'We',
#   '[foreboding',
#   'Here.',
#   '[gentle,',
#   'Father',
#   'You',
#   'Now,',
#   'I’ll',
#   'When'],
#  'One-one-thousand,': ['two-one-thousand…'],
#  'two-one-thousand…': ['Have'],
#  'waxing?': ['Three'],
#  'Three': ['seconds.'],
#  'seconds.': ['That’s'],
#  'That’s': ['a', 'me.', 'so', 'quite', 'a'],
#  'personal': ['best.', 'development'],
#  'best.': ['[sniffing]', 'Because'],
#  '[sniffing]': ['Are'],
#  'Are': ['you', 'you'],
#  'feeling': ['well?'],
#  'well?': ['You’re'],
#  'looking': ['a'],
#  'touch': ['anemic.', 'someone'],
#  'anemic.': ['Have'],
#  'eating': ['enough'],
#  'enough': ['red', 'about', 'to'],
#  'red': ['meat?'],
#  'meat?': ['It’s'],
#  'It’s': ['good', 'not', 'been', 'time', 'not', 'not', 'a'],
#  'good': ['to', 'times', 'stretch', 'egg.'],
#  'too,': ['Mom.'],
#  'Mom.': ['And'],
#  'And': ['you,',
#   'I',
#   'then',
#   'I',
#   'by',
#   'if',
#   'hope',
#   'that’s',
#   'cuffing',
#   'by',
#   'thanks',
#   'for',
#   'it'],
#  'Dad.': ['[somber,', 'You', 'Well,', 'I'],
#  '[somber,': ['inquisitive', 'emotional'],
#  'inquisitive': ['music', 'music'],
#  'Not': ['sure', 'even', 'this', 'ever.'],
#  'much': ['more', 'more.', 'to', 'as', 'if'],
#  'more': ['of',
#   'MorningSong',
#   'morbid',
#   'than',
#   'self-control',
#   'ravishing',
#   'potent,',
#   'powerful.'],
#  'togetherness': ['I'],
#  'can': ['take.',
#   'take',
#   'cut',
#   'see',
#   'it',
#   'discuss',
#   'be',
#   'never',
#   'I',
#   'and',
#   'figure',
#   'that',
#   'post',
#   'lead'],
#  'take.': ['Think'],
#  'Think': ['you', 'it’s'],
#  'skipped': ['where'],
#  'where': ['you', 'he’ll', 'no'],
#  'apologize': ['for'],
#  'acting': ['like'],
#  'jerk': ['last'],
#  'last': ['weekend.', 'week.', 'one', 'night'],
#  'sorry': ['for', 'I', 'you'],
#  'dance.': ['I', 'Ansel'],
#  'shouldn’t': ['have'],
#  'asked': ['you'],
#  'siren-song': ['me'],
#  'that.': ['Guessing', 'Potpourri?', '[Pugsley]', 'Mine.'],
#  'Guessing': ['your'],
#  'dad’s': ['a'],
#  'no-show': ['again'],
#  'again': ['this'],
#  'year?': ['Yeah.'],
#  'Yeah.': ['I', 'You'],
#  'got': ['a',
#   'one',
#   'a',
#   'the',
#   'one',
#   'until',
#   'security',
#   'them',
#   'my',
#   'the',
#   'off',
#   'your'],
#  'text': ['this'],
#  'morning.': ['You?', '[Morticia'],
#  'You?': ['Gabrielle'],
#  'Gabrielle': ['hasn’t'],
#  'shown': ['her'],
#  'face': ['since'],
#  'since': ['I', 'I', 'they', 'she'],
#  'started': ['here.', 'stalking', 'by'],
#  'here.': ['Probably', 'He', '[erratic', 'But'],
#  'Probably': ['sunning'],
#  'sunning': ['herself'],
#  'herself': ['somewhere', 'in'],
#  'somewhere': ['in', 'I'],
#  'Seychelles.': ['[woman]'],
#  '[woman]': ['My'],
#  'My': ['darling',
#   'picture’s',
#   'name',
#   'siren',
#   'appetite',
#   'little',
#   'life',
#   'father',
#   'father'],
#  'darling': ['daughter.'],
#  'daughter.': ['I'],
#  'made': ['it.', 'squat,', 'him', 'it'],
#  'it.': ['Wouldn’t',
#   'Um,',
#   'You',
#   'Both',
#   'What',
#   'Why',
#   'Which',
#   'Our',
#   'Well,',
#   'I'],
#  'Wouldn’t': ['miss'],
#  'miss': ['this', 'being', 'you.', 'you,', 'him,'],
#  'world.': ['I'],
#  'guess': ['you', 'that'],
#  'misjudged': ['her.'],
#  'builds': ['ominously,'],
#  'ominously,': ['fades'],
#  'fades': ['away]', 'away]'],
#  'away]': ['[gasps', '[Wednesday'],
#  '[gasps': ['softly]'],
#  'softly]': ['Our'],
#  'Our': ['old', 'mission', 'psychic'],
#  'old': ['yearbook.', 'case.'],
#  'yearbook.': ['I'],
#  'laid': ['eyes'],
#  '20': ['years.'],
#  'years.': ['Such', '[Galpin]'],
#  'Such': ['good'],
#  'times': ['we', 'I'],
#  'had,': ['didn’t'],
#  'didn’t': ['we,',
#   'deserve',
#   'you',
#   'escape.',
#   'have',
#   'it?',
#   'take',
#   'kill',
#   'look',
#   'you?',
#   'feel',
#   'have'],
#  'we,': ['Larissa?'],
#  'Larissa?': ['Some'],
#  'better': ['than', 'father.'],
#  'than': ['others.', 'adequate.', 'you'],
#  'others.': ['Oh,'],
#  'so': ['modest.',
#   'much.',
#   'that',
#   'happy',
#   'excited',
#   'we',
#   'sweet.',
#   'there',
#   'why',
#   'much',
#   'grateful',
#   'blinded',
#   'happy,',
#   'much,',
#   'much.'],
#  'modest.': ['You'],
#  'You': ['always',
#   'make',
#   'got',
#   'okay?',
#   'know',
#   'insisted',
#   'don’t',
#   'think',
#   'actually',
#   'haven’t',
#   'got',
#   'must',
#   'were',
#   'don’t',
#   'gotta',
#   'heard',
#   'know',
#   'have',
#   'have',
#   'are',
#   'didn’t',
#   'want',
#   'forgot',
#   'have',
#   'were',
#   'understand',
#   'said',
#   'were',
#   'can',
#   'look',
#   'knew',
#   'were',
#   'do',
#   'have',
#   'won’t',
#   'and'],
#  'filled': ['a'],
#  'room': ['with', 'and'],
#  'with': ['your',
#   'the',
#   'Wednesday,',
#   'the',
#   'her.',
#   'some',
#   'you',
#   'the',
#   'his',
#   'guilt',
#   'your',
#   'murderous',
#   'the',
#   'me.',
#   'him',
#   'sharks?',
#   'more',
#   'the',
#   'a'],
#  'presence.': ['Like'],
#  'Like': ['a'],
#  'stately': ['sequoia'],
#  'sequoia': ['tree.'],
#  'tree.': ['And'],
#  'would': ['make', 'be', 'say', 'find', 'you', 'come', 'have', 'have', 'he'],
#  'lumberjack.': ['[laughs]'],
#  '[laughs]': ['There’s'],
#  'There’s': ['that', 'only', 'only'],
#  'biting': ['sense'],
#  'sense': ['of'],
#  'humor': ['that'],
#  'adored.': ['Do'],
#  'Do': ['you', 'we'],
#  'remember': ['when', 'Garrett'],
#  'did': ['that',
#   'nothing',
#   'you',
#   'you',
#   'it?',
#   'you',
#   'not',
#   'he?',
#   'you',
#   'you',
#   'your',
#   'witness',
#   'you',
#   'what'],
#  'duet': ['for'],
#  'Solstice': ['Talent'],
#  'Talent': ['Show?'],
#  'Show?': ['Your'],
#  'Your': ['Judy',
#   'father',
#   'father',
#   'mother',
#   'saber',
#   'father',
#   'father',
#   'father',
#   'visions'],
#  'Judy': ['Garland', 'Garland,'],
#  'Garland': ['impression'],
#  'impression': ['was'],
#  'dead': ['ringer.'],
#  'ringer.': ['Sounds'],
#  'Sounds': ['positively'],
#  'positively': ['suicidal.'],
#  'suicidal.': ['Oh.'],
#  'Oh.': ['My', 'How'],
#  'picture’s': ['gone.'],
#  'gone.': ['Really?', 'Your'],
#  'Really?': ['Well,'],
#  'Well,': ['that', 'that', 'that', 'I', 'he’s', 'if', 'until', 'well,', 'at'],
#  'odd.': ['May'],
#  'May': ['I'],
#  'borrow': ['this'],
#  'weekend?': ['That'],
#  'way': ['Gomez', 'to', 'into', 'the', 'he', 'he', 'to', 'he', 'to'],
#  'take': ['a', 'the', 'control', 'control', 'comfort', 'long.'],
#  'walk': ['down'],
#  'down': ['memory', 'to'],
#  'memory': ['lane.'],
#  'lane.': ['Rawr.'],
#  'Rawr.': ['[purrs'],
#  '[purrs': ['playfully]'],
#  'playfully]': ['[Weems]', 'Here.'],
#  '[Weems]': ['All'],
#  'right.': ['Let’s', '[foreboding', 'Tape', '[Santiago]'],
#  'hand,': ['shall'],
#  'shall': ['we?'],
#  'we?': ['Hmm?'],
#  'Hmm?': ['Unfortunately,'],
#  'Unfortunately,': ['Wednesday’s', 'someone'],
#  'assimilation': ['has'],
#  'rocky': ['at'],
#  'Because': ['I', 'I', 'back', 'I’m', 'we', 'Rowan'],
#  'refuse': ['to', 'to', 'to'],
#  'embrace': ['the'],
#  'culture': ['of'],
#  'dishonesty': ['and'],
#  'denial': ['permeating'],
#  'permeating': ['this'],
#  'Starting': ['with'],
#  'Rowan': ['and', 'getting', 'appeared', 'was', 'in'],
#  'put': ['Eugene', 'away'],
#  'ICU.': ['Although'],
#  'Although': ['I'],
#  'hear': ['he’s'],
#  'mend.': ['We’ve'],
#  'We’ve': ['always', 'been'],
#  'encouraged': ['Wednesday'],
#  'speak': ['her'],
#  'mind.': ['Sometimes', 'A', 'His'],
#  'Sometimes': ['her', 'when'],
#  'sharp': ['tongue'],
#  'tongue': ['can'],
#  'deep.': ['Apparently'],
#  'Apparently': ['her'],
#  'therapist': ['feels'],
#  'feels': ['she', 'like', 'when'],
#  'process.': ['Their'],
#  'Their': ['time'],
#  'time': ['together', 'my', 'nor', 'to', 'fitting', 'someone’s', 'I'],
#  'together': ['has'],
#  'yielded': ['the'],
#  'results': ['we’d', 'on', 'already?'],
#  'we’d': ['hoped.'],
#  'hoped.': ['I’m'],
#  'lab': ['rat.'],
#  'rat.': ['Dr.'],
#  'Dr.': ['Kinbott', 'Anwar'],
#  'Kinbott': ['and'],
#  'spoken,': ['and'],
#  'both': ['agree', 'know', 'under', 'have'],
#  'agree': ['it', 'to'],
#  'beneficial': ['for'],
#  'attend': ['a'],
#  'No.': ['I', 'This', 'Well,', '[thunderclaps]'],
#  'might': ['be'],
#  'reaction,': ['but'],
#  'wisdom': ['in'],
#  'Um,': ['not'],
#  'side': ['with'],
#  'Wednesday,': ['but,', 'stop.'],
#  'but,': ['um,'],
#  'um,': ['we’re'],
#  'we’re': ['only', 'not', 'ready.'],
#  'only': ['here',
#   'ever',
#   'son.',
#   'ever',
#   'when',
#   'one',
#   'reputation',
#   'blood',
#   'a',
#   'did'],
#  'here': ['for', 'to', 'is', 'for'],
#  'on.': ['What', 'We’ve', 'Let’s', 'Ask.'],
#  'What': ['can',
#   'were',
#   'do',
#   'case?',
#   'happened',
#   'are',
#   'are',
#   'happened?',
#   'did',
#   'I',
#   'do',
#   'on'],
#  'hurt?': ['To'],
#  'To': ['be'],
#  'honest,': ['I’ve'],
#  'big': ['fan'],
#  'fan': ['of'],
#  'head-shrinking.': ['It’s'],
#  'kind': ['of'],
#  'head-shrinking,': ['mon'],
#  'mon': ['chéri.'],
#  'chéri.': ['Well,'],
#  'disappointing.': ['But'],
#  'anything': ['for', 'less.', 'at'],
#  'girl.': ['Ah.'],
#  'Ah.': ['[quirkily'],
#  'search': ['that'],
#  'cave': ['for'],
#  'sign': ['of', 'of'],
#  'creature.': ['No'],
#  'No': ['stone', 'one', 'match.', 'doubt'],
#  'stone': ['unturned.'],
#  'unturned.': ['They'],
#  'bag': ['and'],
#  'tag': ['everything,'],
#  'everything,': ['all'],
#  'right?': ['And', 'I'],
#  'then': ['follow', 'there’s', 'I’m'],
#  'follow': ['up'],
#  'lab.': ['I'],
#  'want': ['the', 'any', 'to', 'to', 'you', 'is', 'to', 'to', 'to', 'to', 'to'],
#  'DNA': ['results', 'evidence.', 'results.', 'on'],
#  'claw.': ['We'],
#  'We': ['already',
#   'are',
#   'all',
#   'got',
#   'need',
#   'must',
#   'tried.',
#   'need',
#   'used'],
#  'already': ['got', 'got', 'knew', 'knows'],
#  'kid': ['in'],
#  'ICU,': ['a'],
#  'bunch': ['of'],
#  'people': ['in', 'take', 'are'],
#  'morgue.': ['I', 'Guys'],
#  '[foreboding': ['music', 'music'],
#  'Son': ['of'],
#  'bitch.': ['What’s'],
#  'What’s': ['wrong?', 'going', 'happening,'],
#  'wrong?': ['Just'],
#  'Just': ['hard'],
#  'hard': ['to', 'not', 'time.'],
#  'stomach': ['a'],
#  'murderer': ['wandering'],
#  'wandering': ['around'],
#  'around': ['town', 'you.', 'to'],
#  'town': ['scot-free.'],
#  'scot-free.': ['At'],
#  'least': ['they', 'we’ll', 'we'],
#  'care': ['enough'],
#  'go': ['to', 'to', 'without', 'on.'],
#  'Tyler,': ['come'],
#  'through': ['this.', 'you.', 'someone’s', 'video', 'a', 'the'],
#  'just…': ['I’m'],
#  'comfortable': ['dredging'],
#  'dredging': ['up'],
#  'some': ['complete', 'single', 'honey.', 'coincidence?'],
#  'complete': ['stranger.'],
#  'stranger.': ['Think'],
#  'easy': ['for'],
#  'sit': ['there'],
#  'there': ['and', 'won’t', 'that', 'had'],
#  'talk': ['about', 'about', 'about'],
#  'crap?': ['[phone'],
#  '[phone': ['ringing]'],
#  'ringing]': ['I’ve'],
#  'lot': ['on'],
#  'plate': ['now,'],
#  'now,': ['bud.'],
#  'bud.': ['You'],
#  'already?': ['All'],
#  'Tape': ['off'],
#  'off': ['the', 'my', 'on', 'of'],
#  'scene.': ['I’ll'],
#  'I’ll': ['be', 'just', 'be', 'never', 'never', 'come'],
#  'going': ['on?', 'through', 'to', 'to', 'to', 'to'],
#  'on?': ['[sighs]'],
#  '[sighs]': ['You', 'What'],
#  'Reggie,': ['the'],
#  'local': ['coroner?'],
#  'coroner?': ['He'],
#  'He': ['just',
#   'wants',
#   'didn’t',
#   'was',
#   'was',
#   'was',
#   'seemed',
#   'mistook',
#   'had',
#   'won’t',
#   'was',
#   'died',
#   'wasn’t',
#   'was',
#   'claimed',
#   'has'],
#  'just': ['blew',
#   'have',
#   'scamming',
#   'saw',
#   'have',
#   'want',
#   'ordinary',
#   'trying',
#   'that.'],
#  'blew': ['his'],
#  'brains': ['out.'],
#  '[ticking]': ['So,'],
#  'wants': ['to', 'you'],
#  'start?': ['Maybe'],
#  'discuss': ['what'],
#  'having': ['Wednesday', 'Wednesday'],
#  'away': ['from', 'his', 'again?'],
#  'from': ['home?',
#   'Mother.',
#   'harm',
#   'Mexico.',
#   'our',
#   'Garrett.',
#   'nightshade',
#   'his',
#   'the',
#   'the',
#   'our',
#   'beyond',
#   'controversy',
#   'harm.'],
#  'home?': ['I'],
#  'mean,': ['for'],
#  'me…': ['[hesitating]…it’s'],
#  '[hesitating]…it’s': ['been'],
#  'around.': ['I'],
#  'I’d': ['miss', 'be', 'done.'],
#  'being': ['waterboarded',
#   'objective,',
#   'honest',
#   'held',
#   'served.',
#   'separated'],
#  'waterboarded': ['so'],
#  'much.': ['Morticia,', 'Querida.'],
#  'Morticia,': ['Gomez.'],
#  'coping?': ['It’s'],
#  'torture': ['for'],
#  'too.': ['[Gomez]'],
#  'Fortunately,': ['my'],
#  'brother': ['Fester’s'],
#  'Fester’s': ['rack'],
#  'rack': ['fits'],
#  'fits': ['two'],
#  'two': ['people.', 'get'],
#  'people.': ['[Morticia]'],
#  'Nothing': ['like'],
#  'stretch': ['to'],
#  'bring': ['out'],
#  'out': ['the',
#   'your',
#   'how',
#   'yet?',
#   'to',
#   'of',
#   'of',
#   'and',
#   'who',
#   'the',
#   'from',
#   'of',
#   'how'],
#  'each': ['other.', 'other'],
#  'other.': ['Querida'],
#  'Querida': ['mía.'],
#  'mía.': ['[kissing'],
#  '[kissing': ['passionately]'],
#  'passionately]': ['Um…', 'Not'],
#  'Um…': ['[long,'],
#  '[long,': ['protracted'],
#  'protracted': ['smooch]'],
#  'smooch]': ['Enough!'],
#  'Enough!': ['I'],
#  'high': ['time'],
#  'faced': ['the'],
#  'music.': ['It'],
#  'It': ['seems',
#   'all',
#   'was',
#   'worked',
#   'doesn’t',
#   'was',
#   'was',
#   'was',
#   'was'],
#  'seems': ['they’ve'],
#  'they’ve': ['been'],
#  'lying': ['to'],
#  'me.': ['Keeping',
#   'You',
#   'You',
#   'A',
#   'Garrett,',
#   'But',
#   'He',
#   'I',
#   'But',
#   'I',
#   '[curious'],
#  'Keeping': ['secrets.'],
#  'secrets.': ['Murderous', 'I'],
#  'Murderous': ['secrets'],
#  'secrets': ['that'],
#  'need': ['to', 'to', 'to', 'to', 'to', 'to', 'me'],
#  'addressed.': ['[dramatic'],
#  '[dramatic': ['music', 'music', 'music', 'music'],
#  'Who': ['was', 'sees'],
#  'Gates,': ['and', 'did'],
#  'why': ['are', 'try?', 'you’ve'],
#  'you\xa0accused': ['of'],
#  'murdering': ['him?'],
#  'Whoa.': ['Those'],
#  'Those': ['charges'],
#  'charges': ['were', 'dropped.'],
#  'dropped.': ['Your', 'My'],
#  'father': ['is',
#   'like',
#   'did',
#   'is',
#   'did',
#   'drank',
#   'doesn’t',
#   'fighting',
#   'was',
#   'took',
#   'had',
#   'will',
#   'already'],
#  'innocent': ['man.', 'woman.'],
#  'man.': ['Local'],
#  'Local': ['sheriff'],
#  'sheriff': ['doesn’t', 'in'],
#  'doesn’t': ['seem', 'revolve', 'just', 'suit'],
#  'seem': ['too'],
#  'too': ['convinced.', 'far,', 'much'],
#  'convinced.': ['Wednesday,'],
#  'stop.': ['This'],
#  'This': ['is', 'does', 'session', 'wasn’t', 'may', 'is', 'reminds'],
#  'neither': ['the'],
#  'nor': ['the'],
#  'place.': ['Actually,', 'These'],
#  'Actually,': ['this', 'that’s', 'I'],
#  'exactly': ['the', 'what'],
#  'sessions': ['are…'],
#  'are…': ['Doctor.'],
#  'Doctor.': ['This'],
#  'does': ['not'],
#  'concern': ['you.'],
#  'debate': ['a'],
#  'decades-old': ['witch-hunt', 'murder'],
#  'witch-hunt': ['with'],
#  'now.': ['I…', 'Go'],
#  'I…': ['Darling,'],
#  'Darling,': ['maybe'],
#  'should…': ['No.'],
#  'over.': ['Have', 'How'],
#  'way,': ['Mother.'],
#  'Mother.': ['Wednes…', 'The', 'Did', 'Hello,', 'But', '[wry'],
#  'Wednes…': ['Wednesday?'],
#  'Wednesday?': ['If'],
#  'If': ['you', 'you', 'I’m', 'there', 'I', 'I’m', 'you'],
#  'truth,': ['I’ll'],
#  'excavate': ['it'],
#  'myself.': ['You…', '[lachrymose'],
#  'You…': ['Thanks'],
#  'Thanks': ['for', 'for'],
#  'candy.': ['Actually,'],
#  'potpourri.': ['Why'],
#  'Why': ['don’t', 'did', 'didn’t', 'would', 'did', 'would'],
#  'bowl?': ['[cuckoo'],
#  '[cuckoo': ['clock'],
#  'clock': ['chirps]'],
#  'chirps]': ['What'],
#  'thinking?': ['How'],
#  'ambush': ['your'],
#  'that?': ['Wednesday.', 'Someone', 'Because'],
#  'Wednesday.': ['How',
#   'Eugene’s',
#   '[Wednesday]',
#   'It’s',
#   'So',
#   'Everything',
#   'So',
#   'Did',
#   'Always.',
#   'But',
#   'Goody'],
#  'I?': ['You'],
#  'insisted': ['I'],
#  'Did': ['you', 'you', 'you', 'you'],
#  'wouldn’t': ['find', 'tolerate', 'matter'],
#  'secret?': ['You'],
#  'story.': ['Your'],
#  'nothing': ['wrong.'],
#  'wrong.': ['I’ll'],
#  'judge': ['of'],
#  'Potpourri?': ['[car'],
#  '[car': ['door'],
#  'door': ['closes]'],
#  'closes]': ['Mmm!'],
#  'Mmm!': ['How'],
#  'me?': ['MorningSong', '[gasps]', 'Morticia?', 'Who', 'When'],
#  'MorningSong': ['community', 'bracelets', 'are'],
#  'community': ['misses'],
#  'misses': ['you.'],
#  'community,': ['you'],
#  'mean': ['cult?', 'to', 'you.'],
#  'cult?': ['We'],
#  'development': ['movement'],
#  'movement': ['that'],
#  'helps': ['people'],
#  'control': ['of', 'of', 'it.'],
#  'their': ['lives.', 'bank', 'daughter'],
#  'lives.': ['After'],
#  'After': ['you', 'he’s'],
#  'bank': ['accounts.'],
#  'accounts.': ['I'],
#  'fight,': ['Brandy'],
#  'Brandy': ['Jane.'],
#  'Jane.': ['My'],
#  'name': ['is', 'to'],
#  'Bianca.': ['New', '[laughs'],
#  'New': ['name.', 'life.'],
#  'name.': ['New', 'Colt'],
#  'life.': ['It’s', 'It'],
#  'home.': ['That', 'Gideon'],
#  'Gideon': ['said'],
#  'said': ['you’d', 'he', 'she', 'Garrett'],
#  'you’d': ['resist.'],
#  'resist.': ['Don’t'],
#  'Don’t': ['say', 'you', 'you', 'crowd', 'push'],
#  'say': ['that', 'your', 'can', 'you’ve', 'Parents’'],
#  'man’s': ['name'],
#  'he’d': ['give'],
#  'damn': ['about', 'family’s.'],
#  'single': ['mom'],
#  'daughter': ['if', 'a', 'and'],
#  'if': ['we', 'I', 'none', 'the', 'anyone', 'you', 'you'],
#  'weren’t': ['sirens?'],
#  'sirens?': ['[chuckles]'],
#  '[chuckles]': ['That'],
#  'stepfather.': ['You'],
#  'actually': ['married'],
#  'married': ['him.'],
#  'home,': ['so'],
#  'real': ['family.', 'friend.'],
#  'family.': ['Hard'],
#  'Hard': ['pass.'],
#  'pass.': ['He’s'],
#  'He’s': ['already', 'gonna', 'innocent.'],
#  'siren': ['to', 'song', 'can'],
#  'bidding.': ['Goodbye,'],
#  'Goodbye,': ['Ma.'],
#  'Ma.': ['I'],
#  'bracelets': ['anywhere'],
#  'anywhere': ['near'],
#  'near': ['this'],
#  'town.': ['My', 'All'],
#  'song': ['is'],
#  'drying': ['up.'],
#  'up.': ['[distressing', '[inhales,'],
#  '[distressing': ['music'],
#  'Recruitment': ['numbers'],
#  'numbers': ['are'],
#  'down,': ['and'],
#  'wrong': ['people', 'foot'],
#  'starting': ['to'],
#  'ask': ['questions.', 'what'],
#  'questions.': ['This'],
#  'wasn’t': ['a', 'a', 'rage', 'just', 'killed', 'a'],
#  'request.': ['And'],
#  'refuse?': ['Then'],
#  'Then': ['everybody'],
#  'everybody': ['here'],
#  'gonna': ['know', 'be', 'miss', 'be'],
#  'siren’d': ['your'],
#  'something': ['of', 'more'],
#  'myself': ['and', 'in'],
#  'destroy': ['it.'],
#  'squat,': ['Bianca.'],
#  '[laughs': ['maliciously]'],
#  'maliciously]': ['You’re'],
#  'scamming': ['a'],
#  'higher': ['class'],
#  'class': ['of'],
#  'people,': ['but'],
#  'friends.': ['Sooner'],
#  'Sooner': ['or'],
#  'later': ['they'],
#  'will': ['see', 'be', 'be', 'be', 'be'],
#  'change': ['her'],
#  'scales.': ['You'],
#  'until': ['the', 'that', 'the'],
#  'end': ['of'],
#  'goodbyes.': ['[music'],
#  'builds,': ['fades', 'trails'],
#  '[Wednesday': ['sighs]'],
#  'harvested': ['hive'],
#  'hive': ['number'],
#  'number': ['three.'],
#  'three.': ['[monitor'],
#  '[monitor': ['beeps]'],
#  'beeps]': ['The'],
#  'bees': ['miss', 'like'],
#  'Eugene.': ['[labored', 'How'],
#  '[labored': ['breathing]'],
#  'breathing]': ['We'],
#  'do.': ['[melancholy', 'The'],
#  '[melancholy': ['music'],
#  '[Thing': ['tapping]', 'sliding'],
#  'tapping]': ['Thanks'],
#  'keeping': ['an'],
#  'eye': ['on'],
#  'Any': ['updates?'],
#  'updates?': ['He'],
#  'deserve': ['this.'],
#  'bed.': ['Why'],
#  'without': ['me?', 'the', 'the', 'casting'],
#  '[gasps]': ['Didn’t', 'You'],
#  'Didn’t': ['mean'],
#  'startle': ['you,'],
#  'dear.': ['You'],
#  'must': ['be', 'stay', 'be'],
#  'Eugene’s': ['moms.'],
#  'moms.': ['Sue'],
#  'Sue': ['and'],
#  'Janet.': ['You'],
#  'lately.': ['He', 'Navigating'],
#  'joined': ['the'],
#  'Hummers.': ['Eugene'],
#  'easiest': ['time'],
#  'fitting': ['in'],
#  '[Sue]': ['He', 'He’s'],
#  'excited': ['to', 'all'],
#  'brought': ['him', 'you'],
#  'honey.': ['Eugene'],
#  'loves': ['those'],
#  'dang': ['bees'],
#  'they’re': ['his', 'a'],
#  'kids.': ['His'],
#  'His': ['fuzzy-buzzy',
#   'infatuation',
#   'twisted',
#   'eyes',
#   'mother',
#   'father',
#   'eyes',
#   'telekinetic',
#   'tragic'],
#  'fuzzy-buzzy': ['babies.'],
#  'babies.': ['[Sue]'],
#  'okay,': ['right?', 'darling.'],
#  ...}

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ep_5_dict)
# Out:
# 'Stop! Leave him alone! I’ll just trying to distract her. [music swells] I don’t. Because.'

# %%
import random
from collections import defaultdict

def generate_sentence(chain, count=15):
    if not chain:
        return "Cannot generate a sentence from an empty dictionary"

    # Use defaultdict to handle missing keys gracefully
    chain = defaultdict(list, chain)

    # Choose the first word randomly
    word1 = random.choice(list(chain.keys()))

    # Capitalize the first word
    sentence = word1.capitalize()

    # Generate subsequent words until the sentence has the desired length
    for i in range(count-1):
        # Choose the next word randomly based on its frequency in the chain
        word2 = random.choices(chain[word1], weights=[chain[word1].count(w) for w in chain[word1]])[0]

        # Add the word to the sentence
        sentence += ' ' + word2

        # Update the current word
        word1 = word2

        # End the sentence with appropriate punctuation
        if i == count-2:
            sentence += random.choice(['.', '!', '?'])

    return sentence

# %%
episodes=[]
for i in range(8):
    episodes.append(f"episode {i+1}")

# %%
sen={}

# %%
for episode in episodes:
    ep_text = data.transcript.loc[episode]
    ep_text[:200]
    ep_dict = markov_chain(ep_text)
    sentence=generate_sentence(ep_5_dict)
    sen[episode]=sentence

# %%
sen
# Out:
# {'episode 1': 'Drunken stupor. It was so excited to start? Maybe we have all the reason he’s?',
#  'episode 2': 'Turned into the little death by a murderer wandering around town scot-free. At present time,?',
#  'episode 3': 'Bed. Why did not your fishing gear. Stop trying to be in the hospital. That?',
#  'episode 4': 'Date: November\xa023,\xa02022 32 years ago? [screams] [music builds ominously, fades away] [Wednesday sighs] I made?',
#  'episode 5': 'Guilt for the punch and he had broken into the results we’d hoped. I’m sorry?',
#  'episode 6': '[intense, sweeping music playing] Ah, Nevermore. [Sue] He’s already got a distraction. No, this in?',
#  'episode 7': 'Suit you. And hope that I thought they are you have a stab wound. [Walker?',
#  'episode 8': 'Had been living with the truth about my son have to be right way he.'}

# %%
import pandas as pd

# %%
sentences=[sen[episode] for episode in episodes]
sentences
# Out:
# ['Drunken stupor. It was so excited to start? Maybe we have all the reason he’s?',
#  'Turned into the little death by a murderer wandering around town scot-free. At present time,?',
#  'Bed. Why did not your fishing gear. Stop trying to be in the hospital. That?',
#  'Date: November\xa023,\xa02022 32 years ago? [screams] [music builds ominously, fades away] [Wednesday sighs] I made?',
#  'Guilt for the punch and he had broken into the results we’d hoped. I’m sorry?',
#  '[intense, sweeping music playing] Ah, Nevermore. [Sue] He’s already got a distraction. No, this in?',
#  'Suit you. And hope that I thought they are you have a stab wound. [Walker?',
#  'Had been living with the truth about my son have to be right way he.']

# %%
dic={'episode':episodes,'sentences':sentences}

# %%
pd.set_option('display.max_colwidth', None)
df = pd.DataFrame(dic)
# Set 'Name' column as the index
df = df.set_index('episode')

# %%
print(df)
# Out:
#                                                                                                                 sentences
# episode
# episode 1                                  Drunken stupor. It was so excited to start? Maybe we have all the reason he’s?
# episode 2                   Turned into the little death by a murderer wandering around town scot-free. At present time,?
# episode 3                                    Bed. Why did not your fishing gear. Stop trying to be in the hospital. That?
# episode 4  Date: November 23, 2022 32 years ago? [screams] [music builds ominously, fades away] [Wednesday sighs] I made?
# episode 5                                   Guilt for the punch and he had broken into the results we’d hoped. I’m sorry?
# episode 6             [intense, sweeping music playing] Ah, Nevermore. [Sue] He’s already got a distraction. No, this in?
# episode 7                                      Suit you. And hope that I thought they are you have a stab wound. [Walker?
# episode 8                                            Had been living with the truth about my son have to be right way he.
