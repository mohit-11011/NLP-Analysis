# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                               transcript        full_name
# brad   ♪ bluesy rock music ♪ ♪ energetic pop rock mus...    brad williams
# brian  Filmed in 2020 at the Tuacahn outdoor amphithe...      brian regan
# david  This is the full transcript of David Cross’ la...      david cross
# doug   Recorded live at Dante’s in Portland, Oregon W...    doug stanhope
# jerry  Jerry Seinfeld’s new hourlong comedy special, ...   jerry seinfeld
# jim    Australian comedian Jim Jefferies breaks down ...    jim jefferies
# kenny  Make some noise for Kenny Sebastian. Oh my God...  kenny sebastian
# kevin  Streaming on Netflix from November 17, 2020   ...       kevin hart
# nikki  A NETFLIX ORIGINAL COMEDY SPECIAL Thank you! T...     nikki glaser
# ray    It’s been 23 years since I did a comedy specia...       ray romano
# ricky  [audience cheering and applauding] [announcer]...    ricky gervais
# ron    [Ron White] You ever take a crap so big your p...        ron white

# %%
# Extract only Brad Williams's text
brad_text = data.transcript.loc['brad']
brad_text[:200]
# Out:
# '♪ bluesy rock music ♪ ♪ energetic pop rock music ♪ – Southern California, are you ready to have a good time tonight? (audience cheering) Get excited, make it loud, for Brad Williams! ♪ hard rock music'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
brad_dict = markov_chain(brad_text)
brad_dict
# Out:
# {'♪': ['bluesy',
#   '♪',
#   'energetic',
#   '–',
#   'hard',
#   '(audience',
#   'Climb',
#   'It’s',
#   'My',
#   'My',
#   'That’s',
#   'And',
#   '♪',
#   'The',
#   'I',
#   'Sunshine',
#   'No,',
#   'bluesy',
#   'And',
#   'bluesy',
#   '–',
#   'bluesy',
#   '–',
#   'upbeat'],
#  'bluesy': ['rock', 'rock', 'rock', 'rock'],
#  'rock': ['music', 'music', 'music', 'music', 'music', 'music'],
#  'music': ['♪', '♪', '♪', '♪', '♪', '♪', '♪'],
#  'energetic': ['pop'],
#  'pop': ['rock'],
#  '–': ['Southern',
#   'What’s',
#   '[Voiceover]',
#   'Alright,',
#   'I',
#   'I',
#   'Okay,',
#   'Alright,',
#   'Size',
#   'Yeah,',
#   '(chuckles)',
#   'Yeah,',
#   'Okay,',
#   'Okay',
#   'This',
#   '(clears',
#   'Okay,',
#   'Hey,',
#   'Yes,',
#   'Oh,',
#   'Yes,',
#   'Awesome,',
#   'See?',
#   'Alright,',
#   'That',
#   'Adorable.',
#   'I'],
#  'Southern': ['California,',
#   'California',
#   'California',
#   'California',
#   'California'],
#  'California,': ['are', 'I'],
#  'are': ['you',
#   'just',
#   'you',
#   'feeling',
#   'you',
#   'just',
#   'aware',
#   'in',
#   'laughing,',
#   'like,',
#   'walking',
#   'using',
#   'scared',
#   'busy?',
#   'you',
#   'one',
#   'dwarfs.”',
#   'little',
#   'you',
#   'going',
#   'gonna',
#   'the',
#   'now',
#   'taught,',
#   'a',
#   'sayin’',
#   'laughing',
#   'like,',
#   'like,',
#   'permanent.”',
#   'not',
#   'you',
#   'not',
#   'you',
#   'always',
#   'thrilled',
#   'going',
#   'some',
#   'some',
#   'laughing.',
#   'some',
#   'jokes',
#   'going',
#   'you',
#   'looking',
#   'like,',
#   'like,',
#   'alive',
#   'not',
#   'your',
#   'you',
#   'like,',
#   'you',
#   'like,'],
#  'you': ['ready',
#   'guys',
#   'guys',
#   'get',
#   'do,',
#   'didn’t',
#   'have',
#   'don’t',
#   'doing?',
#   'are',
#   'proud',
#   'can’t',
#   'have',
#   'knock',
#   'drag',
#   'owe',
#   'guys.',
#   'guys',
#   'trip,',
#   'fall,',
#   'look',
#   'can',
#   'are',
#   'think',
#   '“just',
#   'tall',
#   'are',
#   'gotta',
#   'exactly',
#   'look',
#   'gotta',
#   'gotta',
#   'just',
#   'guys',
#   'didn’t,',
#   'don’t',
#   'did',
#   'something',
#   'guys',
#   'hold',
#   'do',
#   'talk',
#   'joke',
#   'have',
#   'learn.',
#   'gain',
#   'learn',
#   'love',
#   'like,',
#   'need',
#   'one',
#   'could',
#   'are',
#   'should',
#   'think',
#   'go',
#   'kidding',
#   'gotta',
#   'who',
#   'are',
#   'know',
#   'get',
#   'off',
#   'were',
#   'said',
#   'have',
#   'care?”',
#   'care?',
#   'guys',
#   'to',
#   'realize',
#   'know,',
#   'don’t',
#   'whatsoever.',
#   'whatsoever.\nWhy',
#   'people',
#   'are',
#   'are',
#   'see',
#   'can',
#   'got',
#   'say',
#   'say',
#   'think',
#   'don’t',
#   'starve.',
#   'are',
#   'know',
#   'order',
#   'can',
#   'want',
#   'be',
#   'are',
#   'pose',
#   'know',
#   'pose',
#   'mean',
#   'mean,',
#   'live',
#   'wanna',
#   'become',
#   'become',
#   'can',
#   'have',
#   'say',
#   'as',
#   'can',
#   'like',
#   'a',
#   'say.',
#   'can',
#   'do',
#   'should',
#   'can’t.',
#   'can’t.',
#   'just',
#   'going',
#   'have',
#   'imagine',
#   'look',
#   'saw',
#   'though,',
#   'have',
#   'still',
#   'if',
#   'watch',
#   'watch',
#   'guys',
#   'can',
#   'can’t',
#   'want',
#   'if',
#   'do',
#   'what',
#   'kidding',
#   'ladies,',
#   'to',
#   'fake',
#   'have',
#   'for',
#   'see',
#   'don’t',
#   'don’t',
#   'have',
#   'have',
#   'just',
#   'what',
#   'do.',
#   'do.',
#   'got',
#   'miss',
#   'go.',
#   'got',
#   'do',
#   'better.',
#   'don’t',
#   'do?',
#   'do?”',
#   'what',
#   'think',
#   'women',
#   'get',
#   'women',
#   'guys!”',
#   'are',
#   'in',
#   'and',
#   'feel',
#   'are',
#   'to.',
#   'guys',
#   'think',
#   'think',
#   'know',
#   'know',
#   'see',
#   'see',
#   'know',
#   'and',
#   'want',
#   'should',
#   'should',
#   'want',
#   'hear',
#   'men',
#   'didn’t',
#   'said,',
#   'say',
#   'could',
#   'like,',
#   'say',
#   'look',
#   'want,”',
#   'mad',
#   'to',
#   'know',
#   'realize',
#   'doggy',
#   'have',
#   'women',
#   'can',
#   'thought',
#   'act',
#   'just',
#   'got',
#   'put',
#   'gay,',
#   'gay!”',
#   'really',
#   'gay?',
#   'gay?',
#   'have',
#   'do',
#   'do?',
#   'do?',
#   'react',
#   'knew',
#   'do',
#   'gonna',
#   'get',
#   'made',
#   'have',
#   'know',
#   'talking',
#   'wanna',
#   'know,',
#   'want',
#   'put',
#   'do!',
#   'start',
#   'finish',
#   'better',
#   'start,',
#   'start',
#   'finish',
#   'know',
#   'never',
#   'can’t',
#   'get',
#   'are',
#   'leave',
#   'a',
#   'have',
#   'get',
#   'think',
#   'want',
#   'want',
#   'want',
#   'want',
#   'don’t',
#   'have',
#   'have',
#   'for',
#   'for',
#   'for',
#   'could',
#   'guys',
#   'to',
#   'guys.',
#   'just',
#   'needed',
#   'mean?',
#   'size',
#   'serious?',
#   'just',
#   'would',
#   'needed',
#   'measure'],
#  'ready': ['to', 'to', 'to', 'for', 'to'],
#  'to': ['have',
#   'that,',
#   'party?',
#   'have',
#   'party.',
#   'drink.',
#   'drink',
#   'pay',
#   'know',
#   'know',
#   'my',
#   'him',
#   'him,',
#   'my',
#   'burst',
#   'him.',
#   'make',
#   'heaven',
#   'him',
#   'this',
#   'be',
#   'as.',
#   'be',
#   'a',
#   'the',
#   'acknowledge',
#   'say.',
#   'come',
#   'Southern',
#   'do',
#   'one',
#   'my',
#   'me',
#   'go',
#   'the',
#   'go',
#   'the',
#   'the',
#   'a',
#   'this',
#   'use',
#   'use',
#   'the',
#   'a',
#   'get',
#   'a',
#   'a',
#   'do',
#   'do',
#   'kill',
#   'laugh',
#   'tell',
#   'tell',
#   'apologize',
#   'the',
#   'be',
#   'talk',
#   'me.',
#   'fix',
#   'be',
#   'help',
#   'help',
#   'do',
#   'fix',
#   'do.',
#   'make',
#   'make',
#   'prepare',
#   'bring',
#   'other',
#   'do',
#   'that',
#   'know',
#   'me',
#   'arms',
#   'all',
#   'rise',
#   'you.',
#   'tell',
#   'Katy',
#   'know',
#   'motorboat',
#   'do',
#   'their',
#   'hurt,',
#   'say',
#   'say,',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'appear',
#   'my',
#   'pass',
#   'be.”',
#   'change,',
#   'your',
#   'your',
#   'say',
#   'treat',
#   'treat',
#   'do',
#   'be',
#   'be',
#   'be',
#   'being',
#   'be',
#   'be',
#   'be',
#   'be',
#   'do?”',
#   'do',
#   'see',
#   'me?',
#   'happen',
#   'my',
#   'go',
#   'go',
#   'the',
#   'assess',
#   'me.',
#   'do',
#   'grocery',
#   'your',
#   'see',
#   'see',
#   'see',
#   'theirs.',
#   'me.\nNo,',
#   'do,',
#   'watch',
#   'see',
#   'a',
#   'watch.',
#   'watch',
#   'judge',
#   'watch',
#   'find',
#   'watch',
#   'hear,',
#   'be',
#   'just',
#   'understand',
#   'say.',
#   'react.',
#   'the',
#   'say',
#   'be',
#   'be',
#   'win',
#   'see',
#   'do',
#   'quote',
#   'do',
#   'do.',
#   'do',
#   'show',
#   'do.',
#   'do,',
#   'do.',
#   'do',
#   'you.',
#   'say',
#   'fuck',
#   'it',
#   'go',
#   'have',
#   'that.',
#   'do',
#   'end,',
#   'you.',
#   'come?”',
#   'this',
#   'come',
#   'turn',
#   'do',
#   'know',
#   'do',
#   'put',
#   'preschool,',
#   'do',
#   'you,',
#   'me',
#   'feel',
#   'feel',
#   'feel',
#   'be',
#   'be',
#   'be',
#   'understand',
#   'say,',
#   'give',
#   'a',
#   'be',
#   'be',
#   'school?',
#   'do.',
#   'come',
#   'you.',
#   'make',
#   'make',
#   'you.',
#   'make',
#   'do.”',
#   'kindergarten,',
#   'me,',
#   'the',
#   'say',
#   'learn',
#   'go',
#   'be',
#   'start',
#   'him',
#   'be',
#   'discipline',
#   'discipline',
#   'hit',
#   'the',
#   'school.',
#   'you,',
#   'conquer',
#   'ask',
#   'be?',
#   'be',
#   'be?',
#   'be',
#   'that',
#   'know',
#   'do.',
#   'protect',
#   'some',
#   'do',
#   'let',
#   'be',
#   'protect',
#   'the',
#   'deal',
#   'have',
#   'get',
#   'regroup.',
#   'regroup.',
#   'go',
#   'watch',
#   'almost',
#   'never',
#   'know',
#   'quit.',
#   'be',
#   'one',
#   'be',
#   'have',
#   'UCI',
#   'go',
#   'go',
#   'go',
#   'the',
#   'determine',
#   'that.'],
#  'have': ['a',
#   'a',
#   'to',
#   'that',
#   'tall',
#   'never',
#   'everyone',
#   'to',
#   'amazing',
#   'a',
#   'a',
#   'been',
#   'to',
#   'to',
#   'ADD,',
#   'discussion,',
#   'asked',
#   'tried',
#   'turned',
#   'turned',
#   'other',
#   'children',
#   'got',
#   'looked',
#   'thrown',
#   'the',
#   'a',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'seen',
#   'not',
#   'sex',
#   'sex',
#   'to',
#   'more',
#   'to',
#   'to',
#   'to',
#   'to',
#   'never',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'one,',
#   'fun',
#   'fun',
#   'very',
#   'one',
#   'sex',
#   'small',
#   'sex',
#   'great',
#   'my',
#   'a',
#   'to',
#   'dwarf',
#   'to',
#   'no',
#   'the',
#   'to',
#   'to',
#   'to',
#   'part',
#   'son.',
#   'that'],
#  'a': ['good',
#   'lot',
#   'dwarf',
#   'midget',
#   'hot',
#   'dude.',
#   'game',
#   'math',
#   'Special',
#   'great',
#   'midget',
#   'dwarf',
#   'joygasm.',
#   'Wish',
#   'kid',
#   'kid',
#   'wheelchair.',
#   'wheelchair?',
#   'performance',
#   'enhh',
#   'enhh',
#   'marshmallow',
#   'six',
#   'four',
#   'chest',
#   'dick',
#   'dick',
#   'fart',
#   'fart',
#   'my',
#   'my',
#   'God',
#   'blizzard',
#   'foot',
#   'half',
#   'foot',
#   'half',
#   'foot',
#   'half',
#   'foot',
#   'half',
#   'foot',
#   'half',
#   'big',
#   'foot',
#   'half',
#   'foot',
#   'half',
#   'loser.”',
#   'shit,',
#   'lot,',
#   'long',
#   'little',
#   'lot',
#   'public',
#   'urinal?”',
#   'urinal.',
#   'two',
#   'cornucopia',
#   'plethora',
#   'dwarf',
#   'guy.',
#   'dwarf',
#   'spell',
#   'regular',
#   'regular',
#   'bathroom',
#   'fun',
#   'lot.',
#   'year.',
#   'bit.',
#   'job',
#   'DJ',
#   'morning',
#   'morning',
#   'dude',
#   'bunch',
#   'couple',
#   'meeting.',
#   'Dodger',
#   'professional.',
#   'fucking',
#   'jersey',
#   'jersey',
#   'good',
#   'black',
#   'press',
#   'black',
#   'black',
#   'black',
#   'humorous',
#   'greater',
#   'second,',
#   'commercial',
#   'Christmas',
#   'gnome',
#   'black',
#   'bag',
#   'bag',
#   'champion.',
#   'woman',
#   'show.',
#   'midget',
#   'couple',
#   'shot.”',
#   'shit',
#   'shit',
#   'shit',
#   'shit',
#   'great',
#   'chance',
#   'firework”.',
#   'little',
#   'little',
#   'chupacabra.”',
#   'chupacabra?”',
#   'shit.',
#   'wonderful',
#   'wonderful',
#   'doozy,',
#   'woman,',
#   'wonderful',
#   'pair',
#   'white',
#   'white',
#   'tell',
#   'pencil',
#   'white',
#   'black',
#   'black',
#   'black',
#   'mm-hmm',
#   'black',
#   'black',
#   'black',
#   'black',
#   'reverse',
#   'while',
#   'dick',
#   'dude',
#   'woman.',
#   'dude',
#   'woman,',
#   're-dick-otomy,',
#   'black',
#   'black',
#   'hamster.”',
#   'little',
#   'black',
#   'black',
#   'black',
#   'black',
#   'nigglet.',
#   'little',
#   'black',
#   '(squeals).”',
#   'lot',
#   'reason',
#   'comedian.',
#   'car',
#   'light',
#   'dwarf',
#   'great',
#   'light',
#   'retarded',
#   'car',
#   'car',
#   'moron,',
#   'sudden,',
#   'dwarf,',
#   'grocery',
#   'lottery',
#   'freak,',
#   'freak.',
#   'midget',
#   'midget',
#   'little',
#   'little',
#   'little',
#   'little',
#   'porno',
#   'midget',
#   'midget',
#   'girl',
#   'mirror,',
#   'dick',
#   'vagina,',
#   'little',
#   'little,',
#   'penis',
#   'damn',
#   'woman’s',
#   'lazy',
#   'little',
#   'shit.',
#   'lot',
#   'low',
#   'lot',
#   'little',
#   'sexual',
#   'van',
#   'basement,',
#   'little',
#   'while,',
#   'thousand',
#   'lot',
#   'pretty',
#   'finger',
#   'great',
#   'little',
#   'lot',
#   'lot',
#   'game',
#   'couple',
#   'finger',
#   'situation',
#   'man',
#   'woman,',
#   'very',
#   'lot',
#   'football',
#   'football.',
#   'little',
#   'fact,',
#   'very',
#   'trained',
#   '50/50',
#   'bitch.',
#   'big',
#   'helmet',
#   'three-foot',
#   'fight',
#   'fight,',
#   'goddamned',
#   'pussy.”',
#   'father',
#   'father',
#   'parent,',
#   'parent',
#   'creative',
#   'dwarf,',
#   'counter,',
#   'parachute,',
#   'while.',
#   'shelf.”',
#   'car.”',
#   'block',
#   'visionary.',
#   'lot',
#   'man,',
#   'little',
#   'world',
#   'bruise,',
#   'little',
#   'family,',
#   'bitch.',
#   'man',
#   'counter',
#   'part',
#   'comedian.',
#   'professional',
#   'comedian',
#   'professional',
#   'popular',
#   'dragon',
#   'glass',
#   'good',
#   'comedian.',
#   'cute'],
#  'good': ['time',
#   'stores',
#   'tester',
#   'about',
#   'about',
#   'at.”',
#   'at',
#   'chance',
#   'for',
#   'or',
#   'if',
#   'if',
#   'friend'],
#  'time': ['tonight?',
#   'backwards.',
#   'you',
#   'you’ll',
#   'when',
#   'I',
#   'to',
#   'he’s',
#   'your',
#   'you’re',
#   'that',
#   'your',
#   'you’re',
#   'I',
#   'out,',
#   'out,',
#   'at'],
#  'tonight?': ['(audience', 'Good!'],
#  '(audience': ['cheering)',
#   'cheering)',
#   'cheering)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'applauds)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)\nThen',
#   'laughing)',
#   'laughing)\nBut',
#   'laughing)',
#   'laughs)',
#   'laughs)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'laughing)',
#   'boos)',
#   'groans)',
#   'laughing)',
#   'applauds)',
#   'laughing)',
#   'applauds)',
#   'cheers',
#   'applauds)'],
#  'cheering)': ['Get', '–', 'What’s'],
#  'Get': ['excited,', 'it,'],
#  'excited,': ['make', 'so'],
#  'make': ['it',
#   'that',
#   'reference',
#   'a',
#   'a',
#   'any',
#   'fun',
#   'fun',
#   'fun',
#   'fun',
#   'things',
#   'everything',
#   'everything',
#   'everything',
#   'better.',
#   'boring',
#   'everything',
#   'better.',
#   'boring',
#   'porno',
#   'porn',
#   'you',
#   'everything',
#   'you',
#   'you',
#   'fun',
#   'fun',
#   'him',
#   'him'],
#  'it': ['loud,',
#   'was',
#   'was',
#   'was',
#   'was',
#   'like',
#   'here.',
#   'shitty',
#   'off,',
#   'off,',
#   'off.',
#   'is',
#   'for',
#   'in.',
#   'in',
#   'all',
#   'in.',
#   'in,',
#   'effects',
#   'up',
#   'off,',
#   'back',
#   'all',
#   'said,',
#   'up,',
#   'helps',
#   'helps',
#   'doesn’t',
#   '’cause',
#   'every',
#   'changes',
#   'in,',
#   'here.',
#   'right',
#   'starts',
#   'in',
#   'is.',
#   'was',
#   'out,',
#   'wrecked,',
#   'totaled?',
#   'was',
#   'should',
#   'was',
#   'should',
#   'kill',
#   'kill',
#   'is.',
#   'and',
#   'again,',
#   'in',
#   'comes',
#   'ladies.',
#   'together',
#   'in.',
#   'is',
#   'feels',
#   'feels',
#   'depends',
#   'feels',
#   'in',
#   'or',
#   'or',
#   'doesn’t',
#   'says',
#   'or',
#   'out,',
#   'up,',
#   'will,',
#   'because',
#   'is',
#   'is',
#   'up',
#   'counts.'],
#  'loud,': ['for'],
#  'for': ['Brad',
#   'it.',
#   '20',
#   'him.',
#   'him.',
#   'me!',
#   'me!',
#   'you',
#   'my',
#   'way',
#   'me,',
#   'your',
#   'any',
#   'a',
#   'what',
#   'help',
#   'a',
#   'help',
#   'a',
#   'a',
#   'an',
#   'the',
#   'the',
#   'the',
#   'a',
#   'her.',
#   'once',
#   'you',
#   'the',
#   'you,',
#   'you',
#   'my',
#   'me.”',
#   'you,',
#   'you',
#   'a',
#   'target',
#   'a',
#   'three',
#   'that.',
#   'a',
#   'the',
#   'them,',
#   'plastic',
#   'teaching',
#   'teaching',
#   'teaching',
#   'being',
#   'keeping',
#   'Brad',
#   'real?'],
#  'Brad': ['Williams!', 'to', 'Williams,', 'Williams!'],
#  'Williams!': ['♪', '♪'],
#  'hard': ['rock', 'enough,', 'it'],
#  'What’s': ['up!?', 'goin’'],
#  'up!?': ['(audience'],
#  'goin’': ['on'],
#  'on': ['everybody!?',
#   'won.',
#   'crutches.',
#   'the',
#   'stage',
#   'the',
#   'him',
#   'your',
#   'the',
#   'a',
#   'Google.',
#   'this',
#   'the',
#   'air',
#   'air',
#   'their',
#   'air',
#   'air',
#   'it,',
#   'behalf',
#   'behalf',
#   'three.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'me.',
#   'two',
#   'TV',
#   'that',
#   'my',
#   'her',
#   'her',
#   'the',
#   'the',
#   'the',
#   'tonight.”',
#   'you.',
#   'you.',
#   'me',
#   'them',
#   'them,',
#   'the',
#   'a',
#   'the',
#   'a',
#   'my',
#   'this',
#   'a',
#   'stage.',
#   'stage,',
#   'stage',
#   'a'],
#  'everybody!?': ['(laughing)'],
#  '(laughing)': ['There’s', 'He'],
#  'There’s': ['no', 'always', 'no', 'a'],
#  'no': ['way',
#   'big',
#   'exaggeration.',
#   'one',
#   'one',
#   'such',
#   'questions',
#   'man',
#   'man',
#   'dwarves',
#   'germs',
#   'idea',
#   'murder,',
#   'rape,',
#   'ISIS,',
#   'Justin',
#   'one.'],
#  'way': ['I', 'up', 'the', 'because'],
#  'I': ['can',
#   'like',
#   'like',
#   'don’t',
#   'party,',
#   'like',
#   'like',
#   'never',
#   'know',
#   'don’t',
#   'drink,',
#   'don’t',
#   'drink,',
#   'get',
#   'might',
#   'also',
#   'would',
#   'was',
#   'put',
#   'was',
#   'turned',
#   'said',
#   'would',
#   'was',
#   'turn',
#   'go,',
#   'should',
#   'should',
#   'say',
#   'have',
#   'say',
#   'was',
#   'was!',
#   'ran',
#   'was',
#   'mean?',
#   'like',
#   'knew,',
#   'knew',
#   'was',
#   'had',
#   'was',
#   'had',
#   'travel',
#   'was',
#   'am',
#   'trip',
#   'die.',
#   'was',
#   'went',
#   'bought',
#   'just',
#   'travel',
#   'was',
#   'had',
#   'couldn’t',
#   'landed,',
#   'really',
#   'run',
#   'don’t',
#   'do,',
#   'have',
#   'go',
#   'gotta',
#   'just',
#   'couldn’t',
#   'just',
#   'was',
#   'was',
#   'would',
#   'don’t',
#   'use',
#   'gotta',
#   'can’t',
#   'haven’t',
#   'was',
#   'just',
#   'ever',
#   'see',
#   'will',
#   'love',
#   'been',
#   'get',
#   'was',
#   'took',
#   'took',
#   'lasted',
#   'got',
#   'will',
#   'was',
#   'was',
#   'was',
#   'don’t',
#   'go',
#   'go',
#   'know',
#   'can',
#   'ordered',
#   'love',
#   'just',
#   'love',
#   'love',
#   'realized,',
#   'have',
#   'understand',
#   'know',
#   'know',
#   'am,',
#   'just',
#   'went',
#   'do',
#   'mean?',
#   'actually',
#   'hate',
#   'hate.',
#   'don’t',
#   'hate',
#   'mean',
#   'hate',
#   'hope',
#   'know.',
#   'got',
#   'know',
#   'had',
#   'was',
#   'was',
#   'would',
#   'said',
#   'would',
#   'can',
#   'hope',
#   'was',
#   'hacked',
#   'drive',
#   'sing',
#   'love',
#   'understand',
#   'say',
#   'will',
#   'will',
#   'just',
#   'see',
#   'see',
#   'hate',
#   'hate',
#   'don’t',
#   'speak',
#   'know',
#   'love',
#   'want',
#   'do,',
#   'want',
#   'forgot',
#   'knew',
#   'could',
#   'looked',
#   'watched',
#   'did',
#   'support',
#   'felt',
#   'get',
#   'understand.”',
#   'am',
#   'identify',
#   'might',
#   'am',
#   'support',
#   'support',
#   'identify',
#   'identify',
#   'can',
#   'can',
#   'am',
#   'still',
#   'want',
#   'would',
#   'don’t',
#   'want',
#   'want',
#   'want',
#   'saw',
#   'get',
#   'get',
#   'can',
#   'can',
#   'made',
#   'did,',
#   'was',
#   'freak',
#   'look',
#   'go,',
#   'do?',
#   'wasn’t',
#   'just',
#   'knew',
#   'had',
#   'start',
#   'okay,',
#   'have',
#   'get',
#   'make',
#   'made',
#   'was',
#   'was',
#   'was',
#   'look',
#   'make',
#   'make',
#   'make',
#   'do',
#   'buy',
#   'make',
#   'make',
#   'like',
#   'like',
#   'said',
#   'don’t',
#   'don’t',
#   'don’t',
#   'did',
#   'did',
#   'would',
#   'want',
#   'watch',
#   'don’t.',
#   'don’t.',
#   'don’t',
#   'watch',
#   'wanted',
#   'would',
#   'watch.',
#   'like',
#   'like',
#   'feel',
#   'like',
#   'go',
#   'like',
#   'would',
#   'don’t',
#   'don’t',
#   'put',
#   'already',
#   'have',
#   'always',
#   'have',
#   'know',
#   'say',
#   'do',
#   'know,',
#   'know.',
#   'say',
#   'get',
#   'have',
#   'have',
#   'will',
#   'have',
#   'make',
#   'like',
#   'want',
#   'want',
#   'know',
#   'like',
#   'like',
#   'like',
#   'know',
#   'say',
#   'don’t',
#   'said',
#   'want',
#   'know,',
#   'have',
#   'do,',
#   'get',
#   'get',
#   'know,',
#   'tell',
#   'am',
#   'got',
#   'was',
#   'walked',
#   'will',
#   'looked',
#   'live',
#   'had',
#   'see.',
#   'see',
#   'look',
#   'got',
#   'had',
#   'would',
#   'would',
#   'knocked',
#   'got.',
#   'run',
#   'lived',
#   'still',
#   'had',
#   'was',
#   'tell',
#   'know',
#   'say',
#   'thank',
#   'knew',
#   'had',
#   'loved',
#   'was',
#   'knew',
#   'know',
#   'want',
#   'love',
#   'am',
#   'would',
#   'don’t',
#   'co-host',
#   'go',
#   'take',
#   'heard',
#   'fucked'],
#  'can': ['live',
#   'power',
#   'be',
#   'tune',
#   'use',
#   'tell',
#   'get',
#   'get',
#   'get',
#   'end',
#   'say',
#   'fart,',
#   'just',
#   'pull',
#   'do',
#   'get',
#   'do',
#   'be',
#   'be',
#   'be',
#   'never',
#   'say',
#   'say',
#   'because',
#   'do.',
#   'block',
#   'like',
#   'get',
#   'get',
#   'try',
#   'try',
#   'just',
#   'have',
#   'you'],
#  'live': ['up', 'for', 'with', 'in', 'in.', 'in'],
#  'up': ['to',
#   'tonight.”',
#   'in',
#   'to',
#   'here,',
#   'there,',
#   'the',
#   'the',
#   'and',
#   'it',
#   'because',
#   'to',
#   'and',
#   'just',
#   'and',
#   'to',
#   'is',
#   'titties',
#   'titties.',
#   'in',
#   'and',
#   'sense',
#   'to',
#   'to',
#   'on',
#   'and',
#   'for',
#   'comedian',
#   'comedian.',
#   'right'],
#  'that,': ['but',
#   'I',
#   'it’s',
#   'I’d',
#   'first',
#   'once',
#   'we',
#   'you’d',
#   'I',
#   'your',
#   '“they',
#   'he’ll',
#   'you’re',
#   'you',
#   'we',
#   'and',
#   'don’t'],
#  'but': ['dammit,',
#   'when',
#   'I',
#   'I',
#   'he’s',
#   'that',
#   'he',
#   'he',
#   'he',
#   'he',
#   'you',
#   'want',
#   'you',
#   'okay,',
#   'never',
#   'he',
#   'we',
#   'why',
#   'guess',
#   'I',
#   'there’s',
#   'you',
#   'don’t',
#   'you',
#   'you',
#   'you',
#   'if',
#   'you',
#   'that’s',
#   'you',
#   'I'],
#  'dammit,': ['I’m'],
#  'I’m': ['gonna',
#   'drunk',
#   'sorry',
#   'not',
#   'not',
#   'just',
#   'already',
#   'allowed',
#   'gonna',
#   'losing',
#   'the',
#   'looking',
#   'not',
#   'one',
#   'on',
#   'gonna',
#   'talking',
#   'behind',
#   'casting',
#   'not',
#   'not.',
#   'the',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'a',
#   'not',
#   'one',
#   'not',
#   'feeling',
#   'gonna',
#   'not',
#   'from',
#   'trying',
#   'saying',
#   'talking',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'supposed',
#   'not',
#   'against',
#   'halfway',
#   'halfway',
#   'a',
#   'clever.',
#   'cute,',
#   'very',
#   'downright',
#   'a',
#   'pretty',
#   'buying',
#   'not',
#   'going',
#   'not',
#   'talking',
#   'going',
#   'serious,',
#   'not',
#   'not',
#   'not',
#   'worried',
#   'going',
#   'sitting',
#   'here',
#   'dancing',
#   'like,',
#   'not',
#   'so',
#   'here,',
#   'ready',
#   'a',
#   'small'],
#  'gonna': ['try!',
#   'go',
#   'kick',
#   'live.',
#   'be',
#   'do',
#   'happen.”',
#   'wear',
#   'support',
#   'love',
#   'fuck',
#   'do',
#   'tell',
#   'be',
#   'wanna',
#   'laugh',
#   'wanna',
#   'have',
#   'go',
#   'wake',
#   'be',
#   'do?',
#   'cry'],
#  'try!': ['(audience'],
#  'laughing)': ['Are',
#   'It’s',
#   'I',
#   'I',
#   'So',
#   'So',
#   'This',
#   'Just',
#   'I',
#   'See,',
#   'Like',
#   'But',
#   'But',
#   'Realize',
#   'Okay,',
#   'Guarantee',
#   'Now',
#   'You',
#   '“That',
#   '“That',
#   'I',
#   'Think',
#   '“I',
#   'From',
#   'You',
#   'Just',
#   'It’s',
#   '“Can',
#   'And',
#   'People,',
#   '“You',
#   'That',
#   'I',
#   'Get',
#   'Really,',
#   'I',
#   'You’re',
#   '“Lucky',
#   'No,',
#   'Some',
#   'Right',
#   '16th'],
#  'Are': ['you', 'you', 'you', 'you', 'you'],
#  'guys': ['ready',
#   'ready',
#   'walk',
#   'laughed,',
#   'right',
#   'laugh.',
#   'got',
#   'remember',
#   'do',
#   'getting',
#   'to',
#   'are',
#   'who',
#   'very'],
#  'party?': ['Are'],
#  'lot': ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'of': ['fuckin’',
#   'the',
#   'your',
#   'the',
#   'it.',
#   'a',
#   'the',
#   'a',
#   'Make',
#   'you',
#   'me?”',
#   'you!',
#   'you.”',
#   'me',
#   'him',
#   'the',
#   'you,',
#   'snow',
#   'snow',
#   'snow.”',
#   'snow.”',
#   'snow.”',
#   'snow,',
#   'snow,',
#   'those',
#   'those',
#   'the',
#   'urinals.',
#   'urinals',
#   'you',
#   'shit',
#   'you',
#   'you',
#   'them',
#   'crackers',
#   'life.',
#   'customer',
#   'under',
#   'those',
#   'little',
#   'these',
#   'another',
#   'dicks.',
#   'dicks.',
#   'dicks.',
#   'another',
#   'right',
#   'call',
#   'feet',
#   'these',
#   'you',
#   'my',
#   'the',
#   'you',
#   'the',
#   'the',
#   'you',
#   'Washington',
#   'her',
#   'the',
#   'Colored',
#   'Uggs,',
#   'all.',
#   'man.',
#   'things',
#   'you',
#   'control,',
#   'the',
#   'control,',
#   'a',
#   'the',
#   'the',
#   'Lucky',
#   'Lucky',
#   'my',
#   'two',
#   'it.',
#   'cock',
#   'penis',
#   'this',
#   'you',
#   'you',
#   'you',
#   'the',
#   'your',
#   'advice',
#   'you',
#   'women,',
#   'a',
#   'women,',
#   'our',
#   'her',
#   'her',
#   'you',
#   'men',
#   'that',
#   'Jenga.',
#   'guys',
#   'nowhere,',
#   'humor.',
#   'humor',
#   'humor',
#   'people',
#   'me',
#   'you.',
#   'school,',
#   'line',
#   'the',
#   'getting',
#   'work,',
#   'the',
#   'each',
#   'Purell,',
#   'it,',
#   'me',
#   'you',
#   'you',
#   'you',
#   'you,',
#   'you',
#   'you.',
#   'me.',
#   'his',
#   'a',
#   'me.',
#   'this.',
#   'it?',
#   'Mountain',
#   'mine'],
#  'fuckin’': ['fun', 'day,'],
#  'fun': ['tonight?',
#   'job.',
#   'of,',
#   'of',
#   'of.',
#   'of',
#   'size',
#   'of',
#   'of,',
#   'with',
#   'with',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'Good!': ['Good!', 'I'],
#  'like': ['havin’',
#   'to',
#   'to',
#   'to',
#   'to',
#   'me',
#   'it’s',
#   'the',
#   '♪',
#   'putting',
#   'that',
#   'some',
#   'to',
#   'to',
#   'a',
#   'this.',
#   'a',
#   '“Oh',
#   'this',
#   'a',
#   'last',
#   'right',
#   '48',
#   'the',
#   'that.',
#   'white',
#   'we',
#   'that?',
#   'it.',
#   'a',
#   'when',
#   'I',
#   'me',
#   'me,',
#   'turning',
#   'how',
#   'that,',
#   'a',
#   'tattoos,',
#   'that’s',
#   'a',
#   'I’m',
#   'a',
#   'car',
#   'grocery',
#   'you',
#   'you.',
#   'to',
#   'to',
#   'you’re',
#   'to',
#   'you’re',
#   'to',
#   'to',
#   'that',
#   'that',
#   'a',
#   'points',
#   'one',
#   'a',
#   'that.',
#   'my',
#   'my',
#   'that,',
#   'the',
#   'this.',
#   'some',
#   'a',
#   'that',
#   'nothing',
#   'on',
#   'put',
#   'you',
#   'round',
#   'you',
#   'don’t',
#   'you’re',
#   'look',
#   'my',
#   'all',
#   'Yoda',
#   'any',
#   'he',
#   'you’re',
#   'any',
#   'a'],
#  'havin’': ['fun,'],
#  'fun,': ['I', 'but,', 'it’s'],
#  'party.': ['I'],
#  'don’t': ['know',
#   'know',
#   'know',
#   'know',
#   'feel',
#   'think',
#   'you',
#   'possess',
#   'like',
#   'like',
#   'you',
#   'have',
#   'like,',
#   'say',
#   'say',
#   'get',
#   'know',
#   'know',
#   'laugh',
#   'mean',
#   'worry,',
#   'get',
#   'get',
#   'get',
#   'affect',
#   'smoke',
#   'smoke',
#   'stop',
#   'say',
#   'say',
#   'worry.',
#   'speak',
#   'speak',
#   'give',
#   'do',
#   'care',
#   '♪',
#   '♪',
#   'judge,',
#   'judge',
#   'want',
#   'want',
#   'want',
#   'want',
#   'judge',
#   'hear',
#   'hear',
#   'know',
#   'know',
#   'know',
#   'know',
#   'have',
#   'have',
#   'have',
#   'have',
#   'have',
#   'know',
#   'give',
#   'like',
#   'like',
#   'like',
#   'know',
#   'worry.',
#   'get',
#   'do',
#   'do',
#   'believe',
#   'think',
#   'want',
#   'think'],
#  'know': ['about',
#   'what',
#   'that.”',
#   'it’s',
#   'why!',
#   'if',
#   'what',
#   'what',
#   'what',
#   'what',
#   'have',
#   'we',
#   'we',
#   'what',
#   'what',
#   'this',
#   'I’m',
#   'what',
#   'that',
#   '“you’re',
#   'you',
#   'they',
#   'Katy',
#   'what',
#   'what',
#   'what',
#   'she',
#   'she',
#   'what?',
#   'what?',
#   'what,',
#   'the',
#   'you',
#   'what',
#   'how',
#   'how',
#   'if',
#   'I',
#   'we',
#   'because',
#   'there’s',
#   'there’s',
#   'what',
#   'once',
#   'that.',
#   'a',
#   'why',
#   'that',
#   'how',
#   'who’s',
#   'what',
#   'you',
#   'that',
#   'what',
#   'this,',
#   'how'],
#  'about': ['you,',
#   'him.',
#   'it,',
#   'some',
#   'this',
#   'it',
#   'the',
#   'the',
#   'the',
#   'yourself.',
#   'racial',
#   'certain',
#   'racial',
#   'it,',
#   'that',
#   'myself,',
#   'the',
#   'that,',
#   'it.',
#   'how',
#   'shit',
#   'it.',
#   'my',
#   'things',
#   'that?',
#   'myself.',
#   'that',
#   'that.',
#   'grocery',
#   'what',
#   'what',
#   'doing.',
#   'what',
#   'the',
#   'faking',
#   'your',
#   'your',
#   'the',
#   'the',
#   'that',
#   'the',
#   'it?',
#   'it,',
#   'that?”',
#   'what',
#   'my',
#   'two'],
#  'you,': ['but',
#   'like,',
#   'my',
#   'one',
#   'so',
#   'it',
#   'it',
#   'I',
#   'I',
#   'ladies.',
#   'I',
#   'we',
#   'when',
#   'you',
#   'fuck',
#   '“he',
#   'some',
#   'Brad?”',
#   'thank'],
#  'when': ['I',
#   'a',
#   'I',
#   'I',
#   'a',
#   'I’m',
#   'enhh',
#   'a',
#   'that',
#   'that',
#   'I',
#   'I',
#   'you',
#   'I',
#   'they',
#   'you',
#   'you',
#   'you',
#   'I',
#   'people',
#   'some',
#   'you',
#   'you',
#   'you',
#   'I',
#   'they',
#   'they’re',
#   'I',
#   'a',
#   'you',
#   'we',
#   'we',
#   'it',
#   'the',
#   'you',
#   'we',
#   'they',
#   'he',
#   'something',
#   'my',
#   'he'],
#  'party,': ['I'],
#  'drink.': ['One'],
#  'One': ['of', 'fuckin’', 'might', 'time', 'comedian.'],
#  'the': ['main',
#   'club',
#   'same',
#   'end',
#   'night',
#   'team',
#   'midgets',
#   'tree',
#   'fuck',
#   'end',
#   'end',
#   'Special',
#   'Special',
#   'portal',
#   'legs',
#   'Youth',
#   'same',
#   'same',
#   'far',
#   'track,',
#   'politically',
#   'guy',
#   'stands.',
#   'entire',
#   'chest',
#   'face,',
#   'face.',
#   'country,',
#   'reasons',
#   'time.',
#   'schools',
#   'entire',
#   'road',
#   'window',
#   'person',
#   'bathroom',
#   'entire',
#   'bathroom.',
#   'airport',
#   'gentlemen',
#   'fuck',
#   'men',
#   'fuck',
#   'guy,',
#   'bathroom,',
#   'dude,',
#   'Southwest',
#   'muscle',
#   'regular',
#   'regular',
#   'guy.',
#   'past',
#   'road',
#   'sports',
#   'morning',
#   'sports',
#   'San',
#   'World',
#   'San',
#   'next',
#   'next',
#   'San',
#   'radio',
#   'Giants.”',
#   'Giants?”',
#   'maximum',
#   'time,',
#   'African',
#   'salmon',
#   'wrong',
#   'funniest',
#   'first',
#   'fucker,',
#   'Asian',
#   'time',
#   'time.',
#   'role.',
#   'fuck',
#   'springtime.',
#   'summer,',
#   'people',
#   'most',
#   'people',
#   'fun',
#   'family',
#   'worst',
#   'first',
#   'word',
#   'fuck',
#   'word',
#   'little',
#   'fuck',
#   'audience,',
#   'lessons',
#   'scary',
#   'first',
#   'race',
#   'kid.',
#   'worst.',
#   'kids',
#   'mom',
#   'head',
#   'Mexican',
#   'mom',
#   'white',
#   'fuck',
#   'damn',
#   'hell',
#   'dad',
#   'hell',
#   'message',
#   'NAACP.',
#   'hell?”',
#   'great',
#   'NAACP,',
#   'Advancement',
#   'news,',
#   'NAACP.”',
#   'fuck',
#   'hair.',
#   'announcement.',
#   'Today',
#   'lines',
#   'best',
#   'history',
#   'inside,',
#   'outside.',
#   'Caitlyn',
#   'hormone',
#   'plastic',
#   'people',
#   'Caitlyn',
#   'funniest',
#   'fuck',
#   'fuck',
#   'beach,',
#   'street.',
#   'woman’s',
#   'sudden,',
#   'street',
#   'other',
#   'hospital?”',
#   'cars',
#   'damage.',
#   'human',
#   'aisle',
#   'greatest',
#   'people',
#   'magic',
#   'fuck',
#   'bedroom',
#   'baby.”',
#   'orgasm,',
#   'orgasm.',
#   'very',
#   'ghosts',
#   'way,',
#   'krakken.”',
#   'first',
#   'audience',
#   'women',
#   'fuck',
#   'fuck',
#   'titties.',
#   'titties.',
#   'titties,',
#   'other',
#   'case,',
#   'nice',
#   'Downs',
#   'president',
#   'itty',
#   'small',
#   'audience',
#   'size',
#   'show.',
#   'guy',
#   'guy',
#   'guy',
#   'guy',
#   'giddy',
#   'pornos.',
#   'face,”',
#   'devil',
#   'back',
#   'angel',
#   'tits.”',
#   'small',
#   'small',
#   'freak.',
#   'entire',
#   'revenge,',
#   'disposer',
#   'tower',
#   'tower',
#   'guys,',
#   'homophobic',
#   'butt,',
#   'only',
#   'other',
#   'idea.',
#   'time',
#   'entire',
#   'principal’s',
#   'office.',
#   'principal,',
#   'kid.',
#   'principal',
#   'phone',
#   'old',
#   'younger',
#   'bottom',
#   'rule.',
#   'difference.',
#   'principal',
#   'speaker',
#   'problem',
#   'problem',
#   'other',
#   'office.',
#   'other',
#   'big',
#   'Christmas',
#   'counter,',
#   'kitchen,',
#   'garage,',
#   'damn',
#   'first',
#   'appropriate',
#   'fuck',
#   'world',
#   'world',
#   'world',
#   'world',
#   'person',
#   'entire',
#   'street',
#   'family',
#   'man',
#   'man',
#   'second',
#   'man',
#   'fuck',
#   'sign',
#   'side',
#   'sign'],
#  'main': ['reasons'],
#  'reasons': ['I', 'that'],
#  'drink': ['is'],
#  'is': ['because',
#   'a',
#   'unbelievable.',
#   'up',
#   'not',
#   'a',
#   'awesome.',
#   'cool.',
#   'also',
#   '68',
#   'like,',
#   'my',
#   'reserved',
#   'reserved',
#   'reserved',
#   'all.',
#   'being',
#   'being',
#   'exactly',
#   'a',
#   'you',
#   'what',
#   'surrounded',
#   'awesome.',
#   'the',
#   'how',
#   'details',
#   'in',
#   'that',
#   'infinitely',
#   'you’re',
#   'legal',
#   'legal',
#   'not',
#   'gonna',
#   'wrong',
#   'offended,',
#   'wrong',
#   'Rachel',
#   'president',
#   'running',
#   'real!',
#   'going',
#   'pure',
#   'not',
#   'a',
#   'a',
#   'the',
#   'driving,',
#   'it',
#   'the',
#   'midget',
#   'an',
#   'in',
#   'sleeping',
#   'not',
#   'about',
#   'a',
#   'honest',
#   'missionary',
#   'that?',
#   'all',
#   'all',
#   'what',
#   'perfect?',
#   'ever',
#   'really',
#   'that',
#   'freaky,',
#   'freaky.',
#   'not',
#   'a',
#   'to',
#   'that',
#   'having',
#   'or',
#   'more',
#   'sitting',
#   'my',
#   'my',
#   'my',
#   'bullshit!',
#   'going',
#   'a',
#   'very',
#   'weird.'],
#  'because': ['I',
#   'I',
#   'I',
#   'we',
#   'we',
#   'they',
#   'it',
#   'I',
#   'I',
#   'I’m',
#   'I’m',
#   'it',
#   'those',
#   'in',
#   'porn,',
#   'their',
#   'for',
#   'no',
#   'we',
#   'I',
#   'he’s',
#   'he',
#   'you',
#   'I',
#   'he’s',
#   'I',
#   'you’re',
#   'my',
#   'he',
#   'my'],
#  'never': ['have',
#   'say',
#   'say',
#   'say',
#   'seen',
#   'gonna',
#   'wear',
#   'seen',
#   'want',
#   'make',
#   'do',
#   'be',
#   'do',
#   'stop',
#   'done',
#   'done',
#   '(scoffing),',
#   'tell',
#   'been',
#   'happened.',
#   'seen',
#   'do',
#   'know.',
#   'know',
#   'happened,',
#   'say,',
#   'tried',
#   'forget',
#   'ever,',
#   'stop',
#   'stopped',
#   'hit',
#   'had',
#   'got',
#   'got',
#   'going',
#   'truly',
#   'fear',
#   'to'],
#  'pay': ['for'],
#  'it.': ['Ever.',
#   'It’s',
#   'You',
#   'So',
#   'I',
#   'I’m',
#   '“Just',
#   'Body,',
#   'Don’t',
#   'First',
#   'Like,',
#   '“No,',
#   'But',
#   '‘Cause',
#   '(audience',
#   '‘Cause',
#   '“Little',
#   'We',
#   'And',
#   'And',
#   'See,',
#   'Now,',
#   'You',
#   'So',
#   'Some',
#   'And'],
#  'Ever.': ['‘Cause'],
#  '‘Cause': ['everyone', 'the', 'we', 'I', 'you', 'they'],
#  'everyone': ['wants', 'just', 'of', 'would'],
#  'wants': ['to', 'to', 'to,', 'to,', 'to', 'to'],
#  'what': ['happens',
#   'happens.',
#   'you’re',
#   'they',
#   'happens',
#   'happens.',
#   'I',
#   'to',
#   'makes',
#   'urinal',
#   'he',
#   'happened.',
#   'happened.',
#   'they',
#   'to',
#   'to',
#   'I',
#   'you’re',
#   'you’re',
#   'I',
#   'these',
#   'that',
#   'the',
#   'I’m',
#   'I’m',
#   'she',
#   'I',
#   'she',
#   'she',
#   'I’m',
#   'she’s',
#   'you',
#   'you',
#   'the',
#   'just',
#   'was',
#   'the',
#   'sex',
#   'you',
#   'you',
#   'you',
#   'you’ve',
#   'I',
#   'I',
#   'I',
#   'you’re',
#   'to',
#   'you',
#   'we',
#   'he',
#   'time',
#   'he',
#   'would',
#   'would',
#   'my',
#   'you’re',
#   'you’re',
#   'my',
#   'that',
#   'are',
#   'they',
#   'you',
#   'a',
#   'a',
#   'he',
#   'I',
#   'to',
#   'do'],
#  'happens': ['when', 'when', 'when', 'you', 'to', 'in'],
#  'dwarf': ['gets',
#   'buddy,',
#   'runs',
#   'dancing',
#   'dancing',
#   'lifeguard',
#   'said',
#   'children.'],
#  'gets': ['drunk.', 'a', 'wet,', 'offended', 'a', 'the', 'my'],
#  'drunk.': ['Right'],
#  'Right': ['now', 'here.', 'now,', 'there,', 'now,', 'now,'],
#  'now': ['you’re',
#   'in',
#   'more',
#   'breakdown',
#   'teaching',
#   'and',
#   'they’re',
#   'but',
#   'because',
#   'cancer'],
#  'you’re': ['thinking,',
#   'missing',
#   'like',
#   'like,',
#   'from',
#   'a',
#   'gonna',
#   'gonna',
#   'allowed',
#   'Asian,',
#   'a',
#   'doing',
#   'doing',
#   'turning',
#   'saying,',
#   'not',
#   'a',
#   'a',
#   'white',
#   'trying',
#   'born',
#   'like,',
#   'a',
#   'a',
#   'like,',
#   'adorable,',
#   'gonna',
#   'all',
#   'going',
#   'holier',
#   'going',
#   'going',
#   'going',
#   'having',
#   'like,',
#   'like,',
#   'down',
#   'too',
#   'just',
#   'playing',
#   'going',
#   'going',
#   'little.”',
#   'never',
#   'in',
#   'an',
#   'a',
#   'a',
#   'not',
#   'like,',
#   'never',
#   'too'],
#  'thinking,': ['“I'],
#  '“I': ['wonder',
#   'would',
#   'am',
#   'can',
#   'am,',
#   'meant',
#   'am',
#   'am',
#   'don’t',
#   'have',
#   'have',
#   'don’t',
#   'would',
#   'will',
#   'know',
#   'got',
#   'did',
#   'respect',
#   'am',
#   'identify',
#   'identify',
#   'identify',
#   'got',
#   'was',
#   'am',
#   'like',
#   'love',
#   'hope',
#   'can’t',
#   'bought'],
#  'wonder': ['what'],
#  'happens.': ['“I', 'And'],
#  'would': ['really',
#   'absolutely',
#   'never',
#   'just',
#   'love',
#   'do',
#   'never',
#   'you',
#   'be',
#   'never',
#   'never',
#   'understand',
#   'get',
#   'any',
#   'have',
#   'love',
#   'be',
#   'I',
#   'love',
#   'I',
#   'bang',
#   'like',
#   'it',
#   'it',
#   'never',
#   'you',
#   'you',
#   'you',
#   'you',
#   'make',
#   'tell',
#   'have',
#   'mess',
#   'do.',
#   'mess',
#   'pick',
#   'love',
#   'be'],
#  'really': ['like',
#   'wasn’t',
#   'had',
#   'awkward',
#   'good',
#   'into',
#   'think',
#   'athletic'],
#  'that.”': ['And', 'And', 'So', 'And'],
#  'And': ['I',
#   'then',
#   'don’t',
#   'he',
#   'you',
#   'then',
#   'we',
#   'I’m',
#   'I',
#   'then',
#   'they’re',
#   'we',
#   'that’s',
#   'I',
#   'it',
#   'I',
#   'the',
#   'I',
#   'who',
#   'why',
#   'I’m',
#   'they',
#   'they',
#   'if',
#   'then',
#   'I',
#   'would',
#   'by',
#   'then',
#   'you',
#   'ladies,',
#   'you',
#   'you',
#   'when',
#   'we’ll',
#   'there',
#   'cock',
#   'there’s',
#   'someone',
#   'we’re',
#   'the',
#   'then',
#   'we',
#   'we',
#   'then',
#   'now,',
#   'thank'],
#  'it’s': ['like',
#   'awesome.”',
#   'the',
#   'just',
#   'my,”',
#   'no',
#   'big',
#   'just',
#   'winter',
#   'required',
#   'all',
#   'just,',
#   'like,',
#   'difficult.',
#   'just',
#   'wrong.',
#   'a',
#   'a',
#   'falling',
#   'pure.',
#   'gone,',
#   'gone.',
#   'gone.',
#   'embarrassing',
#   'amazing.',
#   'like,',
#   'an',
#   'going',
#   'my',
#   'easy',
#   'nice,',
#   'easy,',
#   'a',
#   'not',
#   'the',
#   'the'],
#  'me': ['and',
#   'and',
#   'when',
#   'and',
#   'and',
#   'a',
#   'out.',
#   'like,',
#   'fell',
#   'sir!”',
#   'sir.”',
#   'to',
#   'my',
#   'wrong,',
#   'up',
#   'for',
#   'feel',
#   'feel',
#   'right',
#   'identify',
#   'identify',
#   'recently',
#   'what',
#   'feel',
#   'afterward.',
#   'for',
#   'the',
#   'seeing',
#   'and',
#   'like.',
#   'and',
#   'right',
#   'about',
#   'like,',
#   'to',
#   'right',
#   'later',
#   'wrong',
#   'later.',
#   'first.',
#   'and',
#   'back,',
#   'back',
#   'like',
#   'today.”',
#   'and',
#   'that',
#   'in',
#   'because',
#   'but',
#   'up,',
#   'on',
#   'up,',
#   'on',
#   'up',
#   'a',
#   'to',
#   'never',
#   'to',
#   'wrong,',
#   'and',
#   'and',
#   'up',
#   'on',
#   'that'],
#  'and': ['hot',
#   'hot',
#   'everyone',
#   'goes,',
#   'by',
#   'the',
#   'I',
#   'watch',
#   'then',
#   'I’m',
#   'it’s',
#   'my',
#   'goes,',
#   'raised,',
#   'I’ll',
#   'they',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'fall',
#   'a',
#   'I',
#   'had',
#   'the',
#   'there’s',
#   'that',
#   'they’re',
#   'this',
#   'goes,',
#   'I',
#   'you',
#   'say',
#   'black',
#   'be',
#   'you',
#   'it',
#   'appreciate',
#   'he',
#   'that',
#   'other',
#   'in',
#   'it’s',
#   'you’re',
#   'fight',
#   'then',
#   'then',
#   'said,',
#   'I',
#   'you',
#   'go',
#   'gasping.',
#   'hits',
#   'gentlemen,',
#   'they',
#   'be',
#   'I’m',
#   'they',
#   'then,',
#   'you’re',
#   'I',
#   'you',
#   'you',
#   'once',
#   'while',
#   'goes,',
#   'be',
#   'then',
#   'sees',
#   'screams)',
#   'it’s',
#   'sees',
#   'just',
#   'just',
#   'enjoy',
#   'be',
#   'I',
#   'go,',
#   'said,',
#   'be',
#   'I',
#   'there’s',
#   'just',
#   'you',
#   'a',
#   'this',
#   'have',
#   'ladies,',
#   'a',
#   'be',
#   'be',
#   'you’re',
#   'says,',
#   'be',
#   'we',
#   'see',
#   'just',
#   'dad.',
#   'sometimes,',
#   'when',
#   'dad',
#   'he',
#   'then',
#   'Luke',
#   'goes,',
#   'went,',
#   'he',
#   'says,',
#   'then',
#   'then,',
#   'the',
#   'my',
#   'then',
#   'half',
#   'a',
#   'you’re',
#   'lollipops',
#   'it',
#   'to',
#   'gentlemen,',
#   'announced',
#   'try',
#   'we',
#   'I',
#   'now',
#   'applauds)',
#   'hopefully',
#   'son',
#   'we’re',
#   'we’re',
#   'we’re',
#   'get',
#   'pick',
#   'put',
#   'be',
#   'I',
#   'I’m',
#   'his'],
#  'hot': ['chicks,', 'chicks', 'chick', 'to'],
#  'chicks,': ['me'],
#  'chicks': ['have'],
#  'that': ['thing',
#   'fucked',
#   'I',
#   'I',
#   'I',
#   'shit,',
#   'to',
#   'joke,',
#   'joke',
#   'and',
#   'it',
#   'it',
#   'happens,',
#   'happens',
#   'is',
#   'when',
#   'makes',
#   'makes',
#   'works?',
#   'shit',
#   'I',
#   'is',
#   'urinal!',
#   'is',
#   'is',
#   'shit.”',
#   'was',
#   'was',
#   'was',
#   'I',
#   'I',
#   'guy’s',
#   'has',
#   'ever.',
#   'says',
#   'joke',
#   'joke,',
#   'for',
#   'made',
#   'it’s',
#   'you’re',
#   'to',
#   'joke',
#   'I',
#   'gets',
#   'has',
#   'they',
#   'when',
#   'group',
#   'are',
#   'was',
#   'don’t',
#   'action',
#   'song.',
#   'joke',
#   'joke.',
#   'joke.',
#   'people',
#   'is.',
#   'from',
#   'I’m',
#   'if',
#   'one',
#   'happen?”',
#   'picture?',
#   'fucking',
#   'fucking',
#   'was',
#   'doing',
#   'that',
#   'shit.',
#   'in',
#   'is',
#   'sex,',
#   'entire',
#   'really',
#   'ever',
#   'shit',
#   'is',
#   'is',
#   'I',
#   'a',
#   'you',
#   'laughed',
#   'is',
#   'shit,',
#   'you’ve',
#   'it?”',
#   'it?”',
#   'and',
#   'and',
#   'for',
#   'for',
#   'for',
#   'to',
#   'we’re',
#   'situation',
#   'direction.',
#   'side',
#   'and',
#   'those',
#   'you?',
#   'your',
#   'stuff.”',
#   'guy.',
#   'is,',
#   'happens,',
#   'shit,',
#   'and',
#   'but',
#   'right',
#   'we',
#   'freak',
#   'every',
#   'butt.',
#   'move,',
#   'move.',
#   'to',
#   'was',
#   'right',
#   'to',
#   'depends',
#   'thing?”',
#   'on',
#   'makes',
#   'and',
#   'tall',
#   'situation?',
#   'to',
#   'one',
#   'means.',
#   'Purell.',
#   'thing.',
#   'to',
#   'day.',
#   'day.',
#   'just',
#   'moment',
#   'my',
#   'thing',
#   'look.',
#   'look.',
#   'did',
#   'my',
#   'he',
#   'is',
#   'should',
#   'should',
#   'kid.',
#   'kid,',
#   'kid’s',
#   'but',
#   'he',
#   'cancer',
#   'didn’t',
#   'didn’t',
#   'son',
#   'you',
#   'moment',
#   'moment',
#   'one',
#   'one,',
#   'smells'],
#  'thing': ['in', 'as', 'I’ve', 'with', 'as', 'to', 'unscathed,'],
#  'in': ['common',
#   'the',
#   'the',
#   'different',
#   'the',
#   'the',
#   'a',
#   'this',
#   'the',
#   'front',
#   'the',
#   'the',
#   'New',
#   'one',
#   'a',
#   'a',
#   'this',
#   'a',
#   'this',
#   'the',
#   'San',
#   'general.',
#   'because',
#   'trouble.',
#   'our',
#   'my',
#   'desperate',
#   'my',
#   'my',
#   'my',
#   'this',
#   'this',
#   'your',
#   'the',
#   'your',
#   'my',
#   'the',
#   'there',
#   'your',
#   'Spanish',
#   'this',
#   'this',
#   'that,',
#   'the',
#   'a',
#   'town.',
#   'trouble.',
#   'a',
#   'a',
#   'one',
#   'a',
#   'www.humpaleg.com',
#   'my',
#   'your',
#   'your',
#   'the',
#   'my',
#   'a',
#   'your',
#   'the',
#   'that',
#   'its',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'that',
#   'hot!”',
#   'the',
#   'my',
#   'that',
#   'a',
#   'front',
#   'my',
#   'California,',
#   'the',
#   'my',
#   'time',
#   'time',
#   'a',
#   'that',
#   'one,',
#   'a',
#   'my',
#   'the',
#   'my',
#   'the',
#   'a',
#   'because',
#   'this',
#   'this',
#   'the',
#   'every',
#   'movies,'],
#  'common': ['where'],
#  'where': ['we',
#   'I',
#   'we',
#   'I',
#   'if',
#   'everything',
#   'do',
#   'a',
#   'I',
#   'are',
#   'they’re',
#   'unfortunately,',
#   'we’re',
#   'it'],
#  'we': ['walk',
#   'have',
#   'know.',
#   'come',
#   'hold',
#   'know',
#   'can',
#   'walk',
#   'know',
#   'can',
#   'laugh',
#   'have',
#   'stop.',
#   'can',
#   'go.”',
#   'found',
#   'took',
#   'immediately',
#   'all',
#   'all',
#   'measure',
#   'do',
#   'do.',
#   'are,',
#   'are',
#   'see',
#   'see',
#   'know',
#   'are',
#   'do',
#   'will',
#   'hold',
#   'hold',
#   'love',
#   'love',
#   'hold',
#   'want',
#   'want',
#   'not?',
#   'go',
#   'go,',
#   'go.”',
#   'live',
#   'knew,',
#   'got',
#   'started',
#   'had',
#   'had',
#   'got'],
#  'walk': ['into', 'around', 'around'],
#  'into': ['the',
#   'gold',
#   'it.',
#   'his',
#   'a',
#   'a',
#   'sex.',
#   'glazed',
#   'kindergarten'],
#  'club': ['and'],
#  'just': ['looks',
#   'Brad',
#   'going',
#   'so',
#   'die',
#   'little',
#   'pause',
#   'staring',
#   'a',
#   'a',
#   'duct',
#   'had',
#   'looked',
#   'turns',
#   'said,',
#   'to',
#   'like,',
#   'say',
#   'don’t',
#   'asks',
#   'called',
#   'help',
#   'want',
#   'elf,',
#   'messed',
#   'flying',
#   'wanna',
#   'fart,',
#   'pointing',
#   'grabs',
#   'like',
#   'make',
#   'saw',
#   'looks',
#   'happened',
#   'in',
#   'goes.',
#   'see',
#   'reaching',
#   'fake',
#   'look',
#   'really',
#   'went,',
#   'hangs',
#   'like,',
#   'understand',
#   '(audience',
#   'do',
#   'going',
#   'like',
#   'on',
#   'on',
#   'looking',
#   'want',
#   'do',
#   'like,',
#   'dropped',
#   'make',
#   'make',
#   'because',
#   'running',
#   '♪',
#   'like',
#   'need',
#   'said',
#   'see',
#   'step'],
#  'looks': ['at', 'down', 'at', 'up', 'and', 'at'],
#  'at': ['us',
#   'him',
#   'the',
#   'the',
#   'that',
#   'the',
#   'him',
#   'each',
#   'me',
#   'me',
#   'the',
#   'me,',
#   'jokes',
#   'that',
#   'his',
#   'the',
#   'that',
#   'my',
#   'the',
#   'her',
#   'work',
#   'Adam,',
#   'me',
#   'the',
#   'all',
#   'my',
#   'it.',
#   'all',
#   'me',
#   'you',
#   'your',
#   'you',
#   'us',
#   'me?',
#   'us',
#   'their',
#   'me,',
#   'all.',
#   'him',
#   'me',
#   'school.',
#   'the',
#   'the',
#   'Christmas,',
#   'me',
#   'me'],
#  'us': ['and', 'pussies,', 'a', 'and', 'the'],
#  'goes,': ['“We’re',
#   '“My',
#   '“No',
#   '“What',
#   '“Ha',
#   '“I',
#   '“Did',
#   '“Well',
#   '“Well'],
#  '“We’re': ['gettin’'],
#  'gettin’': ['that'],
#  'fucked': ['up', 'up,', 'up', 'up', 'up', 'up', 'him,'],
#  'tonight.”': ['(audience', '“Why'],
#  'It’s': ['true,',
#   'not',
#   'not',
#   'like',
#   'dumb.',
#   'fun,',
#   'a',
#   'like,',
#   'wrong.',
#   'fucked',
#   'just',
#   'not',
#   'an',
#   'not.',
#   'like,',
#   'a',
#   'gone!',
#   'not',
#   'like,',
#   'not',
#   'not',
#   'like,',
#   'boring',
#   'awesome,',
#   'been',
#   'not',
#   'not',
#   'me,',
#   'weird.'],
#  'true,': ['but'],
#  'why!': ['Because'],
#  'Because': ['nothing',
#   'black',
#   'white',
#   'in',
#   'two',
#   'there’s',
#   'what',
#   'they',
#   'you’re',
#   'if',
#   'when'],
#  'nothing': ['happens',
#   'crazy.',
#   'to',
#   'when',
#   'to',
#   'happens',
#   'to',
#   'unusual',
#   'but',
#   'on',
#   'is'],
#  'drink,': ['nothing', 'it’s'],
#  'crazy.': ['Like'],
#  'Like': ['I',
#   'all',
#   'that',
#   'the',
#   'right',
#   'how',
#   'that’s,',
#   'what',
#   'I’m',
#   'I',
#   'if',
#   'any',
#   'he’s',
#   'that,',
#   'that,',
#   'there’s'],
#  'if': ['one',
#   'I',
#   'you',
#   'you',
#   'five',
#   'you',
#   'your',
#   'I’m',
#   'every',
#   'weed',
#   'you',
#   'you’re',
#   'gay',
#   'you',
#   'you',
#   'you',
#   'you’re',
#   'she',
#   'you’re',
#   'you’re',
#   'you’re',
#   'I',
#   'you',
#   'you',
#   'you',
#   'I',
#   'you’re',
#   'that’s',
#   'your',
#   'I',
#   'your',
#   'you’re',
#   'you’re',
#   'you',
#   'they',
#   '“you',
#   'you’re',
#   'you',
#   'you’re'],
#  'one': ['of',
#   'knows',
#   'of',
#   'of',
#   'day,',
#   'of',
#   'of',
#   'that’s',
#   'is',
#   'urinal',
#   'of',
#   'else',
#   'thing,',
#   'of',
#   'of',
#   'give',
#   'of',
#   'of',
#   'of',
#   'lesson',
#   'out.',
#   'minor',
#   'know',
#   'know',
#   'was',
#   'sex,',
#   'and',
#   'box',
#   'titty',
#   'piece',
#   'answer',
#   'so',
#   'right.',
#   'question.',
#   'has',
#   'day',
#   'day,',
#   'day,'],
#  'your': ['friends',
#   'bubble,',
#   'cock',
#   'knee',
#   'five',
#   'leg,',
#   'station.”',
#   'Indian',
#   'own',
#   'wok.”',
#   'illegitimate',
#   'mouth.',
#   'life.',
#   'windows,',
#   'puppy.',
#   'life.',
#   'happy',
#   'midget',
#   'family,',
#   'tattoos.',
#   'computers,',
#   'porn',
#   'porn.',
#   'porno.',
#   'browser',
#   'level',
#   'man',
#   'life.',
#   'favorite',
#   'man',
#   'man’s',
#   'man’s',
#   'man',
#   'small',
#   'small',
#   'man',
#   'man,',
#   'man',
#   'man',
#   'man,',
#   'man,',
#   'man',
#   'man',
#   'man',
#   'women',
#   'sister?”',
#   'man',
#   'man',
#   'engagement',
#   'mom',
#   'child',
#   'son',
#   'mom',
#   'dad',
#   'father.”',
#   'son,',
#   'child',
#   'school',
#   'school',
#   'kid',
#   'kid',
#   'kid',
#   'kid'],
#  'friends': ['told'],
#  'told': ['you,'],
#  'like,': ['“No,',
#   '“Yeah!',
#   '“Daddy,',
#   '“No,',
#   '“All',
#   '“Oh',
#   '“There’s',
#   '“Yeah,',
#   '“Brad,',
#   '“He',
#   '“I',
#   '“Excuse',
#   '“Boop,',
#   '“Brad,',
#   'pee,',
#   '“Yeah,',
#   '“If',
#   '“Brad,',
#   '“Nope.',
#   '“No?”',
#   '“No,',
#   '“That’s',
#   '“What?',
#   '“I',
#   '“Because',
#   'that’s',
#   '“Hey',
#   '“Don’t',
#   '“I’m',
#   '“Ohhh',
#   '“Golly',
#   '“Oh',
#   '“Oh,',
#   '“Oh,',
#   '“Right,',
#   'white',
#   '“Don’t',
#   'sorry,',
#   '(foreign',
#   '“What’s',
#   '“What',
#   '“A',
#   '“What?',
#   '“She',
#   'how',
#   '“She',
#   '“You',
#   '“That’s',
#   '“I’m',
#   '“You',
#   '“You',
#   '“Tattoos',
#   '“I',
#   'fine,',
#   '“Oh,',
#   '“I',
#   '“Oh',
#   '“Fuck',
#   '“The',
#   '“Yeah!”',
#   '“Is',
#   '“(gasping)',
#   '“Release',
#   '“Yeah,',
#   '“Brad,',
#   '“What',
#   '“Hey,',
#   '“Brad,',
#   '“Oh',
#   '“Yeah,',
#   '“I',
#   '“It’s',
#   '“T',
#   '“Baby,',
#   '“Anywhere',
#   '“What,',
#   '“She',
#   '“Baby,',
#   '“Yeah,',
#   '“Oh,',
#   '“Ah,',
#   '“Where',
#   '“Alright,',
#   '“You',
#   '“No',
#   '“I',
#   '“What?”',
#   '“I',
#   '“What,',
#   '“You',
#   '“What’s',
#   '“Hey',
#   '“Oh,',
#   '“Alright,',
#   '“Grandpa'],
#  '“No,': ['man,', 'I’m', 'it’s', 'you', 'no,', 'no.”', 'not'],
#  'man,': ['you', 'because', 'your', 'oh', 'it’s', 'shut'],
#  'get': ['a',
#   'very',
#   'together',
#   'up',
#   'away?”',
#   'burned',
#   'away',
#   'over',
#   'in',
#   'busted.',
#   'fired.',
#   'scared',
#   'me',
#   'why',
#   'offended',
#   'up,',
#   'up,',
#   'up,',
#   'up.',
#   'that.',
#   'married,',
#   'a',
#   'in',
#   'it.',
#   '’em',
#   'you',
#   'to',
#   'it,',
#   'that',
#   'three',
#   'out',
#   'it,',
#   'boob',
#   'like',
#   'that',
#   'a',
#   'the',
#   'me',
#   'my',
#   'my',
#   'the',
#   'sent',
#   'last',
#   'it.',
#   'to',
#   'that',
#   'that',
#   'me',
#   'mad'],
#  'midget': ['drunk,',
#   'run,',
#   'that',
#   'my',
#   'ass?”',
#   'porn.',
#   'porn.',
#   'porn',
#   'porn',
#   'porn',
#   'porn?',
#   'porn.',
#   'porn,'],
#  'drunk,': ['“they'],
#  '“they': ['explode', 'don’t', 'could'],
#  'explode': ['into'],
#  'gold': ['coins.'],
#  'coins.': ['“It’s'],
#  '“It’s': ['ridiculous,',
#   'like',
#   'just',
#   'a',
#   'like',
#   'my',
#   'stupid,',
#   'dumb.”',
#   'fun,',
#   'a',
#   'not'],
#  'ridiculous,': ['like'],
#  'awesome.”': ['Nothing'],
#  'Nothing': ['happens!', 'to', 'entertaining'],
#  'happens!': ['Basically'],
#  'Basically': ['when'],
#  'same': ['thing', 'disability.', 'time,'],
#  'as': ['when',
#   'a',
#   'laughter.',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'that',
#   'a',
#   'bandwagon.',
#   'such,',
#   'a',
#   'a',
#   'long',
#   'we',
#   'Channing',
#   'quietly',
#   'they',
#   'a'],
#  'chick': ['drinks.'],
#  'drinks.': ['I'],
#  'very': ['emotional,',
#   'excited,',
#   'difficult',
#   'cute.',
#   'first',
#   'small',
#   'careful,',
#   'fucked',
#   'awesome',
#   'scary',
#   'much',
#   'expensive.'],
#  'emotional,': ['I’ll'],
#  'I’ll': ['probably',
#   'be',
#   'dress',
#   'tell',
#   'handle',
#   'tell',
#   'explain,',
#   'be',
#   'tell',
#   'tell',
#   'do',
#   'tell',
#   'tell',
#   'do'],
#  'probably': ['text'],
#  'text': ['an'],
#  'an': ['ex,',
#   'actor',
#   'elf',
#   'inspirational',
#   'idiot,',
#   'escape',
#   'emotional',
#   'Academy',
#   'asshole.',
#   'undefeated',
#   'audience.'],
#  'ex,': ['and'],
#  'by': ['the',
#   'law,',
#   'the',
#   'that',
#   'the',
#   'far,',
#   'that',
#   'that',
#   'the',
#   'the'],
#  'end': ['of', 'of', 'of', 'racism.'],
#  'night': ['I'],
#  'might': ['blow', 'even', 'say', 'have', 'be'],
#  'blow': ['a'],
#  'dude.': ['(audience'],
#  'also': ['say', 'what'],
#  'say': ['things',
#   'sober',
#   'if',
#   'that',
#   'that',
#   'chest',
#   'they',
#   'something',
#   'something',
#   '“anything',
#   'shit,',
#   'shit,',
#   'shit,',
#   'shit.”',
#   'about',
#   'about',
#   'it',
#   'anything.',
#   'anything,',
#   'something,',
#   'stuff,',
#   'it',
#   'is,',
#   'after',
#   'things',
#   'things',
#   'that?',
#   'that.',
#   'something',
#   'that',
#   'absolutely',
#   'that',
#   'something',
#   'that',
#   'anywhere,',
#   'anywhere,',
#   'anywhere?”',
#   'about',
#   'those'],
#  'things': ['when',
#   'weren’t',
#   'that',
#   'to',
#   'that',
#   'that',
#   'better.',
#   'better,',
#   'of',
#   'do'],
#  'drunk': ['that'],
#  'absolutely': ['never', 'nothing'],
#  'sober': ['under'],
#  'under': ['any', 'the', 'any', 'any'],
#  'any': ['circumstances.',
#   'man',
#   'sense',
#   'circumstance',
#   'one',
#   'man’s',
#   'circumstances.',
#   'kid',
#   'father'],
#  'circumstances.': ['Like,', 'Ladies,'],
#  'Like,': ['not',
#   '“No,',
#   'most',
#   'Hollywood',
#   'I',
#   'are',
#   '“No,',
#   'you',
#   'you',
#   'that’s'],
#  'not': ['too',
#   'like',
#   'his',
#   'his',
#   'gonna',
#   'proud',
#   'proud',
#   'inhale!”',
#   'a',
#   'going',
#   'too',
#   'for',
#   'concern',
# ...
#   'the',
#   'every',
#   'about',
#   'your',
#   'that?',
#   'somebody',
#   'I’m',
#   'about',
#   'that',
#   'that',
#   'so.'],
#  'gentlemen': ['in'],
#  'aware': ['of,'],
#  'of,': ['okay?', 'and', '“and', '“Well,'],
#  'Uh,': ['ladies,'],
#  'ladies,': ['you', 'I', 'would', 'there', 'just', 'a', 'pretend'],
#  'tune': ['out.'],
#  'does': ['not', 'it', 'that', 'happen'],
#  'concern': ['you.'],
#  'Gentlemen,': ['when'],
#  'public': ['bathroom,'],
#  'bathroom,': ['stay', 'now', 'it’s', 'they'],
#  'stay': ['the'],
#  'away': ['from', 'from', 'from', 'to'],
#  'from': ['my',
#   'it',
#   'your',
#   'Southern',
#   'home.”',
#   'doing',
#   'Southern',
#   'Chipotle?”',
#   'everything',
#   'the',
#   'real',
#   'Subways',
#   'my',
#   'school.',
#   'life'],
#  'urinal.': ['(audience', 'In', 'I', 'If'],
#  'See,': ['the', 'look'],
#  'men': ['are', 'do', 'don’t', '“want', 'are'],
#  'laughing,': ['’cause'],
#  '’cause': ['they', 'I', 'them', 'one', 'you', 'you', 'they', 'I', 'check'],
#  'urinal': ['I’m', 'is'],
#  'talking': ['about.', 'about?', 'with', 'about', 'about', 'about?'],
#  'about.': ['The'],
#  'women': ['are',
#   'because',
#   'in',
#   'right',
#   'get',
#   'have',
#   'just',
#   'into',
#   'hate'],
#  '“He': ['has'],
#  'has': ['a',
#   'nothing',
#   'into',
#   'nothing',
#   'never',
#   'this',
#   'ever',
#   'a',
#   'sex',
#   'an',
#   'gone'],
#  'urinal?”': ['Yes,', 'Listen,'],
#  'Yes,': ['I', 'I', 'cock', 'I', 'Jenga,', 'yes,', 'perfect.'],
#  'In': ['every', 'my', 'the', 'the', 'her'],
#  'single': ['bathroom'],
#  'United': ['States,'],
#  'States,': ['it’s'],
#  'required': ['by'],
#  'law,': ['there’s'],
#  'always': ['two', 'one', 'some', 'fantasized', 'carry', 'ecstatic', 'look'],
#  'three': ['urinals', 'years,', 'wishes', 'minutes.'],
#  'urinals': ['for', 'and'],
#  'here,': ['and', 'you’re', 'check', 'I’m'],
#  'mine,': ['that'],
#  'urinal!': ['Do', 'That'],
#  'Do': ['not', 'you', 'you', 'that', 'you', 'you'],
#  'use': ['that', 'that', 'a', 'a', 'the', 'the', 'their'],
#  'reserved': ['for', 'for', 'for'],
#  'year': ['old', 'that'],
#  'old': ['son', 'it', 'school', 'school,'],
#  'son': ['Zachary,', 'was', 'of', 'where', 'does,', 'will'],
#  'Zachary,': ['and'],
#  'man': ['with',
#   'takes',
#   'takes',
#   'would',
#   'is',
#   'has',
#   'doesn’t',
#   'is',
#   'is',
#   'is,',
#   'is',
#   'will',
#   'says',
#   'and',
#   'has',
#   'does',
#   'is',
#   'who',
#   'who',
#   'and',
#   'that'],
#  'dick,': ['okay?', 'okay?', 'this'],
#  'all.': ['So…', 'And', 'I'],
#  'Black': ['guy’s', 'people', 'people', 'kids'],
#  'guy’s': ['clappin’,', 'not'],
#  'clappin’,': ['he’s'],
#  'shit.”': ['Anyway.', '(audience', '‘Cause'],
#  'Anyway.': ['(laughing)'],
#  'can.': ['So'],
#  'open': ['urinals.', 'up', 'with', 'it'],
#  'urinals.': ['It’s', 'One'],
#  'cornucopia': ['of'],
#  'plethora': ['of'],
#  'they’re': ['all',
#   'like,',
#   'supposed',
#   'not',
#   'supposed',
#   'being',
#   'being',
#   'the',
#   'like,',
#   'not',
#   'doin’.',
#   'hopping',
#   'not',
#   'like,',
#   'like,',
#   'from.'],
#  'wide': ['open.'],
#  'open.': ['Only'],
#  'Only': ['one', 'bad'],
#  'being': ['taken', 'taken', 'so', 'a', 'made', 'black,', 'in', 'a', 'a'],
#  'taken': ['up.', 'up?', 'off'],
#  'up.': ['Guess', '“Stay', 'I’m', 'Just', 'My', 'Shut', '(audience'],
#  'Guess': ['which'],
#  'which': ['one'],
#  'up?': ['Mine!', '“Am', '–'],
#  'Mine!': ['All'],
#  'All': ['right?', 'right?', '32', 'of', 'you'],
#  'now,': ['I’m', 'I', 'look', 'looking', 'concerned', 'a', 'a', 'it'],
#  'behind': ['the', 'him.', 'a', 'someone,', 'him.', 'my'],
#  'sward': ['I-gotta-pee'],
#  'I-gotta-pee': ['dance'],
#  'dance': ['like'],
#  'other': ['people',
#   'job',
#   'parts',
#   'cultures.',
#   'up,',
#   'groups',
#   'groups,',
#   'family',
#   'way.',
#   'one’s',
#   'one’s',
#   'kids,',
#   'kid’s',
#   'kid.'],
#  'walking': ['in'],
#  'see': ['a',
#   'a',
#   'one',
#   'it',
#   'one',
#   'it.',
#   'how',
#   'something',
#   'anything',
#   'something',
#   'me,',
#   'him',
#   'someone',
#   'this',
#   'me,',
#   'real',
#   'that.',
#   'what',
#   'a',
#   'it,',
#   'it',
#   'the',
#   'the',
#   'the',
#   '(clicking',
#   'that,',
#   'that,',
#   'the',
#   'how',
#   'how'],
#  'dancing': ['right', 'behind', 'around'],
#  'guy.': ['You', 'I', 'While', 'I’m'],
#  'someone,': ['you'],
#  'casting': ['a'],
#  'spell': ['on'],
#  'shit.': ['And', 'I', 'Basically,', 'Don’t', '(audience', 'We’ll', 'Now,'],
#  'moment': ['where', 'where', 'that', 'with', 'and'],
#  'take': ['anymore,', 'it,', 'it,', 'offense'],
#  'anymore,': ['so', 'Merry'],
#  'looked': ['at', 'black.”', 'like.”', 'at', 'at', 'at'],
#  'dude,': ['I', 'tall,'],
#  '“Excuse': ['me', 'me'],
#  'sir!”': ['He'],
#  'around,': ['and', 'that'],
#  'exactly': ['what', 'what', 'life'],
#  'did,': ['no', 'true'],
#  'exaggeration.': ['He'],
#  'turns': ['around'],
#  '“No': ['fucking', 'Brad,'],
#  'way.”': ['(audience'],
#  'Southwest': ['Airline'],
#  'Airline': ['logo,'],
#  'logo,': ['like,'],
#  '“Boop,': ['wanna'],
#  'away?”': ['Like'],
#  'telling': ['my', 'you'],
#  'story,': ['he'],
#  'why': ['don’t',
#   'don’t',
#   'we’re',
#   'the',
#   'do',
#   'I',
#   'would',
#   'should',
#   'all'],
#  '“just': ['use', 'don’t', 'dip'],
#  'regular': ['size', 'sized', 'sized', 'sized'],
#  'size': ['urinal?”', 'bag,', 'bag', 'of', 'up,'],
#  'Listen,': ['I', 'if', 'if'],
#  'love': ['to',
#   'this',
#   'that',
#   'racial',
#   'this',
#   'makin’',
#   'Asian',
#   'Asian',
#   'Indian',
#   'that',
#   'black',
#   'to',
#   'to',
#   'you.',
#   'you,',
#   'pussy…”',
#   'you',
#   'to'],
#  'sized': ['urinal.', 'urinal.', 'urinal,'],
#  'possess': ['the'],
#  'muscle': ['control'],
#  'control': ['necessary'],
#  'necessary': ['to'],
#  'urinal,': ['I', 'I'],
#  'pee,': ['shut', 'shut', 'shut'],
#  'shut': ['it', 'it', 'it', 'the'],
#  'off,': ['pee,', 'pee,', 'I', 'covered'],
#  'off.': ['I', '“Brad,', 'It'],
#  'that.': ['I',
#   'The',
#   'All',
#   'But',
#   'I',
#   'But',
#   'You',
#   'But',
#   'I',
#   'You',
#   'This',
#   'So',
#   'If',
#   'Okay,',
#   'And',
#   'When',
#   'Tonight,',
#   'Here’s',
#   '“So',
#   'So',
#   'Vin'],
#  'haven’t': ['done'],
#  'done': ['enough', '(scoffing),', 'that', '“and'],
#  'enough': ['kegels.', 'to'],
#  'kegels.': ['(audience'],
#  'nice': ['to', 'anymore.', 'about', 'I’m', 'about', 'titty', 'spot,'],
#  'said,': ['“Excuse', '“Be', '“Let’s', '“Here,', '“Actually', '“Anywhere.”'],
#  'sir.”': ['He'],
#  'anymore.': ['I’m'],
#  'not.': ['If', 'But'],
#  'ever': ['go',
#   'seen',
#   'heard',
#   'so',
#   'since',
#   'heard',
#   'going',
#   'taken',
#   'look',
#   'been',
#   'supposed'],
#  'fucks': ['and', 'with'],
#  'using': ['my'],
#  'will': ['go',
#   'tell',
#   'wait',
#   'hold.”',
#   'meet',
#   'finally',
#   'and',
#   'work.',
#   'make',
#   'say',
#   'check',
#   'not',
#   'still',
#   'never',
#   'look'],
#  'full': ['R.'],
#  'R.': ['Kelly'],
#  'Kelly': ['on'],
#  'leg,': ['all'],
#  'part': ['about', 'is', 'of', 'of', 'of'],
#  'lot.': ['Like'],
#  'past': ['three', 'that'],
#  'years,': ['I'],
#  '48': ['weeks'],
#  'weeks': ['a', 'ago,', 'ago,'],
#  'year.': ['So'],
#  'burned': ['out.', 'out,'],
#  'out,': ['that', 'that', 'I', 'he', '“should', 'Brad.', 'look'],
#  'job': ['just', 'as', 'like,', 'was'],
#  'bit.': ['I'],
#  'DJ': ['in', 'on'],
#  'San': ['Francisco,', 'Francisco', 'Francisco', 'Francisco'],
#  'Francisco,': ['California'],
#  'morning': ['show.', 'show', 'show.'],
#  'show.': ['Don’t', 'Obviously,', 'Angry,', 'She’s', 'Great,'],
#  'cheer.': ['I'],
#  'lasted': ['six'],
#  'months,': ['then'],
#  'fired.': ['I', 'You'],
#  'tell': ['you',
#   'you',
#   'racial',
#   'you',
#   'you',
#   'me',
#   'her',
#   'you,',
#   'it',
#   'right',
#   'at',
#   'you',
#   'you.',
#   'you.',
#   'you',
#   'a',
#   'me,',
#   'those'],
#  'happened.': ['They', '(chuckling)', 'But'],
#  'Google.': ['This'],
#  'show': ['DJ', 'you'],
#  'show,': ['I'],
#  'sports': ['guy', 'guy.'],
#  'Obviously,': ['you', 'you’ve'],
#  '“there’s': ['a'],
#  'dude': ['who', 'laugh', 'and', 'and', 'but', 'and'],
#  'who': ['got', 'they', 'are', 'the', 'gives', 'are', 'do', 'raised', 'I'],
#  'picked': ['first', 'me'],
#  'first': ['“for',
#   'time',
#   'place.',
#   'time.',
#   'of',
#   'time,',
#   'time',
#   'electric'],
#  '“for': ['every'],
#  'growin’': ['up.”'],
#  'up.”': ['I’m'],
#  'While': ['I'],
#  'there,': ['the', 'I’ll', 'it’s', 'that’s', 'like,'],
#  'Francisco': ['Giants', 'Giants.', 'Giants.'],
#  'Giants': ['won', 'team', 'on'],
#  'won': ['the'],
#  'World': ['Series.'],
#  'Series.': ['Now,'],
#  'Giants.': ['So', 'You'],
#  'air': ['the', 'the', 'tomorrow,', 'and'],
#  'yeah!': ['I'],
#  'talk': ['a', 'about', 'about', 'to'],
#  'bunch': ['of'],
#  'know,': ['make', 'classy', 'things', 'I', 'when', 'it’s', 'I', 'I', '“they'],
#  'reference': ['to'],
#  'couple': ['players', 'of', 'of'],
#  'players': ['that'],
#  'cheating': ['on'],
#  'their': ['wives.',
#   'kids',
#   'kids.',
#   'four-year-old',
#   'women,',
#   'XBox',
#   'self',
#   'children'],
#  'wives.': ['You'],
#  'classy': ['stuff.'],
#  'stuff.': ['They'],
#  'radio': ['station,'],
#  'station,': ['just'],
#  '“If': ['that', 'every', 'you', 'it'],
#  'fired,': ['“suspended,'],
#  '“suspended,': ['or'],
#  'apologizes,': ['“we’re'],
#  '“we’re': ['pulling', 'going'],
#  'pulling': ['all'],
#  'our': ['funding', 'heart,', 'tall', 'heads.'],
#  'funding': ['from'],
#  'station.”': ['The'],
#  'station': ['panics,'],
#  'panics,': ['they'],
#  'call': ['me', 'more', 'a', 'to'],
#  'meeting.': ['They’re'],
#  'They’re': ['like,', 'like,', 'like,', 'not', 'taught', 'like,', 'like,'],
#  'tomorrow,': ['“say'],
#  '“say': ['something'],
#  'Giants.”': ['I’m'],
#  '“Nope.': ['“Not'],
#  '“Not': ['gonna'],
#  '“No?”': ['(cheering)'],
#  '(cheering)': ['They’re', 'Same', 'I’m'],
#  '“Just': ['go', 'don’t', 'old'],
#  '“That’s': ['never', 'a', 'what', 'what', 'my'],
#  'happen.”': ['They’re'],
#  '“What?': ['“‘Cause', '“How'],
#  '“‘Cause': ['you’re'],
#  '“and': ['you’re', 'I’m', 'I', 'men', 'then,', 'they’ll', 'they’ll', 'at'],
#  'Dodger': ['fan?”'],
#  'fan?”': ['I’m'],
#  'am,': ['but', 'I’m'],
#  'it.”': ['Nothing', '“Alright,', 'So'],
#  'professional.': ['They'],
#  '“Well,': ['why', 'you', 'hit'],
#  '“anything': ['nice'],
#  'Giants?”': ['It’s'],
#  '“Because': ['I’m'],
#  'midget!': ['“I’m', 'I’d'],
#  'wear': ['a', 'a'],
#  'jersey': ['“that', 'that'],
#  '“that': ['says', 'makes'],
#  'says': ['Giants',
#   'cops.',
#   '“he',
#   'that,',
#   'You’re',
#   'that',
#   'this,',
#   'must',
#   'must'],
#  'asshole!”': ['(audience'],
#  'Realize': ['that?'],
#  'that?': ['I’m', 'Fuck', 'And', 'What?', 'What', '“Is', 'Do', 'You'],
#  'support': ['something', 'each', 'black', 'transgender', 'you.'],
#  'trying': ['to', 'to', 'to', 'to'],
#  'kill': ['me', 'you', 'you'],
#  'life.': ['No', 'Even', 'I', 'All', 'Didn’t', 'You', 'We', 'That'],
#  'else': ['would', 'from'],
#  'ever.': ['A', 'They', 'Now,'],
#  'A': ['black', 'black', 'black', 'lot', 'man’s', 'lot', 'line'],
#  'black': ['guy',
#   'people',
#   'people',
#   'guy',
#   'guy',
#   'guy',
#   'guys',
#   'guy',
#   'dude',
#   'male,',
#   'kids.',
#   'kids,',
#   'hair,',
#   'hair.',
#   'woman?”',
#   'people,',
#   'culture,',
#   'woman?”',
#   'woman,',
#   'woman',
#   'woman?',
#   'woman.',
#   'woman',
#   'woman.',
#   'on',
#   'person.”',
#   'person.',
#   'ass',
#   'ass.',
#   'ass.',
#   'midget!',
#   'midget.',
#   'dudes',
#   'dudes'],
#  'cops.': ['(audience'],
#  'okay.': ['That’s',
#   'And',
#   'It’s',
#   'Nothing,',
#   'Whatever',
#   'Obviously,',
#   'Never,',
#   '–',
#   'I',
#   'If'],
#  'tester': ['joke.', 'joke.'],
#  'joke.': ['Good', 'Some', 'She’s', 'She'],
#  'Good': ['tester'],
#  'laughed,': ['some'],
#  'didn’t,': ['that’s', 'he'],
#  'fine.': ['You', 'But'],
#  'jokes': ['you', 'in', '“but'],
#  'yourself.': ['You’re'],
#  'You’re': ['white.', 'a', 'a', 'supposed', 'lying,', 'Special.”'],
#  'white.': ['(audience'],
#  'Guarantee': ['you.'],
#  'racial': ['jokes', 'jokes.', 'issues.', 'issues,'],
#  'general.': ['They’re'],
#  'afraid': ['of', 'of', 'of'],
#  'them': ['like', 'doing', 'titties.', 'in', 'but', 'a', 'forever.'],
#  'white': ['people.',
#   'people,',
#   'people',
#   'people.',
#   'kids',
#   'kids,',
#   'people',
#   'in',
#   'in',
#   'woman',
#   'woman.',
#   'woman,',
#   'hair.',
#   'bitch.”',
#   'suburban',
#   'on',
#   'people.'],
#  'people.': ['White', 'You’ll', 'I', 'And', 'Please', 'I'],
#  'White': ['people', 'people', 'kids', 'people,'],
#  'scared': ['to', 'and', 'because'],
#  'jokes.': ['Black'],
#  'aren’t.': ['You’ve'],
#  'You’ve': ['never', 'never'],
#  '“Hey': ['guys,', 'Brad,', 'Katie,'],
#  'guys,': ['I’ve', 'the'],
#  'I’ve': ['got', 'ever', 'been', 'been'],
#  'a…”': ['“Cracker'],
#  '“Cracker': ['joke'],
#  'now.”': ['No!', 'I'],
#  'No!': ['A'],
#  'wait': ['until'],
#  'until': ['he'],
#  'surrounded': ['by'],
#  'maximum': ['number'],
#  'number': ['of'],
#  'crackers': ['before'],
#  'before': ['He’ll', 'they'],
#  'He’ll': ['call'],
#  'over.': ['“Richard,', 'You'],
#  '“Richard,': ['get'],
#  'people,': ['we', 'they’re', 'all', '“I', 'no.', 'that'],
#  'hold': ['it', 'it', 'it', 'it', 'it', 'it', 'in', 'in'],
#  'in.': ['We', 'White', 'I', 'We'],
#  'We': ['hold',
#   'can',
#   'found',
#   'did.',
#   'have',
#   'gotta',
#   'both',
#   'all',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'will',
#   'already',
#   'do,',
#   'are',
#   'see',
#   'don’t',
#   'want',
#   'look',
#   'just',
#   'live',
#   'just'],
#  'trouble.': ['So', 'I'],
#  'day': ['with', 'of', 'of', 'that', 'have'],
#  'voice': ['in'],
#  'heart,': ['like,'],
#  '“Don’t': ['say', 'look,'],
#  '“don’t': ['say', 'get'],
#  'busted.': ['We'],
#  'apologize': ['for'],
#  'issues.': ['There’s'],
#  'celebrity': ['who’s'],
#  'who’s': ['gotta', 'back'],
#  'press': ['conference'],
#  'conference': ['and'],
#  'African': ['American'],
#  'American': ['community.'],
#  'community.': ['“I'],
#  'meant': ['nothing'],
#  'ordered': ['the'],
#  'salmon': ['blackened.”'],
#  'blackened.”': ['(audience'],
#  'in,': ['and', 'hold', 'it’s'],
#  'effects': ['other'],
#  'parts': ['of'],
#  'Even': ['something', 'more'],
#  'basic': ['as'],
#  'laughter.': ['Because'],
#  'want': ['to',
#   'equality.',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'you',
#   'to',
#   'to',
#   'to',
#   'to',
#   'that.',
#   'you',
#   'you',
#   'to',
#   'me',
#   'to.”',
#   'to',
#   'you',
#   'to',
#   'to,',
#   'to',
#   'to',
#   'to',
#   'to',
#   'your',
#   'your',
#   'your',
#   'your',
#   'that',
#   'to',
#   'to',
#   'to'],
#  'caught': ['laughing'],
#  'laughing': ['at', '’cause'],
#  'wrong': ['joke,', 'with', 'with', 'ladies,', 'for'],
#  'ADD,': ['it’s'],
#  'just,': ['“Ha', '“Hey!'],
#  '“Ha': ['ha!”', 'ha,', 'ha,'],
#  'ha!”': ['And'],
#  'stop.': ['You'],
#  'no.': ['I', 'My', '“This', 'I’m', 'I'],
#  'makin’': ['black'],
#  'laugh.': ['You', 'It', 'Some'],
#  'laugh,': ['he'],
#  'puts': ['everything'],
#  'everything': ['he',
#   'to',
#   'that',
#   'better.',
#   'changed',
#   'goes',
#   'better.',
#   'better!',
#   'better!',
#   'look'],
#  'Body,': ['soul.'],
#  'soul.': ['Black'],
#  'burn': ['calories', 'a'],
#  'calories': ['when'],
#  '“Ohhh': ['shit!”'],
#  'shit!”': ['(audience', 'Okay,'],
#  '“That': ['is', 'was'],
#  'funniest': ['thing', 'joke'],
#  'heard': ['“in', 'that', 'you'],
#  '“in': ['my'],
#  'life!”': ['Try'],
#  'Try': ['it,'],
#  'You’ll': ['like', 'try,', 'never', 'never'],
#  'wrong,': ['you’re', 'never', 'he’s'],
#  'First': ['time', 'day'],
#  'you’ll': ['be'],
#  '“Golly': ['gee'],
#  'gee': ['willickers!”'],
#  'willickers!”': ['(audience'],
#  'humorous': ['anecdote.”'],
#  'anecdote.”': ['(audience'],
#  'we’re': ['not',
#   'talking,',
#   'all',
#   'just',
#   'having',
#   'freaky.',
#   'freaks.',
#   'just',
#   'all',
#   'taking',
#   'arguing,',
#   'having',
#   'arguing',
#   'getting',
#   'ready.'],
#  'certain': ['things.'],
#  'things.': ['It'],
#  'doesn’t': ['make',
#   'effect',
#   'change',
#   'affect',
#   'have',
#   'care.',
#   'feel',
#   'live',
#   'matter,',
#   'matter,'],
#  'sense': ['to', 'of', 'of', 'of'],
#  'opinion,': ['when', 'your'],
#  'issues,': ['when'],
#  'discussion,': ['that’s'],
#  'learn.': ['That’s'],
#  'gain': ['a'],
#  'greater': ['appreciation.'],
#  'appreciation.': ['You'],
#  'learn': ['and', 'something'],
#  'appreciate': ['other'],
#  'cultures.': ['Like', 'Like'],
#  'Asian': ['people.', 'people', 'buddy', 'people.', 'women.', 'women'],
#  'now.': ['Because', '“I', '“But', 'That’s'],
#  'yes,': ['two', 'perfect.'],
#  'buddy': ['called'],
#  'asked': ['me', 'me,', 'his', 'me,', 'her,'],
#  'help': ['to', '“with', 'me.', 'me', 'me,'],
#  'fix': ['his', 'my'],
#  'iPhone.': ['(audience'],
#  'Think': ['about'],
#  'second,': ['okay?'],
#  'could': ['have', 'please', 'tell', 'do', 'we', 'fall', 'be'],
#  'cousin.': ['His'],
#  'cousin': ['built'],
#  'built': ['the'],
#  'made': ['me',
#   'me',
#   'fun',
#   'fun',
#   'the',
#   'a',
#   'my',
#   'him',
#   '“another',
#   'fun',
#   'fun',
#   'fun'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(brad_dict)
# Out:
# 'Francisco, California “and they’ll want that. All of Purell, “just use the old school parents.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
brian_text = data.transcript.loc['brian']
brian_text[:200]
# Out:
# 'Filmed in 2020 at the Tuacahn outdoor amphitheater, Utah. [upbeat rock music plays] [crowd cheering, applauding] [announcer] Ladies and gentlemen, please welcome Brian Regan! [audience cheering, whist'

# %%
brian_dict = markov_chain(brian_text)
brian_dict
# Out:
# {'Filmed': ['in'],
#  'in': ['2020',
#   'the',
#   'hair',
#   'that',
#   'the',
#   'the',
#   'the',
#   'the',
#   'for',
#   'a',
#   'agony.',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'order',
#   'there',
#   'the',
#   'calendars',
#   'the',
#   'the',
#   'addition',
#   'the',
#   'river',
#   'a',
#   'that',
#   'with',
#   'our',
#   'relation',
#   'a',
#   'the',
#   'my',
#   'the',
#   'life…',
#   'the',
#   'concert.',
#   'microscopes.',
#   'its',
#   'the',
#   'the',
#   'my',
#   'trouble!”',
#   'question.”',
#   'prison',
#   'his',
#   'his',
#   'this',
#   'his',
#   'this',
#   'his',
#   'my',
#   'the',
#   'the',
#   'the',
#   'front',
#   'my',
#   'the',
#   'a',
#   'in',
#   'gowns',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'this',
#   'blimps',
#   'and',
#   'the',
#   'it!',
#   'a',
#   'and',
#   'the'],
#  '2020': ['at'],
#  'at': ['the',
#   'the',
#   'me',
#   'least',
#   'home?”',
#   'the',
#   'a',
#   'the',
#   'five',
#   'this',
#   'the',
#   'the',
#   'that',
#   'me',
#   'that',
#   'my',
#   'me.',
#   'the',
#   'night.',
#   'that.”',
#   '7:00',
#   'that',
#   'it.',
#   'this.',
#   'that',
#   'the'],
#  'the': ['Tuacahn',
#   'gray',
#   'way.',
#   'gray',
#   'hair-color',
#   'difference',
#   'entire',
#   'age',
#   'first',
#   'dermatologist.',
#   'drugstore',
#   'proper',
#   'tip',
#   'tip',
#   'pain.',
#   'size',
#   'house.',
#   'house?',
#   'human',
#   'animal',
#   'hardest',
#   'world.',
#   'bighorn',
#   'American',
#   'best',
#   'world.',
#   'clipboard?',
#   'neck.',
#   'table?”',
#   'doughnut',
#   'protocol…',
#   'concept.”',
#   'word',
#   'ground',
#   'choir!”',
#   'top',
#   'bottom',
#   'books',
#   'completion',
#   'middle',
#   'books',
#   'process',
#   'top',
#   'middle',
#   'start',
#   'title',
#   'book…',
#   'process',
#   'top',
#   'middle',
#   'way',
#   'introduction,',
#   'foreword,',
#   'book',
#   'way',
#   'bottom.',
#   'middle',
#   'page.',
#   'sentence',
#   'thought,',
#   'page',
#   'middle',
#   'right.',
#   'ones',
#   'symptoms.',
#   'number',
#   'type',
#   'stove',
#   'type',
#   'stove.',
#   'whole',
#   'bookstore,',
#   'clerk,',
#   'self-help',
#   'section.',
#   'next',
#   'new',
#   'months',
#   'bottom.',
#   '31st',
#   '24th:',
#   'hell',
#   'top',
#   'next',
#   'corner',
#   'diagonal',
#   'Eastern',
#   'Pacific',
#   'Eastern',
#   'voice',
#   'time',
#   'time.',
#   'formula?',
#   'world.',
#   'lines',
#   'top,',
#   'pole',
#   'OCD,',
#   'time.',
#   'Jeng-man',
#   '‘Mongo-lian',
#   '‘con-kerer’',
#   'others',
#   'hit',
#   'plate',
#   'dynamic.',
#   'SAT',
#   '“ha-ha-ha.”',
#   'temperature',
#   'beavers?”',
#   'beavers?”',
#   'beavers?”',
#   'beavers?”',
#   'beavers?”',
#   'beavers?”',
#   'water,',
#   'sticks',
#   'flow',
#   'surface',
#   'water…',
#   'riverbank:',
#   'honeybees?”',
#   'honeybees?”',
#   'honeybees?”',
#   'honeybees?”',
#   'honeybees',
#   'other',
#   'flowers',
#   'fridge',
#   'lottery',
#   '2,',
#   '4',
#   'first',
#   '5',
#   'second',
#   'second',
#   'last',
#   'second',
#   'story',
#   '2',
#   '4',
#   'first',
#   'second,',
#   '6',
#   'third.',
#   '18.”',
#   '19.”',
#   'last',
#   'third',
#   '2.”',
#   '2.”',
#   '2.”',
#   'street',
#   '2.”',
#   '4,',
#   'other',
#   "3.'”",
#   '3.',
#   '44.”',
#   '44',
#   "44.'”",
#   'right',
#   'fire',
#   'proper',
#   'tickets',
#   'end.”',
#   'tables.”',
#   'groups.',
#   'beginning',
#   'factory',
#   'mashed',
#   'big',
#   'problem.',
#   'menu.”',
#   'kitchen,',
#   'degree',
#   'broiling',
#   'point',
#   'degree',
#   'word',
#   'rest',
#   'letters',
#   'expression',
#   'sweet',
#   'cat’s',
#   'smallest?',
#   'planet',
#   'message',
#   'rocks',
#   'way',
#   'scientists',
#   'end',
#   'moisture',
#   'front:',
#   'wheels:',
#   'moon.',
#   'equation.”',
#   'reason',
#   'numbers…',
#   'crime…',
#   'time.”',
#   'time.”',
#   'motto',
#   'crime…',
#   'federal',
#   'time!”',
#   'other',
#   'county',
#   'actual',
#   'scope',
#   'crime',
#   'crime.',
#   'scene',
#   'fingerprints',
#   'crime',
#   'possibility',
#   'evidence.”',
#   'lead',
#   'most',
#   'hat,',
#   'news,\xa0\xa0a',
#   'case?',
#   'defendant',
#   'stand',
#   'judge',
#   'jury',
#   'defendant',
#   'stand',
#   'other',
#   'rest',
#   'evidence.”',
#   'need',
#   'judge',
#   'defendant',
#   'stand',
#   'stand',
#   'electric',
#   'chair,',
#   'morning.',
#   'night',
#   'rack.”',
#   'face.',
#   'emergency',
#   'flight',
#   'line',
#   'other',
#   'back',
#   'head.',
#   'ravine,',
#   'harness',
#   'harness',
#   'woods.',
#   'horse',
#   'tree',
#   'woods.',
#   'orchestra.',
#   'pit!',
#   'pit!”',
#   'pit!”',
#   'pit!”',
#   'end',
#   'show,',
#   'actor',
#   'difference.”',
#   'actor',
#   'character?',
#   'others',
#   'otter?”',
#   'tuba',
#   'bagpipes…',
#   'patent',
#   'world',
#   'pipes',
#   'best.”',
#   'bag.'],
#  'Tuacahn': ['outdoor'],
#  'outdoor': ['amphitheater,'],
#  'amphitheater,': ['Utah.'],
#  'Utah.': ['[upbeat'],
#  '[upbeat': ['rock'],
#  'rock': ['music'],
#  'music': ['plays]', 'playing]', 'continues]'],
#  'plays]': ['[crowd'],
#  '[crowd': ['cheering,'],
#  'cheering,': ['applauding]', 'whistling]', 'whistling'],
#  'applauding]': ['[announcer]',
#   '[audience',
#   '“I’ve',
#   '[Brian',
#   '“My',
#   'So',
#   'I',
#   'How',
#   'Well,',
#   'I’ll',
#   'I',
#   '[woman',
#   'Smart.',
#   '[audience',
#   'If',
#   'I',
#   '[in',
#   'Hey,',
#   '[audience',
#   'They',
#   'If',
#   'If',
#   'Seriously.',
#   'This',
#   'Amazing.',
#   'Makes',
#   '[imitates'],
#  '[announcer]': ['Ladies'],
#  'Ladies': ['and'],
#  'and': ['gentlemen,',
#   'came',
#   'cheering]',
#   'men',
#   'a',
#   'I',
#   'he’s',
#   'said,',
#   'throat',
#   'I',
#   'all',
#   'throat',
#   'applauding]',
#   'whistling]',
#   'microchips.',
#   'don’t',
#   'tension',
#   'rage',
#   'downright',
#   'applauding]',
#   'you’re',
#   'stay',
#   'one',
#   'it’s',
#   'applauding]',
#   'applauding]',
#   'it’s',
#   'I',
#   'applauding]',
#   'applauding]',
#   'some',
#   'divide',
#   'over',
#   'I',
#   'averaged',
#   'applauding]',
#   'applauding]',
#   'time.',
#   'saw',
#   'I',
#   'walk',
#   'applauding,',
#   'stuff,',
#   'the',
#   'applauding]',
#   'trying',
#   'says,',
#   'they',
#   'bring',
#   'they',
#   'slap',
#   'they',
#   'applauding]',
#   'they',
#   'they',
#   'started',
#   'wiggle',
#   'it',
#   'applause]',
#   'he',
#   'a',
#   '6',
#   'get',
#   'the',
#   'applauding]',
#   'rearranged',
#   'applauding]',
#   'into',
#   'applauding]',
#   'put',
#   'gave',
#   'applauding]',
#   'applauding]',
#   'applauding]',
#   'shoot',
#   'pass',
#   'cheering]',
#   'fill',
#   'desolate.”',
#   'I’ve',
#   'right.”',
#   'applauding]',
#   'dreams.”',
#   'getting',
#   'gotten',
#   'cheering]',
#   'applauding]',
#   'applauding]',
#   'you',
#   'applauding]',
#   'all',
#   'applause]',
#   'chains,',
#   'harnesses,',
#   'figure',
#   'get',
#   'going',
#   'soon',
#   'go,',
#   'applause]',
#   'applauding]',
#   'applauding]',
#   'tuxedos.',
#   'bow.',
#   'low',
#   'stuff',
#   'applauding]',
#   'start',
#   'trying',
#   'stuff!”',
#   'applause]',
#   'threw',
#   'out'],
#  'gentlemen,': ['please'],
#  'please': ['welcome'],
#  'welcome': ['Brian'],
#  'Brian': ['Regan!'],
#  'Regan!': ['[audience'],
#  '[audience': ['cheering,',
#   'cheering]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'clapping',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing,',
#   'laughing]',
#   'laughing,',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'cheering',
#   'laughing]',
#   'applauding]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'cheering',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'cheering,',
#   'laughs]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'applauding]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'cheering]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'laughing',
#   'cheering]',
#   'laughing]',
#   'cheering]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'applauding',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering',
#   'cheering',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'applauding]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'laughing]',
#   'cheering]'],
#  'whistling]': ['Thank', 'My', 'They'],
#  'Thank': ['you.',
#   'you',
#   'you.',
#   'you',
#   'you.',
#   'you.',
#   'you.”',
#   'you',
#   'you.',
#   'you'],
#  'you.': ['Thank',
#   'Thank',
#   '[audience',
#   'If',
#   'Thank',
#   'Thank',
#   '“Wouldn’t',
#   '[bagpipe'],
#  'you': ['very',
#   'very,',
#   'won’t',
#   'know',
#   'find',
#   'intrigued,',
#   'could',
#   'have',
#   'are',
#   'another',
#   'can',
#   'can',
#   'have',
#   'distinguish',
#   'want',
#   'the',
#   'the',
#   'tell',
#   'try',
#   'one',
#   'don’t',
#   'put',
#   'plan',
#   'were',
#   'hired',
#   'be',
#   'where',
#   'with',
#   'don’t',
#   'know',
#   'can',
#   'got',
#   'can’t',
#   'flipped',
#   'never',
#   'ordered.”',
#   'love',
#   'like',
#   'like',
#   'like',
#   'like',
#   'concur.”',
#   'concur',
#   'do',
#   'can’t',
#   'can’t',
#   'doing?”',
#   'crazy?”',
#   'commit',
#   'were',
#   'get',
#   'do',
#   'knucklehead.”',
#   'to',
#   'want',
#   'didn’t',
#   'in',
#   'could',
#   'want',
#   'what',
#   'sit',
#   'agree',
#   'might',
#   'were',
#   'guys',
#   'see',
#   'very',
#   'go',
#   'all',
#   'wonder,',
#   'sit',
#   'were',
#   'tell',
#   'guys',
#   'very',
#   'so'],
#  'very': ['much,',
#   'much.',
#   'peculiar.',
#   'quickly',
#   'strong',
#   'much.”',
#   'much.'],
#  'much,': ['everybody.'],
#  'everybody.': ['[audience'],
#  'cheering]': ['Thank',
#   'It’s',
#   'So',
#   '[man]',
#   'Losing',
#   'No,',
#   'I',
#   'We',
#   'I',
#   'Thank'],
#  'very,': ['very'],
#  'much.': ['Well,', 'Thank', 'You'],
#  'Well,': ['let’s', 'the', 'I', 'in', 'I', 'I', 'everyone', 'this'],
#  'let’s': ['get', 'get', 'march.”'],
#  'get': ['the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'in',
#   'that',
#   'the',
#   'the',
#   'out',
#   'us',
#   'to',
#   'some',
#   'down',
#   'the',
#   'close',
#   'the',
#   'to',
#   'here?”'],
#  'gray': ['hair', 'hair?”'],
#  'hair': ['out', 'color', 'color', 'color:'],
#  'out': ['of',
#   'there,',
#   'a',
#   'your',
#   'of',
#   'whether',
#   'of',
#   'there,',
#   'for',
#   'the',
#   'of',
#   'of',
#   'like',
#   'very',
#   'of',
#   'of',
#   'of',
#   'of',
#   'capital',
#   'how',
#   'while',
#   'from',
#   'of'],
#  'of': ['the',
#   'that',
#   'a',
#   'my',
#   'your',
#   'a',
#   'all',
#   'bar',
#   'coming',
#   'the',
#   'reading.”',
#   'the',
#   'reading',
#   'page',
#   'that',
#   'page',
#   'a',
#   'my',
#   'symptoms.',
#   'person',
#   'person',
#   'here!”',
#   'the',
#   'those',
#   'a',
#   'squished',
#   'here.”',
#   'strangers.',
#   '‘Cheena’?”',
#   'it',
#   'a',
#   'muddy',
#   'their',
#   'the',
#   'them',
#   'flame',
#   'the',
#   'the',
#   'this.',
#   'that',
#   'mushrooms,',
#   'unrecognizability…',
#   'the',
#   'stuff',
#   'time.',
#   'the',
#   'oomph.',
#   'the',
#   'this',
#   'crime.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'here!”',
#   'everything.”',
#   'that?',
#   'the',
#   'parole.”',
#   'the',
#   'here,',
#   'the',
#   'something.',
#   'throwing',
#   'me!”',
#   'that.',
#   'outstanding.”',
#   'the',
#   'some',
#   'the',
#   'money',
#   'the',
#   'musicians',
#   'it!”'],
#  'way.': ['[audience'],
#  'laughing]': ['Because',
#   'I',
#   '[audience',
#   'I',
#   'Black!',
#   'Ah,',
#   '[chuckles]',
#   'Are',
#   'I',
#   'So',
#   'And',
#   'I',
#   'Or',
#   'I',
#   'The',
#   '“Go',
#   'I’m',
#   '“But',
#   '“I’d',
#   'So',
#   '“My',
#   'So',
#   '“Suffer”',
#   '“I',
#   '“Quit',
#   'The',
#   '“And',
#   '“And',
#   'I',
#   'You',
#   'I',
#   'If',
#   'Number',
#   'Number',
#   'So',
#   'I',
#   'So',
#   '“Get',
#   'I’ve',
#   'Oh!',
#   'I',
#   'Uh,',
#   'When?',
#   '“Where',
#   'I',
#   '“I',
#   'I',
#   'I’m',
#   'Well,',
#   'I’ve',
#   '“I',
#   'I',
#   '“Low-hanging',
#   'But',
#   '[woman]',
#   'I',
#   'But',
#   'Forcing',
#   'There',
#   'Except',
#   'So',
#   'Hoover',
#   'Human',
#   'So',
#   'Well,',
#   'And',
#   '“What',
#   '[chuckles]',
#   '“What',
#   '[cheering',
#   'With',
#   '“Jengus”',
#   'Walk',
#   'I’m',
#   '“Third',
#   '“I',
#   '“I',
#   '“Anyway…',
#   'So',
#   'So',
#   'When',
#   '“Woo-hoo!”',
#   '“What',
#   '“Whoa!”',
#   '“What',
#   '“Could',
#   'So',
#   'Sitting',
#   '“You',
#   'My',
#   '“No,',
#   '[woman',
#   'There',
#   '…that',
#   '…with',
#   'I',
#   'People',
#   '…do',
#   'Here',
#   '…raisins…',
#   '“Oh.”',
#   '“I',
#   '“You',
#   '“Well?”',
#   'I',
#   'It',
#   'But',
#   '“You',
#   '“Capital',
#   '…and',
#   'When',
#   'So',
#   'I',
#   '“Pajamas”',
#   'Kind',
#   'Scientists',
#   '“Professor,',
#   'How',
#   '“The',
#   'I',
#   'So',
#   '[audience',
#   'If',
#   'Even',
#   'We’re',
#   'I',
#   '“How’s',
#   'They’re',
#   'And',
#   'The',
#   'We’re',
#   'I',
#   'One',
#   '“The',
#   '…it',
#   '“Sure,',
#   'Another',
#   '[audience',
#   '[yells]',
#   '“I',
#   '“I',
#   '“I’m',
#   '“I',
#   'Talk',
#   'Tampering',
#   '“That’s',
#   '“You’re',
#   'You’re',
#   '…we',
#   '“In',
#   'How',
#   '“Get',
#   '[clearing',
#   'I',
#   '“I',
#   '“I’ll',
#   '“Fire',
#   'Is',
#   'I’ll',
#   '[imitating',
#   'You',
#   '…how',
#   '[cheers',
#   'I',
#   'Then',
#   'Am',
#   'I’m',
#   'Turn',
#   '[cheering',
#   '“Just',
#   '“Stupid',
#   'The',
#   'Why',
#   'At',
#   '[imitates',
#   '“Paid',
#   '[imitates',
#   'What',
#   '[audience',
#   'I',
#   'You',
#   '“Why',
#   'Yes,',
#   '“Hey,',
#   '…so',
#   '“Great',
#   '[imitates',
#   '[cheering',
#   'You',
#   '“What',
#   '“No,',
#   '“Why?”',
#   '“What',
#   '“What',
#   'What',
#   'How',
#   'This',
#   'Hey,'],
#  'Because': ['if', 'of'],
#  'if': ['I',
#   'you',
#   'I',
#   'I',
#   'one',
#   'your',
#   'I',
#   'I',
#   'I',
#   'you',
#   'you',
#   'they',
#   'there’s',
#   'there',
#   'it',
#   'you',
#   'I',
#   'you',
#   'I',
#   'it',
#   'you',
#   'anybody’s'],
#  'I': ['don’t,',
#   'say',
#   'don’t',
#   'went',
#   'was',
#   'like',
#   'don’t',
#   'wake',
#   'do',
#   'don’t',
#   'have',
#   'say,',
#   'got',
#   'was',
#   'said,',
#   'go',
#   'said,',
#   'want',
#   'vowed',
#   'haven’t',
#   'went\xa0',
#   'went',
#   'have',
#   'have',
#   'am',
#   'check',
#   'never',
#   'could',
#   'got',
#   'think',
#   'said,',
#   'supposed',
#   'said,',
#   'learned',
#   'suffer',
#   'look',
#   'think',
#   'allowed',
#   'am,',
#   'got',
#   'start',
#   'move',
#   'organize',
#   'know',
#   'do',
#   'make',
#   'allow',
#   'don’t',
#   'do',
#   'make',
#   'make',
#   'finish',
#   'turn',
#   'write',
#   'move',
#   'don’t',
#   'first',
#   'might',
#   'Googled',
#   'have,',
#   'don’t.',
#   'have,',
#   'have',
#   'decided',
#   'wish',
#   'was',
#   'listed',
#   'said',
#   'feel',
#   'have',
#   'am',
#   'had',
#   'forgot',
#   'looked',
#   'did',
#   'scribbled',
#   'got',
#   'went',
#   'checked',
#   'came',
#   'changed',
#   'took',
#   'decided',
#   'go',
#   'ask',
#   'finally',
#   'spent',
#   'have',
#   'get',
#   'always',
#   'don’t',
#   'squeeze',
#   'grew',
#   'now',
#   'know',
#   'am.',
#   'have',
#   'was',
#   'looked',
#   'thought,',
#   'also',
#   'force',
#   'don’t',
#   'walk',
#   'hear,',
#   'go,',
#   'wanted',
#   'was',
#   'felt',
#   'don’t',
#   'don’t',
#   'don’t',
#   'walk',
#   'look',
#   'could',
#   'couldn’t',
#   'didn’t',
#   'don’t',
#   'decided',
#   'said,',
#   'didn’t',
#   'just',
#   'can’t',
#   'could',
#   'asked',
#   'looked',
#   'just',
#   'got,',
#   'picked',
#   'had',
#   'had',
#   'got',
#   'picked',
#   'always',
#   'had',
#   'got',
#   'got',
#   'got',
#   'got',
#   'knew',
#   'had',
#   'got',
#   'get',
#   'wanted',
#   'was',
#   'didn’t',
#   'just',
#   'do',
#   'need',
#   'need',
#   'was',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'did',
#   'don’t',
#   'made',
#   'don’t',
#   'don’t',
#   'just',
#   'like',
#   'love',
#   'put',
#   'do',
#   'like',
#   'could',
#   'could',
#   'couldn’t',
#   'found',
#   'wasn’t',
#   'didn’t',
#   'would',
#   'would',
#   'saw',
#   'changed',
#   'saw',
#   'saw',
#   'saw',
#   'tweet,',
#   'never',
#   'also',
#   'saw',
#   'wanted',
#   'didn’t',
#   'also',
#   'settled',
#   'think',
#   'hit',
#   'was',
#   'like',
#   'love',
#   'saw',
#   'want',
#   'discovered.”',
#   'pull',
#   'have',
#   'was',
#   'didn’t',
#   'remember',
#   'was',
#   'love',
#   'don’t',
#   'don’t',
#   'want',
#   'want',
#   'could,',
#   'have',
#   'have',
#   'have',
#   'think',
#   'think',
#   'saw',
#   'understand',
#   'think',
#   'think',
#   'can’t',
#   'was',
#   'heard',
#   'think',
#   'heard',
#   'like',
#   'know',
#   'would',
#   'wouldn’t',
#   'would',
#   'asking',
#   'scrub',
#   'needed',
#   'know.”',
#   'wouldn’t',
#   'get',
#   'play',
#   'never',
#   'don’t',
#   'understand',
#   'don’t',
#   'got',
#   'don’t',
#   'too',
#   'see'],
#  'don’t,': ['you'],
#  'won’t': ['listen'],
#  'listen': ['to'],
#  'to': ['a',
#   'pretend',
#   'remember',
#   'that',
#   'sound',
#   'put',
#   'the',
#   'do',
#   'hurt.”',
#   'numb',
#   'puncture',
#   'my',
#   'get',
#   'it,',
#   'an',
#   'an',
#   'be',
#   'this',
#   'fix',
#   'get',
#   'be',
#   'what',
#   'say,',
#   'pay',
#   'run',
#   'him?',
#   'the',
#   'alphabetize',
#   'count',
#   'alphabetize',
#   'alphabetize',
#   'alphabetize',
#   'the',
#   'the',
#   'complete',
#   'the',
#   'alphabetize',
#   'make',
#   'rate',
#   '10',
#   'check',
#   'make',
#   'wash',
#   'answer',
#   'go',
#   '2.',
#   'buy',
#   'find',
#   'share',
#   'be',
#   'the',
#   'you.',
#   'be',
#   'dump.”',
#   'compute',
#   'be',
#   'the',
#   'go',
#   'parties',
#   'try',
#   'sound',
#   'this',
#   'sound',
#   'this',
#   'do',
#   'do',
#   'take',
#   'the',
#   'figure',
#   'make',
#   'make',
#   'say,',
#   'me.',
#   'all',
#   'gather',
#   'one',
#   'put',
#   'build',
#   'go',
#   'do',
#   'show',
#   'make',
#   'this',
#   'learn',
#   'be',
#   'just',
#   'try',
#   'duplicate',
#   'be',
#   'leapfrog',
#   'look,',
#   'throw',
#   'keep',
#   'throw',
#   'follow',
#   'a',
#   'stand,',
#   'be',
#   'pinball',
#   'be',
#   'be',
#   'Donnie',
#   'what',
#   'count.',
#   'notice…',
#   'worry',
#   'do',
#   'smother',
#   'the',
#   'talk',
#   'go,',
#   'hit',
#   'the',
#   'you?”',
#   'the',
#   'come',
#   'break',
#   'try',
#   'sound',
#   'sound',
#   'tweet',
#   'come',
#   'try',
#   'sound',
#   'boogie.”',
#   'know',
#   'explore',
#   'build',
#   'Mars.',
#   'believe',
#   'Mars…',
#   'find',
#   'bring',
#   'my',
#   'be',
#   'see',
#   'be',
#   'sell',
#   'make',
#   'do',
#   'do',
#   'do',
#   'do',
#   'criminals',
#   'get',
#   'tamper',
#   'note',
#   'tamper',
#   'choose…',
#   'instruct',
#   'this',
#   'take',
#   'weigh',
#   'take',
#   'know',
#   'go',
#   'get',
#   'hit',
#   'save',
#   'put',
#   'save',
#   'the',
#   'be',
#   'bring',
#   'get',
#   'get',
#   'stop',
#   'want',
#   'do',
#   'play',
#   'dress',
#   'a',
#   'be',
#   'fly',
#   'see',
#   'stuff',
#   'stuff',
#   'be.',
#   'spell',
#   'be',
#   'play'],
#  'a': ['word',
#   'senior',
#   'spatula.',
#   'spatula,',
#   'hand',
#   'biopsy',
#   'little',
#   'painkiller.”',
#   'sharp',
#   'little',
#   'fist.',
#   'pill',
#   'dictionary.',
#   'trick',
#   'doctor',
#   'veterinarian',
#   'clipboard',
#   'world',
#   'pen',
#   'flower',
#   'patient',
#   'therapeutic',
#   'Reiki',
#   'word.',
#   'guy',
#   'rib',
#   'kook.”',
#   'book,',
#   'shelf',
#   'sentence,',
#   'disorder?',
#   'color-coded',
#   'book',
#   'triangle.',
#   'friend',
#   'favor.',
#   'kid,',
#   'globe',
#   'little',
#   'word',
#   'person.',
#   'big',
#   'lighthearted',
#   'little',
#   'river.”',
#   'company',
#   'dam…',
#   'figure-eight',
#   'champagne',
#   'country.',
#   'better',
#   'guy',
#   'story',
#   'story.',
#   '2…',
#   '2.\xa0',
#   '2.”',
#   '5',
#   'ticket,',
#   'ticket,',
#   'twist',
#   'curveball',
#   'party,',
#   'dinner',
#   'crapshoot.',
#   'result',
#   'consulting',
#   'food',
#   'psychological',
#   'picnic',
#   'plate',
#   'ham',
#   'grape',
#   'New',
#   'New',
#   'turkey',
#   'very',
#   'unicorn.',
#   'unicorn.',
#   'purple',
#   'compliment.',
#   'young',
#   'funny',
#   'look',
#   'scientist',
#   'space',
#   'hundred',
#   'better,',
#   'waste',
#   'TV.',
#   'life',
#   'kid:',
#   'choice',
#   'great',
#   'family',
#   'crime?',
#   'crime!”',
#   'crime.',
#   'tip',
#   'thing',
#   'case',
#   'tad.',
#   'short',
#   'crime:',
#   'little',
#   'backpack',
#   'ravine?',
#   'duck',
#   'toothbrush…',
#   'little',
#   'beautiful',
#   'show',
#   'lot',
#   'flute',
#   'deadline',
#   'counter.',
#   'bag!',
#   'bag!”',
#   'bag',
#   'guy'],
#  'word': ['I', '“suffer”', 'for', 'differently', '“extra.”'],
#  'say': ['for',
#   'the',
#   'they',
#   'it',
#   'nothing.',
#   'anything,',
#   'nothing.',
#   'mushrooms',
#   'the',
#   'they'],
#  'for': ['an',
#   'someone',
#   'every',
#   'my',
#   'my',
#   'many',
#   'the',
#   'a',
#   'me.',
#   'the',
#   'the',
#   'word,',
#   'about',
#   'longer',
#   'her.',
#   'you,',
#   'me.”',
#   'three',
#   "‘mayonnaise.'”",
#   'water',
#   'water',
#   'instructions.',
#   'too',
#   'people.”',
#   'some',
#   'these',
#   'bands?'],
#  'an': ['hour.',
#   '‘everything',
#   'ear,',
#   'arch-of-the-foot,',
#   'upside-down',
#   'energy',
#   'energy',
#   'administrative',
#   'old',
#   'additional',
#   'almost-responder!”',
#   'orchestra',
#   'orchestra,',
#   'idea.”'],
#  'hour.': ['You’ll'],
#  'You’ll': ['be'],
#  'be': ['out',
#   'the',
#   'impressed',
#   'like',
#   'open?”',
#   'awfully',
#   'receiving',
#   'reserved',
#   'square-sharing',
#   'wedged',
#   'out',
#   'on',
#   'a',
#   'challenging,',
#   'able',
#   'sitting',
#   'two',
#   'sitting',
#   'happy',
#   'able',
#   'endless.”',
#   'dry',
#   'doing',
#   'wrong.”',
#   'done',
#   'part',
#   'the',
#   'a',
#   'thanked.',
#   'good',
#   'good',
#   'hearing',
#   'easier',
#   'a'],
#  'there,': ['“Did', 'when'],
#  '“Did': ['you'],
#  'know': ['anything',
#   'what',
#   'the',
#   'exactly',
#   'what',
#   'what',
#   'what',
#   'these',
#   'how',
#   'how',
#   'how',
#   'that',
#   'where',
#   'how',
#   'me,',
#   'why',
#   'me,',
#   'I',
#   'who',
#   'if',
#   'how',
#   'when',
#   'that',
#   'when',
#   'I',
#   'what',
#   'what',
#   'how'],
#  'anything': ['about', 'up', 'out'],
#  'about': ['the',
#   'three',
#   'the',
#   'the',
#   'myself.',
#   'it.',
#   '20',
#   'time',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'them?”',
#   'the',
#   'the',
#   'how',
#   'that.”',
#   'social',
#   'crime.',
#   'piling',
#   'cruel.',
#   'what’s'],
#  'hair?”': ['“I’m'],
#  '“I’m': ['just', 'here', 'a', 'doing', 'wiping', 'awfully', 'sure'],
#  'just': ['as',
#   'as',
#   'rescheduling',
#   'been',
#   'above',
#   'above',
#   'means',
#   'call',
#   'south',
#   'been',
#   'got',
#   'took',
#   'felt',
#   'decided',
#   'say',
#   'went',
#   'blowing',
#   'don’t',
#   'dried-up',
#   'a',
#   'crushing',
#   'mushing',
#   'be',
#   'tweak',
#   'want',
#   'a',
#   'hauls',
#   'ran'],
#  'as': ['befuddled',
#   'you.”',
#   'well.',
#   'to',
#   'being',
#   'a',
#   'you',
#   'cocktail',
#   'a',
#   'itty-bitty.”',
#   'I’m',
#   'a',
#   'they',
#   'you’re',
#   'you’re'],
#  'befuddled': ['as'],
#  'you.”': ['[audience',
#   '[audience',
#   '“We',
#   '“The',
#   'No,',
#   '“Yeah,',
#   '“Thank',
#   '“Thank',
#   'You'],
#  'don’t': ['know',
#   'know.',
#   'want',
#   'even',
#   'know',
#   'actually',
#   'actually',
#   'have',
#   'have',
#   'count',
#   'have',
#   'know.”',
#   'you',
#   'like',
#   'want',
#   'want',
#   'want',
#   'like',
#   'like',
#   'know',
#   'agree',
#   'know',
#   'know',
#   'know',
#   'think',
#   'know',
#   'have',
#   'know',
#   'revive',
#   'like',
#   'like',
#   'like',
#   'like',
#   'have',
#   'know',
#   'like',
#   'like',
#   'like',
#   'want',
#   'say',
#   'have',
#   'do',
#   'do',
#   'have',
#   'have',
#   'belong',
#   'want',
#   'understand',
#   'understand',
#   'see',
#   'you',
#   'we',
#   'think'],
#  'what': ['happened',
#   'doctor',
#   'if',
#   'was',
#   'you’re',
#   'date',
#   'time',
#   'to',
#   'I’m',
#   'we',
#   'I’m',
#   'I',
#   'if',
#   'I’ve',
#   'are',
#   'should',
#   'you',
#   'went',
#   'kills',
#   'instrument',
#   'teams'],
#  'happened': ['either.', 'too', 'upon'],
#  'either.': ['Covid', 'I', 'One', 'Not'],
#  'Covid': ['hit,'],
#  'hit,': ['I'],
#  'went': ['into', 'to', 'that', 'that', 'to', 'over', 'down'],
#  'into': ['hibernation',
#   'the',
#   'the',
#   'the',
#   'other',
#   'liking',
#   'a',
#   'mulch.',
#   'consideration…',
#   'the',
#   'the',
#   'the'],
#  'hibernation': ['and'],
#  'came': ['out', 'back'],
#  'senior': ['citizen.'],
#  'citizen.': ['[audience'],
#  'clapping': ['and'],
#  'It’s': ['just',
#   'fun',
#   'about',
#   'weird,',
#   'a',
#   'happened',
#   'not',
#   'amazing',
#   'easy.”',
#   'a'],
#  'well.': ['I'],
#  'was': ['never',
#   'like,',
#   'going',
#   'done',
#   'started.',
#   'making',
#   'on.',
#   'so',
#   'a',
#   'weird',
#   'just',
#   'actually',
#   'like,',
#   'no',
#   'a',
#   'drilling',
#   'like,',
#   'the',
#   'the',
#   'like,',
#   'all',
#   'telling',
#   'substandard',
#   'a',
#   'the',
#   '11',
#   'gathered',
#   'a',
#   'the',
#   'innocent',
#   'an',
#   'a'],
#  'never': ['comfortable',
#   'feel',
#   'make',
#   'order',
#   'preceded',
#   'want',
#   'be',
#   'understood'],
#  'comfortable': ['in'],
#  'hair-color': ['aisle'],
#  'aisle': ['anyway.'],
#  'anyway.': ['You'],
#  'You': ['always',
#   'know,',
#   'should',
#   'can’t',
#   'know,',
#   'know,',
#   'know,',
#   'don’t',
#   'might',
#   'and',
#   'want',
#   'don’t',
#   'imagine',
#   'know',
#   'ever',
#   'can’t',
#   'know',
#   'don’t',
#   'don’t',
#   'got',
#   'got',
#   'ever',
#   'have',
#   'guys'],
#  'always': ['have',
#   'thinking',
#   'look',
#   'been',
#   'feel',
#   'getting',
#   'grappled',
#   'on',
#   'got',
#   'wondered,',
#   'be'],
#  'have': ['to',
#   'hair',
#   'to',
#   'a',
#   'fallen',
#   'a',
#   'all',
#   'them.',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'OCD,',
#   'more',
#   'each',
#   'OCD!',
#   'to',
#   'a',
#   'a',
#   'to',
#   'sworn',
#   'sworn',
#   'to',
#   'that',
#   'hit',
#   'to',
#   'to',
#   'the',
#   'a',
#   'enough',
#   'enough',
#   'enough',
#   'available',
#   'done.',
#   'been',
#   'oil',
#   'an',
#   'to',
#   'taken',
#   'thought',
#   'a'],
#  'pretend': ['like'],
#  'like': ['you’re',
#   'the',
#   'ruby',
#   'I’m',
#   'it’s',
#   'that?',
#   'that’',
#   'an',
#   'I’m',
#   'I’m',
#   'the',
#   'when',
#   'everybody',
#   'this',
#   'a',
#   'dinner',
#   'restaurants',
#   'mushrooms.',
#   'mushrooms.',
#   'mushrooms.',
#   'raisins',
#   'raisins.',
#   'grapes?”',
#   'grapes.”',
#   'ham',
#   'if',
#   'that?”',
#   'mayonnaise.',
#   'mayonnaise',
#   'a',
#   'an',
#   'a',
#   'words.',
#   'me.”',
#   'to'],
#  'you’re': ['there',
#   'not',
#   'going',
#   'wondering.',
#   'going',
#   'going',
#   'white',
#   'someone',
#   'in',
#   'walking',
#   'hearing:',
#   'walking'],
#  'there': ['for',
#   'are',
#   'with',
#   'were',
#   'are',
#   'at',
#   'was',
#   'telling',
#   'is',
#   'are',
#   'look',
#   'was'],
#  'someone': ['else.', 'who', 'would'],
#  'else.': ['“Women,', 'I’m'],
#  '“Women,': ['huh?”'],
#  'huh?”': ['[audience'],
#  'difference': ['in'],
#  'color': ['names', 'names', 'spectrum.'],
#  'names': ['between', 'like'],
#  'between': ['women', 'the', 'two'],
#  'women': ['and'],
#  'men': ['Women'],
#  'Women': ['have'],
#  'ruby': ['fusion.'],
#  'fusion.': ['Chocolate'],
#  'Chocolate': ['cherry.'],
#  'cherry.': ['Butterscotch.'],
#  'Butterscotch.': ['Men’s'],
#  'Men’s': ['hair'],
#  'color:': ['brown!'],
#  'brown!': ['[audience', 'Dark'],
#  'Black!': ['Light'],
#  'Light': ['brown!'],
#  'Dark': ['black!'],
#  'black!': ['For'],
#  'For': ['men,'],
#  'men,': ['that'],
#  'that': ['is',
#   'day.',
#   'splotch',
#   'sounds',
#   'can',
#   'moment…',
#   'way',
#   'and',
#   'strange',
#   'way',
#   'way?”',
#   'you',
#   'just',
#   'book?”',
#   'word',
#   'book',
#   'to',
#   'a',
#   'I',
#   'I',
#   'I',
#   'first',
#   'out.',
#   'mistake',
#   'yourself?”',
#   'all',
#   'there',
#   'bug',
#   'little',
#   'point.',
#   'they',
#   'to',
#   'he',
#   'he’s',
#   'fourth',
#   "3.'”",
#   '3.’',
#   "3.'”",
#   'direction,',
#   'was',
#   'meeting,',
#   'the',
#   'is',
#   'chicken',
#   'it',
#   'I',
#   'are',
#   'they',
#   'this',
#   'a',
#   'will',
#   'first',
#   'volcanoes…',
#   'kind',
#   'green',
#   'expression',
#   'side',
#   'I',
#   'the',
#   'would',
#   'crime?',
#   'crime.”',
#   'particular',
#   'crime.”',
#   'crime.”',
#   'I',
#   'tampering',
#   'would',
#   'into',
#   'always',
#   'one',
#   'means…',
#   'guy',
#   'you',
#   'animal',
#   'up-on-the-hind-leg',
#   'has',
#   'again',
#   'how',
#   'otter',
#   'otter',
#   'idea.”',
#   'monstrosity?',
#   'on',
#   'thing.”'],
#  'is': ['the',
#   'try',
#   'it',
#   'the',
#   'so',
#   'we',
#   'a',
#   'just',
#   'too',
#   'not',
#   'for',
#   'for',
#   'special',
#   'where',
#   'it',
#   'even',
#   'looking',
#   'the',
#   'way',
#   'in',
#   'not',
#   'more',
#   'smothered…',
#   'a',
#   'the',
#   'itty-bitty.”',
#   'biggy-wiggy?',
#   'hugey-magroojy!”',
#   'clear.',
#   'a',
#   'life',
#   'fantastic.”',
#   'an',
#   'over,',
#   'nothing',
#   'if',
#   'a',
#   'that?',
#   'that',
#   'it',
#   'that?”'],
#  'entire': ['color', 'illustrious'],
#  'spectrum.': ['I'],
#  'know.': ['I’m'],
#  'I’m': ['at',
#   'going',
#   'bragging,',
#   'always',
#   'eavesdropping.',
#   'watching',
#   'learning',
#   'suffering?',
#   'trying',
#   'weirder',
#   'like,',
#   'not',
#   'in',
#   'not',
#   'going',
#   'higher',
#   'under',
#   'like,',
#   'washing',
#   'like,',
#   'like,',
#   'like,',
#   'always',
#   'going',
#   'at',
#   'like,',
#   'guessing',
#   'supposed',
#   'like,',
#   'like,',
#   'trying',
#   'going',
#   'always',
#   'boring',
#   'intrigued',
#   'saying',
#   'sorry.',
#   'intrigued',
#   'against',
#   'going',
#   'saying',
#   'going',
#   'wearing'],
#  'age': ['where'],
#  'where': ['I', 'it', 'the', 'I', 'the', 'the'],
#  'wake': ['up,'],
#  'up,': ['the', 'this', 'they’re', 'because'],
#  'first': ['thing',
#   'with',
#   'suspected',
#   'question.',
#   'ticket,',
#   'ticket.”',
#   'ticket',
#   'one'],
#  'thing': ['I', 'is', 'I', 'about\xa0', 'on', 'out'],
#  'do': ['is',
#   'a',
#   'it',
#   'I',
#   'you',
#   'it…',
#   'read',
#   'they',
#   'that?',
#   'me',
#   'that',
#   'when',
#   'as',
#   'animals',
#   'on',
#   'that',
#   'you?”',
#   'go',
#   'with',
#   'like',
#   'today…',
#   'send',
#   'it?',
#   'crime?”',
#   'crime…',
#   'crime.”',
#   'the',
#   'the',
#   'the',
#   'the',
#   'it!”',
#   'that',
#   'that',
#   'that',
#   'to',
#   'want',
#   'that?',
#   'it?”',
#   'you',
#   'that',
#   'this',
#   'they'],
#  'try': ['to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'remember': ['what', 'that'],
#  'doctor': ['I’m', 'and', 'looked', 'for', 'visit.', 'told'],
#  'going': ['to',
#   'into',
#   'to',
#   'to',
#   'to',
#   'on?”',
#   'to',
#   'on.”',
#   'to',
#   'to',
#   'up',
#   'to',
#   'on.”',
#   'to',
#   'to',
#   'somewhere.”',
#   'to',
#   'to',
#   'on',
#   'to',
#   'to',
#   'berserk,',
#   'nuts,',
#   'to',
#   'to',
#   'to'],
#  'day.': ['[audience'],
#  'Ah,': ['the'],
#  'dermatologist.': ['Because'],
#  'splotch': ['on'],
#  'on': ['my',
#   'my',
#   'the',
#   'there.”',
#   'it.”',
#   'this',
#   'the',
#   'the',
#   'the',
#   'my',
#   'the',
#   'the',
#   'me.',
#   'the',
#   'my',
#   'their',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'that',
#   'the',
#   'the',
#   'earth',
#   'the',
#   'a',
#   'a',
#   'my',
#   'social',
#   'TV',
#   'Mars.',
#   'Mars?”',
#   'Mars.',
#   'Mars…',
#   'the',
#   'the',
#   'that',
#   'the',
#   'how',
#   'top',
#   'the',
#   'the',
#   'this',
#   'me',
#   'this',
#   'some',
#   'a'],
#  'my': ['back.',
#   'back',
#   'lady?',
#   'Little',
#   'nose,',
#   'regular',
#   'right',
#   'small’s',
#   'doctor',
#   '10',
#   'doctor',
#   'head',
#   'eyes',
#   'wallet.”',
#   'case.',
#   'books',
#   'books.',
#   'books.',
#   'mind!',
#   'hands.',
#   'hands.',
#   'hands',
#   'time.',
#   'time,',
#   'script',
#   'script.',
#   'thinking',
#   'living',
#   'sandwiches.',
#   'resolution.',
#   'mind.”',
#   'followers',
#   'kitchen',
#   'crime',
#   'calendar.”',
#   'defense',
#   'chances.”',
#   'wake!”',
#   'family'],
#  'back.': ['I', 'I', 'I’m'],
#  'want': ['to',
#   'an',
#   'things',
#   'roommates.',
#   'the',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'mayonnaise!”',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'you',
#   'to',
#   'from',
#   'the',
#   'a',
#   'to'],
#  'sound': ['like', 'smart.', 'smart.', 'too', 'too', 'like'],
#  'bragging,': ['but'],
#  'but': ['I', 'am', 'then', 'there', 'it’s', 'I', 'I', 'it’s', 'I', 'they’re'],
#  'put': ['medicine', 'your', 'mud', 'onto', 'one', 'it', 'your'],
#  'medicine': ['on'],
#  'back': ['using', 'to', 'and', 'and', 'with…', 'of'],
#  'using': ['a'],
#  'spatula.': ['[audience'],
#  '[chuckles]': ['It’s', '[audience', 'So', 'Okay.', '[imitates'],
#  'fun': ['going'],
#  'drugstore': ['when'],
#  'when': ['they',
#   'I',
#   'I',
#   'she',
#   'that',
#   'I',
#   'you',
#   'I',
#   'I',
#   'anybody',
#   'somebody',
#   'somebody',
#   'we',
#   'people',
#   'they’re',
#   'we',
#   'I',
#   'fleeing',
#   'you',
#   'the'],
#  'they': ['ask,',
#   'feel',
#   'suffer',
#   'have',
#   'call',
#   'mention',
#   'do',
#   'always',
#   'have',
#   'all',
#   'know',
#   'can',
#   'all',
#   'all',
#   'are!’?”',
#   'only',
#   'were',
#   'know,',
#   'build',
#   'expect',
#   'should',
#   'do,',
#   'have',
#   'stand'],
#  'ask,': ['“Can'],
#  '“Can': ['we', 'you'],
#  'we': ['help',
#   'live',
#   'do',
#   'take',
#   'realized',
#   'had',
#   'were',
#   'go.',
#   'don’t',
#   'do',
#   'given',
#   'landed',
#   'shouldn’t',
#   'do',
#   'get',
#   'kick',
#   'support?”'],
#  'help': ['you'],
#  'find': ['anything?”', 'that', 'water.'],
#  'anything?”': ['And'],
#  'And': ['I',
#   'it',
#   'that',
#   'she',
#   'I’m',
#   'there',
#   'some',
#   'the',
#   'I’m',
#   'I',
#   'I',
#   'she',
#   'then',
#   'what’s',
#   'I',
#   'this',
#   'she',
#   'I’m',
#   'there',
#   'somebody',
#   'I',
#   'some',
#   'I’ve',
#   'we’re',
#   'it’s',
#   'how',
#   'stick'],
#  'say,': ['“Yes,', '‘you', '“What', '“What’s', '“You'],
#  '“Yes,': ['a'],
#  'spatula,': ['Lotrimin'],
#  'Lotrimin': ['and'],
#  'hand': ['mirror.”', 'is', 'on'],
#  'mirror.”': ['[audience'],
#  'Are': ['you'],
#  'intrigued,': ['my'],
#  'lady?': ['[audience'],
#  'got': ['my',
#   'around',
#   'to',
#   'stuck',
#   'them',
#   'some',
#   'here.”',
#   'out',
#   'real',
#   'those',
#   'on',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'them',
#   'this',
#   'a',
#   'to',
#   'to',
#   'to',
#   'an'],
#  'Little': ['Red'],
#  'Red': ['Riding'],
#  'Riding': ['Hood'],
#  'Hood': ['Walgreens'],
#  'Walgreens': ['basket,'],
#  'basket,': ['if'],
#  'could': ['direct',
#   'squeeze',
#   'step',
#   'hang',
#   'say',
#   'quench',
#   'have',
#   'be',
#   'not',
#   'order',
#   'muscle'],
#  'direct': ['me'],
#  'me': ['to',
#   'and',
#   'to',
#   'where',
#   'a',
#   'back.',
#   'back.”',
#   'and',
#   'to',
#   'out',
#   'be.”',
#   'explain',
#   'into',
#   'up',
#   'take',
#   'to',
#   'on',
#   'if'],
#  'proper': ['aisles.', 'heat'],
#  'aisles.': ['[audience'],
#  'laughing,': ['whistling]', 'cheering]'],
#  'My': ['dermatologist', 'doctor', 'brain', 'face', 'parents'],
#  'dermatologist': ['said'],
#  'said': ['he', 'I’m', 'it'],
#  'he': ['needed', 'the', 'had', 'was', 'shares'],
#  'needed': ['to', 'from'],
#  'biopsy': ['of'],
#  'little': ['mole',
#   'area',
#   'social',
#   'circle',
#   'circle.”',
#   '“ha-ha-ha.”',
#   'circle',
#   'circle.',
#   'heads-up:',
#   'quack-you.',
#   'duck'],
#  'mole': ['on'],
#  'tip': ['of', 'of', 'of'],
#  'nose,': ['and'],
#  'like,': ['“Wow,',
#   '“What’s',
#   '“I',
#   '“Are',
#   '“What',
#   '“Brian,',
#   '“Uh,',
#   '“Uh,',
#   '“Why',
#   '“I’ll',
#   '“I',
#   '“Oh,',
#   '“Oh,',
#   '“Oh,',
#   '“Anybody',
#   '“You',
#   '“I',
#   '“So',
#   '“Whoo!”'],
#  '“Wow,': ['that'],
#  'sounds': ['like'],
#  'it’s': ['going',
#   'an',
#   'hard',
#   'off?',
#   'your',
#   'going',
#   'a',
#   'teensy-weensy?',
#   '15',
#   'unfair',
#   'because',
#   'going',
#   'kicking',
#   'ridiculous.'],
#  'hurt.”': ['He'],
#  'He': ['said,', 'said,\xa0', 'recently', 'had', 'must', 'probably'],
#  'said,': ['“Don’t',
#   '“How?”',
#   '“You',
#   '“Brian,',
#   '“I',
#   '“I',
#   '“This',
#   '“I',
#   '“Why',
#   '“Oh,',
#   '“What',
#   '“The',
#   '“What',
#   '“Uh,',
#   '‘Get',
#   'Go',
#   '‘Jump',
#   '‘Nail'],
#  '“Don’t': ['worry.', 'do', 'do'],
#  'worry.': ['We’re'],
#  'We’re': ['going', 'looking', 'wheeling', 'just', 'not'],
#  'numb': ['it'],
#  'it': ['first',
#   'doesn’t',
#   'feels',
#   '“lying”',
#   'every',
#   'from',
#   'ends',
#   'up',
#   'by',
#   'manifests',
#   'says,',
#   'is',
#   'was',
#   'up',
#   'like',
#   'either.',
#   'can',
#   'for',
#   'smolder',
#   'going?”',
#   'is',
#   'shriveled',
#   'on',
#   'to',
#   'had',
#   'out,',
#   'ever',
#   'going',
#   'with',
#   'paid,',
#   'a',
#   'was',
#   'just',
#   'weren’t',
#   'down.”',
#   'good',
#   'on',
#   'normal',
#   'do?”',
#   'do?',
#   'do?”',
#   'do?”',
#   'do?”',
#   'do?'],
#  'with': ['a',
#   'the',
#   'a',
#   'all',
#   'your',
#   'you?”',
#   'that.',
#   'humans.',
#   'the',
#   'less.”',
#   'any',
#   'mushrooms.”',
#   'this.”',
#   'no',
#   'Swiss',
#   'our',
#   'that',
#   'evidence',
#   'evidence.',
#   'evidence',
#   'evidence…',
#   'the',
#   'everything',
#   'a',
#   'our',
#   'pipes!”'],
#  'painkiller.”': ['I'],
#  '“How?”': ['He'],
#  'said,\xa0': ['“We’re'],
#  '“We’re': ['going', 'gonna', 'not'],
#  'puncture': ['a'],
#  'sharp': ['needle'],
#  'needle': ['into'],
#  'your': ['nose.”',
#   'clipboard.',
#   'clipboard.”',
#   'torso.”',
#   'blood',
#   'energy',
#   'ribs.”',
#   'OCD,',
#   'books',
#   'hands',
#   'birthday,',
#   'time.”',
#   'hand',
#   'Uncle',
#   'lawyer',
#   'discomfort.”',
#   'backpacks',
#   'life',
#   'little',
#   'elbow'],
#  'nose.”': ['[audience'],
#  'So': ['you’re',
#   'I',
#   'I',
#   'my',
#   'after',
#   'when',
#   'I’m',
#   'I',
#   'I',
#   'I',
#   'I’m',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'she',
#   'I',
#   'I',
#   'she',
#   'I',
#   'as',
#   'I',
#   'I',
#   'I',
#   'I',
#   'here’s',
#   'I',
#   'the',
#   'why'],
#  'not': ['canceling',
#   'true,',
#   'a',
#   'out',
#   'I',
#   'working.”',
#   'a',
#   'a',
#   'order',
#   'itty-bitty.”',
#   'pay.”',
#   'pay?',
#   'allowed',
#   'allowed.',
#   'tampered',
#   'to',
#   'take',
#   'to',
#   'allowed',
#   'to',
#   'taking',
#   'to–',
#   'ready!',
#   'ready!”'],
#  'canceling': ['the'],
#  'pain.': ['You’re'],
#  'You’re': ['just', 'thinking,', 'not', 'not', 'walking'],
#  'rescheduling': ['it.'],
#  'it.': ['[audience', 'And', 'I', 'He', 'But', 'You', 'Good'],
#  'go': ['to', 'wash', 'into', 'to', 'in', 'to', 'tell', 'to'],
#  'regular': ['doctor', 'voice]'],
#  'he’s': ['like,', 'sharing', 'finished'],
#  '“What’s': ['going', 'the', 'that'],
#  'on?”': ['I'],
#  '“You': ['tell',
#   'should',
#   'don’t',
#   'know',
#   'know',
#   'managed',
#   'missed',
#   'don’t',
#   'had',
#   'do?”',
#   'hear',
#   'don’t',
#   'are',
#   'might'],
#  'tell': ['me.', 'me', 'him', 'you', 'if'],
#  'me.': ['Just', 'They', '[audience', '[audience', 'She', 'He’s', 'Don’t'],
#  'Just': ['above', 'say', 'a'],
#  'above': ['my', 'you,', 'it.”'],
#  'right': ['knee', 'across', 'log'],
#  'knee': ['there’s', 'doctors?'],
#  'there’s': ['a', 'a', 'life'],
#  'area': ['about'],
#  'three': ['inches', 'hours', 'weeks…'],
#  'inches': ['up.'],
#  'up.': ['It’s', 'I', '[audience'],
#  'size': ['of'],
#  'fist.': ['That’s'],
#  'That’s': ['where', 'got', 'Looney', 'one', 'not', 'why', 'us', 'why', 'all'],
#  'doesn’t': ['hurt.', 'say', 'pay!”', 'pay,', 'know'],
#  'hurt.': ['[audience'],
#  'feels': ['very'],
#  'peculiar.': ['Do'],
#  'Do': ['you'],
#  'pill': ['that'],
#  'can': ['make',
#   'experience',
#   'use',
#   'I',
#   'ever',
#   'affect',
#   'let',
#   'imagine,',
#   'start',
#   'you'],
#  'make': ['everything',
#   'myself',
#   'myself',
#   'myself',
#   'a',
#   'sure',
#   'that',
#   'a',
#   'a',
#   'friends,',
#   'sure',
#   'it'],
#  'everything': ['else', 'you', 'about', 'in'],
#  'else': ['feel', 'like', 'to', 'is', 'would'],
#  'feel': ['like', 'comfortable.', 'like', 'about', 'I', 'they'],
#  'that?': ['I', 'Days', '“You’ve', '“Case', 'You'],
#  '‘everything': ['else'],
#  'that’': ['pill.”'],
#  'pill.”': ['My'],
#  'looked': ['at', 'up–', 'at', 'at'],
#  '“Brian,': ['you', 'with', 'do', 'you’re'],
#  'are': ['way',
#   'the',
#   'weird.',
#   'just',
#   'different',
#   'you',
#   'you',
#   'at',
#   'things',
#   'smarter',
#   'smarter',
#   'smarter',
#   'smarter',
#   'you?',
#   'just',
#   'necessary',
#   'from',
#   'things',
#   'unfair.',
#   'you',
#   'not',
#   'hitting',
#   'smarter',
#   'open.”',
#   'many',
#   'wonderful.',
#   'great.'],
#  'way': ['too', 'you', 'and', 'I', 'to', 'it', 'too', 'to', 'or'],
#  'too': ['sedentary.”',
#   'big,',
#   'strong',
#   'claustrophobic.',
#   'many',
#   'young.',
#   'old.',
#   'much?',
#   'big.',
#   'subtle.',
#   'late?”'],
#  'sedentary.”': ['So'],
#  'vowed': ['in'],
#  'moment…': ['to'],
#  'dictionary.': ['[audience'],
#  'haven’t': ['got'],
#  'around': ['to',
#   'the',
#   'the',
#   'the',
#   'town.',
#   'for',
#   'on',
#   'and',
#   'trying',
#   'a',
#   'this',
#   'and'],
#  'it,': ['just'],
#  'been': ['laying',
#   'a',
#   'interested',
#   'ostracized.',
#   'taught.”',
#   'found',
#   'able'],
#  'laying': ['around'],
#  'house.': ['[audience'],
#  'Or': ['is'],
#  '“lying”': ['around'],
#  'house?': ['Doctors'],
#  'Doctors': ['specialize,'],
#  'specialize,': ['right?'],
#  'right?': ['Last'],
#  'Last': ['month', 'week'],
#  'month': ['I', 'in'],
#  'went\xa0': ['to'],
#  'ear,': ['nose'],
#  'nose': ['and'],
#  'throat': ['doctor.', 'and', 'doctors?', 'loudly]'],
#  'doctor.': ['Last', '[audience'],
#  'week': ['I'],
#  'arch-of-the-foot,': ['small-of-the-back,'],
#  'small-of-the-back,': ['nape-of-the-neck'],
#  'nape-of-the-neck': ['doctor.'],
#  'fallen': ['arches,'],
#  'arches,': ['my'],
#  'small’s': ['too'],
#  'big,': ['and'],
#  'trick': ['nape.'],
#  'nape.': ['It’s'],
#  'weird,': ['in', 'unless'],
#  'human': ['world,'],
#  'world,': ['there’s', 'a'],
#  'every': ['body', 'year.'],
#  'body': ['part.'],
#  'part.': ['But'],
#  'But': ['in', 'I', 'nobody', 'I', 'I', 'before', 'you', 'I’m', 'I', 'I', 'I'],
#  'animal': ['world,', 'rescue'],
#  'veterinarian': ['takes'],
#  'takes': ['care'],
#  'care': ['of', 'about'],
#  'all': ['animals…',
#   'their',
#   'those',
#   'this',
#   'roiling',
#   'of',
#   'of',
#   'of',
#   'the',
#   'their',
#   'the',
#   'the',
#   'get',
#   'know',
#   'got',
#   'started',
#   'the',
#   'going',
#   'by',
#   'along.”',
#   'the',
#   'around',
#   'the',
#   'I',
#   'due',
#   'practice'],
#  'animals…': ['and'],
#  'their': ['parts.',
#   'books',
#   'shoes…',
#   'tails',
#   'trucks…',
#   'thirst',
#   'eyebrows.'],
#  'parts.': ['That’s'],
#  'hardest': ['job'],
#  'job': ['in'],
#  'world.': ['Where', 'I’ll', 'I', 'And'],
#  'Where': ['are'],
#  'bighorn': ['sheep'],
#  'sheep': ['knee'],
#  'doctors?': ['[audience', '[audience'],
#  'The': ['wildebeest',
#   'giraffe',
#   'alphabetizing',
#   'camera',
#   'problem,',
#   'people',
#   'marching'],
#  'wildebeest': ['gastroenterologists?'],
#  'gastroenterologists?': ['The'],
#  'giraffe': ['throat,'],
#  'throat,': ['throat'],
#  'laughing': ['and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and'],
#  'cheering': ['and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and'],
#  'They': ['say', 'ask', 'expect', 'have', 'got', 'come'],
#  'American': ['medical'],
#  'medical': ['system'],
#  'system': ['is'],
#  'best': ['in', 'you'],
#  'I’ll': ['be', 'seek', 'self-diagnose', 'show', 'tell'],
#  'impressed': ['when'],
#  'am': ['no', 'I', 'A-okay.'],
#  'no': ['longer', 'other', 'input', 'idea.”', 'one'],
#  'longer': ['handed', 'than'],
#  'handed': ['a'],
#  'clipboard': ['when'],
#  'check': ['in', 'the'],
#  'visit.': ['That'],
#  'That': ['is', 'I'],
#  'so': ['Stone',
#   'disorganized,',
#   'I',
#   'I',
#   'I',
#   'I',
#   'it',
#   'that’s',
#   'nice?',
#   'much.'],
#  'Stone': ['Age.'],
#  'Age.': ['You'],
#  'know,': ['we', 'I', 'do', 'when', 'if', 'but'],
#  'live': ['in', 'in'],
#  'world': ['of', 'is'],
#  'bar': ['codes'],
#  'codes': ['and'],
#  'microchips.': ['What’s'],
#  'What’s': ['with', 'the'],
#  'clipboard?': ['“I’m'],
#  'here': ['for', 'for', 'so', 'next'],
#  '10': ['o’clock', 'minutes', 'minutes', 'how'],
#  'o’clock': ['appointment.”', 'my', 'your'],
#  'appointment.”': ['“Here’s'],
#  '“Here’s': ['your', 'a', 'that'],
#  'clipboard.': ['There’s', 'And'],
#  'There’s': ['257'],
#  '257': ['pages'],
#  'pages': ['on'],
#  'there.”': ['“Here’s'],
#  'pen': ['with'],
#  'flower': ['on'],
#  'it.”': ['[audience', '“You', '[audience'],
#  '“Go': ['sit'],
#  'sit': ['with', 'in', 'down'],
#  'those': ['other', 'chronologically', 'days', 'back-to-back', 'babies'],
#  'other': ['people',
#   'line',
#   'honeybees',
#   'ticket,',
#   'foods',
#   'hand,',
#   'while',
#   'souls'],
#  'people': ['and', 'do', 'try', 'boarding', 'in', 'who', 'in'],
#  'even': ['think', 'right.”', 'looking', 'more', 'imagine', 'see'],
#  'think': ['of',
#   'things',
#   'the',
#   'I’m',
#   'that’s',
#   'so.”',
#   'I',
#   'some',
#   'are',
#   'it’s',
#   'they',
#   'the',
#   'I’m',
#   'someone',
#   'he’s'],
#  'coming': ['back', 'in.”'],
#  'this': ['counter',
#   'information.”',
#   'side',
#   'up.',
#   'nagging',
#   'message:',
#   'party,',
#   'group',
#   'guy',
#   'guy.”',
#   'little',
#   'second',
#   'woman',
#   'woman',
#   'little',
#   'third',
#   'guy',
#   'baby',
#   'kind',
#   'clear:',
#   'amoeba…',
#   'amoeba',
#   'up…',
#   'thing.”',
#   'appears',
#   'crime,',
#   'effect:',
#   'trial',
#   'trial,',
#   'plane',
#   'horse',
#   'thing',
#   'without',
#   'stupid',
#   'show.”',
#   'world.',
#   'added'],
#  'counter': ['till'],
#  'till': ['you’ve', 'Uncle'],
#  'you’ve': ['completely'],
#  'completely': ['filled'],
#  'filled': ['out'],
#  'clipboard.”': ['[audience'],
#  '“I’ve': ['been'],
#  'patient': ['here'],
#  'many': ['years.', 'times', 'occupations'],
#  'years.': ['You'],
#  'should': ['have', 'be', 'be', 'just', 'just', 'say,', 'be'],
#  'information.”': ['“Well,'],
#  '“Well,': ['our', 'wouldn’t'],
#  'our': ['policy', 'Des', 'northeast', 'rovers.', 'bodies…'],
#  'policy': ['is'],
#  'year.': ['We'],
#  'We': ['give', 'do', 'need', 'need'],
#  'give': ['you'],
#  'another': ['clipboard.'],
#  'experience': ['angst'],
#  'angst': ['and'],
#  'tension': ['and'],
#  'rage': ['and'],
#  'downright': ['fury,'],
#  'fury,': ['all'],
#  'roiling': ['through'],
#  'through': ['your', 'that', 'this.”', 'your'],
#  'torso.”': ['“And'],
#  '“And': ['then', 'the', 'the', 'my', 'as', 'you’ll'],
#  'then': ['we', 'I', 'right', 'cheering]'],
#  'take': ['your', 'this?”', 'that.', 'a', 'the', 'the', 'the', 'my', 'note'],
#  'blood': ['pressure.”'],
#  'pressure.”': ['[audience'],
#  '[Brian': ['chuckles]'],
#  'chuckles]': ['You'],
#  'can’t': ['fix', 'handle', 'take', 'risk', 'do', 'do', 'even', 'even'],
#  'fix': ['that', 'me?'],
#  'me?': ['So', 'When'],
#  'told': ['me'],
#  'therapeutic': ['massage'],
#  'massage': ['for'],
#  'neck.': ['Um,'],
#  'Um,': ['massages'],
#  'massages': ['are'],
#  'weird.': ['You'],
#  'comfortable.': ['Always'],
#  'Always': ['looking'],
#  'looking': ['through', 'up,', 'over', 'in', 'for', 'for'],
#  'strange': ['doughnut'],
#  'doughnut': ['hole.', 'hole.”'],
#  'hole.': ['[audience'],
#  'thinking': ['weird', 'weird', 'on', 'of'],
#  'weird': ['things', 'things', 'way', 'living', 'learning'],
#  'things': ['like,', 'like,', 'like,', 'about', 'in', 'people', 'we'],
#  '“I': ['wonder',
#   'feel',
#   'don’t',
#   'started',
#   'don’t',
#   'don’t',
#   'have',
#   'organize',
#   'don’t',
#   'don’t',
#   'still',
#   'was',
#   'already',
#   'just',
#   'just',
#   'don’t',
#   'knew',
#   'picked',
#   'don’t',
#   'could',
#   'didn’t',
#   'had',
#   'want',
#   'would',
#   'love',
#   'don’t',
#   'wish',
#   'don’t',
#   'have',
#   'base',
#   'know,',
#   'only',
#   'was',
#   'bet',
#   'stuck'],
#  'wonder': ['if'],
#  'squeeze': ['my', 'in'],
#  'head': ['through', 'and'],
#  'this.”': ['[audience', '“We'],
#  '“But': ['what', 'crime'],
#  'stuck': ['underneath', 'in', 'in', 'the'],
#  'underneath': ['the', 'us…'],
#  'table?”': ['“Then'],
#  '“Then': ['I’d', 'how'],
#  'I’d': ['be', 'be'],
#  'upside-down': ['periscope.”'],
#  'periscope.”': ['“I’d'],
#  '“I’d': ['better', 'be'],
#  'better': ['leave', 'listener.'],
#  'leave': ['well'],
#  'well': ['enough'],
#  'enough': ['alone', 'mayonnaise.', 'time', 'time.', 'time', 'not', 'to'],
#  'alone': ['and'],
#  'stay': ['on'],
#  'side': ['of', 'of'],
#  'hole.”': ['Then'],
#  'Then': ['I', 'do', 'haul'],
#  '“Are': ['my', 'you'],
#  'eyes': ['supposed'],
#  'supposed': ['to', 'to', 'to', 'to', 'to'],
#  'open?”': ['“I'],
#  'eavesdropping.': ['I’m'],
#  'watching': ['her'],
#  'her': ['feet'],
#  'feet': ['moving'],
#  'moving': ['around.”'],
#  'around.”': ['Started'],
#  'Started': ['thinking'],
#  '“What': ['if',
#   'time',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about',
#   'if',
#   'happened?”',
#   'a',
#   'a',
#   'do',
#   'in',
#   'does',
#   'does',
#   'does',
#   'does',
#   'does'],
#  'one': ['shoe',
#   'shoe',
#   'before',
#   'all',
#   'weird',
#   'of',
#   'o’clock',
#   'area,',
#   'of',
#   'outside…',
#   'before',
#   'month',
#   'way',
#   'thanks'],
# ...
#  '“This': ['is'],
#  'Reiki': ['massage.”'],
#  'massage.”': ['“I'],
#  'actually': ['touch', 'touch', 'pronounced'],
#  'touch': ['you.”', 'my'],
#  '“My': ['hands', 'hand'],
#  'hands': ['are', 'over', 'I’m'],
#  'you,': ['and', 'but', '“Do', 'thank'],
#  'energy': ['healing.”', 'payment…', 'bill,'],
#  'healing.”': ['[audience'],
#  'done': ['I', 'just', 'naturally'],
#  'wallet.”': ['[audience'],
#  'receiving': ['an'],
#  'payment…': ['that'],
#  'use': ['to', 'the'],
#  'pay': ['your'],
#  'bill,': ['see'],
#  'see': ['how', 'if', 'news', 'them.', 'their', 'the', 'marching', 'it.”'],
#  'how': ['they',
#   'would',
#   'strongly',
#   'do',
#   'to',
#   'to',
#   'to',
#   'smart',
#   'to',
#   'to',
#   'are',
#   'our',
#   'I',
#   'to',
#   'much',
#   'to',
#   'come',
#   'the',
#   'come',
#   'to'],
#  'concept.”': ['[audience'],
#  'learning': ['things', 'about'],
#  'myself.': ['I'],
#  'learned': ['recently', 'about'],
#  'recently': ['I', 'left', 'picked.'],
#  'suffer': ['from', 'from'],
#  'from': ['OCD.',
#   'things,',
#   'the',
#   '0',
#   'the',
#   'situations.',
#   'Peoria.”',
#   'you.”',
#   'now',
#   'volcanoes.',
#   'me?”',
#   'you.',
#   'underneath'],
#  'OCD.': ['Uh–'],
#  'Uh–': ['[woman'],
#  '[woman': ['whoops]', 'cheers]', 'whooping]'],
#  'whoops]': ['Thank'],
#  '“Suffer”': ['is'],
#  'strong': ['a', 'political'],
#  'word.': ['People', 'I'],
#  'People': ['say', 'think', 'say,', 'love'],
#  'things,': ['when'],
#  'means': ['they'],
#  'them.': ['You', '[audience'],
#  'look': ['like', 'ahead', 'at', 'at', 'tremendous.', 'amazing.', 'at'],
#  'suffering?': ['I'],
#  '“suffer”': ['should'],
#  'reserved': ['for'],
#  'guy': ['writhing', 'goes,', 'there', 'was', 'supposed', 'over'],
#  'writhing': ['on'],
#  'ground': ['in'],
#  'agony.': ['He’s'],
#  'He’s': ['suffering.', 'like,'],
#  'suffering.': ['Am'],
#  'Am': ['I', 'I'],
#  'allowed': ['to', 'to', 'to'],
#  'run': ['up'],
#  'up': ['to',
#   'and',
#   'to',
#   'in',
#   'here.”',
#   'in',
#   'there?”',
#   'there?',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'late',
#   'to',
#   'here?',
#   'the',
#   'the',
#   'and'],
#  'him?': ['“You’re'],
#  '“You’re': ['preaching', 'going'],
#  'preaching': ['to'],
#  'choir!”': ['[audience'],
#  'alphabetize': ['everything!”', 'your', 'my', 'them.”', 'my'],
#  'everything!”': ['[audience'],
#  '“Quit': ['wriggling.'],
#  'wriggling.': ['I’m'],
#  'trying': ['to', 'to', 'to', 'to', 'to'],
#  'count': ['your', 'technically', 'the'],
#  'ribs.”': ['“I’m'],
#  'rib': ['counter.”'],
#  'counter.”': ['[audience'],
#  'alphabetizing': ['thing'],
#  'true,': ['at'],
#  'least': ['in'],
#  'case.': ['People'],
#  'weirder': ['than'],
#  'than': ['I',
#   'others.',
#   '5',
#   'finding',
#   'everybody',
#   'people.”',
#   'two',
#   'people.”',
#   'people.”',
#   'people.”',
#   'mushrooms.',
#   'animals.”'],
#  'am,': ['and'],
#  'hard': ['for'],
#  'ask': ['questions', 'the', 'what'],
#  'questions': ['like,'],
#  'OCD,': ['do', 'I', 'I'],
#  'books': ['at', 'by', 'I’ve', 'I’m', 'rather'],
#  'home?”': ['And'],
#  '“Uh,': ['no.”', 'zero.', 'the'],
#  'no.”': ['“I'],
#  'organize': ['my', 'those'],
#  'by': ['when', 'the', 'the', 'the', 'ourselves…', 'a'],
#  'them': ['chronologically',
#   'to',
#   'around',
#   'to',
#   'all\xa0',
#   'all',
#   'back',
#   'a',
#   'well?'],
#  'chronologically': ['on', 'by', 'by'],
#  'top': ['shelf.”', 'shelf', 'shelf', 'of', 'of', 'bunk'],
#  'shelf.”': ['“I'],
#  'books.': ['I’m', 'I’m'],
#  'kook.”': ['[audience'],
#  'bottom': ['shelf'],
#  'shelf': ['is', 'to', 'and', 'in', 'change.', 'furthest'],
#  'I’ve': ['completed',
#   'always',
#   'done',
#   'always',
#   'loved',
#   'learned',
#   'always',
#   'crunched',
#   'been'],
#  'completed': ['reading.”'],
#  'reading.”': ['“Organized', '“When'],
#  '“Organized': ['chronologically'],
#  'completion': ['date.”'],
#  'date.”': ['“I', 'I'],
#  'them.”': ['Der!'],
#  'Der!': ['[audience'],
#  'middle': ['shelf…', 'shelf', 'shelf?”', 'of', 'shelf'],
#  'shelf…': ['is'],
#  'process': ['of', 'of'],
#  '“When': ['I', 'I'],
#  'start': ['reading', 'date.”', 'validating', 'walking'],
#  'reading': ['a', 'the', 'that'],
#  'book,': ['I'],
#  'move': ['it', 'that'],
#  'exactly': ['what'],
#  'wondering.': ['You’re'],
#  'thinking,': ['“Well,'],
#  'wouldn’t': ['reading', 'be', 'have'],
#  'title': ['of'],
#  'book…': ['count'],
#  'technically': ['as'],
#  'being': ['in'],
#  'book?”': ['“Then'],
#  'would': ['you',
#   'you',
#   'you',
#   'you',
#   'order',
#   'like',
#   'describe',
#   'be',
#   'be',
#   'you',
#   'take',
#   'never',
#   'want'],
#  'distinguish': ['between'],
#  'shelf?”': ['Well,'],
#  'it…': ['[audience'],
#  'myself': ['read', 'read', 'turn', 'to'],
#  'read': ['all', 'all', 'all'],
#  'page': ['one', 'one', 'back.'],
#  'before': ['I', 'I', 'it', 'takeoff.”', 'the', 'we'],
#  'allow': ['a'],
#  'change.': ['[audience'],
#  'introduction,': ['or'],
#  'or': ['the',
#   'the',
#   'not',
#   '“teensy-weensy”?',
#   'bottom.”',
#   'the',
#   'not',
#   'the'],
#  'foreword,': ['or'],
#  'book': ['jacket.', 'was', 'about'],
#  'jacket.': ['I'],
#  'word,': ['but'],
#  'bottom.': ['Unless', 'They'],
#  'Unless': ['it'],
#  'ends': ['in'],
#  'sentence,': ['I'],
#  'turn': ['the', 'the'],
#  'page.': ['I'],
#  'finish': ['the'],
#  'sentence': ['to'],
#  'complete': ['the'],
#  'thought,': ['I', '“What'],
#  'write': ['down', 'zero.'],
#  'down': ['what', 'the', 'that', 'before', 'into', 'in', 'and'],
#  'date': ['that'],
#  'started.': ['I'],
#  'furthest': ['on'],
#  'right.': ['I'],
#  'mind!': ['[audience'],
#  'How': ['come', 'would', 'come', 'come', 'else', 'can'],
#  'come': ['when',
#   'into',
#   'off',
#   'over',
#   'only',
#   'we',
#   'when',
#   'in',
#   'as',
#   'none'],
#  'order': ['they',
#   'mushrooms.”',
#   'mushrooms.',
#   'extra',
#   'mayonnaise,',
#   'lunch.'],
#  'call': ['that', 'me'],
#  'disorder?': ['[audience'],
#  'suspected': ['that'],
#  'might': ['have', 'think', 'notice', 'have', 'be'],
#  'Googled': ['it.'],
#  'different': ['symptoms.'],
#  'symptoms.': ['And', 'I', '[chuckles]'],
#  'some': ['I',
#   'I',
#   'I',
#   'ink',
#   'bookshelves.',
#   'scientists',
#   'of',
#   'science',
#   'good',
#   'states',
#   'sleep',
#   'shut-eye.”',
#   'wild',
#   'pretty',
#   'reason,',
#   'wood'],
#  'have,': ['and', 'some'],
#  'don’t.': ['And'],
#  'ones': ['I'],
#  'more': ['strongly', 'often', 'twisted:', 'in'],
#  'strongly': ['than', 'I'],
#  'others.': ['So'],
#  'decided': ['to', 'to', 'to', 'to', 'all', 'to'],
#  'color-coded': ['graph.'],
#  'graph.': ['[audience'],
#  'wish': ['I', 'I'],
#  'making': ['this'],
#  'listed': ['the'],
#  'rate': ['from'],
#  '0': ['to'],
#  'each': ['symptom.'],
#  'symptom.': ['Total'],
#  'Total': ['it'],
#  'divide': ['it'],
#  'number': ['of', 'on–', 'on'],
#  'If': ['I’m', 'I’m', 'it’s', 'I', 'they', 'the', 'you’re'],
#  'higher': ['than'],
#  '5': ['I’ll', 'on', 'on', 'and'],
#  'seek': ['professional'],
#  'professional': ['help.'],
#  'help.': ['If'],
#  'under': ['5,'],
#  '5,': ['I’ll', '6.”', '6,'],
#  'self-diagnose': ['that'],
#  'A-okay.': ['[audience'],
#  'Number': ['one:', 'two:'],
#  'one:': ['are'],
#  'type': ['of', 'of'],
#  'person': ['who', 'who'],
#  'who': ['has', 'has', 'are', 'does', 'you’re', 'does', 'work'],
#  'has': ['to', 'to', 'to', 'an'],
#  'stove': ['repeatedly'],
#  'repeatedly': ['to'],
#  'sure': ['it’s', 'you', 'know', 'the'],
#  'off?': ['And'],
#  'zero.': ['That’s', 'Okay.”'],
#  'Looney': ['Tunes'],
#  'Tunes': ['land.”'],
#  'land.”': ['[audience'],
#  'two:': ['are'],
#  'wash': ['your', 'my'],
#  'over': ['and',
#   'again?',
#   'at',
#   'at',
#   'the',
#   'and',
#   'here.',
#   'to',
#   'here–',
#   'here–'],
#  'again?': ['And'],
#  'had': ['this',
#   'to',
#   'recently',
#   'everyone',
#   'the',
#   'the',
#   'the',
#   'the',
#   'an',
#   'anticipated',
#   'nothing',
#   'no',
#   'to',
#   'to'],
#  'nagging': ['feeling…'],
#  'feeling…': ['that'],
#  'forgot': ['to'],
#  'answer': ['that'],
#  'question.': ['[audience'],
#  'up–': ['“Yeah,'],
#  '“Yeah,': ['I', 'I', 'I'],
#  'did': ['write', 'they', 'notice.”'],
#  'Okay.”': ['“Hand'],
#  '“Hand': ['washing.”'],
#  'washing.”': ['“Six.”'],
#  '“Six.”': ['“That'],
#  '“That': ['ain’t'],
#  'ain’t': ['even', 'never'],
#  'right.”': ['I', '“But'],
#  'scribbled': ['that'],
#  'out.': ['I', 'You'],
#  'ink': ['on'],
#  'hands.': ['I', 'While'],
#  'While': ['I’m'],
#  'washing': ['my'],
#  '“Why': ['did', 'don’t', 'don’t', 'don’t'],
#  'mention': ['stoves?”'],
#  'stoves?”': ['So'],
#  'checked': ['the'],
#  'stove.': ['It'],
#  'It': ['was', 'was', 'could', 'doesn’t', 'was'],
#  'on.': ['I’m', 'Anything', 'It’s'],
#  '“I’ll': ['never', 'take'],
#  'mistake': ['again.”'],
#  'again.”': ['And'],
#  'changed': ['“hand', 'my'],
#  '“hand': ['washing”'],
#  'washing”': ['to'],
#  '2.': ['[audience'],
#  'took': ['the', 'the'],
#  'whole': ['test', 'family'],
#  'test': ['and'],
#  'averaged': ['5.0.'],
#  '5.0.': ['So'],
#  'still': ['don’t'],
#  'know.”': ['[audience', '“People'],
#  'buy': ['a'],
#  'bookstore,': ['I'],
#  'clerk,': ['“Can'],
#  'self-help': ['section'],
#  'section': ['is?”'],
#  'is?”': ['And'],
#  'yourself?”': ['[audience'],
#  'finally': ['found'],
#  'found': ['the', 'out', 'guilty'],
#  'section.': ['It'],
#  'disorganized,': ['I'],
#  'spent': ['the'],
#  'next': ['three', 'page.”', 'to.', 'to'],
#  'hours': ['rearranging'],
#  'rearranging': ['all'],
#  'rather': ['than'],
#  'finding': ['out'],
#  'whether': ['or'],
#  'OCD!': ['[audience'],
#  'whistling': ['and'],
#  'show': ['you', 'you', 'that'],
#  'manifests': ['itself.'],
#  'itself.': ['Every'],
#  'Every': ['year'],
#  'year': ['when'],
#  'new': ['calendar,'],
#  'calendar,': ['I'],
#  'ahead': ['because'],
#  'because': ['I', 'this', 'I', 'that', 'you’re'],
#  'months': ['who'],
#  'expect': ['days', 'me'],
#  'days': ['to', 'is'],
#  'share': ['squares.'],
#  'squares.': ['My'],
#  'brain': ['can’t'],
#  'handle': ['that.'],
#  'that.': ['[audience', 'I', '[audience', '“Hey,', 'You’re'],
#  'laughs]': ['“Oh'],
#  '“Oh': ['no,'],
#  'no,': ['October’s'],
#  'October’s': ['going'],
#  'square-sharing': ['month.”'],
#  'month.”': ['Why'],
#  'Why': ['do', 'do'],
#  'Days': ['don’t'],
#  'roommates.': ['You'],
#  '31st': ['going'],
#  '24th:': ['“Hey,'],
#  '“Hey,': ['can', 'Brian,', 'how’s', 'how', 'I', 'uh…', 'I'],
#  'you?”': ['[audience', '“I', 'I’m', '“Would'],
#  '“Get': ['the', 'some', 'out', 'some', 'in', 'down', 'in'],
#  'hell': ['out', 'with'],
#  'here!”': ['“There’s', '“Toby,'],
#  '“There’s': ['empty'],
#  'empty': ['squares'],
#  'squares': ['on'],
#  'page.”': ['You'],
#  'that’s': ['weird,', 'why', 'supposed'],
#  'unless': ['one'],
#  'special': ['to'],
#  'birthday,': ['you', 'sort'],
#  'wedged': ['up'],
#  'corner': ['of'],
#  'triangle.': ['“Happy'],
#  '“Happy': ['birthday,'],
#  'sort': ['of,'],
#  'of,': ['kind'],
#  'kind': ['of', 'of', 'of'],
#  'squished': ['up'],
#  'here.”': ['And', 'Well,', '[audience'],
#  'across': ['the'],
#  'diagonal': ['it'],
#  'says,': ['“Take', '“Animals', '“Animals'],
#  '“Take': ['trash'],
#  'trash': ['to'],
#  'dump.”': ['[audience'],
#  'interested': ['in'],
#  'calendars': ['and'],
#  'time.': ['Uh,', 'That’s', 'He', 'You', '[audience', 'I'],
#  'Uh,': ['I', 'just'],
#  'grew': ['up'],
#  'Eastern': ['Time', 'Time'],
#  'Time': ['Zone.', 'Zone.', 'Zone'],
#  'Zone.': ['I', 'And'],
#  'now': ['live', 'we’ll'],
#  'Pacific': ['Time'],
#  'what’s': ['weird', 'in'],
#  'living': ['out', 'will.'],
#  'anybody': ['from', 'ever'],
#  'Zone': ['leaves'],
#  'leaves': ['the'],
#  'voice': ['message,'],
#  'message,': ['they'],
#  'compute': ['the'],
#  'time': ['difference.', 'it', 'zones.', 'is', 'to', 'to', 'I'],
#  'difference.': ['I’m'],
#  'getting': ['messages:', 'in', 'enough', 'rid', 'hurt,'],
#  'messages:': ['“Hey,'],
#  'Brian,': ['it’s,'],
#  'it’s,': ['four'],
#  'four': ['o’clock', 'lottery'],
#  'time.”': ['[audience', '[audience]', 'Damn.'],
#  'Oh!': ['[groans'],
#  '[groans': ['softly]'],
#  'softly]': ['[audience'],
#  'am.': ['[audience'],
#  'friend': ['who'],
#  'does': ['that',
#   'not',
#   'not',
#   'not',
#   'that,',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it'],
#  'left': ['this', 'and'],
#  'message:': ['“Brian,'],
#  'favor.': ['Call'],
#  'Call': ['me'],
#  '20': ['minutes'],
#  'time,': ['that’s,'],
#  'that’s,': ['uh…'],
#  'uh…': ['[audience', '[clears', 'doors'],
#  'back.”': ['[audience'],
#  'When?': ['What’s'],
#  'formula?': ['When'],
#  'When': ['I', 'you', 'I', 'you'],
#  'kid,': ['it'],
#  'zones.': ['Learning'],
#  'Learning': ['that'],
#  'were': ['24',
#   'you?”',
#   'there',
#   'agape.',
#   'in',
#   'great,',
#   'nice',
#   'willing',
#   'seated.”',
#   'sitting'],
#  '24': ['around'],
#  'globe': ['and'],
#  'saw': ['all', 'something', 'a', 'a', 'a', 'Metallica', 'a', 'a'],
#  'lines': ['met'],
#  'met': ['at'],
#  'top,': ['and'],
#  'there?”': ['Could'],
#  'Could': ['you'],
#  'pole': ['and'],
#  'walk': ['around,', 'up', 'up,'],
#  'around,': ['“It’s'],
#  '“It’s': ['1:00,', 'in', 'just', 'a'],
#  '1:00,': ['2:00,'],
#  '2:00,': ['3:00,'],
#  '3:00,': ['4:00,'],
#  '4:00,': ['5:00,'],
#  '5:00,': ['6:00!”?'],
#  '6:00!”?': ['[audience'],
#  'applauding,': ['then'],
#  '[man]': ['Yeah!'],
#  'Yeah!': ['How', '[people'],
#  'plan': ['anything'],
#  'there?': ['“We’re'],
#  'gonna': ['meet'],
#  'meet': ['at'],
#  'five': ['o’clock.”'],
#  'o’clock.”': ['[audience'],
#  '“Where': ['were'],
#  'south': ['of'],
#  'addition': ['to'],
#  'also': ['have', 'don’t', 'didn’t'],
#  'social': ['anxiety.', 'media.', 'media:'],
#  'anxiety.': ['But'],
#  'force': ['myself'],
#  'parties': ['and'],
#  'stuff,': ['but'],
#  'bug': ['me.'],
#  'somebody': ['pronounces', 'says', 'could', 'replied,'],
#  'pronounces': ['a'],
#  'differently': ['than'],
#  'everybody': ['else', 'else.', 'about'],
#  'smart.': ['Just', 'So'],
#  'party,': ['I', 'I'],
#  'group': ['of', 'of'],
#  'strangers.': ['First'],
#  'First': ['thing'],
#  'hear,': ['uh,'],
#  'uh,': ['this', 'Genghis', 'four', 'first'],
#  'goes,': ['“Another'],
#  '“Another': ['thing'],
#  'about\xa0': ['‘Jengus’'],
#  '‘Jengus’': ['Khan…”'],
#  'Khan…”': ['I’m'],
#  '“Oh,': ['jeez.”',
#   'uh,',
#   'Jengus',
#   'jeez.”',
#   'how',
#   'I',
#   'I’ve',
#   'well,',
#   'that',
#   'great.”'],
#  'jeez.”': ['[audience', '[audience'],
#  'already': ['don’t'],
#  'guy.”': ['[audience'],
#  'go,': ['“Oh,', '“Brian…', '“Thanks.”'],
#  'Genghis': ['Khan?”'],
#  'Khan?”': ['“It'],
#  '“It': ['was', 'might'],
#  'pronounced': ["‘Jengus.'”"],
#  "‘Jengus.'”": ['[chuckles'],
#  '[chuckles': ['haughtily]'],
#  'haughtily]': ['[audience'],
#  'guessing': ['you'],
#  'Jeng-man': ['palling'],
#  'palling': ['around'],
#  'town.': ['So'],
#  'wanted': ['to', 'to', 'to'],
#  'Jengus': ['Khan,'],
#  'Khan,': ['the'],
#  '‘Mongo-lian': ['em-peror.’'],
#  'em-peror.’': ['[audience'],
#  'cheers]': ['Wasn’t'],
#  'Wasn’t': ['he'],
#  '‘con-kerer’': ['of'],
#  '‘Cheena’?”': ['[audience'],
#  'felt': ['this', 'the'],
#  'circle': ['tighten', 'popped'],
#  'tighten': ['on'],
#  'ostracized.': ['Walk'],
#  'Walk': ['up', 'up'],
#  'second': ['group.', 'ticket…', 'ticket.”', 'ticket.”', 'ticket.”'],
#  'group.': ['And'],
#  'says': ['something'],
#  'something': ['I', 'interesting', 'I’ve', 'to'],
#  'agree': ['with.', 'to'],
#  'with.': ['I'],
#  'person.': ['I’ve'],
#  'grappled': ['with'],
#  'woman': ['says,', 'glares'],
#  '“Animals': ['are', 'are'],
#  'smarter': ['than', 'than', 'than', 'than', 'than'],
#  'people.”': ['I’m', '“Like,', '“They', '“They', '[audience'],
#  'others': ['like,', 'have'],
#  '“Anybody': ['want'],
#  'this?”': ['[audience'],
#  '“Low-hanging': ['fruit.”'],
#  'fruit.”': ['“I'],
#  'hit': ['over', 'them', 'the', 'the', 'the'],
#  'circle.”': ['“If'],
#  '“If': ['somebody', 'you', 'you'],
#  'step': ['up'],
#  'plate': ['here', 'and'],
#  'hang': ['around'],
#  'two': ['minutes…”', 'hours.', 'selfish'],
#  'minutes…”': ['[audience'],
#  'nobody': ['else'],
#  'they’re': ['shuffling', 'looking', 'thinking', 'practicing?', 'coming'],
#  'shuffling': ['their'],
#  'shoes…': ['and'],
#  'figure': ['out', 'out'],
#  'dynamic.': ['“They'],
#  '“They': ['must', 'know', 'know'],
#  'must': ['work', 'have'],
#  'work': ['for', 'there'],
#  'her.': ['Something’s'],
#  'Something’s': ['going'],
#  'couldn’t': ['say', 'use'],
#  'nothing.': ['But', 'And'],
#  'didn’t': ['want',
#   'get',
#   'fit',
#   'order',
#   'want',
#   'want',
#   'want',
#   'have',
#   'pursue',
#   'do'],
#  'big': ['deal', 'deal?”'],
#  'deal': ['out'],
#  'these': ['people.', 'fellas', 'tickets.”', 'chairs'],
#  'people.': ['So'],
#  'lighthearted': ['joke.'],
#  'joke.': ['So'],
#  'animals': ['do'],
#  'SAT': ['test?”'],
#  'test?”': ['[audience'],
#  '[woman]': ['Yeah!'],
#  '[people': ['whooping]'],
#  'whooping]': ['Just', 'I'],
#  '“ha-ha-ha.”': ['[audience', 'I'],
#  'temperature': ['drop.'],
#  'drop.': ['And'],
#  'glares': ['at'],
#  '“Like,': ['case'],
#  'case': ['closed.”', 'without'],
#  'closed.”': ['Well,'],
#  'anything,': ['she'],
#  ...}

# %%
generate_sentence(brian_dict)
# Out:
# 'Soon as to put onto and bring the foreword, or the harness off like mushrooms..'

# %%
david_text = data.transcript.loc['david']
david_text[:200]

david_dict = markov_chain(david_text)
david_dict

generate_sentence(david_dict)
# Out:
# 'Bill is how that’s in lube and thinking, “Well… at me, and… It’s a time.'

# %%
doug_text = data.transcript.loc['doug']
doug_text[:200]

doug_dict = markov_chain(doug_text)
doug_dict

generate_sentence(doug_dict)
# Out:
# 'De Niro used to come back downstairs? Yeah. Why would just catch you. They’re both.'

# %%
jerry_text = data.transcript.loc['jerry']
jerry_text[:200]

jerry_dict = markov_chain(jerry_text)
jerry_dict

generate_sentence(jerry_dict)
# Out:
# 'Alien spaceship. We like somebody to me… When my children’s lives, I’d rather someone some.'

# %%
jim_text = data.transcript.loc['jim']
jim_text[:200]

jim_dict = markov_chain(jim_text)
jim_dict

generate_sentence(jim_dict)
# Out:
# 'Making good points. [Audience applauding] See, if someone else. And we had the guns. I.'

# %%
kenny_text = data.transcript.loc['kenny']
kenny_text[:200]
kenny_dict = markov_chain(kenny_text)
kenny_dict
# Out:
# {'Make': ['some'],
#  'some': ['noise',
#   'eye',
#   'mascara,',
#   'Doctor',
#   'guy',
#   'reason',
#   'money',
#   'music'],
#  'noise': ['for'],
#  'for': ['Kenny',
#   'this.',
#   'that.',
#   'women',
#   'men,',
#   'me.”',
#   'the',
#   'the',
#   'a',
#   'my',
#   'him?',
#   'this',
#   'looking',
#   'opinions',
#   'like',
#   'that.',
#   'a',
#   'the',
#   '45',
#   'the',
#   'crying',
#   'no',
#   'two',
#   'two',
#   'maids…',
#   'a',
#   '28',
#   'some',
#   'the',
#   'using',
#   'keeping',
#   'just',
#   'you',
#   'everybody,',
#   'the',
#   'guitar',
#   'the',
#   'the',
#   'you.”',
#   'you',
#   'independent',
#   'lunch?”',
#   'lunch,',
#   'water,',
#   'consent?',
#   'consent?',
#   'the',
#   'the',
#   'you',
#   'this',
#   'tonight.'],
#  'Kenny': ['Sebastian.', 'is', 'Sebastian.'],
#  'Sebastian.': ['Oh', 'You’ve'],
#  'Oh': ['my',
#   'shit.',
#   'they',
#   'my',
#   'you’re',
#   'so,',
#   'you',
#   'you',
#   'you',
#   'sorry.'],
#  'my': ['God.',
#   'friends',
#   'ego',
#   'brain.',
#   'soul.',
#   'nutrition',
#   'God.',
#   'party.',
#   'dream,',
#   'job.',
#   'face?',
#   'grandfather.',
#   'hair',
#   'fingers.',
#   'friend',
#   'hands?',
#   'dictionary.',
#   'hand',
#   'hand?',
#   'parents',
#   'princess,',
#   'noodles.',
#   'table.',
#   'hand',
#   'life',
#   'hand,',
#   'spit.',
#   'laughs',
#   'presence.',
#   'brain',
#   'eyes',
#   'dating',
#   'own',
#   'house',
#   'maid',
#   'mouth.',
#   'house.”',
#   'mom.',
#   'mom',
#   'mom',
#   'mom',
#   'maid’s',
#   'mom.',
#   'mom.',
#   'mom',
#   'maid,',
#   'mom',
#   'mom',
#   'maid’s',
#   'mom.',
#   'mother.',
#   'mom',
#   'house.',
#   'mom',
#   'mom.',
#   'son,',
#   'house.',
#   'mom.',
#   'maid’s',
#   'heart',
#   'Uber',
#   'heart.',
#   'eyes',
#   'sister’s',
#   'phone',
#   'arms.',
#   'leg',
#   'maid.'],
#  'God.': ['Thank', 'Shit,'],
#  'Thank': ['you', 'you.', 'you.', 'you.', 'you', 'you.', 'you', 'you'],
#  'you': ['so',
#   'guys',
#   'know',
#   'don’t',
#   'go',
#   'go',
#   'want',
#   'have',
#   'stop',
#   'please',
#   'don’t',
#   'grow',
#   'become',
#   'lose',
#   'enter',
#   'even',
#   'have',
#   'making',
#   'dance',
#   'can',
#   'were',
#   'genuinely',
#   'hate',
#   'and',
#   'so',
#   'used',
#   'care',
#   'even',
#   'even',
#   'son',
#   'say',
#   'say',
#   'say',
#   'son',
#   'seen',
#   'got',
#   'are',
#   'put',
#   'know',
#   'mean',
#   'hold',
#   'hold',
#   'do',
#   'make',
#   'know',
#   'know.',
#   'stories',
#   'a',
#   'go?”',
#   'a',
#   'are',
#   'don’t',
#   'can',
#   'and',
#   'want',
#   'said',
#   'listen',
#   'listen',
#   'can',
#   'can',
#   'meet',
#   'take',
#   'laugh,',
#   'apologise.',
#   'can',
#   'of',
#   'of',
#   'of',
#   'do',
#   'are',
#   'get',
#   'guys',
#   'enter',
#   'get',
#   'the',
#   'come',
#   'do',
#   'are',
#   'do',
#   'coming',
#   'put',
#   'get',
#   'if',
#   'doing?”',
#   'doing',
#   'not',
#   'not',
#   'guys',
#   'want',
#   'an',
#   'for',
#   'the',
#   'don’t',
#   'respected',
#   'learn,',
#   'are.”',
#   'get',
#   'were',
#   'just',
#   'end',
#   'because',
#   'for',
#   'are.',
#   'don’t',
#   'could',
#   'have',
#   'say',
#   'don’t',
#   'guys?',
#   'guys',
#   'believe…',
#   'guys',
#   'guys',
#   'guys',
#   'seen',
#   'seen',
#   'so',
#   'attention',
#   'should',
#   'are',
#   'guys.',
#   'don’t',
#   'like',
#   'need',
#   'have',
#   'just',
#   'want',
#   'become',
#   'have',
#   'just',
#   'even',
#   'selfish.',
#   'to',
#   'put',
#   'ask',
#   'ask',
#   'with',
#   'do?',
#   'seen',
#   'please',
#   'move',
#   'sit',
#   'know',
#   '♫\n♫',
#   '♫\n♫',
#   'gotta',
#   'got',
#   'want',
#   'guys.',
#   'guys',
#   'a',
#   'a',
#   '‘hey’.',
#   'guys',
#   'have',
#   'want',
#   'can',
#   'take',
#   'put',
#   'guys',
#   'guys',
#   'take',
#   'bring',
#   'so',
#   'guys.',
#   'so'],
#  'so': ['much',
#   'painful',
#   'nice.',
#   'you',
#   'many',
#   'much?',
#   'much?',
#   'many',
#   'hot,',
#   'clingy,',
#   'many',
#   'sweet.',
#   'high.',
#   'dry.',
#   'sorry.',
#   'they',
#   'I',
#   'you',
#   'nice.',
#   'important',
#   'sad.',
#   'happy?',
#   'sad.',
#   'cute,',
#   'much,',
#   'much.'],
#  'much': ['Mumbai.', 'shit', 'from'],
#  'Mumbai.': ['Thank'],
#  'you.': ['Thank',
#   'Really.',
#   'At',
#   'Can',
#   '♫',
#   'After',
#   'Your',
#   'Sometimes',
#   'Thank'],
#  'Really.': ['How'],
#  'How': ['are', 'dare', 'dare', 'dare', 'can', 'many', 'many', 'many', 'to'],
#  'are': ['you',
#   'great',
#   'we',
#   'just',
#   'the',
#   'we',
#   'you',
#   'certain',
#   'your',
#   'certain',
#   'like,',
#   'like,',
#   'teaching',
#   'really',
#   'like,',
#   'amazing',
#   'amazing',
#   'the',
#   'dating',
#   'so',
#   'too',
#   'staring',
#   'just',
#   'just',
#   'just',
#   'very',
#   'four',
#   'like',
#   'moving,',
#   'pissed',
#   'like',
#   'people',
#   'genuinely',
#   'you',
#   'you',
#   'you',
#   'you',
#   'rude,',
#   'not',
#   'you?”',
#   'talking.',
#   'only',
#   'dying',
#   'going',
#   'you',
#   'playing',
#   'incredible,',
#   'sad.',
#   'because',
#   'like,',
#   'also',
#   'here.”',
#   'albino',
#   'an',
#   'good.',
#   'good,'],
#  'guys': ['doing?',
#   'are',
#   'as',
#   'know',
#   'are',
#   'in',
#   'about',
#   'come',
#   'with',
#   'who',
#   'know',
#   'know',
#   'and',
#   'keep',
#   'can',
#   'can',
#   'can’t',
#   'are',
#   'be',
#   'are',
#   'because',
#   'can',
#   'are',
#   'are',
#   'have',
#   'do'],
#  'doing?': ['Oh'],
#  'shit.': ['Let’s', 'It’s', 'I', 'Guys,', 'Diga', 'It', 'Yeah,', 'You'],
#  'Let’s': ['do', 'make', 'make', 'go', 'chill.”', 'watch', 'protect', 'do'],
#  'do': ['this.',
#   'you',
#   'you',
#   'the',
#   'a',
#   'they',
#   'you',
#   'we',
#   'that.',
#   'I',
#   'that',
#   'that',
#   'you',
#   'a',
#   'that?',
#   'this',
#   'this.”',
#   'it.',
#   'anything',
#   'that.',
#   'anything',
#   'that.',
#   'the',
#   'this',
#   'that.',
#   'we',
#   'all',
#   'that.',
#   'a',
#   'you',
#   'this.',
#   'it.',
#   'something',
#   'it.',
#   'it',
#   'you',
#   'with',
#   'the',
#   '‘hey’.',
#   'this'],
#  'this.': ['Come',
#   'Is',
#   'I',
#   '*Doorbell',
#   'I',
#   'He',
#   'He’s',
#   'He',
#   'But',
#   'There'],
#  'Come': ['on', 'to', 'let’s', 'do', 'on,', 'on.'],
#  'on': ['guys.',
#   'drinks',
#   'the',
#   'stage',
#   'my',
#   'the',
#   'one.',
#   'one.',
#   'one',
#   'me.”',
#   'a',
#   'the',
#   'the',
#   'his',
#   'stage?',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'it.',
#   'a'],
#  'guys.': ['It’s',
#   'The',
#   'It',
#   'I’m',
#   'She',
#   'I’ve',
#   'Don’t',
#   'First',
#   'I',
#   'Because',
#   'Everybody.',
#   'Thank'],
#  'It’s': ['the',
#   'nice,',
#   'not',
#   'the',
#   'awesome.',
#   'the',
#   'bad',
#   'awesome.',
#   'our',
#   'your',
#   'so',
#   'such',
#   'awesome.',
#   'nice.',
#   'very',
#   'damn',
#   'my',
#   'just',
#   'just',
#   'crazy.',
#   'like',
#   'crazy,',
#   'fine.”',
#   'a',
#   'all',
#   'a',
#   'a',
#   'a',
#   'some',
#   'not',
#   'a',
#   'just…',
#   'not',
#   'cool.',
#   'less',
#   'basically',
#   'coming',
#   'warm.”',
#   'fine.',
#   'like',
#   'all',
#   'all',
#   'crazy.',
#   'crazy',
#   'crazy.',
#   'awesome.',
#   'like',
#   'fine.',
#   'a',
#   'his',
#   'raining,',
#   'so',
#   'going',
#   'right',
#   'magic.',
#   'magic.',
#   'a',
#   'damn',
#   'awesome.',
#   'damn',
#   'damn',
#   'damn',
#   'so',
#   'happy.”',
#   'a',
#   'going',
#   'the',
#   'crazy.',
#   'a',
#   'the',
#   'just'],
#  'the': ['Royal',
#   'history',
#   'great',
#   'best.',
#   'best',
#   'club?',
#   'way,',
#   'best.',
#   'best.',
#   'environment,',
#   'dancing.',
#   'club',
#   'loudest',
#   'club',
#   'leg',
#   'rhythm.”',
#   'centre.',
#   'centre.”',
#   'club.',
#   'only',
#   'guys',
#   'women',
#   'sun',
#   'Himalayas,',
#   'bathroom,',
#   'wild.',
#   'true',
#   'guys',
#   'road,',
#   'worst',
#   'world',
#   'past',
#   'best',
#   'physical',
#   'cuddling.',
#   'number',
#   'shack.',
#   'shack,',
#   'beach,',
#   'most',
#   'bill…',
#   'story',
#   'story,',
#   'word',
#   'room.',
#   'entire',
#   'moment',
#   'sexiest',
#   'time?”',
#   'director’s',
#   'best',
#   'moment',
#   'photoshoot.',
#   'photo',
#   'door.',
#   'door…',
#   'door',
#   'door',
#   'light',
#   'lights',
#   'door',
#   'Indian',
#   'photoshoot,',
#   'camera',
#   'camera.',
#   'camera.',
#   'first',
#   'window.',
#   'first',
#   'great',
#   'nonchalantness',
#   'juice?',
#   'great',
#   'apartment',
#   'sarcasm',
#   'house',
#   'maid.',
#   'way',
#   'correct',
#   'hell',
#   'President’s',
#   'door',
#   'maid',
#   'worst',
#   'worst',
#   'morning.”',
#   'emotional',
#   'emotional',
#   'maid?',
#   'maid?”',
#   'sweetest,',
#   'way.',
#   'morning.',
#   'maid',
#   'maid',
#   'ghetto.',
#   'Godfather’s',
#   'maid',
#   'bell',
#   'middle',
#   'room',
#   'salary.',
#   'highest',
#   'whole',
#   'house.',
#   'floor.',
#   'dishes,',
#   'the',
#   'dishes.”',
#   'kitchen,',
#   'dishes.',
#   'window',
#   'windows',
#   'neighbour’s',
#   'dishes,',
#   'window.',
#   'neighbour’s',
#   'light',
#   'game.',
#   'holy',
#   'maid',
#   'mission',
#   'goddamn',
#   'way',
#   'sofa,',
#   'house,',
#   'walls,',
#   'maid?”',
#   'top',
#   'room?”',
#   'room?”',
#   'TV?”',
#   'TV?”',
#   'room',
#   'best.',
#   'next',
#   'front',
#   'line.',
#   'attention',
#   'professor',
#   'most?',
#   'nice',
#   'last',
#   'nicest',
#   'planet.',
#   'phone.',
#   'sound',
#   'wall',
#   'universe.',
#   'windshield',
#   'thing.',
#   'cab.',
#   'mirror,',
#   'mirror',
#   'last',
#   'next',
#   'phone',
#   'back.',
#   'back.',
#   'minimum',
#   'traffic',
#   'minimum',
#   'door,',
#   'universe',
#   'auto',
#   'car,',
#   'AC?”',
#   'car,',
#   'guitar',
#   'faculty',
#   'judges.”',
#   'lyrics.',
#   'guitar',
#   'guitar?',
#   'guitar?',
#   'guitar?',
#   'few',
#   'floor,',
#   'tabla,',
#   'ultimate.',
#   'musician',
#   'ground.',
#   'crushing',
#   'sound',
#   'water',
#   'ultimate',
#   'water',
#   'window',
#   'window',
#   'band',
#   'audience.',
#   'audience',
#   'count',
#   'ultimate',
#   'song.',
#   'speech,',
#   'midnight',
#   'world',
#   'sadness.',
#   'window',
#   'last'],
#  'Royal': ['Opera', 'Opera', 'Opera'],
#  'Opera': ['House,', 'House.', 'House,'],
#  'House,': ['guys.', 'the'],
#  'The': ['Royal',
#   'Royal',
#   'leg',
#   'moment',
#   'time',
#   'body',
#   'moment',
#   'moment',
#   'second',
#   'worst',
#   'Mrs.',
#   '19',
#   'strict',
#   'strict',
#   'nice',
#   'moment',
#   'only',
#   'next',
#   'universe.',
#   'love',
#   'trees',
#   'clouds',
#   'humidity',
#   'speech',
#   'trees',
#   'cloud-♫'],
#  'House.': ['Yeah,'],
#  'Yeah,': ['it’s', 'right?', 'my', 'I', 'that’s', 'I', 'so', 'it’s', 'you'],
#  'it’s': ['a',
#   'a',
#   'a',
#   'crazy.',
#   'kind',
#   'great.',
#   'great.',
#   'about',
#   'my',
#   'fine.',
#   'fine.',
#   'like',
#   'just',
#   'nice.',
#   'sister.',
#   'a',
#   'usually',
#   'fine.',
#   'your',
#   'your',
#   'crazy',
#   'really',
#   'a',
#   'fine.',
#   'important,',
#   'air-guitar',
#   'fine',
#   'just',
#   'great.',
#   'all',
#   'a',
#   'a',
#   'just',
#   'an',
#   'Indian.”'],
#  'a': ['big',
#   'big',
#   'big',
#   'good',
#   'club,',
#   'great',
#   'Jack',
#   'barbaric',
#   'neck',
#   'book',
#   'circle',
#   'circle.',
#   'book',
#   'new',
#   'shot,',
#   'bit.”',
#   'shit',
#   'party,',
#   'wizard,',
#   'DJ.',
#   'bad',
#   'comedian',
#   'joke?',
#   'bitch.',
#   'bitch.',
#   'bitch.”',
#   'joke.',
#   'joke.',
#   'bathroom,',
#   'new',
#   'bear',
#   'player.',
#   'truck',
#   'group.',
#   'group,',
#   'life',
#   'truthful',
#   'round',
#   'trip',
#   'story,',
#   'beach,',
#   'chill',
#   'beer,',
#   'chill',
#   'shack,',
#   'chill',
#   'club?',
#   'club.',
#   'new',
#   'guy,',
#   'room',
#   'photoshoot.',
#   'supermodel',
#   'bath',
#   'floor',
#   'shit',
#   'small',
#   'small',
#   'guy',
#   'guy',
#   'word.',
#   'simple',
#   'mass',
#   'date',
#   'nice',
#   'mess',
#   'hotel.',
#   'correct',
#   'little',
#   'reason.',
#   'very',
#   'hard',
#   'panda.',
#   'gangster.',
#   'gangster,',
#   'gangster.',
#   'gun',
#   'maid,',
#   'new',
#   'new',
#   'wave',
#   'Hype-Man…',
#   'sick',
#   'mission',
#   'while.',
#   'former',
#   'nice',
#   'store,',
#   'nice',
#   'proposal.',
#   'proposal.',
#   'dam.',
#   'nice',
#   'medium.',
#   'fifteen',
#   'conversation',
#   'self',
#   'situation',
#   'sign',
#   'dam',
#   'guitar.',
#   'guitar.”',
#   'guitar',
#   'guitar',
#   'great',
#   'cheer.',
#   'request',
#   'layered',
#   'musical',
#   'guitar,',
#   'love',
#   'puppy,',
#   'drum',
#   'horrible',
#   'puppy,',
#   'tough',
#   'love',
#   'boy',
#   'girl.',
#   'shit.',
#   'concert,',
#   'train',
#   'long',
#   'nuclear',
#   'line',
#   'plane,',
#   'power',
#   'terrorist,',
#   'train',
#   'train',
#   'window.',
#   'train',
#   'train',
#   'plastic',
#   'joke,',
#   'patronising',
#   'word,',
#   'big',
#   'famous',
#   'radio',
#   'famous',
#   'train',
#   'lovely',
#   'lot'],
#  'big': ['deal.', 'deal.', 'occasion', 'responsibility,'],
#  'deal.': ['I', 'I'],
#  'I': ['know',
#   'took',
#   'have.',
#   'don’t',
#   'am',
#   'was',
#   'don’t',
#   'used',
#   'have',
#   'can’t',
#   'never',
#   'read',
#   'dance',
#   'remember',
#   'have',
#   'stop.',
#   'hate',
#   'want',
#   'don’t',
#   'can’t',
#   'can’t',
#   'can’t',
#   'still',
#   'feel',
#   'mean',
#   'don’t',
#   'don’t',
#   'put',
#   'put',
#   'put',
#   'put',
#   'met',
#   'straightened',
#   'lost',
#   'don’t',
#   'don’t',
#   'be',
#   'really',
#   'even',
#   'know.',
#   'feel',
#   'step',
#   'moonwalk',
#   'am,',
#   'hate',
#   'am',
#   'just',
#   'talk',
#   'just',
#   'just',
#   'can',
#   'can’t',
#   'just',
#   'just',
#   'hate',
#   'am',
#   'don’t',
#   'am',
#   'see',
#   'be',
#   'got',
#   'say',
#   'am.',
#   'had',
#   'like',
#   'have',
#   'always',
#   'don’t',
#   'hear',
#   'don’t',
#   'heard',
#   'was',
#   'said',
#   'had',
#   'am',
#   'have',
#   'was',
#   'was',
#   'was',
#   'mean',
#   'said,',
#   'am',
#   'don’t',
#   'keep',
#   'have',
#   'share',
#   'am',
#   'put',
#   'ask?”',
#   'find',
#   'did',
#   'forgot',
#   'didn’t',
#   'didn’t.',
#   'am',
#   'am',
#   'live',
#   'just',
#   'be',
#   'have',
#   'enter',
#   'have',
#   'am',
#   'mean',
#   'don’t',
#   'turned',
#   'don’t',
#   'brought',
#   'am',
#   'hate',
#   'used',
#   'just',
#   'go',
#   'just',
#   'learn.”',
#   'have',
#   'have',
#   'figured',
#   'met',
#   'knew',
#   'taking',
#   'just',
#   'won’t',
#   'went',
#   'sat',
#   'am',
#   'had',
#   'counted.”',
#   'have',
#   'am',
#   'know,',
#   'know.',
#   'make',
#   'put?',
#   'don’t',
#   'don’t',
#   'switch',
#   'got',
#   'opened',
#   'built',
#   'play',
#   'get',
#   'have',
#   'have',
#   'can’t',
#   'will',
#   'have',
#   'have',
#   'have',
#   'don’t',
#   'could',
#   'love',
#   'don’t.',
#   'have',
#   'took',
#   'am',
#   'just',
#   'am',
#   'have',
#   'am',
#   'love',
#   'am',
#   'get',
#   'am',
#   'am',
#   'am',
#   'look',
#   'am',
#   'look',
#   'long',
#   'look',
#   'think',
#   'need',
#   'need',
#   'like',
#   'will',
#   'know.',
#   'will',
#   'am',
#   'know',
#   'don’t',
#   'am',
#   'look',
#   'am',
#   'am'],
#  'know': ['none',
#   'the',
#   'why',
#   'so…',
#   'how',
#   'there',
#   'what',
#   'what',
#   'you',
#   'me',
#   'me.',
#   'how',
#   'what',
#   'if',
#   'that.',
#   'didi,',
#   'my',
#   'if',
#   'this,',
#   'if',
#   'what?',
#   'what’s',
#   'what',
#   'how',
#   'there',
#   'that',
#   'how',
#   'you'],
#  'none': ['of'],
#  'of': ['you',
#   'difficult.',
#   'a',
#   'shots?”',
#   'a',
#   'a',
#   'my',
#   'a',
#   'men.',
#   'women',
#   'applause',
#   'my',
#   'this',
#   'myself.',
#   'perfection.',
#   'Distant',
#   'Distant',
#   'Distant',
#   'the',
#   'this',
#   'opening',
#   'eye',
#   'this',
#   'the',
#   'her,',
#   'here.”',
#   'my',
#   'honour.',
#   'the',
#   'being',
#   'here.”',
#   'the',
#   'them',
#   'them',
#   'his',
#   'a',
#   'apology',
#   'you',
#   'you',
#   'it',
#   'your',
#   'three.'],
#  'history': ['but', 'and', 'has'],
#  'but': ['it’s',
#   'diet',
#   'you’re',
#   'you’re',
#   'powerful.',
#   'now',
#   'then',
#   'you',
#   'I',
#   'I',
#   'you'],
#  'took': ['bath', 'three', 'to'],
#  'bath': ['twice', 'twice.'],
#  'twice': ['for'],
#  'Is': ['that', 'that', 'just'],
#  'that': ['even',
#   'Hogwarts?',
#   'I’ve',
#   'reaction',
#   'finger',
#   'finger',
#   'I',
#   'emotion',
#   'shyness,',
#   'again.',
#   'she',
#   'window?”',
#   'every',
#   'guy,',
#   'the',
#   'came',
#   'as',
#   'middle',
#   'cost.',
#   'emotion.',
#   'to',
#   'is',
#   'life',
#   'no',
#   'shit?',
#   'time.',
#   'never'],
#  'even': ['possible?',
#   'come',
#   'seen',
#   'seen',
#   'wearing',
#   'the',
#   'going',
#   'a',
#   'I',
#   'want',
#   'want',
#   'calculate.”',
#   'need',
#   'notice',
#   'you'],
#  'possible?': ['Apparently'],
#  'Apparently': ['it'],
#  'it': ['is.',
#   'right',
#   'right!',
#   'from',
#   'seems.',
#   'evolves',
#   'up.',
#   'is',
#   'casual.',
#   'looks',
#   'because',
#   'very',
#   'gets',
#   'gets',
#   'up.',
#   'damn',
#   'as',
#   'was',
#   'might',
#   'went.',
#   'starts',
#   'doesn’t',
#   'works',
#   'it’s',
#   'know',
#   'in',
#   'goes',
#   'provides',
#   'on',
#   'like,',
#   'dying,',
#   'more',
#   'more',
#   'together,',
#   'more'],
#  'is.': ['Yes.', 'Super'],
#  'Yes.': ['The', 'Yes.', 'I'],
#  'great': ['deal', 'at', 'plan,', 'Tsunami.', 'elders.', 'vowel'],
#  'deal': ['and'],
#  'and': ['it’s',
#   'Coke',
#   'at',
#   'me.',
#   'right.',
#   'shit.',
#   'be',
#   'shit.',
#   'I',
#   'they',
#   'I’m',
#   'I',
#   'Gopal',
#   'drink',
#   'eating',
#   'they’re',
#   'say',
#   'then…',
#   'an',
#   'you',
#   'he',
#   'he',
#   'he',
#   'he',
#   'this',
#   'you',
#   'didn’t',
#   'dying?',
#   'they',
#   'be',
#   'caring.',
#   'caring.',
#   'suddenly',
#   'the',
#   'she’s',
#   'she’s',
#   'makes',
#   'like,',
#   'entropy',
#   'my',
#   'I’m',
#   'we',
#   'only',
#   'be',
#   'go',
#   'he’s',
#   'driven',
#   'it’s',
#   'it',
#   'nicely',
#   'the',
#   'an',
#   'he’s',
#   'handle',
#   'despair?',
#   'I',
#   'then',
#   'he',
#   'he’s',
#   'put',
#   'the',
#   'sound',
#   'they’re',
#   'you',
#   'they’re',
#   'random',
#   'you',
#   'you'],
#  'occasion': ['because'],
#  'because': ['I’ve',
#   'you’re',
#   'my',
#   'human',
#   'she',
#   'we',
#   'the',
#   'for',
#   'they',
#   'nice',
#   'recently',
#   'this',
#   'there',
#   'when',
#   'the',
#   'your',
#   'they',
#   'indie'],
#  'I’ve': ['just', 'gotten', 'grown', 'grown.'],
#  'just': ['turned',
#   'so',
#   'like',
#   'dance',
#   'say',
#   'make',
#   'a',
#   'a',
#   'want',
#   'hates',
#   'wanna',
#   'wanna',
#   'wanna',
#   'the',
#   'want',
#   'want',
#   'sucks.',
#   'bullshit…',
#   'grinding…”',
#   'grinding',
#   'like',
#   'freezes',
#   'fell.',
#   'fell.',
#   'standing',
#   'like…',
#   'feed',
#   'came',
#   'in',
#   'focused.',
#   'want',
#   'walking',
#   'realised,',
#   'noticed',
#   'have',
#   'reflect',
#   'tell',
#   'like…',
#   'existing.',
#   'sing',
#   'use',
#   'one',
#   'like…',
#   'make',
#   'asked',
#   'a',
#   'talk',
#   'condensation',
#   'cool.'],
#  'turned': ['26.', 'all', '26.'],
#  '26.': ['Yeah.', 'You', 'Like…', 'I', 'I'],
#  'Yeah.': ['I', 'My', 'I’m', 'Let', 'His'],
#  'have.': ['I'],
#  'don’t': ['know',
#   'dance',
#   'care',
#   'have',
#   'care',
#   'care.',
#   'have',
#   'want',
#   'know.',
#   'need',
#   'need',
#   'want',
#   'know.”',
#   'know',
#   'want',
#   'need',
#   'know',
#   'be',
#   'tell',
#   'know,',
#   'know',
#   'know',
#   'deserve.”',
#   'mind',
#   'know',
#   'know',
#   'mind,',
#   'even',
#   'do',
#   'like',
#   'care.',
#   'sound',
#   'have',
#   'trust',
#   'think'],
#  'why': ['people', 'are', 'are', 'do', 'am', 'I', 'I', 'are'],
#  'people': ['cheer',
#   'who',
#   'one',
#   'coming',
#   'died.',
#   'will',
#   'told',
#   'if',
#   'can’t',
#   'protect',
#   'can’t',
#   'can’t',
#   'can’t',
#   'who',
#   'ask,'],
#  'cheer': ['for'],
#  'that.': ['Because',
#   'It’ll',
#   'I',
#   'It’s',
#   'I',
#   'Yes.',
#   'It’s',
#   'That’s',
#   'Don’t',
#   'Feel',
#   'My',
#   'Some',
#   'Just',
#   'Let’s',
#   'It',
#   'It’s',
#   'Men,'],
#  'Because': ['they’re',
#   'at',
#   'for',
#   'at',
#   'at',
#   'they',
#   'women,',
#   'guys',
#   'then',
#   'the',
#   'even',
#   'like',
#   'she',
#   'they',
#   'women',
#   'if',
#   'we',
#   'I',
#   'they’ll',
#   'he',
#   'Uber',
#   'the',
#   'I',
#   'technically,',
#   'that’s',
#   'trains',
#   'most',
#   'radio',
#   'the'],
#  'they’re': ['like,', 'like,', 'like,', 'like…', 'like,', 'crushing'],
#  'like,': ['“Hey,',
#   '“Bro,',
#   '“Bro!',
#   '“Shots?',
#   '“Whoo!',
#   '“Ssh!',
#   '“Whoo!',
#   '“Bro,',
#   '“Hey!',
#   '“At',
#   '“No,',
#   '“Brutal',
#   '“Really?',
#   '“Excuse',
#   '“What',
#   '“I',
#   '“Bro,',
#   'No,',
#   '“Baby,',
#   '“Bro,',
#   '“Hey',
#   '“Yeah,',
#   'Excuse',
#   '“Okay!',
#   '“What?',
#   '“What',
#   '“Hey',
#   '“Hey,',
#   '“No!',
#   '“Let',
#   '“Come',
#   '“I',
#   'coughing.',
#   'what?',
#   '“Oh',
#   '“The',
#   '“One,',
#   '“No!',
#   '“Hey!',
#   'respect',
#   '“Hey',
#   '“You',
#   '“I',
#   '“Why',
#   '“Kenny,',
#   '“Woah!',
#   '“Oh',
#   '“Get',
#   '“Aunty,',
#   '“Shit,',
#   '“Okay.',
#   '“Sir,',
#   '“Oh!',
#   '“Okay',
#   '“This',
#   '“How',
#   '“Sorry!',
#   '“Sir,',
#   '“Hey!',
#   '“So,',
#   '“So',
#   '“Gopal.',
#   '“Bro!',
#   '“Sir,',
#   '“Thank',
#   '“Hmm!',
#   '“Sir,',
#   'I',
#   '“Hello,',
#   '“Hey!',
#   '“How',
#   '“It’s',
#   '“Yaay!',
#   '“Sir,',
#   '“Okay',
#   'one,'],
#  '“Hey,': ['he’s', 'a', 'shut', 'it’s'],
#  'he’s': ['going',
#   'like,',
#   'doing',
#   'like,',
#   'like.',
#   'like,',
#   'like,',
#   'like.'],
#  'going': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'to': ['die',
#   'die',
#   'dance',
#   'dance.',
#   'watch.',
#   'a',
#   'drink?',
#   'do',
#   'the',
#   'the',
#   'the',
#   'pay',
#   'your',
#   'your',
#   'go',
#   'be',
#   'the',
#   'dark,',
#   'light,',
#   'wash',
#   'get',
#   'wear',
#   'live',
#   'me,',
#   'you?',
#   'say',
#   'say',
#   'Goa.',
#   'give',
#   'go',
#   'Thailand,',
#   'know.',
#   'you',
#   'go',
#   'a',
#   'a',
#   'the',
#   'the',
#   'do',
#   'be',
#   'be',
#   'your',
#   'come',
#   'be',
#   'the',
#   'walk.',
#   'meet',
#   'look',
#   'believe',
#   'challenge',
#   'your',
#   'keep',
#   'work',
#   'go',
#   'work',
#   'work',
#   'get',
#   'the',
#   'my',
#   'do',
#   'the',
#   'impress',
#   'my',
#   'make',
#   'college',
#   'be',
#   'do',
#   'evaluate',
#   'say',
#   'be',
#   'be',
#   'a',
#   'take',
#   'put',
#   'protect',
#   'protect',
#   'build',
#   'air',
#   'propagate,',
#   'where',
#   'where',
#   'him,',
#   'my',
#   'make',
#   'me.”',
#   'die.”',
#   'cover',
#   'an',
#   'me',
#   'go',
#   'channel',
#   'take',
#   'handle',
#   'me',
#   'talk',
#   'be',
#   'be',
#   'me',
#   'me',
#   'you,',
#   'be',
#   'get',
#   'learn',
#   'do,',
#   'make',
#   'a',
#   'make',
#   'be',
#   'be',
#   'go',
#   'an',
#   'be',
#   'be',
#   'make',
#   'be',
#   'it?',
#   'reach',
#   'a',
#   'make',
#   'put',
#   'do',
#   'make',
#   'be',
#   'do',
#   'say',
#   'make',
#   'do',
#   'still',
#   'me.'],
#  'die': ['soon.', 'soon.', 'or', 'literally.'],
#  'soon.': ['Yaay!”', 'Yes,'],
#  'Yaay!”': ['Yea,'],
#  'Yea,': ['I'],
#  'am': ['going',
#   'I',
#   'talking',
#   'not',
#   'sitting',
#   'intelligent',
#   '26.',
#   'so',
#   'not',
#   'encouraging',
#   'chilling',
#   'just',
#   'a',
#   'sitting',
#   'already',
#   'going',
#   'listening',
#   'going',
#   'sorry,',
#   'sitting',
#   'sitting',
#   'sitting',
#   'sitting',
#   'not',
#   'sitting',
#   'Kenny',
#   'done'],
#  'Yes,': ['it’s', 'can'],
#  'crazy.': ['Like', 'Guys', 'It’s', 'Yeah.', 'So'],
#  'Like': ['26…',
#   'women',
#   'me',
#   'you',
#   'the',
#   'the',
#   'all',
#   'if',
#   'his',
#   'the'],
#  '26…': ['You'],
#  'You': ['won’t',
#   'know,',
#   'know.',
#   'are',
#   'don’t',
#   'just',
#   'know',
#   'never',
#   'know,',
#   'know…',
#   'know',
#   'son',
#   'enter',
#   'know',
#   'guys',
#   'know',
#   'make',
#   'know?',
#   'went',
#   'become',
#   'comb',
#   'just…',
#   'just…',
#   'can',
#   'must',
#   'stay',
#   'deserve',
#   'will',
#   'nice',
#   'can’t',
#   'got',
#   'could',
#   'believe.',
#   'guys',
#   'know',
#   'have',
#   'need',
#   'were',
#   'throw',
#   'can',
#   'look',
#   'guys',
#   'need',
#   'guys',
#   'guys'],
#  'won’t': ['believe', 'affect', 'come'],
#  'believe': ['it,', 'that'],
#  'it,': ['I', 'after'],
#  'was': ['19',
#   'going',
#   'like,',
#   'a',
#   'like,',
#   'cured',
#   'doing',
#   'a',
#   'struggling',
#   'this',
#   'there.',
#   'like,',
#   'not',
#   'silent',
#   'the',
#   'taught',
#   'just',
#   'like,',
#   'like,',
#   'a',
#   'not',
#   'decided',
#   'the',
#   'my',
#   'nice',
#   'so',
#   'up',
#   'dying',
#   'driving,',
#   'going'],
#  '19': ['once.',
#   'you',
#   'when',
#   'when',
#   'it’s',
#   'there’s',
#   'you',
#   'you’re',
#   'I',
#   'you',
#   'the',
#   'year'],
#  'once.': ['It’s'],
#  'nice,': ['like'],
#  'like': ['at',
#   'no',
#   'neat,',
#   'the',
#   'left',
#   'eye',
#   'how',
#   'you',
#   'eight',
#   'a',
#   'hey',
#   'surrounding',
#   'a',
#   'great,',
#   'photoshoots.',
#   'great,',
#   'five',
#   'me',
#   'as',
#   'I',
#   'South',
#   'fools',
#   'this.',
#   'you',
#   'death',
#   'the',
#   'she',
#   'knighthood.',
#   'a',
#   'a',
#   'it’s',
#   'she',
#   'a',
#   'we’re',
#   'that.',
#   'cleaning.',
#   'that.',
#   'no',
#   'this.',
#   'let',
#   'at',
#   'it?',
#   'mainstream?',
#   'we’re',
#   'them.'],
#  'at': ['26.',
#   '19',
#   'dancing.',
#   '19',
#   '19',
#   '19',
#   '19',
#   '19',
#   '19',
#   '26.',
#   'your',
#   'home.',
#   'the',
#   'me,',
#   'me,',
#   'me,',
#   'you?”',
#   'her.',
#   '9:55',
#   '10?”',
#   '9:55',
#   'night',
#   'home',
#   'it.',
#   'home',
#   'home.',
#   'home.',
#   'all.',
#   'me',
#   'the',
#   'least',
#   'this',
#   'me,',
#   'you',
#   'me'],
#  'know,': ['it’s', 'I’m', 'some', 'I', 'go'],
#  'kind': ['of', 'of', 'of'],
#  'difficult.': ['I'],
#  'dance': ['as', 'the', 'like', 'though.', 'once', 'and'],
#  'as': ['much.', 'they', 'novels.', 'she', 'I', 'a', 'a', 'they', 'he'],
#  'much.': ['You', 'It'],
#  'know.': ['At', 'Don’t', 'That', 'I', 'It’s', 'That’s', 'I'],
#  'At': ['19,',
#   '26',
#   '19',
#   '26',
#   '19',
#   '19',
#   '19,',
#   '26,',
#   '26',
#   '19,',
#   'least',
#   'the',
#   'the'],
#  '19,': ['I', 'you', 'you'],
#  'used': ['to', 'to', 'to'],
#  'best.': ['Because', 'You', 'Petroleum', 'Niceness'],
#  'care': ['about', 'and', 'about', 'about', 'about'],
#  'about': ['anyone',
#   'you.',
#   'you',
#   'you',
#   'you',
#   'my',
#   'any',
#   'this',
#   'my',
#   'it.',
#   'the',
#   'yourself.',
#   'your',
#   'stuff',
#   'a'],
#  'anyone': ['else.', 'say'],
#  'else.': ['That’s'],
#  'That’s': ['the',
#   'not',
#   'how',
#   'why',
#   'why',
#   'what',
#   'not',
#   'great.',
#   'how',
#   'great.',
#   'it.',
#   'rude.',
#   'the',
#   'how',
#   'important.”',
#   'the',
#   'how',
#   'how',
#   'the',
#   'how'],
#  'best': ['way', 'eight', 'version'],
#  'way': ['to', 'the', 'of', 'man,'],
#  'dance.': ['Dance', 'Why'],
#  'Dance': ['like'],
#  'no': ['one’s',
#   'like,',
#   'very',
#   'to',
#   'reason.',
#   'purpose',
#   'point',
#   'one',
#   'one',
#   'one',
#   'one',
#   'idea',
#   'idea',
#   'coming'],
#  'one’s': ['watching'],
#  'watching': ['applies'],
#  'applies': ['for'],
#  'women': ['who',
#   'are',
#   'come',
#   'who',
#   'are',
#   'get',
#   'are',
#   'are',
#   'are',
#   'think',
#   'have'],
#  'who': ['are', 'give', 'are', 'were', 'didn’t', 'had', 'was', 'was', 'play'],
#  'dancing.': ['Men', 'It’s', 'It’s'],
#  'Men': ['should'],
#  'should': ['stop.', 'be', 'I', 'I', 'be'],
#  'stop.': ['Please.', 'Deduct'],
#  'Please.': ['Because'],
#  'men,': ['anything'],
#  'anything': ['which', 'less', 'more', 'that'],
#  'which': ['is', 'really', 'are'],
#  'is': ['not',
#   'dancing.',
#   'music.',
#   'just',
#   'this?',
#   'this?',
#   'yours.',
#   'this',
#   'do',
#   'why',
#   'like,',
#   'like,',
#   'the',
#   'this',
#   'super',
#   'not',
#   'being',
#   'the',
#   'going',
#   'obviously',
#   'after',
#   'coined',
#   'when',
#   'in',
#   'like…',
#   'scanning',
#   'standing.',
#   '10:10',
#   'going',
#   'fake',
#   'my',
#   'shining',
#   'super',
#   'walking',
#   'walking',
#   'happening?',
#   'walking',
#   'so',
#   '10:10',
#   'standing',
#   'that',
#   'so',
#   'damn',
#   'okay',
#   'happening?',
#   'too',
#   'a',
#   'paining.',
#   'the',
#   'the',
#   'my',
#   'the',
#   'actually',
#   'super',
#   'like',
#   'being',
#   'scared',
#   'eye',
#   'like…',
#   'my',
#   'lame,',
#   'me,',
#   'cleaning',
#   'just',
#   'just',
#   'the',
#   'in',
#   'the',
#   'not',
#   'not',
#   'not',
#   'not',
#   'weak,',
#   'not',
#   'how',
#   'number',
#   'Gopal.”',
#   'like…',
#   'me.',
#   'so',
#   'driving,',
#   'how',
#   'true.',
#   'like,',
#   'too',
#   'arguing',
#   'completely',
#   'drenched,',
#   'a',
#   'he',
#   'coming?',
#   'giving',
#   'when',
#   'screwed',
#   'so',
#   'one',
#   'in',
#   'independent',
#   'not',
#   'indie.',
#   'when',
#   'emptiness,',
#   'talking',
#   'talking',
#   'serving',
#   'for',
#   'for',
#   'a',
#   'a',
#   'hitting',
#   'easily',
#   'happiness',
#   'sorrow',
#   'reservation',
#   'a',
#   'going',
#   'little',
#   'where'],
#  'not': ['standing',
#   'a',
#   'dancing',
#   'high',
#   'getting',
#   'a',
#   'feeling',
#   'pretty',
#   'pretty',
#   'in',
#   'shy.',
#   'even',
#   'even',
#   'be',
#   'my',
#   'kind.',
#   'like',
#   'a',
#   'decided',
#   'coming',
#   'to',
#   'with',
#   'with',
#   'rewarded',
#   'rewarded.',
#   'working.',
#   'rewarded.',
#   'rewarded.',
#   'nice',
#   'kidding,',
#   'for',
#   'mainstream',
#   'patronising'],
#  'standing': ['is', 'there', 'here,', 'behind'],
#  'good': ['enough', 'for', 'evening.', 'happens'],
#  'enough': ['bar,', 'for', 'it', 'pressure'],
#  'bar,': ['okay.'],
#  'okay.': ['I’m', 'Those', 'Gamma'],
#  'I’m': ['like,',
#   'dancing.”',
#   'like,',
#   'late',
#   'not',
#   'not…',
#   'around',
#   'not',
#   'not',
#   'like,',
#   'talking',
#   'sorry',
#   'sorry',
#   'so',
#   'like,',
#   'not',
#   'your',
#   'like,',
#   'sitting',
#   'a',
#   'a',
#   'sitting',
#   'a',
#   'like,',
#   'talking',
#   'like',
#   'like,',
#   'waiting',
#   'like,',
#   'like,',
#   'just',
#   'like,',
#   'very',
#   'standing',
#   'like',
#   'like,',
#   'obviously',
#   'like,',
#   'like,',
#   'half',
#   'behind',
#   'pushing',
#   'a',
#   'changing',
#   'chilling',
#   'sorry,',
#   'like,',
#   'sorry.',
#   'troubling',
#   'like,',
#   'like',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like',
#   'like,',
#   'not',
#   'sitting',
#   'like,',
#   'sorry,',
#   'never',
#   'going',
#   'going',
#   'sitting',
#   'like,'],
#  '“Bro,': ['there', 'I’m', 'why', 'how', 'why', 'what', 'this', 'can', 'I'],
#  'there': ['is',
#   'with',
#   'are',
#   'are',
#   'are',
#   'are',
#   'was',
#   'was',
#   'like…',
#   'was',
#   'is',
#   'is.',
#   'isn’t',
#   'is',
#   'will'],
#  'music.': ['Dance,'],
#  'Dance,': ['no.”'],
#  'no.”': ['“Bro,'],
#  'dancing.”': ['That’s'],
#  'dancing': ['guys.'],
#  'It': ['is',
#   'is',
#   'just',
#   'becomes',
#   'just',
#   'couldn’t',
#   'just',
#   'can’t',
#   'must',
#   'was',
#   'gets',
#   'was',
#   'was',
#   'gets',
#   'gets',
#   'won’t',
#   'breaks',
#   'hits',
#   'is',
#   'can’t',
#   'serves',
#   'means'],
#  'painful': ['to'],
#  'watch.': ['But'],
#  'But': ['at',
#   'at',
#   'you',
#   'there',
#   'I',
#   'I’ll',
#   'your',
#   'he',
#   'what',
#   'then',
#   'I',
#   'this',
#   'like',
#   'it',
#   'if',
#   'usually',
#   'our',
#   'she',
#   'it',
#   'I',
#   'it’s',
#   'let’s'],
#  'when': ['you',
#   'you',
#   'they',
#   'I',
#   'I',
#   'we',
#   'a',
#   'you',
#   'the',
#   'the',
#   'you',
#   'it’s',
#   'you',
#   'you',
#   'you',
#   'you'],
#  'go': ['to',
#   'out,',
#   'to',
#   'shake',
#   'for',
#   'anywhere,',
#   'inside',
#   'and',
#   'to',
#   'to',
#   'to',
#   'to',
#   'into',
#   'out.”',
#   'out.”',
#   'outside',
#   'now.”',
#   'for'],
#  'club,': ['it’s'],
#  'great.': ['You’re', 'And', 'Director’s', 'So', 'Even'],
#  'You’re': ['already', 'like,', 'my', 'sitting'],
#  'already': ['having', 'high.', 'part'],
#  'having': ['fun', 'noodles.'],
#  'fun': ['because'],
#  'you’re': ['already',
#   'still',
#   'like,',
#   'like,',
#   'there',
#   'Tina.',
#   'talking',
#   'really',
#   'cute.”',
#   'like,',
#   'on',
#   'a',
#   'like,',
#   'a',
#   'done',
#   'crying'],
#  'high.': ['Yeah,', 'That'],
#  'right?': ['Because', 'The'],
#  'out,': ['one', 'it'],
#  'one': ['guy',
#   'on',
#   'on',
#   'on',
#   'with',
#   'bullshit',
#   'is',
#   'second.',
#   'part',
#   'second',
#   'second,',
#   'second,',
#   'hour.”',
#   'or',
#   'because',
#   'will',
#   'will',
#   'request.',
#   'will',
#   'bed',
#   'can',
#   'has',
#   'gives',
#   'part',
#   'family,'],
#  'guy': ['will',
#   'friends',
#   'next',
#   'with',
#   'came',
#   'but',
#   'is',
#   'ever.',
#   'was'],
#  'will': ['have',
#   'we',
#   'die',
#   'be',
#   'get',
#   'leave.',
#   'stay',
#   'reflect',
#   'handle',
#   'handle',
#   'sing',
#   'touch',
#   'explode.',
#   'come',
#   'be',
#   'try',
#   'say',
#   'awaken,'],
#  'have': ['a',
#   'preferences.',
#   'a',
#   'diet',
#   'Jack',
#   'a',
#   'to',
#   'so',
#   'stage',
#   'you',
#   'to',
#   'become',
#   'been',
#   'taken',
#   'a',
#   'to',
#   'the',
#   'my',
#   'an',
#   'two',
#   'high',
#   'tried.',
#   'to',
#   'no',
#   'a',
#   'a',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'to',
#   'a',
#   'a',
#   'a',
#   'a',
#   'you',
#   'a',
#   'to',
#   'to',
#   'no',
#   'you',
#   'money,',
#   'audience.',
#   'to',
#   'to'],
#  'plan,': ['“Bro,'],
#  'we': ['spending',
#   'can',
#   'forgetting',
#   'have',
#   'make?”',
#   'do',
#   'party?',
#   'have',
#   'discovered',
#   'have',
#   'decided',
#   'can’t',
#   'solved',
#   'forgot',
#   'didn’t',
#   'have',
#   'do?',
#   'leave',
#   'can',
#   'are',
#   'were',
#   'all',
#   'need',
#   'got',
#   'do'],
#  'spending': ['400'],
#  '400': ['bucks'],
#  'bucks': ['on'],
#  'drinks': ['in'],
#  'in': ['the',
#   'awhile.',
#   'our',
#   'civilisation.',
#   'my',
#   'a',
#   'a',
#   'this',
#   'the',
#   'the',
#   'front',
#   'a',
#   'a',
#   '3D.',
#   'one',
#   'my',
#   'the',
#   'Bandra.',
#   'our',
#   'like',
#   'my',
#   'my',
#   'my',
#   'your',
#   'the',
#   'her',
#   'the',
#   'front',
#   'my',
#   'my',
#   'the',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'life',
#   'loop…',
#   'the',
#   'my',
#   'this',
#   'right',
#   'their',
#   'a',
#   'a',
#   'this',
#   'this.',
#   'this',
#   'every…'],
#  'club?': ['When', 'We'],
#  'When': ['we', 'you', 'I’m', 'guests', 'you', 'our', 'the', 'the', 'I'],
#  'can': ['drink',
#   'say',
#   'I',
#   'tell',
#   'we',
#   'do.',
#   'you',
#   'do,',
#   'do.',
#   'do',
#   'do',
#   'I',
#   'sense',
#   'we',
#   'all',
#   'call',
#   'I',
#   'go',
#   'I',
#   'play',
#   'play',
#   'escape',
#   'we',
#   'carry',
#   'do',
#   'handle'],
#  'drink': ['on', 'bro!'],
#  'way,': ['bro.”'],
#  'bro.”': ['What', '“Arjun,', 'It’s', '“Hey'],
#  'What': ['do',
#   'kind',
#   'is',
#   'is',
#   'is',
#   'if…',
#   'if…',
#   'is',
#   'shocked',
#   'the',
#   'is',
#   'filter',
#   'do'],
#  'want': ['to',
#   'to',
#   'that',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'much',
#   'the',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'drink?': ['“Whatever'],
#  '“Whatever': ['gets'],
#  'gets': ['me',
#   'cured',
#   'very',
#   'very',
#   'very',
#   'very',
#   'very',
#   'very',
#   'very',
#   'out.'],
#  'me': ['high',
#   'warm.',
#   'a',
#   'follow',
#   'bathroom',
#   'now,',
#   'and',
#   'feel',
#   'better',
#   'tell',
#   'and',
#   'tell,',
#   'not',
#   'for',
#   'because',
#   'and',
#   'was',
#   'only.',
#   'lame',
#   'that,',
#   'ignore',
#   'give',
#   'and',
#   'start',
#   'about',
#   'that',
#   'and',
#   'in',
#   'and',
#   '♫\n♫',
#   '♫\n♫',
#   'a',
#   'anyway.',
#   'with'],
#  'high': ['fast.”', 'you’re', 'EQ.'],
#  'fast.”': ['It’s'],
#  'neat,': ['neat,', 'neat,', 'neat.'],
#  'neat.': ['It’s'],
#  'awesome.': ['At', 'You', 'It’s', 'But', 'The', 'The'],
#  '26': ['you', 'you’re', 'you'],
#  'preferences.': ['“Can'],
#  '“Can': ['I', 'you', 'you'],
#  'Jack': ['and', 'with…'],
#  'Coke': ['but'],
#  'diet': ['Coke,', 'Coke.'],
#  'Coke,': ['please.'],
#  'please.': ['Oh'],
#  'they': ['don’t',
#   'care',
#   'care',
#   're-invent',
#   'go',
#   'go',
#   'get',
#   'just',
#   'get',
#   'have',
#   'get',
#   'turned',
#   'come',
#   'get',
#   'might',
#   'take',
#   'become',
#   'are',
#   'are',
#   'call',
#   'are',
#   'are?',
#   'die',
#   'will',
#   'take',
#   'don’t',
#   'don’t',
#   'have',
#   'stop'],
#  'Coke.': ['What'],
#  'barbaric': ['place'],
#  'place': ['is'],
#  'this?': ['I', 'Petroleum?'],
#  'can’t': ['have',
#   'come',
#   'today.”',
#   'do',
#   'tell',
#   'handle',
#   'be.',
#   'make',
#   'protect',
#   'ignore',
#   'ignore',
#   'ignore',
#   'get',
#   'because',
#   'be',
#   'play',
#   'be',
#   'be'],
#  'with…': ['Wine'],
#  'Wine': ['for'],
#  'me.”': ['At', '“No,', '“So', '“Please', '–', '*Phone'],
#  'And': ['by',
#   'then',
#   'second',
#   'you',
#   'suddenly,',
#   'now',
#   'two',
#   'then',
#   'there',
#   'then',
#   'as',
#   'I’m',
#   'you’ll',
#   'it’s',
#   'I',
#   'the',
#   'there',
#   'it’s',
#   'we’re',
#   'she',
#   'my',
#   'my',
#   'my',
#   'then',
#   'she',
#   'I’m',
#   'then',
#   'I’ve',
#   'he’s',
#   'you’re',
#   'we',
#   'here’s',
#   'I’m',
#   'my',
#   'Gopal',
#   'Uber',
#   'this',
#   'he’s',
#   'I',
#   'I',
#   'kids'],
#  'by': ['any', 'me.', 'this', 'then.', 'the', 'us.', 'her.', 'the'],
#  'any': ['chance', 'trip', 'idea.'],
#  'chance': ['if'],
#  'if': ['you’re',
#   'you',
#   'you',
#   'you',
#   'you',
#   'see',
#   'she',
#   'you',
#   'I',
#   'you',
#   'he',
#   'it’s',
#   'someone’s',
#   'you',
#   'you'],
#  'still': ['not', 'feel', 'climb', 'looking', 'say'],
#  '“Bro!': ['Shots!?”', 'Can'],
#  'Shots!?”': ['“Sir,'],
#  '“Sir,': ['what',
#   'how',
#   'this',
#   'please',
#   'where',
#   'an',
#   'if',
#   'okay!',
#   'if',
#   'it’s',
#   'it’s',
#   'your'],
#  'what': ['kind',
#   'I’m',
#   'you’re',
#   'I',
#   'happened',
#   'happened?”',
#   'kids',
#   'happens',
#   'happens',
#   'he’s',
#   'happens',
#   'are',
#   'do',
#   'he',
#   'he',
#   'he'],
#  'shots?”': ['“Uh,', '“Uh,'],
#  '“Uh,': ['shots!?”', 'shot-shots!?”'],
#  'shots!?”': ['“Sir,'],
#  'how': ['many',
#   'do',
#   'much',
#   'can',
#   'to',
#   'cool',
#   'amazing',
#   'you',
#   'I',
#   'he',
#   'nice',
#   'did',
#   'this',
#   'you',
#   'it',
#   'annoying',
#   'you',
#   'I'],
#  'many': ['shots?”', 'rules', 'doors', 'doors', 'of', 'of', 'guys'],
#  'shot-shots!?”': ['“Can'],
#  'stop': ['shouting,', 'shouting?”', 'feeling', 'now.', 'mid-sentence.'],
#  'shouting,': ['sir?'],
#  'sir?': ['Can'],
#  'Can': ['you',
#   'you',
#   'you',
#   'you',
#   'we',
#   'we',
#   'you',
#   'you',
#   'you',
#   'I',
#   'you',
#   'you',
#   'you',
#   'we'],
#  'please': ['stop', 'don’t', 'stand', 'hurry'],
#  'shouting?”': ['You'],
#  'there’s': ['no'],
#  '“Shots?': ['What'],
#  'Petroleum?': ['Yeah!”'],
#  'Yeah!”': ['It’s'],
#  'Petroleum': ['shots.'],
#  'shots.': ['It’s'],
#  'bad': ['for', 'show.'],
#  'environment,': ['good'],
#  'club': ['is', 'like,'],
#  'yours.': ['You’re'],
#  '“Whoo!': ['Yeah,', 'Let’s'],
#  'friends': ['and', 'for', 'come', 'can.', 'come', 'ask'],
#  'me.': ['It’s',
#   'Basically',
#   'She',
#   'What’s',
#   'I’m',
#   'This',
#   'My',
#   'My',
#   '“Kenny,',
#   'So',
#   'They',
#   'Did',
#   'Because'],
#  'our': ['night.”', 'house?', 'lives.', 'female', 'female'],
#  'night.”': ['At'],
#  '“Ssh!': ['We'],
#  'We': ['are',
#   'practised',
#   'could',
#   'went',
#   'are',
#   'stole',
#   'have',
#   'need',
#   'have',
#   'have',
#   'can',
#   'don’t'],
#  'loudest': ['table'],
#  'table': ['here,'],
#  'here,': ['guys.”', 'facing'],
#  'guys.”': ['But', 'So'],
#  'care.': ['At', '“Sir,'],
#  'with': ['your',
#   'these',
#   'them',
#   'you,',
#   'this',
#   'you.”',
#   'me.',
#   'me',
#   'leprosy',
#   'two',
#   'her',
#   'it',
#   'that.',
#   'me,',
#   'her?”',
#   'her',
#   'her',
#   'us',
#   'this',
#   'the',
#   'it,',
#   'life',
#   'elation',
#   'the'],
#  'your': ['friends.',
#   'night,',
#   'friends.',
#   'parents',
#   'parents.',
#   'dad',
#   'mom',
#   'eight',
#   'prince,',
#   'hair.',
#   'body.',
#   'face.”',
#   'house.',
#   'house?”',
#   'house',
#   'birthday.',
#   'birthday.”',
#   'case,',
#   'phone',
#   'name?”',
#   'sister.”',
#   'phone’s',
#   'trip,',
#   'inner',
#   'life',
#   'nuclear',
#   'life',
#   'watchman'],
#  'friends.': ['It’s', 'Because'],
#  'night,': ['it’s'],
#  'never': ['felt', 'let', 'going', 'meets.'],
#  'felt': ['cold…'],
#  'cold…': ['because'],
#  'ego': ['kept'],
#  'kept': ['me'],
#  'warm.': ['It’s', 'You'],
#  'nice.': ['When', 'At', 'I', 'Just', 'That', 'Broke'],
#  'grow': ['older'],
#  'older': ['you'],
#  'become': ['open', 'the', 'hyper', 'rude.', 'negatively…'],
#  'open': ['minded'],
#  'minded': ['so'],
#  'lose': ['heat.'],
#  'heat.': ['“Give'],
#  '“Give': ['me'],
#  'neck': ['warmer.”'],
#  'warmer.”': ['I'],
#  'read': ['a'],
#  'book': ['today.', 'or'],
#  'today.': ['You', 'So'],
#  'so…': ['At'],
#  'enter': ['the', 'a', 'you', 'the'],
#  'make': ['a',
#   'a',
#   'a',
#   'me…',
#   'me',
#   'out',
#   'rotis,',
#   'some',
#   'this',
#   'them',
#   'an',
#   'an',
#   'happy',
#   'a',
#   'it',
#   'it',
#   'it',
#   'everything'],
#  'circle': ['guys!'],
#  'guys!': ['Yeah!'],
#  'Yeah!': ['Let’s', 'But', 'He', 'That’s', 'So,'],
#  'circle.': ['It’s'],
#  'such': ['an', 'stunningness.', 'a'],
#  'an': ['awesomely',
#   'adult',
#   'amazingly',
#   'obstacle.”',
#   'angel',
#   'NGO',
#   'example.',
#   'asshole',
#   'auto-rickshaw',
#   'auto',
#   'auto',
#   'indie',
#   'indie',
#   'indie',
#   'eventual',
#   'alaap',
#   'alaap,',
#   'American',
#   'alaap',
#   'alaap.',
#   'awesome'],
#  'awesomely': ['unique'],
#  'unique': ['idea,'],
#  'idea,': ['bro!”'],
#  'bro!”': ['Other', 'It’s', 'All'],
#  'Other': ['guy’s'],
#  'guy’s': ['like,'],
#  'come': ['up',
#   'on',
#   'home,',
#   'and',
#   'like,',
#   'towards',
#   'up',
#   'for',
#   'at',
#   'to',
#   'home.',
#   'from',
#   'home',
#   'home',
#   'back.',
#   'to',
#   'to',
#   'and',
#   'back'],
#  'up': ['with',
#   'with',
#   'died',
#   'in',
#   'in',
#   'with',
#   'air',
#   'to',
#   'the',
#   'and',
#   'in'],
#  'these': ['awesome', 'two', 'three', 'five', '1400'],
#  'awesome': ['ideas?', 'audience,'],
#  'ideas?': ['Do'],
#  'Do': ['you', 'I?', 'you'],
#  'or': ['something?”', 'anything.', 'something.', 'what?”', 'the', 'a'],
#  'something?”': ['“Yeah'],
#  '“Yeah': ['bro,', 'here', 'yeah.'],
#  'bro,': ['it’s', 'listen', 'what', 'give', 'we'],
#  'brain.': ['Okay'],
#  'Okay': ['guys,', 'let’s'],
#  'guys,': ['let’s', 'you', 'my', 'for'],
#  'let’s': ['all', 'try', 'chill.', 'be', 'put', 'participate.'],
#  'all': ['together',
#   'awkward',
#   'cool.”',
#   'the',
#   'their',
#   'clean.',
#   'clean.”',
#   'of',
#   'of',
#   'be',
#   'that.',
#   'connected',
#   'clap'],
#  'together': ['do'],
#  'leg': ['thing.', 'thing.', 'from'],
#  'thing.': ['The', 'Guys,', 'Centre', 'Nice'],
#  'Guys,': ['are', 'by', 'my', 'let’s', 'do'],
#  'forgetting': ['something?'],
#  'something?': ['Bollywood.'],
#  'Bollywood.': ['Arjun,'],
#  'Arjun,': ['get'],
#  'get': ['it',
#   'it',
#   'older,',
#   'naked.',
#   'naked.',
#   'up,',
#   'up.',
#   'intimidated',
#   'dehydrated.',
#   'a',
#   'pissed.',
#   'up',
#   'eye',
#   'out.',
#   'into',
#   'angry,',
#   'into',
#   'into',
#   'the',
#   'laid.',
#   'very',
#   'out.'],
#  'right': ['Arjun.”', 'before', 'next', 'now.'],
#  'Arjun.”': ['“I’m'],
#  '“I’m': ['not'],
#  'getting': ['the'],
#  'rhythm.”': ['“Arjun,'],
#  '“Arjun,': ['get', 'it’s'],
#  'right!': ['We'],
#  'practised': ['this'],
#  'this': ['bro.”',
#   'shit',
#   'new',
#   'shy',
#   'Neha',
#   'house,',
#   'bullshit!”',
#   'emotion.',
#   'hypothetical',
#   'is…”',
#   'Kenny.',
#   'time',
#   'one',
#   'was',
#   'lady.',
#   'woman',
#   'is',
#   'room?”',
#   'weird',
#   'sim',
#   'out.',
#   'is',
#   'guy.',
#   'new',
#   'is',
#   'man',
#   'guy',
#   'is',
#   'more',
#   'sexy',
#   'shit.',
#   'puppy.',
#   'water',
#   'love',
#   'shit.',
#   'shit.',
#   'one',
#   'next',
#   'together?'],
#  'fine.': ['Now', 'Oh!', 'Take', 'And', 'I', 'Just'],
#  'Now': ['we’re', 'I'],
#  'we’re': ['going', 'cool', 'at', 'in'],
#  'new': ['thing.',
#   'venue?',
#   'place.',
#   'person',
#   'emotion.',
#   'alloy.',
#   'dish.',
#   'thing'],
#  'Centre': ['solo'],
#  'solo': ['dance!'],
#  'dance!': ['Go'],
#  'Go': ['to', 'to', 'watch'],
#  'centre.': ['Go'],
#  'centre.”': ['“Bro,'],
#  'making': ['so'],
#  'rules': ['dude?”'],
#  'dude?”': ['“Have'],
#  '“Have': ['a'],
#  'shot,': ['bro!”'],
#  '26,': ['you'],
#  'though.': ['I', 'At', 'When', 'It’s', 'Go'],
#  'once': ['in'],
#  'awhile.': ['Like,'],
#  'Like,': ['go'],
#  'club.': ['I’m', 'So'],
#  '“Hey!': ['Nice', 'What’s', 'Respect', 'What’s', 'It’s'],
#  'Nice': ['beats.', 'to', 'people', 'people', 'people'],
#  'beats.': ['I’ll'],
#  'I’ll': ['go',
#   'show',
#   'still',
#   'give',
#   'just',
#   'come',
#   'go',
#   'stop',
#   'give',
#   'give',
#   'give',
#   'do'],
#  'shake': ['a'],
#  'bit.”': ['And'],
#  'then': ['I',
#   'I',
#   'guys',
#   'the',
#   'I',
#   'suddenly',
#   'there',
#   'she',
#   'it’s',
#   'I',
#   'he'],
#  'remember': ['I'],
#  'pay': ['rent,'],
#  'rent,': ['then'],
#  'Deduct': ['it'],
#  'from': ['my',
#   'light',
#   'the',
#   'guys',
#   'audience]',
#   'such',
#   'China.',
#   'my',
#   'my',
#   'the',
#   'the',
#   'that',
#   'history',
#   'history'],
#  'soul.': ['Yeah'],
#  'Yeah': ['so!'],
#  'so!': ['There'],
#  'There': ['are', 'must', 'is', 'is', 'is', 'is'],
#  'certain': ['advantages', 'things'],
#  'advantages': ['though.'],
#  'say': ['no',
#   'that?',
#   'that?',
#   'that,',
#   'that?',
#   'you',
#   'the',
#   'that…',
#   'that.',
#   'that.”',
#   'excuse',
#   'the',
#   'this.',
#   'hi.',
#   'hi.',
#   'thank',
#   'one,',
#   '‘hey’.',
#   '‘hey’.'],
#  'very': ['confidently…',
#   'ironic,',
#   'dry.”',
#   'tensed.',
#   'tough.',
#   'emotional',
#   'difficult',
#   'like…',
#   'sweet',
#   'tense.',
#   'tense',
#   'tense.',
#   'aggressive,',
#   'aggressive.',
#   'emotional.'],
#  'confidently…': ['to'],
#  'were': ['saying', 'with', 'like,', 'telling', 'driving', 'looking'],
#  'saying': ['no', 'bye?”'],
#  'parents': ['like', 'too,', 'come', 'are'],
#  'left': ['and'],
#  'right.': ['It’s', 'Why', 'You', 'I’m', 'Like', 'So', 'So'],
#  'ironic,': ['at'],
#  'only': ['two', 'the', 'release', 'three', 'reason'],
#  'two': ['people',
#   'girls',
#   'Russian',
#   'Russian',
#   'other',
#   'little',
#   'days!”',
#   'days?”',
#   'people',
#   'metals,',
#   'things.'],
#  'give': ['a', 'you', 'a', 'you', 'you', 'us', 'you', 'you', 'you'],
#  'shit': ['about', 'lighting?', 'I', 'about', 'like'],
#  'genuinely': ['are', 'dirty.'],
#  'parents.': ['But'],
#  'hate': ['them!', 'you,', 'asking', 'asking', 'to'],
#  'them!': ['Because'],
#  'damn': ['annoying,',
#   'dirty.',
#   'badass.',
#   'nice.',
#   'annoying.',
#   'convenient',
#   'convenient.',
#   'convenient.'],
#  'annoying,': ['right.'],
#  'Why': ['do', 'do', 'should', 'would', 'are', 'may', 'would', 'are'],
#  'much?': ['At', 'Oh'],
#  'party,': ['they’ll'],
#  'they’ll': ['be', 'be', 'be'],
#  'be': ['like,',
#   'a',
#   'like,',
#   'a',
#   'better',
#   'like…',
#   'like,',
#   'published',
#   'rude?',
#   'like,',
#   'shooting',
#   'the',
#   'myself.',
#   'an',
#   'a',
#   'Kenny.',
#   'the',
#   'a',
#   'that',
#   'creepy.',
#   'like,',
#   'like,',
#   'at',
#   'like,',
#   'single',
#   'with',
#   'a',
#   'respected.”',
#   'like,',
#   'awesome.”',
#   'like,',
#   'outside',
#   'mean,',
#   'protected.',
#   'like,',
#   'like,',
#   'alright.',
#   'super',
#   'like,',
#   'sad?',
#   'happy',
#   'poetically',
#   'abstract.',
#   'abstract.',
#   'abstract,',
#   'conventional.',
#   'about',
#   'about…',
#   'sad',
#   'this',
#   'like,'],
#  '“At': ['least'],
#  'least': ['eat', 'get', 'bro,'],
#  'eat': ['something…”'],
#  'something…”': ['“Mom,'],
#  '“Mom,': ['why', 'I'],
#  'nutrition': ['so'],
#  'Shit,': ['mom.', 'I'],
#  'mom.': ['I’m', 'Is', 'My', 'My', 'She', 'She', '*beatboxes*', 'It', 'Why'],
#  'late': ['for'],
#  'party.': ['Mom!'],
#  'Mom!': ['Why'],
#  'doors': ['in', 'in'],
#  'house?': ['I'],
#  'you,': ['mom.', 'you', 'is', 'sexiest', 'you’re', 'I’ll', 'you'],
#  'Hogwarts?': ['I’m', 'Can'],
#  'wizard,': ['I'],
#  'DJ.': ['You', 'It'],
#  'let': ['me', 'me'],
#  'follow': ['my'],
#  'dream,': ['mom.”'],
#  'mom.”': ['Yeah!'],
#  'things': ['that', 'get', 'which', 'sad.'],
#  'gotten': ['over'],
#  'over': ['at', 'at'],
#  'Like…': ['You'],
#  'not…': ['I'],
#  'stage': ['fright', 'and', 'of'],
#  'fright': ['anymore.'],
#  'anymore.': ['It’s', 'Shit,'],
#  'job.': ['So…'],
#  'So…': ['I'],
#  '“No,': ['no!', 'you', 'it’s'],
#  'no!': ['I', 'That’s', 'That’s'],
#  'today.”': ['I'],
#  'It’ll': ['be', 'be'],
#  'show.': ['But'],
#  'feel': ['shy', 'all', 'shy', 'like', 'warm.'],
#  'shy': ['though.', 'today.', 'around', 'shit?'],
#  'around': ['really', 'women.', 'him.'],
#  'really': ['pretty', 'need', 'pretty', 'cute.”', 'happened.', 'important.'],
#  'pretty': ['women.', 'enough', 'enough', 'intimidating'],
#  'women.': ['You', 'You'],
#  'know…': ['Yeah,'],
#  'awkward': ['and'],
#  'mean': ['I', 'the', 'live', 'didi'],
#  'reaction': ['or'],
#  'anything.': ['I'],
#  'Don’t': ['worry,', 'do', 'do', 'be', 'do', 'worry,', 'lie.', 'you'],
#  'worry,': ['I’m', 'like'],
#  'feeling': ['shy', 'that'],
#  'So': ['it’s',
#   'I',
#   'these',
#   'when',
#   'recently',
#   'she',
#   'I’m',
#   'I’m',
#   'then',
#   'the',
#   'guys,',
#   'the',
#   'dry.',
#   'my',
#   'she',
#   'please',
#   'my',
#   'my',
#   'I',
#   'I',
#   'what',
#   'no',
#   'I',
#   'I',
#   'he',
#   'I',
#   'as',
#   'I',
#   'sweet',
#   'this',
#   'he',
#   'basically,',
#   'I',
#   'I',
#   'this',
#   'can',
#   'you',
#   'in'],
#  'Oh!': ['Did', 'Okay!”'],
#  'Did': ['he', 'he', 'a', 'the', 'the', 'you', 'anyone', 'you', 'you'],
#  'he': ['just',
#   'just?',
#   'acts',
#   'is',
#   'knows',
#   'do',
#   'was',
#   'was',
#   'was',
#   'gets',
#   'starts',
#   'is',
#   'was',
#   'answered',
#   'was.',
#   'was.',
#   'starts',
#   'would’ve',
#   'thought',
#   'looks',
#   'looks',
#   'was',
#   'is',
#   'has',
#   'turns',
#   'gets',
#   'steps',
#   'enters…',
#   'is',
#   'enters',
#   'is',
#   'did.',
#   'sold',
#   'is',
#   'starts',
#   'touching',
#   'is',
#   'is'],
#  'that?': ['Did', 'How', 'I’m', 'Because'],
#  'just?': ['Did'],
#  'comedian': ['just'],
#  'joke?': ['All'],
#  'All': ['the', 'the', 'the', 'she'],
#  '“Brutal': ['bro!”'],
#  '“Really?': ['Freaking'],
#  'Freaking': ['asshole.'],
#  'asshole.': ['Have'],
#  'Have': ['you', 'you', 'conversations', 'you'],
#  'seen': ['me?', 'me?', 'my', 'happy', 'them?', 'that'],
#  'me?': ['Have', 'What'],
#  'lighting?': ['Give'],
#  'Give': ['me', 'me'],
#  'bathroom': ['lights.'],
#  'lights.': ['I’ll'],
#  'show': ['you,'],
#  'son': ['of', 'of', 'of'],
#  'bitch.': ['How', 'How', 'I'],
#  'dare': ['you', 'you', 'you'],
#  'that,': ['Kenny?', 'I', '“Hey!'],
#  'Kenny?': ['Wow!'],
#  'Wow!': ['We’re'],
#  'We’re': ['not', 'like,', 'gonna', 'driving', 'chill'],
#  'him?': ['You'],
#  'put': ['on',
#   'some',
#   'eyelashes',
#   'like',
#   'them',
#   'my',
#   'food',
#   'a',
#   'them',
#   'all',
#   'all',
#   'him',
#   'it',
#   'an',
#   'an',
#   'an',
#   'an',
#   'a'],
#  'face?': ['My'],
#  'My': ['mother',
#   'friends…',
#   'brain',
#   'brain',
#   'soul',
#   'mom',
#   'maid',
#   'maid,',
#   'mom',
#   'mom',
#   'maid’s',
#   'name',
#   'sister’s',
#   'tears',
#   'parents'],
#  'mother': ['doesn’t'],
#  'doesn’t': ['recognise',
#   'know',
#   'know',
#   'come',
#   'even',
#   'even',
#   'cover',
#   'matter.'],
#  'recognise': ['me'],
#  'now,': ['yeah!'],
#  'yeah!': ['I'],
#  'eye': ['liner,', 'shadow', 'shadow.', 'contact.', 'contact.', 'contact'],
#  'liner,': ['some'],
#  'mascara,': ['I'],
#  'eyelashes': ['to'],
#  'sun': ['roof,'],
#  'roof,': ['bitch.'],
#  'seems.': ['I'],
#  'shadow': ['from'],
#  'light': ['to', 'guys', 'guys', 'behaves'],
#  'dark,': ['dark'],
#  'dark': ['to'],
#  'light,': ['four'],
#  'four': ['dimensional', 'of', 'light'],
#  'dimensional': ['eye'],
#  'shadow.': ['You'],
#  'met': ['my', 'the'],
#  'grandfather.': ['He’s'],
#  'He’s': ['doing', 'like,', 'soft.', 'like…', 'too'],
#  'doing': ['well.', 'is,', 'asanas', 'squats.', 'in', 'this.'],
#  'well.': ['I'],
#  'straightened': ['my'],
#  'hair': ['and'],
#  'lost': ['four'],
#  'fingers.': ['But'],
#  'climb': ['the'],
#  'Himalayas,': ['you'],
#  'bitch.”': ['It’s'],
#  'joke.': ['I', 'Because', 'As'],
# ...
#  'naked.': ['Look', 'So'],
#  'Look': ['at'],
#  'dad': ['at', 'hates', 'is'],
#  'home.': ['Your', 'Yeah!', 'Certain', 'Because', 'I', 'My'],
#  'Your': ['dad', 'dad', 'boyfriend', 'friends', 'parents'],
#  'hates': ['wearing', 'wearing'],
#  'clothes.': ['Yeah!', 'When'],
#  'He': ['just',
#   'won',
#   'was',
#   'looks',
#   'starts',
#   'immediately',
#   'opens',
#   'turns'],
#  'guests': ['come'],
#  'home,': ['your', 'my'],
#  'mom': ['is',
#   'is',
#   'is',
#   'turns',
#   'is',
#   'as',
#   'like,',
#   'is',
#   'and',
#   'could',
#   'just',
#   'catches'],
#  '“What': ['impression', 'if…', 'are', 'if', 'if', 'if'],
#  'impression': ['will'],
#  'make?”': ['Your'],
#  '“I': ['have', 'don’t', 'have', 'am', 'AM', 'don’t'],
#  'wear': ['clothes'],
#  'clothes': ['now?'],
#  'now?': ['No!”'],
#  'No!”': ['No!”', 'It’s', 'What?'],
#  'got': ['a', 'up,', 'off', 'to', 'to', 'it.'],
#  'bear': ['from'],
#  'wild.': ['And'],
#  'teaching': ['him'],
#  'him': ['how', 'and', 'cry.', 'up', 'in', 'on'],
#  'live': ['in', 'happily', 'here?”'],
#  'civilisation.': ['It’s'],
#  'crazy,': ['I'],
#  'That': ['is', 'when', 'the', 'means', 'means'],
#  'true': ['evolutionary'],
#  'evolutionary': ['stage'],
#  'men.': ['They'],
#  'They': ['dance',
#   'are',
#   'are',
#   'should',
#   'come',
#   'can',
#   'can’t',
#   'deserve',
#   'make',
#   'hit',
#   'are'],
#  'intimidating': ['women,'],
#  'talking': ['about.',
#   'about?',
#   'about.',
#   'about',
#   'about',
#   'about.',
#   'about.'],
#  'about.': ['Oh', 'Your', 'But', 'So'],
#  'so,': ['everyone’s'],
#  'everyone’s': ['a'],
#  'player.': ['Okay.'],
#  'Okay.': ['I’m', 'I’m', 'Why?', 'Why', 'If', 'And', 'They'],
#  'sorry': ['guys.', 'for'],
#  'looking': ['stupid.', 'at', 'at', 'at', 'at'],
#  'stupid.': ['All'],
#  'about?': ['What'],
#  'shit?': ['Shy?', 'It’s'],
#  'Shy?': ['Bro', 'I’m'],
#  'Bro': ['that’s', 'there', 'listen,'],
#  'that’s': ['not', 'even', 'how', 'the', 'my', 'the'],
#  'dictionary.': ['I’m'],
#  'hot,': ['when'],
#  'step': ['out'],
#  'out': ['on',
#   'and',
#   'loud.”',
#   'now.',
#   'the',
#   'of',
#   'of',
#   'of',
#   'the',
#   'the',
#   'the'],
#  'road,': ['a'],
#  'truck': ['full'],
#  'full': ['of', 'scared.'],
#  'No,': ['thanks', 'no!', 'no!', 'I'],
#  'thanks': ['and'],
#  'moonwalk': ['home.'],
#  'cool': ['I', 'with'],
#  'am,': ['Kenny.'],
#  'Kenny.': ['Shy?', 'You', 'Nice'],
#  'shy.': ['Yeah?”'],
#  'Yeah?”': ['That’s'],
#  'asking': ['for', 'guys'],
#  'opinions': ['from'],
#  'group.': ['Guys'],
#  'amazing': ['people', 'people.', 'term', 'I', 'at'],
#  'one.': ['They', 'The'],
#  'people.': ['Have', 'Like'],
#  'conversations': ['with'],
#  'them': ['one',
#   'in',
#   'and',
#   'somewhere',
#   'because',
#   'inside.',
#   'inside',
#   'and',
#   'when',
#   'play'],
#  'moment': ['you', 'she', 'you', 'she', 'she', 'he'],
#  'group,': ['they’ll'],
#  'like…': ['Just.',
#   '*Siren',
#   'It’s',
#   '♫',
#   '*fart',
#   'We’ll',
#   'My',
#   '*beatboxes*',
#   '*beatboxes*',
#   '“You',
#   '*Phone',
#   'Like',
#   'good',
#   'It’s',
#   'They'],
#  'Just.': ['They'],
#  'worst': ['people.', 'reason', 'reason.', 'culprit'],
#  'dating': ['guys,', 'advice'],
#  'boyfriend': ['one'],
#  'super': ['emotional.', 'bright.', 'sweet', 'impressed.'],
#  'emotional.': ['They’ll', 'This'],
#  'They’ll': ['be', 'come', 'be'],
#  '“Baby,': ['I'],
#  'wanna': ['say', 'say', 'say'],
#  'world': ['to', 'sleeps'],
#  'baby.”': ['Can', 'Okay'],
#  'hold': ['my', 'my'],
#  'hand': ['while', 'in'],
#  'while': ['I'],
#  'talk': ['to', 'to', 'in', 'about'],
#  'you?': ['Can'],
#  'hand?': ['I'],
#  'past': ['eight'],
#  'eight': ['months', 'months.', 'years.', 'months'],
#  'months': ['have', 'feel'],
#  'months.': ['Can'],
#  'finger': ['thing?', 'thing?'],
#  'thing?': ['Can', 'I'],
#  'that…': ['My'],
#  'friends…': ['Like'],
#  'Gopal': ['have', 'is'],
#  'been': ['friends', 'with', 'a'],
#  'years.': ['But'],
#  'life': ['time',
#   'pocket.',
#   'already,',
#   'savings.',
#   'is',
#   'will',
#   'nourishing',
#   'leaves'],
#  'time': ['baby.', 'is', 'my', 'is', 'you’re', 'was', 'to'],
#  'baby.': ['It'],
#  'physical': ['thing,'],
#  'thing,': ['it’s', 'she'],
#  'cuddling.': ['You'],
#  'me…': ['You'],
#  'know?': ['Like'],
#  'than': ['my', 'you,', 'one', 'one', 'one'],
#  'too,': ['you'],
#  'tell': ['you', 'anybody.', 'you', 'me.”', 'me.”', 'anybody.', 'me'],
#  'stories': ['that', 'though.'],
#  'anybody.': ['Baby,', 'She’s'],
#  'Baby,': ['just…'],
#  'just…': ['You’re', 'I', 'The', 'so'],
#  'princess,': ['I’m'],
#  'prince,': ['I'],
#  'that.”': ['And'],
#  'suddenly,': ['his'],
#  'his': ['guy',
#   'voice',
#   'mouth',
#   'car,',
#   'chair',
#   'phone',
#   'phone',
#   'money,',
#   'life',
#   'house.',
#   'door.',
#   'bed.',
#   'bedsheet.'],
#  'Neha': ['is'],
#  'being': ['so', 'very', 'there.'],
#  'clingy,': ['bro!'],
#  'bro!': ['Shit!', 'Bro', 'Bro', 'I'],
#  'E-M-O,': ['Emo!'],
#  'Emo!': ['Let’s'],
#  'house,': ['man.', 'NGO.', 'the'],
#  'man.': ['Hogwarts?', 'The', 'The'],
#  'party?': ['No!'],
#  'No!': ['Shit.', 'It'],
#  'Shit.': ['No'],
#  'No': ['DJ.', 'one', 'seriously,', 'I', 'one', 'one'],
#  'sucks.': ['Sucks'],
#  'Sucks': ['man.”'],
#  'man.”': ['That’s', '“Where'],
#  'trip': ['they', 'somewhere'],
#  'taken': ['to'],
#  'Goa.': ['Goa'],
#  'Goa': ['is'],
#  'number': ['one', 'one.”'],
#  'bullshit': ['story'],
#  'story': ['manufacturer.', 'bro.'],
#  'manufacturer.': ['No'],
#  'truthful': ['story.'],
#  'story.': ['Yes,'],
#  'round': ['of'],
#  'applause': ['for'],
#  'Thailand,': ['okay.'],
#  'Those': ['stories,'],
#  'stories,': ['Jesus.'],
#  'Jesus.': ['They'],
#  'published': ['as'],
#  'novels.': ['Guys'],
#  'bullshit…': ['I’m'],
#  '“Hey': ['man!',
#   'bro,',
#   'what’s',
#   'you',
#   'dickhead!”',
#   'Kenny,',
#   'Kenny,',
#   'bro,'],
#  'man!': ['You'],
#  'went': ['for', 'to', 'to'],
#  'somewhere': ['right?”', 'to'],
#  'right?”': ['He’s', '“Bro,'],
#  '“Yeah,': ['man.”', 'bro.'],
#  '“Where': ['did'],
#  'did': ['you', 'this.', 'that,', 'the', 'the', 'you'],
#  'go?”': ['“Goa.”'],
#  '“Goa.”': ['–'],
#  '–': ['“Okay,', '“Excuse'],
#  '“Okay,': ['I', 'tell'],
#  'fine.”': ['“Hey'],
#  'listen': ['bro!', 'to', 'to'],
#  'listen,': ['no.'],
#  'no.': ['Let', 'She’s'],
#  'Let': ['me', 'me', 'me', 'me'],
#  'story,': ['bro.', 'bro?”'],
#  'bro.': ['Something',
#   'Looking',
#   'Having',
#   'Cuz',
#   'Just',
#   'Two',
#   'Listen.',
#   'They',
#   'Let',
#   'Can',
#   'After',
#   'He’s',
#   'You',
#   'Because',
#   'Chill'],
#  'Something': ['happened,'],
#  'happened,': ['dude.”'],
#  'dude.”': ['And', 'That’s'],
#  'now': ['you', 'we'],
#  'too': ['interested.', 'early.', 'nice.', 'cliché.', 'confident.'],
#  'interested.': ['“Okay'],
#  '“Okay': ['bro,', 'wait.', 'students,', 'guys,'],
#  'happened': ['tell'],
#  'know.”': ['“Okay,'],
#  '“So': ['I', 'these', 'these', 'why', 'nice.”'],
#  'sitting': ['in',
#   'in',
#   'in',
#   'and',
#   'in',
#   'inside',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on'],
#  'shack.': ['It’s'],
#  'beach,': ['right.', 'bro.'],
#  'shack,': ['bro.', 'having'],
#  'Looking': ['at'],
#  'Having': ['noodles,', 'a'],
#  'noodles,': ['bro.'],
#  'Cuz': ['I’m'],
#  'chill': ['kinda', 'kinda', 'kinda', 'kinda'],
#  'kinda': ['guy,', 'guy.', 'guy.', 'crowd,', 'crowd.”'],
#  'guy,': ['bro.', 'an', 'don’t'],
#  'Just': ['eating',
#   'eating.',
#   'hit',
#   'to',
#   'think',
#   'put',
#   'do',
#   'talk',
#   'put',
#   'ask'],
#  'eating': ['my', 'noodles'],
#  'noodles.': ['Having', 'Which'],
#  'beer,': ['cuz'],
#  'cuz': ['I’m', 'I’m'],
#  'guy.': ['Suddenly', 'Just', 'Yeah.', 'I’m', '[Audience'],
#  'Suddenly': ['Kenny,', 'they', 'an'],
#  'Kenny,': ['I', 'you', 'look'],
#  'see': ['these', 'sick-beat-panda,'],
#  'girls': ['in'],
#  'front': ['of', 'of', 'of'],
#  'table.': ['They’re'],
#  'They’re': ['looking', 'looking', 'still', 'like,', 'sweet.'],
#  'dude.': ['They’re', 'They’re', 'Two', 'At'],
#  'Two': ['Russian', 'Russian…”', 'Russian', 'Russian', 'things'],
#  'Russian': ['chicks,',
#   'chicks.',
#   'women',
#   'women',
#   'women',
#   'women.”',
#   'women'],
#  'chicks,': ['bro.'],
#  'Russian…”': ['“Okay'],
#  'wait.': ['Two'],
#  'chicks.': ['You’re'],
#  'Which': ['is', 'is', 'is', 'is'],
#  'obviously': ['the', 'talking'],
#  'most': ['attractive', 'independent'],
#  'attractive': ['thing'],
#  'thing': ['you', 'you', 'you', 'where', 'is', 'where', 'I’m'],
#  'do.': ['And', '“Excuse'],
#  'staring': ['at'],
#  'you?”': ['“Yeah,', 'He’s'],
#  'Listen.': ['Anyway,'],
#  'Anyway,': ['I’m'],
#  'noodles': ['cuz'],
#  'eating.': ['Suddenly'],
#  'up,': ['bro.', 'paid'],
#  'towards': ['me', 'me.', 'me'],
#  'Excuse': ['me,'],
#  'cute.”': ['“Of', '“Yea,'],
#  '“Of': ['course.'],
#  'course.': ['Two'],
#  'up.': ['Come', 'So', 'And', 'And'],
#  'excuse': ['me,'],
#  '“Yea,': ['bro.'],
#  'tell,': ['no.'],
#  'She’s': ['like', 'like,', 'endangered', 'like,', 'also', 'goes', 'amazing'],
#  'hey': ['do'],
#  'could': ['dance.', 'beatbox.', 'get', 'just', 'just'],
#  'rude?': ['I'],
#  'paid': ['the'],
#  'bill…': ['Tipped'],
#  'Tipped': ['also'],
#  'also': ['and', 'two', 'ten', 'a', 'damn', 'sad.'],
#  'then…': ['We'],
#  'three': ['Russian', 'days', 'days', 'rings', 'and', 'but'],
#  'grinding…”': ['“Wait,'],
#  '“Wait,': ['you'],
#  'said': ['two', 'the'],
#  'women.”': ['“Bro,'],
#  'bro?”': ['“Yes.'],
#  '“Yes.': ['Then'],
#  'Then': ['what', 'she', 'I', 'the', 'she', 'mom’s', 'he', 'we', 'you'],
#  'happened?”': ['“So'],
#  'five': ['Russian', 'times'],
#  'grinding': ['on'],
#  '“Please': ['continue.”'],
#  'continue.”': ['“So'],
#  '1400': ['women'],
#  'surrounding': ['me…”'],
#  'me…”': ['I’m'],
#  '“Okay!': ['Enough.'],
#  'Enough.': ['Enough…'],
#  'Enough…': ['of'],
#  'bullshit!”': ['So'],
#  'word': ['shyness,'],
#  'shyness,': ['women', 'it'],
#  'think': ['I’m', 'about', 'you’re', 'you'],
#  'emotion.': ['No,', 'It', 'Then'],
#  'kids': ['feel.', 'come'],
#  'feel.': ['Guys'],
#  'emotion': ['after'],
#  'after': ['fifth', 'fifth', 'my', 'it'],
#  'fifth': ['standard', 'standard,'],
#  'standard': ['when'],
#  'discovered': ['something'],
#  'something': ['amazing.', 'better.'],
#  'amazing.': ['Yeah!'],
#  'So,': ['what', 'didi', 'he'],
#  'happens': ['is', 'is', '4000', 'to', 'when'],
#  'standard,': ['that'],
#  'evolves': ['into'],
#  'into': ['like',
#   'me.',
#   'you,',
#   'him',
#   'your',
#   'a',
#   'a',
#   'the',
#   'this?”',
#   'traffic',
#   'traffic'],
#  'becomes': ['hyper'],
#  'hyper': ['awareness.', 'aware,'],
#  'awareness.': ['This'],
#  'term': ['is', 'is…'],
#  'coined': ['by'],
#  'Basically': ['what'],
#  'adult': ['male'],
#  'male': ['is'],
#  'room': ['and', 'in', 'and', 'to'],
#  'amazingly': ['stunning'],
#  'stunning': ['woman'],
#  'woman': ['enters', 'was'],
#  'enters': ['the', 'the'],
#  'room.': ['His'],
#  'His': ['brain', 'sound'],
#  'brain': ['is', 'has', 'can’t', 'refused'],
#  '*Siren': ['wailing*'],
#  'wailing*': ['But'],
#  'acts': ['calm,'],
#  'calm,': ['he’s'],
#  '“What?': ['It’s'],
#  'cool.”': ['But', 'That’s'],
#  'is,': ['he', 'the'],
#  'scanning': ['the'],
#  'entire': ['room'],
#  '3D.': ['Like'],
#  'she': ['enters,',
#   'is',
#   'was',
#   'reaches',
#   'entered,',
#   'walks',
#   'is',
#   'passed',
#   'is',
#   'walks',
#   'is',
#   'did',
#   'did',
#   'comes',
#   'doesn’t',
#   'has',
#   'took',
#   'turns',
#   'is',
#   'doesn’t',
#   'wants',
#   'does',
#   'does',
#   'goes,',
#   'starts',
#   'goes',
#   'shouldn’t',
#   'steals',
#   'steal'],
#  'enters,': ['he'],
#  'knows': ['exactly'],
#  'exactly': ['where'],
#  'where': ['she', 'is', 'I', 'are', 'you', 'he', 'right', 'the', 'you'],
#  'standing.': ['And'],
#  'hypothetical': ['situation.'],
#  'situation.': ['They’re'],
#  'if…': ['What', 'She', 'She'],
#  'She': ['doesn’t',
#   'doesn’t',
#   'bumps',
#   'bumps',
#   'reaches',
#   'is',
#   'is',
#   'bumps',
#   'is',
#   'is',
#   'is',
#   'is',
#   'goes',
#   'doesn’t',
#   'runs',
#   'takes',
#   'makes',
#   'cleans',
#   'is'],
#  'am.': ['What', 'This', 'And'],
#  'bumps': ['into', 'into', 'into'],
#  'What’s': ['the', 'that', 'your'],
#  'sexiest': ['thing', 'thing'],
#  'do,': ['Kenny?”', 'I’m'],
#  'Kenny?”': ['She’d'],
#  'She’d': ['be'],
#  'what’s': ['the', 'happening?'],
#  'time?”': ['“The'],
#  '“The': ['time?', 'time'],
#  'time?': ['The'],
#  '10:10': ['pm', 'pm'],
#  'pm': ['baby.”', 'baby!”'],
#  'try': ['that', 'to'],
#  'again.': ['She'],
#  'you.”': ['This', 'I’m', 'And', 'You', 'No,'],
#  '4000': ['times'],
#  'times': ['in', 'by', 'she'],
#  'second.': ['So'],
#  'recently': ['I', 'I'],
#  'had': ['to', 'asthma', 'farted', 'to', 'tears.'],
#  'photoshoot.': ['Okay.', 'So'],
#  'great,': ['I', 'I'],
#  'photoshoots.': ['But'],
#  'director’s': ['like,'],
#  'supermodel': ['is'],
#  'shooting': ['with'],
#  '“No!': ['No!”', 'No!'],
#  'What?': ['Why'],
#  'would': ['he', 'I', 'she'],
#  'version': ['of'],
#  'myself.': ['Which', 'I'],
#  'fake': ['because'],
#  'human': ['instinct'],
#  'instinct': ['is,'],
#  'meet': ['someone', 'you.”'],
#  'someone': ['better', 'passed', 'was'],
#  '“Let': ['me'],
#  'always': ['put'],
#  'pocket.': ['This'],
#  'hand,': ['yes'],
#  'yes': ['this'],
#  'is…”': ['You'],
#  'aware,': ['you'],
#  'take': ['a', 'it.', 'her', 'your', 'the', 'part', 'a', 'a', 'away'],
#  'twice.': ['You', 'My'],
#  'comb': ['your'],
#  'hair.': ['When'],
#  'laugh,': ['nervously'],
#  'nervously': ['spit'],
#  'spit': ['comes'],
#  'apologise.': ['“Oh'],
#  '“Oh': ['shit!', 'hi.', 'cool.”', 'yeah.', 'no!”'],
#  'shit!': ['No,'],
#  'spit.': ['Usually'],
#  'Usually': ['my'],
#  'laughs': ['are'],
#  'dry.”': ['You'],
#  'body.': ['You'],
#  'body': ['just'],
#  'freezes': ['up.'],
#  'waiting': ['in'],
#  'photo': ['studio.'],
#  'studio.': ['And'],
#  '“Come': ['on,'],
#  'on,': ['you', 'let’s'],
#  'this.”': ['And'],
#  'suddenly': ['I', 'the'],
#  'hear': ['her'],
#  'her': ['footsteps.',
#   'like…',
#   'beans.',
#   'for',
#   'house.”',
#   'from',
#   'away.',
#   'talents.',
#   'to',
#   'in',
#   'in',
#   'clean.”'],
#  'footsteps.': ['She'],
#  'reaches': ['the', 'the'],
#  'door.': ['As', 'Picked'],
#  'As': ['she', 'she', 'she', 'he', 'a', 'one', 'the'],
#  'door…': ['the'],
#  'door': ['melted.', 'was', 'who', 'when'],
#  'melted.': ['Because'],
#  'obstacle.”': ['It'],
#  'fell.': ['It', 'And'],
#  'couldn’t': ['take'],
#  'it.': ['“I’ll',
#   'I’m',
#   'Yeah,',
#   'It’s',
#   'Got',
#   'So',
#   'And',
#   '♫',
#   'We’re',
#   'We’ll',
#   'It’s',
#   'Because'],
#  '“I’ll': ['be'],
#  'floor': ['now.”'],
#  'now.”': ['It', 'I’m'],
#  'entered,': ['the'],
#  '45': ['minutes,'],
#  'minutes,': ['who'],
#  'didn’t': ['give', 'wake', 'even', 'know', 'stand'],
#  'presence.': ['The'],
#  'walks': ['in,', 'towards', 'in,'],
#  'in,': ['they', '“WHAT'],
#  'lights': ['toward'],
#  'toward': ['her'],
#  'small': ['light.', 'light.', 'puppies.'],
#  'light.': ['It’s', 'She'],
#  'shining': ['bright.'],
#  'bright.': ['She', 'As'],
#  'walking': ['towards…', 'closer,', 'towards', 'like'],
#  'towards…': ['there'],
#  'next': ['to', 'one', 'customer', 'to', 'to', 'thing', 'to', 'song,'],
#  'asthma': ['and'],
#  'coughing.': ['The'],
#  'passed': ['him,', 'away'],
#  'him,': ['he', 'he'],
#  'cured': ['and', 'and'],
#  'asanas': ['*Ancient'],
#  '*Ancient': ['Breathing'],
#  'Breathing': ['exercises*'],
#  'exercises*': ['I’m'],
#  'what?': ['As', 'I’ll'],
#  'closer,': ['there'],
#  'leprosy': ['who'],
#  'struggling': ['to'],
#  'walk.': ['She'],
#  'starts': ['doing',
#   'an',
#   'doing',
#   'pulling',
#   'ringing.',
#   'raining.',
#   'shivering.'],
#  'squats.': ['He'],
#  'won': ['bronze'],
#  'bronze': ['for'],
#  'Indian': ['Olympics.'],
#  'Olympics.': ['What'],
#  'happening?': ['She', 'Are', 'I’m'],
#  'symbol': ['of'],
#  'perfection.': ['Guys,'],
#  'has': ['fused', 'a', 'this', 'to', 'any', 'no', 'nothing'],
#  'fused': ['twice.'],
#  'handle': ['such', 'it.”', 'it?', 'it?', 'this.', 'it.'],
#  'stunningness.': ['If'],
#  'If': ['that’s', 'you', 'nice', 'they', 'I’m', 'it', 'someone'],
#  'word.': ['So', 'Next'],
#  '♫': ['Oh',
#   'Then',
#   'I',
#   'I',
#   'Oooooo!',
#   'No',
#   'I',
#   'Because',
#   'I',
#   'Windows',
#   'I’m',
#   'Global',
#   'The',
#   'Want',
#   'Aaaaaa',
#   'Do',
#   'I',
#   'True',
#   'The'],
#  'Distant': ['Land', 'Land', 'Land'],
#  'Land': ['♫\n♫', '♫\n♫', '♫'],
#  '♫\n♫': ['Oh',
#   'Oh',
#   'It’s',
#   'Right',
#   'I',
#   'That’s',
#   'Because',
#   'without',
#   'Oooooo!',
#   'O!',
#   'O!',
#   'A-I-O-U!',
#   'But',
#   'While',
#   'I',
#   'I',
#   'I',
#   'The',
#   'Don’t',
#   'The',
#   'Bottle,',
#   'Bottle,',
#   'H2O',
#   'There',
#   'There',
#   'I',
#   'You',
#   'I',
#   'Or',
#   'Bottle,',
#   'Bottle,',
#   'Aaaaaa',
#   'Night…',
#   'Morning…',
#   'Evening…',
#   'Early',
#   'I',
#   'The'],
#  'sweet.': ['She’s', 'You'],
#  'hi.': ['You', 'Okay.', 'Is'],
#  'must': ['be', 'be', 'be'],
#  'baby!”': ['I’m'],
#  'tensed.': ['So'],
#  'part': ['of', 'of.', 'in', 'where', 'is'],
#  'photoshoot,': ['which'],
#  'happened.': ['So'],
#  'camera': ['was'],
#  'there.': ['She', 'So'],
#  'facing': ['the', 'the'],
#  ...}

# %%
import random
from collections import defaultdict

def generate_sentence(chain, count=15):
    if not chain:
        return "Cannot generate a sentence from an empty dictionary"

    # Use defaultdict to handle missing keys gracefully
    chain = defaultdict(list, chain)

    # Choose the first word randomly
    word1 = random.choice(list(chain.keys()))

    # Capitalize the first word
    sentence = word1.capitalize()

    # Generate subsequent words until the sentence has the desired length
    for i in range(count-1):
        # Choose the next word randomly based on its frequency in the chain
        word2 = random.choices(chain[word1], weights=[chain[word1].count(w) for w in chain[word1]])[0]

        # Add the word to the sentence
        sentence += ' ' + word2

        # Update the current word
        word1 = word2

        # End the sentence with appropriate punctuation
        if i == count-2:
            sentence += random.choice(['.', '!', '?'])

    return sentence

# %% [markdown]
# Yes, here's a brief explanation of why the updated implementation of the generate_sentence function is better:
#
# Checks for an empty dictionary: The updated implementation checks if the input dictionary is empty and returns an appropriate message to the user. This makes the function more robust and prevents it from raising an error if the input is invalid.
#
# Uses defaultdict: The updated implementation uses a defaultdict to handle missing keys in the input dictionary. This makes the function more robust by ensuring that it will not raise a KeyError if a word is not present in the dictionary.
#
# Handles punctuation: The updated implementation handles punctuation more gracefully by adding the appropriate punctuation mark at the end of the sentence. This makes the generated sentences more grammatically correct and natural.
#
# Improves randomness: The updated implementation uses random.choices to choose the next word based on its frequency in the chain. This makes the function more diverse by ensuring that less common words are chosen more often, and makes the generated sentences less repetitive.
#
# Overall, these improvements make the function more robust, natural-sounding, and diverse, resulting in better-generated sentences.

# %%
generate_sentence(kenny_dict)
# Out:
# 'He’s like. “Sir, where right now. It was up with her to make a gangster.!'

# %%
generate_sentence(david_dict)
# Out:
# 'Permanence to have this Twitter thing, where, you know, and I don’t know what the.'

# %%
jerry_text = data.transcript.loc['jerry']
jerry_text[:200]

jerry_dict = markov_chain(jerry_text)
jerry_dict
# Out:
# {'Jerry': ['Seinfeld’s', 'Seinfeld:', 'Seinfeld:'],
#  'Seinfeld’s': ['new'],
#  'new': ['hourlong', 'people,', 'movie.'],
#  'hourlong': ['comedy'],
#  'comedy': ['special,'],
#  'special,': ['Jerry', 'put'],
#  'Seinfeld:': ['23', 'Yes,', 'Oh.', 'No'],
#  '23': ['Hours'],
#  'Hours': ['to'],
#  'to': ['Kill',
#   'land',
#   'do?',
#   'be',
#   'find',
#   'be',
#   'get',
#   'the',
#   'be',
#   'put',
#   'do',
#   'be',
#   'convince',
#   'a',
#   'get',
#   'drizzle',
#   'a',
#   'anything',
#   'be',
#   'the',
#   'Petco',
#   'work',
#   'me…',
#   'when',
#   'hack',
#   'get',
#   'take',
#   'heal',
#   'visit…',
#   'invent,',
#   'this',
#   'somebody',
#   'show',
#   'ten',
#   'a',
#   'them',
#   'me.',
#   'information',
#   'anybody',
#   'ride',
#   'think',
#   'get',
#   'get.',
#   'tell',
#   'you,',
#   'do.”',
#   'say.',
#   'it.',
#   'have',
#   'here',
#   'get',
#   'hear',
#   'it?',
#   'be',
#   'bang',
#   'get',
#   'tell',
#   'say.”',
#   'you',
#   'you',
#   'wait',
#   'speed',
#   'leave',
#   'take',
#   'stop',
#   'the',
#   'catch',
#   'compete.',
#   'explain',
#   'go',
#   'the',
#   'be',
#   'us,',
#   'be',
#   'congregate,',
#   'be',
#   'judge',
#   'give',
#   'you',
#   'me',
#   'me',
#   'say',
#   'say',
#   'make',
#   'die',
#   'avail',
#   'think…',
#   'go.”',
#   'use',
#   'be',
#   'relieve',
#   'twitch',
#   'call',
#   'the',
#   'get',
#   'do',
#   'improve',
#   'expand',
#   'press',
#   'turn',
#   'an',
#   'have',
#   'be',
#   'be',
#   'talk',
#   'the',
#   'know',
#   'answer',
#   'bet',
#   'me?',
#   'take',
#   'communicate',
#   'you.',
#   'mention',
#   'eat!”',
#   'imitate',
#   'do',
#   'make',
#   'do',
#   'for',
#   'shut',
#   'keep',
#   'my',
#   'get',
#   'fancy',
#   'a',
#   'get',
#   'stay',
#   'say.',
#   'understand',
#   'accommodate',
#   'aggravate?”',
#   'call:',
#   'go',
#   'be.',
#   'hit',
#   'college.',
#   'be',
#   'do.”',
#   'replace',
#   'keep',
#   'be',
#   'be.',
#   'do',
#   'throw',
#   'hear',
#   'the',
#   'the',
#   'pry',
#   'complete',
#   'go',
#   'make',
#   'bring',
#   'people?',
#   'run',
#   'do.”',
#   'see',
#   'see'],
#  'Kill': ['is'],
#  'is': ['now',
#   'out.',
#   'it.',
#   'you',
#   'right',
#   'a',
#   'hurtin’',
#   'cold.',
#   'not',
#   'an',
#   'great,',
#   'the',
#   'like',
#   'the',
#   'what',
#   'that?',
#   'that?',
#   'here.”',
#   'critical.',
#   'the',
#   'here!',
#   'annoying',
#   'here.”',
#   'anymore.',
#   'phones',
#   'using',
#   'obsolete.',
#   'the',
#   'a',
#   'a',
#   'the',
#   'going',
#   'this',
#   'struggling',
#   'anyway.',
#   'a',
#   'what',
#   'a',
#   'what',
#   'what',
#   'what',
#   'business.”',
#   'what',
#   'really',
#   'my',
#   'everything?”',
#   'outrageous.”',
#   'not',
#   'cookin’',
#   'one',
#   'like',
#   'the',
#   'that',
#   'not',
#   'this',
#   'flowing',
#   'helping',
#   'on',
#   'the',
#   'on',
#   'attacking',
#   'there',
#   '“I,”',
#   '“hate,”',
#   '“you.”',
#   'the',
#   'their',
#   'all',
#   'someone',
#   'here',
#   'the',
#   'even',
#   'the',
#   'the',
#   'it',
#   'why'],
#  'now': ['available', 'to', 'you’re'],
#  'available': ['on'],
#  'on': ['Netflix',
#   'a',
#   'your',
#   'the',
#   'the',
#   'a',
#   'Broadway,',
#   'the',
#   'the',
#   'the',
#   'these',
#   'it.',
#   'the',
#   'your',
#   'my',
#   'the',
#   'the',
#   'text.”',
#   'it',
#   'voice',
#   'the',
#   'voice',
#   'TV.',
#   'in',
#   'a',
#   'the',
#   'licking,',
#   'TV',
#   'the',
#   'top',
#   'the',
#   'in.',
#   'what’s',
#   'in',
#   'the',
#   'a',
#   'a',
#   'high',
#   'to',
#   'a',
#   'with',
#   'that,',
#   'your',
#   'it!',
#   'your',
#   'each',
#   'me!”',
#   'me,”',
#   'me.”',
#   'the',
#   'the',
#   'the',
#   'one',
#   'the',
#   'a',
#   'what',
#   'bikes.',
#   'a',
#   'the',
#   'the',
#   'the',
#   'each',
#   'the'],
#  'Netflix': ['[In'],
#  '[In': ['the'],
#  'the': ['first',
#   'special',
#   'Hudson',
#   'way.”',
#   'opposite',
#   'tickets?',
#   'tickets?',
#   'tickets?”',
#   'word',
#   'tickets.”',
#   'tickets?”',
#   'tickets!”',
#   'last',
#   'ass',
#   'names',
#   'old',
#   'hell',
#   'same',
#   'difference',
#   'good',
#   'next',
#   'work',
#   'hell',
#   'airport.”',
#   'plane?”',
#   'plane',
#   'door',
#   'way.',
#   'world',
#   'entire',
#   '’90s',
#   'Beacon',
#   'vast',
#   'great',
#   'specials?”',
#   'menu.',
#   'team.”',
#   'hell',
#   'drizzling',
#   'end',
#   'little',
#   'bill.',
#   'story.',
#   'story.',
#   'street',
#   'only',
#   'beginning',
#   'exact',
#   'street,',
#   'ice',
#   'top',
#   'cone,',
#   'pavement.',
#   'buffet.',
#   'buffet.',
#   'buffet.”',
#   'idea',
#   'buffet?',
#   'entrance',
#   'shopping.',
#   'parking',
#   'right',
#   'car.',
#   'window',
#   'buffet.”',
#   'group',
#   'biggest',
#   'Pop-Tart,',
#   'back',
#   'Pop-Tart!',
#   'supermarket.',
#   'dirt,',
#   'Pop-Tart',
#   '’60s.',
#   'morning.',
#   'scars',
#   'recipe.',
#   'amount',
#   'bowl!',
#   'hull',
#   'midst',
#   'Kellogg’s',
#   'corporate',
#   'frosted,',
#   'same',
#   'box',
#   'same',
#   'box',
#   'hard',
#   'two',
#   'Ten',
#   'packet!',
#   'world,',
#   'phone',
#   'things',
#   'street,',
#   'phone’s',
#   'way',
#   'phone.',
#   'purpose',
#   'only',
#   'phone',
#   'phone,',
#   'phone',
#   'Uber',
#   'little',
#   'phone.',
#   'hos,',
#   'street',
#   'phone’s',
#   'big',
#   'whole',
#   'drivers,',
#   'money.”',
#   'phone.',
#   'option,',
#   'truth.',
#   'hell',
#   'worst',
#   'x',
#   '“K,”',
#   '“O”',
#   'end',
#   'other',
#   'next',
#   'text',
#   'pistons',
#   'ghosty',
#   'beep?',
#   '21st',
#   'beep.',
#   'African',
#   'beep.',
#   'phone?',
#   'entire',
#   'human',
#   'side',
#   'road?',
#   'least',
#   'area',
#   'picture.',
#   'second',
#   'phone,',
#   'flip',
#   'giant',
#   'numbers.',
#   'numbers.',
#   'tech',
#   'world',
#   'hell',
#   'Postal',
#   'Cub',
#   'streets',
#   'wrong',
#   'postmaster',
#   'stamps!”',
#   'Postal',
#   'letters,',
#   'city,',
#   'city?',
#   'room',
#   'same',
#   'very',
#   'brush,',
#   'direction',
#   'way,',
#   'spring',
#   'door',
#   'bathroom',
#   'grass.',
#   'last',
#   'outside',
#   'basic',
#   'numbers.',
#   'shock',
#   'check?”',
#   'street',
#   'way',
#   'b',
#   'top,',
#   'other',
#   'time!',
#   'most',
#   'biological',
#   'female',
#   'hypothetical.',
#   'whole',
#   'lightning',
#   'morning,',
#   'podium,',
#   'goddamn',
#   'returning',
#   'Morning',
#   'win',
#   'weekend',
#   'guilt-free',
#   'studio.”',
#   'things',
#   'tone',
#   'incorrect',
#   'house',
#   'course',
#   'relationship.',
#   'beginning,',
#   'male',
#   'female,',
#   'courting',
#   'beginning.',
#   'way.',
#   'hell',
#   'fight',
#   'fight',
#   'woman’s',
#   'women',
#   'man,',
#   'voice',
#   'man.',
#   'amazing',
#   'same',
#   'hell',
#   'Lollipop',
#   'board',
#   'chess',
#   'rest',
#   'hell',
#   'equivalent',
#   'emergency',
#   'babies',
#   'morning…',
#   'left',
#   'cup,',
#   'right,',
#   'time.”',
#   'car,',
#   'sidewalk.',
#   'car',
#   'door',
#   'armrest',
#   'spirited',
#   'rest',
#   'drive',
#   'words',
#   'first',
#   'hell',
#   'hotel',
#   'other',
#   'head.',
#   'house?”',
#   'teeth?',
#   'hell',
#   'birth.',
#   'most',
#   'end',
#   'same',
#   'human-being',
#   'supply',
#   'hospital’s',
#   'babies',
#   'world’s',
#   'diapers',
#   'babies',
#   'father,',
#   'most',
#   'female,',
#   'man,',
#   'same',
#   'room',
#   'horsey-ride',
#   'male',
#   'ultimate',
#   'world',
#   'fantasy',
#   'golfing',
#   'family',
#   'exciting',
#   'father',
#   'house',
#   'weekends.',
#   'clothing',
#   'last',
#   'time',
#   'end.',
#   'street:',
#   'kids',
#   'movies',
#   'other',
#   'movie',
#   'garbage',
#   'movie.”',
#   'highway',
#   'credits.”',
#   'one',
#   'movie',
#   'object',
#   'dog',
#   'button,',
#   'line',
#   'toilet,',
#   'sink',
#   'toilet?',
#   'bathroom',
#   'under-display',
#   'lifeless,',
#   'impotent',
#   'cheapest',
#   'world.',
#   'panels',
#   'corners!',
#   'space?',
#   'door?',
#   'horses',
#   'best!',
#   'helicopter,',
#   'doorway.'],
#  'first': ['scene', 'got', 'thing', 'kid', 'words'],
#  'scene': ['of'],
#  'of': ['the',
#   'a',
#   'life.',
#   'whom',
#   'all',
#   '’em',
#   'people',
#   'these?',
#   'intimate',
#   'human',
#   'hearing',
#   'somethin’',
#   'it.',
#   'Lucky',
#   'the',
#   'great',
#   'the',
#   'the',
#   'debauched,',
#   'unlimited',
#   'dog',
#   'all',
#   'ice',
#   'exhibits.',
#   'my',
#   'drops',
#   'liquidity',
#   'Wheat.',
#   'water',
#   'a',
#   'that',
#   'Battle',
#   'Kellogg’s',
#   'breakfast',
#   'the',
#   'that',
#   'the',
#   'power,',
#   'the',
#   'us.',
#   'people',
#   'the',
#   'crust,',
#   'had',
#   '“OK,”',
#   'people',
#   'a',
#   'your',
#   'skateboarders',
#   '“thank',
#   'the',
#   'things,',
#   'the',
#   'piss',
#   'the',
#   'those',
#   'these',
#   'them',
#   'the',
#   'a',
#   'pennies…',
#   'money',
#   'New',
#   'each',
#   'these',
#   'opinions.',
#   'confidence.',
#   'outdoor',
#   'one',
#   'these',
#   'one',
#   'these',
#   'fantastic',
#   'this',
#   'these',
#   'human',
#   'things.',
#   'me.',
#   'people',
#   'marriage',
#   'nitro',
#   'questions.',
#   'the',
#   'the',
#   'earth',
#   'course,',
#   'a',
#   'course,',
#   'garbage',
#   'the',
#   'the',
#   'my',
#   'my',
#   'those',
#   'the',
#   'all,',
#   'voice',
#   'the',
#   'that',
#   'wives',
#   'a',
#   'smoke.',
#   'marriage.',
#   'that…',
#   'your',
#   'a',
#   'air',
#   'an',
#   'the',
#   'leverage',
#   'ideas…',
#   'the',
#   'a',
#   'money',
#   'a',
#   'people…',
#   'life,',
#   'people',
#   'fresh',
#   'friends',
#   'the',
#   'his',
#   'idiotic',
#   'the',
#   'their',
#   'us',
#   'eye',
#   'that',
#   'my',
#   'danger',
#   'pretty'],
#  'special': ['we', 'event.'],
#  'we': ['see',
#   'leave?”',
#   'get',
#   'gonna',
#   'getting',
#   'can',
#   'come',
#   'could',
#   'will',
#   'do',
#   'went',
#   'were',
#   'make',
#   'put',
#   'first',
#   'have',
#   'didn’t',
#   'got',
#   'were',
#   'were',
#   'get',
#   'get',
#   'can',
#   'update',
#   'use',
#   'going',
#   'are',
#   'can',
#   'like!',
#   'run',
#   'go',
#   'know',
#   'have',
#   'talkin’',
#   'speak',
#   'represent',
#   'do',
#   'did',
#   'would',
#   'get',
#   'have',
#   'were',
#   'gotta',
#   'go',
#   'help',
#   'want',
#   'need',
#   'can',
#   'doing'],
#  'see': ['Seinfield',
#   'that',
#   'that.',
#   'ya',
#   'a',
#   'this.',
#   'the',
#   'things,',
#   'on',
#   'that',
#   'around',
#   'in',
#   'this.”',
#   'this.”',
#   'it',
#   'it.',
#   'this',
#   'what’s',
#   'who’s',
#   'them',
#   'fathers',
#   'the',
#   'a',
#   'just',
#   'my',
#   'our',
#   'tomorrow'],
#  'Seinfield': ['arriving'],
#  'arriving': ['at'],
#  'at': ['New',
#   'this',
#   'some',
#   'work;',
#   'home.',
#   'this',
#   'the',
#   'the',
#   'the',
#   'it',
#   'this',
#   'the',
#   'a',
#   'home,',
#   'the',
#   'least',
#   'a',
#   'this',
#   'the',
#   'me,',
#   'all',
#   'Three',
#   'me?”',
#   'some',
#   'that',
#   'it,',
#   'this.',
#   'the',
#   'me'],
#  'New': ['York’s', 'York', 'York.', 'York', 'York,', 'announcement', 'York'],
#  'York’s': ['Beacon'],
#  'Beacon': ['Theater', 'Theatre'],
#  'Theater': ['after'],
#  'after': ['taking',
#   'that,',
#   'the',
#   'going',
#   'you’ve',
#   'I',
#   'work.',
#   'the',
#   'the'],
#  'taking': ['on', 'your'],
#  'a': ['secret-agent',
#   'helicopter',
#   'show',
#   'moment.',
#   'feeling.',
#   'second…',
#   'bigger',
#   'made-up,',
#   'lot',
#   'certain',
#   'fact…',
#   'comedian',
#   'show',
#   'great',
#   'reduction',
#   'half',
#   'bowl',
#   'time,',
#   'baseball',
#   'hot',
#   'work-release',
#   'good',
#   'little',
#   'couple',
#   'chocolate-syrup',
#   'crack',
#   'restaurant',
#   'yogurt',
#   'perfect',
#   'salad',
#   'scoop',
#   'caramelized',
#   'lot',
#   'kid,',
#   'knife!',
#   'murder',
#   'couple',
#   'woodchipper.',
#   'Greek',
#   'town',
#   'cereal',
#   'toaster!',
#   'second.',
#   'charger.”',
#   'gay',
#   'part',
#   'phone.',
#   'complete',
#   'phone.',
#   'phone.',
#   'blacksmith',
#   'face',
#   'nice,',
#   'missed',
#   'piece',
#   'little',
#   'little',
#   'commercial.',
#   'lot',
#   'second',
#   'YouTube',
#   'railing?',
#   'railing,',
#   'thank-you.',
#   'good',
#   'beauty.',
#   'message',
#   'woman.',
#   'good',
#   'puddle',
#   'picture',
#   "picture.'”",
#   'good',
#   'digital,',
#   'time,',
#   'mentally',
#   '21st-century',
#   'random',
#   'stamp',
#   'buck,',
#   'real',
#   'penny',
#   'lot',
#   'social',
#   'plane',
#   'very',
#   'day',
#   'word',
#   'sentence,',
#   'lot',
#   'deal.”',
#   'row',
#   'very',
#   'little',
#   'combat',
#   'trauma',
#   'walk.',
#   'lot',
#   'little',
#   'mental',
#   'year',
#   'half…',
#   'bathroom.',
#   'bath…',
#   'hole',
#   'box',
#   'great',
#   'little',
#   'lot',
#   'lot',
#   'bucket',
#   'bucket',
#   'La-Z-Boy,',
#   'ball',
#   'bit,',
#   'wife,',
#   'girlfriend?',
#   'drill.',
#   'merry-go-round,',
#   'pinwheel!',
#   'truck',
#   'dirt',
#   'married',
#   'married',
#   'lot',
#   'game',
#   'game-show',
#   'hand',
#   'Ten-Minute',
#   'clue.',
#   'single',
#   'marriage.',
#   'musical.',
#   'drive',
#   'walk.',
#   'plastic',
#   'bit',
#   'chess',
#   'married',
#   'normal',
#   'hostile',
#   'waft',
#   'three-foot',
#   'marriage',
#   'full',
#   'moving',
#   'little',
#   'single,',
#   'sudden,',
#   'dime.',
#   'very',
#   'man',
#   'strong',
#   'thought',
#   'warm',
#   'lovey',
#   'lot',
#   'hotel.”',
#   'pristine,',
#   'big,',
#   'great',
#   'lot',
#   'baby',
#   'dad.',
#   'room,',
#   'major',
#   'different',
#   'mess,',
#   'lot',
#   'very',
#   'Tic',
#   'shoebox.”',
#   'half',
#   'clown',
#   'fake',
#   'man',
#   'wooden',
#   'nail',
#   'deal',
#   'cup',
#   'cowboy',
#   'beer',
#   'feeding',
#   'dog',
#   'marlin.',
#   'public',
#   'motion',
#   'David',
#   'metal',
#   'frightened,',
#   'flash',
#   'pupil?',
#   'horse.',
#   'stall.',
#   'stall,',
#   'little',
#   'man',
#   'life',
#   'stranger',
#   'little'],
#  'secret-agent': ['persona'],
#  'persona': ['and'],
#  'and': ['jumping',
#   '“How',
#   'numbers',
#   'movies',
#   'it’s',
#   'we’re',
#   'I…',
#   'I',
#   'we',
#   '“great”',
#   'get',
#   'a',
#   'Pepsi',
#   '“great”',
#   'then',
#   '“great”',
#   'letting',
#   'go,',
#   'say,',
#   'an',
#   'personal',
#   'hopeless',
#   'a',
#   'with',
#   'their',
#   'their',
#   'their…',
#   'then',
#   'going…',
#   'number',
#   'go,',
#   'clapbacks',
#   'they',
#   'our',
#   'whatever',
#   'confused,',
#   'jackets',
#   'victory',
#   'half',
#   'a',
#   'a',
#   'e-mail',
#   'coagulate',
#   'you',
#   'criticize…',
#   'activities',
#   'go…',
#   'who’s',
#   'it',
#   'go,',
#   'you’re',
#   'goes,',
#   'a',
#   'give',
#   'I',
#   'I',
#   'depressing.',
#   'trivial',
#   'live',
#   'on',
#   'capable',
#   'I',
#   'you’re',
#   'bought',
#   'I',
#   'get',
#   'when',
#   'all',
#   'thought,',
#   'you',
#   'life',
#   'sugar',
#   'that’s',
#   'complete',
#   'cohabitate,',
#   'a',
#   'I',
#   'she',
#   'you',
#   'everybody',
#   'you',
#   'eating',
#   'three',
#   '“buh-bye.”',
#   'say,',
#   'a',
#   'weeds',
#   'rides',
#   'a',
#   'the',
#   'a',
#   'tragic'],
#  'jumping': ['out'],
#  'out': ['of',
#   'anywhere',
#   'with',
#   'is',
#   'for',
#   'another',
#   'here',
#   'of',
#   'of',
#   'of',
#   'here.',
#   'like',
#   'there,',
#   'on',
#   'of',
#   'there.',
#   'of',
#   'of',
#   'that',
#   'with',
#   'about',
#   'and',
#   'after',
#   'here',
#   'to',
#   'on',
#   'there,',
#   'than',
#   'to',
#   'to',
#   'three',
#   'like',
#   'from',
#   'of'],
#  'helicopter': ['into'],
#  'into': ['the',
#   'getting',
#   'a',
#   'my',
#   'Jerry’s',
#   'my',
#   'a',
#   'the',
#   'my',
#   'a',
#   'that',
#   'a',
#   'a'],
#  'Hudson': ['River]'],
#  'River]': ['Helicopter'],
#  'Helicopter': ['Pilot:'],
#  'Pilot:': ['Mr.', 'They’re', 'What'],
#  'Mr.': ['Seinfeld,'],
#  'Seinfeld,': ['you'],
#  'you': ['have',
#   'want',
#   'very',
#   'just',
#   'pick',
#   'up?”',
#   'eat?',
#   'gonna',
#   'have',
#   'hear',
#   'get',
#   'have',
#   'don’t',
#   'put',
#   'are,',
#   'gotta',
#   'wanna',
#   'that.',
#   'and',
#   'be',
#   'were',
#   'be',
#   'too.',
#   'love',
#   'can',
#   'out?',
#   'like',
#   'didn’t',
#   'wouldn’t',
#   'got',
#   'think?”',
#   'go',
#   'say?',
#   'gotta',
#   'want',
#   'go',
#   'think…',
#   'get',
#   'can.',
#   'had',
#   'could',
#   'cereal',
#   'live',
#   'hand',
#   'go,',
#   'feel',
#   'know.”',
#   'scroll',
#   'with',
#   'have?',
#   'can',
#   'do',
#   'gonna',
#   'saw?',
#   'the',
#   'could',
#   'the',
#   'this',
#   'feel',
#   'what',
#   'ought',
#   'save?',
#   'can',
#   'those',
#   'yet.',
#   'and',
#   'sure',
#   'would',
#   'got',
#   'actually',
#   'a',
#   'do…',
#   'take',
#   'look',
#   'see',
#   'today.',
#   'alive?',
#   'repeat',
#   'can',
#   'go',
#   'come',
#   'to',
#   'doin’',
#   'so',
#   'into',
#   'a',
#   'the',
#   'to',
#   'just',
#   'wanna',
#   'to',
#   'don’t',
#   'might',
#   'faked',
#   'say',
#   'for',
#   'even',
#   'on',
#   'want',
#   'is',
#   'think',
#   'want.',
#   'eat.”',
#   'yelling',
#   'say,',
#   'see',
#   'don’t',
#   'sound.',
#   'happy.',
#   'don’t',
#   'on',
#   'need',
#   'go',
#   'want',
#   'right',
#   'pulled',
#   'were,',
#   'just…',
#   'navigate',
#   'acclimate?',
#   'procreate',
#   'that.',
#   'more.”',
#   'know,',
#   'feel,',
#   'somehow',
#   'put',
#   'go,',
#   'move',
#   'walk',
#   'have',
#   'see',
#   'want',
#   'would',
#   'see',
#   'doing?',
#   'guys.',
#   'enjoyed',
#   'would',
#   'push',
#   'in',
#   'find',
#   'say',
#   'won’t'],
#  'have': ['a',
#   'the',
#   'the',
#   'chosen',
#   'to',
#   'to',
#   'a',
#   'an',
#   'a',
#   'breakfast,',
#   'always',
#   'left',
#   'a',
#   'it.',
#   'it.',
#   'a',
#   'a',
#   'these',
#   'this',
#   'to',
#   'occasion',
#   'a',
#   'something',
#   'three',
#   'two',
#   'that',
#   'no',
#   'a',
#   'nothing',
#   'a',
#   'if',
#   'some',
#   'some',
#   'a',
#   'on',
#   'all',
#   'never',
#   'caught',
#   'a',
#   'three',
#   'issues?',
#   'a',
#   'been',
#   'they',
#   'to'],
#  'show': ['tonight,', 'in', 'them', 'it'],
#  'tonight,': ['don’t', 'looking'],
#  'don’t': ['ya?',
#   'you',
#   'I',
#   'have',
#   'they',
#   'suck.',
#   'like',
#   'like',
#   'know',
#   'we',
#   'you',
#   'want',
#   'know',
#   'you?',
#   'know',
#   'seem',
#   'wanna',
#   'even',
#   'even',
#   'we?',
#   'know',
#   'know',
#   'remember…',
#   'remember',
#   'want',
#   'we?',
#   'leave',
#   'think',
#   'think',
#   'wanna',
#   'know.',
#   'need',
#   'we',
#   'even',
#   'even',
#   'even',
#   'wanna',
#   'wanna',
#   'want',
#   'want',
#   'already',
#   'lie',
#   'like',
#   'like',
#   'like',
#   'wanna',
#   'feel',
#   'feel',
#   'get',
#   'have',
#   'deny',
#   'forget',
#   'like',
#   'care',
#   'think…',
#   'think',
#   'think',
#   'hear',
#   'think…',
#   'know,',
#   'know',
#   'know',
#   'say,',
#   'just',
#   'know',
#   'care.',
#   'wanna',
#   'even',
#   'wanna',
#   'I'],
#  'ya?': ['Jerry', 'I'],
#  'Yes,': ['I', 'the'],
#  'I': ['do.',
#   'pick',
#   'didn’t',
#   'need',
#   'got',
#   'got',
#   'gotta',
#   'had',
#   'can',
#   'know',
#   'live.',
#   'could',
#   'am',
#   'love',
#   'love',
#   'love',
#   'saw',
#   'know',
#   'know',
#   'don’t',
#   'don’t',
#   'don’t',
#   'didn’t',
#   'heard',
#   'heard',
#   'say',
#   'can',
#   'didn’t',
#   'gotta',
#   'don’t',
#   'was',
#   'can’t',
#   'feel',
#   'have',
#   'don’t',
#   'can’t',
#   'got',
#   'didn’t…',
#   'moved',
#   'didn’t',
#   'am',
#   'just…',
#   'can’t',
#   'gotta',
#   'don’t',
#   'have',
#   'wish',
#   'could',
#   'go',
#   'know',
#   'gotta',
#   'favor?',
#   'delete?”',
#   'don’t',
#   'think',
#   'used',
#   'could',
#   'started',
#   'tell',
#   'feel',
#   'could',
#   'wanna',
#   'could',
#   'think',
#   'can’t',
#   'don’t…',
#   'don’t',
#   'mean,',
#   'know',
#   'know',
#   'don’t',
#   'don’t',
#   'don’t',
#   'can’t',
#   'wanna',
#   'think',
#   'always',
#   'think',
#   'don’t',
#   'don’t,',
#   'wanna',
#   'see',
#   'cannot',
#   'would',
#   'get',
#   'hate',
#   'just',
#   'need',
#   'wanted',
#   'always',
#   'thought',
#   'don’t',
#   'see',
#   'wanna',
#   'will',
#   'apologize',
#   'am',
#   'have',
#   'have',
#   'love',
#   'can’t',
#   'don’t',
#   'like',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'intend',
#   'don’t',
#   'don’t…',
#   'don’t',
#   'just',
#   'don’t',
#   'don’t',
#   'won’t',
#   'made',
#   'turned',
#   'was',
#   'just',
#   'got',
#   'was',
#   'had',
#   'was',
#   'recall.',
#   'was',
#   'had',
#   'would',
#   'found',
#   'have',
#   'find',
#   'believe',
#   'was',
#   'can’t',
#   'wanna',
#   'gotta',
#   'wanna',
#   'found',
#   'dreamt',
#   'went',
#   'set',
#   'wake',
#   'stand',
#   'got',
#   'Think',
#   'would',
#   'have',
#   'did',
#   'got',
#   'found',
#   'got',
#   'would',
#   'was',
#   'so',
#   'thought',
#   'walk',
#   'gettin’',
#   'am',
#   'talk',
#   'speak',
#   'do',
#   'walked',
#   'paid',
#   'said,',
#   'said,',
#   'said',
#   'know',
#   'don’t',
#   'can’t',
#   'said',
#   'was',
#   'don’t',
#   'don’t',
#   'don’t',
#   "could…'”",
#   'never',
#   'don’t',
#   'have',
#   'don’t',
#   'do',
#   'do?”',
#   'wonder',
#   'respond',
#   'go',
#   'like',
#   'go,',
#   'do',
#   'saw',
#   'love',
#   'think',
#   'know',
#   'can’t',
#   'could',
#   'heard',
#   'can',
#   'told',
#   'like',
#   'don’t',
#   'wonder',
#   'look',
#   'found',
#   'think',
#   'love',
#   'was',
#   'remember…',
#   'have',
#   'am',
#   'hadn’t',
#   'open',
#   'hit',
#   'go',
#   'expect',
#   'don’t',
#   'hang',
#   'had',
#   'had',
#   'love',
#   'appreciate'],
#  'do.': ['Pilot:', 'It', 'I’m'],
#  'They’re': ['telling', 'not', 'pushing'],
#  'telling': ['me', 'the', 'me', 'me'],
#  'me': ['there’s',
#   'to',
#   'out',
#   'up?”',
#   'from',
#   'yours.',
#   'it',
#   'today?',
#   'take',
#   'to',
#   'an',
#   'just',
#   '“TY”',
#   'to',
#   'to',
#   'back.”',
#   'one',
#   'and',
#   'to…?”',
#   'of',
#   'three',
#   'from',
#   'a',
#   'a'],
#  'there’s': ['too', 'a', 'nothing'],
#  'too': ['much', 'much', 'advanced!', 'thick!', 'many.'],
#  'much': ['traffic',
#   'suck.',
#   'drizzling!',
#   'as',
#   'time',
#   'longer.',
#   'a',
#   'for',
#   'more'],
#  'traffic': ['to'],
#  'land': ['right', 'out'],
#  'right': ['now.',
#   'now…',
#   'now…',
#   'now.',
#   'now!',
#   'here,',
#   'now.',
#   'amount',
#   'off.',
#   'now.”',
#   'now.',
#   'here.”',
#   'now',
#   'now.”',
#   'anymore.'],
#  'now.': ['Seinfeld:', 'This', 'Could', 'Why'],
#  'Oh.': ['Pilot:'],
#  'What': ['do',
#   'a',
#   'a',
#   'an',
#   'you',
#   'did',
#   'do',
#   'is',
#   'is',
#   'is',
#   'else',
#   'about',
#   'access',
#   'you',
#   'does',
#   'happened',
#   'about',
#   'do',
#   'have',
#   'you'],
#  'do': ['you',
#   'we',
#   'we',
#   'anything',
#   'either,',
#   'to',
#   'you',
#   'the',
#   'not',
#   'well',
#   'you',
#   'without',
#   'it',
#   'those',
#   'they',
#   'I',
#   'you',
#   'that',
#   'that',
#   'somethin’,',
#   'it.',
#   'I',
#   'you',
#   'not.',
#   'the',
#   'things',
#   'not',
#   'know.',
#   'it.',
#   'it.',
#   'it.',
#   'it.',
#   'nothing.',
#   'anything.”',
#   'it',
#   'you',
#   'it!',
#   'it.'],
#  'want': ['me',
#   'at',
#   'any',
#   'to',
#   'to',
#   'to',
#   'you',
#   'me',
#   'still',
#   'in!”',
#   'to',
#   'us',
#   'to'],
#  'do?': ['Seinfeld:'],
#  'No': ['problem.', 'reason,'],
#  'problem.': ['You', 'Or'],
#  'You': ['can',
#   'know',
#   'and',
#   'know',
#   'know',
#   'know',
#   'know',
#   'would',
#   'would',
#   'know',
#   'have',
#   'love',
#   'have',
#   'can',
#   'give',
#   'know',
#   'can',
#   'had',
#   'are',
#   'saw',
#   'see',
#   'need',
#   'think',
#   'are',
#   'can',
#   'don’t',
#   'don’t',
#   'ever',
#   'don’t',
#   'can’t',
#   'see,',
#   'have',
#   'will',
#   'wanna',
#   'know',
#   'wanna',
#   'just',
#   'gotta',
#   'can',
#   'don’t',
#   'have',
#   'single',
#   'better',
#   'better',
#   'did',
#   'think',
#   'got',
#   'said,',
#   'said,',
#   'go,',
#   'should',
#   'go,',
#   "know.'”",
#   'can',
#   'can’t',
#   'can',
#   'don’t',
#   'say,',
#   'just',
#   'don’t',
#   'know,',
#   'know,',
#   'think',
#   'see',
#   'gave',
#   'always',
#   'ever',
#   'made'],
#  'can': ['let',
#   'get',
#   'tell',
#   'learn',
#   'get',
#   'breathe.”',
#   'get',
#   'remember.',
#   'get',
#   'watch',
#   'see',
#   'be',
#   'see.',
#   'say',
#   'either',
#   'only',
#   'only',
#   'feel',
#   'share',
#   'all',
#   'hide'],
#  'let': ['me', 'it', 'the', '’em'],
#  'anywhere': ['along', 'in', 'in'],
#  'along': ['here.', 'great.'],
#  'here.': ['Thank',
#   'I',
#   'I',
#   'This',
#   'It’s',
#   'My',
#   'I',
#   'Hey,',
#   'So,',
#   'This',
#   'Why'],
#  'Thank': ['you!', 'you', 'you,', 'you', 'you', 'you.', 'you,', 'you.'],
#  'you!': ['Thank', 'Thank'],
#  'very': ['much!',
#   'hard',
#   'important,',
#   'popular',
#   'negative',
#   'different',
#   'easy',
#   'good',
#   'challenging'],
#  'much!': ['Oh,'],
#  'Oh,': ['my', 'come', 'here', 'we', 'they'],
#  'my': ['God.',
#   'favorite',
#   'favorite',
#   'head',
#   'little-kid',
#   'phone?',
#   'phone.',
#   'phone',
#   'name',
#   'face',
#   'chest,',
#   'life.',
#   'mind.',
#   'personal',
#   'daughter.',
#   'sixties.',
#   'favorite',
#   'seventies.',
#   'interests,',
#   'age',
#   'friend.',
#   'living',
#   'wife’s',
#   'married',
#   'voice.',
#   'tone?”',
#   'house.',
#   'house,',
#   'voice?',
#   'house?',
#   'own',
#   'friends.',
#   'friends,',
#   'wife',
#   'wife',
#   'God.',
#   'mate',
#   'coffee',
#   'coffee',
#   'car',
#   'wife,',
#   'head,',
#   'daughter',
#   'oldest.',
#   'children’s',
#   'orange',
#   'way',
#   'hand.',
#   'arm',
#   'head',
#   'coworkers',
#   'shoes.',
#   'face,',
#   'own'],
#  'God.': ['What', 'An'],
#  'moment.': ['What', 'Anytime'],
#  'feeling.': ['What'],
#  'an': ['accomplishment',
#   'ex-con',
#   'ice',
#   'unsupervised',
#   'egg-white',
#   'alien',
#   'iPhone.',
#   'e-mail',
#   'announcement',
#   'hour,',
#   'individual',
#   'f,',
#   'automobile.',
#   'idiot',
#   'automatic',
#   'extra',
#   'evil'],
#  'accomplishment': ['this'],
#  'this': ['is…',
#   'is',
#   'nightmare',
#   'point.',
#   'is.',
#   'point.',
#   'is.',
#   'over',
#   'dish',
#   'up!',
#   'pocket',
#   'pocket.',
#   'point,',
#   'big',
#   'whole',
#   'guy’s',
#   'is',
#   'one',
#   'one',
#   'dazed',
#   'emotional,',
#   'caliber.',
#   'point',
#   'time.',
#   'out.',
#   'thing',
#   'in',
#   'authority?',
#   'guy?',
#   'guy?',
#   'could',
#   'stupid',
#   'goddamn',
#   'off,',
#   'thing',
#   'is',
#   'corpse-like',
#   'wall',
#   'to',
#   'is',
#   'one?'],
#  'is…': ['on', 'it’s'],
#  'your': ['part.',
#   'friends',
#   'phone,',
#   'ass',
#   'life',
#   'life',
#   'friends',
#   'friends,',
#   'dog',
#   'dog',
#   'wallet',
#   'dog',
#   'lips',
#   'device',
#   'phone?',
#   'phone',
#   'whole',
#   'contact',
#   'pictures?',
#   'day',
#   'nuts',
#   'kid,',
#   'world.”',
#   'sleep',
#   'dog',
#   'sixties,',
#   'seventies.',
#   'items…',
#   'own',
#   'way',
#   'tone.”',
#   'tone.”',
#   'tone.”',
#   'tone!”',
#   'friends.',
#   'friends.’',
#   'husband',
#   'journey',
#   'car,',
#   'life',
#   'tub,',
#   'finger',
#   'seat'],
#  'part.': ['What', 'I'],
#  'just': ['went',
#   'kill',
#   'suck!',
#   'walk',
#   'kinda',
#   'chimps',
#   'get',
#   'text!',
#   'the',
#   'drains',
#   'open',
#   'say',
#   'come',
#   'need',
#   'doesn’t',
#   'say',
#   'wave',
#   'don’t',
#   'seen',
#   'assume',
#   'want',
#   'wanted',
#   'hungry!”',
#   'a',
#   'turned',
#   'talk',
#   'came',
#   'the',
#   'these',
#   'kick',
#   'the',
#   'barely',
#   'a'],
#  'went': ['through…', 'to', 'out', 'off', 'in,'],
#  'through…': ['going'],
#  'going': ['out,',
#   'through',
#   'tomorrow,',
#   'through',
#   'on',
#   'to',
#   'to',
#   'on',
#   'for'],
#  'out,': ['dealing', 'and', 'rings', 'and', 'now', 'we', 'leave'],
#  'dealing': ['with…', 'with', 'with.'],
#  'with…': ['natural'],
#  'natural': ['obstacles'],
#  'obstacles': ['of'],
#  'life.': ['Difficult', 'It', 'It', 'First,', 'I', 'Having'],
#  'Difficult': ['people,'],
#  'people,': ['arranging,', 'learn', 'Jerry.'],
#  'arranging,': ['planning.'],
#  'planning.': ['Annoying'],
#  'Annoying': ['friends,'],
#  'friends,': ['many', '“I-I', 'you'],
#  'many': ['of', 'times', 'years,', 'pictures,'],
#  'whom': ['you’re'],
#  'you’re': ['sitting',
#   'all',
#   'only',
#   'talkin’',
#   'efficient?',
#   'gonna',
#   'a',
#   'crapping',
#   'in',
#   'in',
#   'in',
#   'on,',
#   'always',
#   'white-water',
#   'doing.',
#   'doing',
#   'not',
#   'with',
#   'legally',
#   'not',
#   'parents.',
#   'rippin’',
#   'walkin’'],
#  'sitting': ['with', 'on'],
#  'with': ['right',
#   'in',
#   'it.',
#   'these',
#   'it',
#   'things',
#   'something',
#   'your',
#   'portion',
#   'a',
#   'the',
#   'sticks.',
#   'a',
#   'the',
#   'the',
#   'people,',
#   'no',
#   'people?',
#   'a',
#   'fake,',
#   'the…',
#   'the',
#   'meaningless',
#   'meaningless',
#   'a',
#   'it',
#   'that.”',
#   'PTSD:',
#   'a',
#   'that,',
#   'single',
#   'real,',
#   'full',
#   'the',
#   'you',
#   'one',
#   'my',
#   'you',
#   'this',
#   'the',
#   'your',
#   'your',
#   'someone',
#   'my',
#   '12-dollar',
#   'a',
#   'something,',
#   'a',
#   'an',
#   'the'],
#  'now…': ['…who,', 'you’re'],
#  '…who,': ['for'],
#  'for': ['some',
#   'them.',
#   'long.',
#   'many,',
#   'a',
#   'it',
#   'not',
#   'you?',
#   'the',
#   'a',
#   'us.',
#   'some',
#   'you.',
#   'the',
#   'anyone?',
#   'old',
#   'each',
#   'us',
#   'an',
#   'you.”',
#   'a',
#   'a',
#   'bein’',
#   'the',
#   '19',
#   'my',
#   'that',
#   '200.”',
#   'the',
#   'playing.',
#   'a',
#   'example,',
#   'the',
#   'real.',
#   'that,',
#   'us?',
#   'comin’'],
#  'some': ['reason,',
#   'point,',
#   'time.',
#   'kind',
#   'unresolved',
#   'of',
#   'goo.',
#   'human',
#   'information',
#   'people.',
#   'of',
#   'money',
#   'pants',
#   'idiot',
#   'time.',
#   'issues.',
#   'answers,',
#   'answers',
#   'point',
#   'marriage',
#   'kind'],
#  'reason,': ['required', 'no'],
#  'required': ['unnecessarily'],
#  'unnecessarily': ['complicated'],
#  'complicated': ['back-and-forth,'],
#  'back-and-forth,': ['communicating'],
#  'communicating': ['about'],
#  'about': ['“Who’s',
#   'the',
#   'their',
#   'goin’',
#   'being',
#   'great',
#   'this.',
#   'your',
#   'what',
#   'this,',
#   'to',
#   'the',
#   'the,',
#   'my',
#   'it,',
#   'now?”',
#   'listening.',
#   'it',
#   'how',
#   'an'],
#  '“Who’s': ['going?”'],
#  'going?”': ['“When'],
#  '“When': ['do', 'are', 'are', 'we'],
#  'leave?”': ['and'],
#  '“How': ['do', 'could', 'are', 'is', 'do'],
#  'get': ['there?”',
#   'their',
#   'tickets',
#   'their',
#   'rid',
#   'the',
#   'the',
#   'home.',
#   'out.”',
#   'back.”',
#   'up.”',
#   'to',
#   'out?”',
#   'this',
#   'on',
#   'whatever',
#   'whatever',
#   'that?',
#   'more.',
#   'a',
#   'the',
#   'to',
#   'around.',
#   'around.',
#   'who',
#   'the',
#   'information',
#   'it',
#   'someone',
#   'the',
#   'the',
#   'the',
#   'it',
#   'that',
#   'there.',
#   'through',
#   'the',
#   'the',
#   'what',
#   'on',
#   'somethin’',
#   'my',
#   'some',
#   'one',
#   'along',
#   'this',
#   '’em',
#   '’em'],
#  'there?”': ['“Why'],
#  '“Why': ['don’t', 'don’t', 'don’t', 'don’t', 'you', 'are', 'is'],
#  'pick': ['me', 'you', 'up'],
#  'up?”': ['“Why', '“It’s', 'I'],
#  '“It’s': ['on', 'the', 'not', 'not', 'your'],
#  'way.”': ['“It’s'],
#  'opposite': ['direction.”'],
#  'direction.”': ['“My'],
#  '“My': ['car.”', 'life', 'phone!', 'tone?”'],
#  'car.”': ['“Your', '“One', '“Two', 'I'],
#  '“Your': ['car.”'],
#  '“One': ['car.”'],
#  '“Two': ['cars.”'],
#  'cars.”': ['“When'],
#  'are': ['we',
#   'your',
#   'we',
#   'pretty',
#   'the',
#   'the',
#   'bad.',
#   'already',
#   'building',
#   'so',
#   'pretty',
#   'not',
#   'you',
#   'the',
#   'not',
#   'people',
#   'people',
#   'you',
#   'we',
#   'all',
#   'you',
#   'rules.”',
#   'things',
#   'doing.',
#   'strong,',
#   'we',
#   'correct,',
#   'you',
#   'included',
#   'made',
#   'they',
#   'here',
#   '“mama,”',
#   'thinking.',
#   'here,',
#   'just',
#   'we',
#   'he',
#   'you'],
#  'gonna': ['eat?',
#   'eat?',
#   'get.',
#   'land?”',
#   'pan-sear',
#   'herb-crust',
#   'drizzle',
#   'wait',
#   'be',
#   'describe',
#   'believe',
#   'be',
#   'have',
#   'get',
#   'take',
#   'be.',
#   'do.’',
#   'kill',
#   'kill',
#   'come'],
#  'eat?': ['Did', 'I', 'I’m'],
#  'Did': ['you', 'they'],
#  'didn’t': ['eat.”',
#   'get',
#   'pay',
#   'care',
#   'reduce',
#   'think',
#   'think',
#   'even',
#   'get',
#   'know',
#   'use',
#   'have',
#   'do'],
#  'eat.”': ['“Are', 'Any'],
#  '“Are': ['you'],
#  'I’m': ['starving.”',
#   'with?”',
#   'here.',
#   'so',
#   'looking',
#   'not',
#   'gonna',
#   'dealing',
#   'trying',
#   'seven.',
#   'rowing',
#   'okay.',
#   'the',
#   'sure',
#   'done',
#   'fine.',
#   'gonna',
#   '65',
#   'walkin’',
#   'married,',
#   'in',
#   'drivin’',
#   'going',
#   'out',
#   'just',
#   'roastin’!',
#   'boilin’!',
#   'sure',
#   'with',
#   'good.',
#   'okay.',
#   'okay.',
#   'not',
#   'the',
#   'done',
#   'not',
#   'doin’',
#   'not',
#   'sure'],
#  'starving.”': ['“I’m'],
#  '“I’m': ['stuffed.”',
#   'working',
#   'tryin’',
#   'sorry,',
#   'not',
#   'freezin’!',
#   'gonna',
#   'gonna',
#   'sorry,'],
#  'stuffed.”': ['“I’ve'],
#  '“I’ve': ['been'],
#  'been': ['eating', 'great.”', 'solder', 'the'],
#  'eating': ['Jolly', 'environment.', 'them.'],
#  'Jolly': ['Ranchers'],
#  'Ranchers': ['all'],
#  'all': ['day.',
#   'of',
#   'gonna',
#   'the',
#   'week.',
#   'just',
#   'things',
#   'their',
#   'night.',
#   'day.”',
#   'up',
#   'by',
#   'freaked',
#   'human.',
#   'right?”',
#   'right.',
#   'your',
#   'times.',
#   'the',
#   'of',
#   'problems',
#   'my',
#   'somehow',
#   'about',
#   'the',
#   'the',
#   'of',
#   'over.”',
#   'see'],
#  'day.': ['I', 'It’s', 'I', 'New'],
#  'need': ['something',
#   'pockets',
#   'to',
#   'the',
#   'some',
#   'to',
#   'them',
#   'anything?”'],
#  'something': ['solid.”', 'that’s', 'that', 'for', 'else', 'else.'],
#  'solid.”': ['“What'],
#  '“What': ['about', 'are', 'do', 'did'],
#  'tickets?': ['Who’s', 'Do'],
#  'Who’s': ['got', 'really'],
#  'got': ['the',
#   'the',
#   '’em',
#   'rib.',
#   'the',
#   'some',
#   'it.',
#   'that…',
#   'the',
#   'text?',
#   'it.',
#   'some',
#   'married',
#   'a',
#   'married',
#   'married',
#   'a',
#   'married,'],
#  'Do': ['you', 'not', 'not', 'you', 'we'],
#  'tickets?”': ['How', '“Yeah,', '“I'],
#  'How': ['many', 'could', '’bout', '’bout', 'did', 'about', 'much'],
#  'times': ['did'],
#  'did': ['you',
#   'you',
#   'you',
#   'you',
#   'not',
#   'not',
#   'you',
#   'it.',
#   'I',
#   'not',
#   'you',
#   'a'],
#  'hear': ['the', 'the', 'their', 'yourself.', 'how', 'the'],
#  'word': ['“tickets”', 'twice'],
#  '“tickets”': ['today?'],
#  'today?': ['“Don’t', 'Who'],
#  '“Don’t': ['forget'],
#  'forget': ['the', 'to', 'that'],
#  'tickets.”': ['“You', 'Why'],
#  '“You': ['have', 'guys', 'just', 'all', 'gotta', 'better', 'always', 'know,'],
#  '“Yeah,': ['I', 'I', 'no,'],
#  'tickets!”': ['“Did'],
#  '“Did': ['you', 'you'],
#  'their': ['tickets?”',
#   'own',
#   'annoying',
#   'emotional',
#   'names',
#   'teeth',
#   'gums',
#   'teeth.',
#   'stupid',
#   'nuts',
#   'business',
#   'difficulties.',
#   'homes.',
#   'lives',
#   'lives',
#   'husbands',
#   'mission.',
#   'lives.'],
#  '“I': ['didn’t',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'didn’t',
#   'heard',
#   'know.',
#   'don’t',
#   'don’t',
#   'disagree.”',
#   'don’t',
#   'gotta',
#   'can’t',
#   'didn’t',
#   'hate',
#   'could'],
#  'tickets': ['for'],
#  'them.': ['They', 'That…'],
#  'They': ['gotta',
#   'didn’t',
#   'got',
#   'just',
#   'just',
#   'don’t',
#   'don’t',
#   'have',
#   'always',
#   'always',
#   'come',
#   'are',
#   'love',
#   'don’t'],
#  'gotta': ['get',
#   'be',
#   'get',
#   'get',
#   'get',
#   'get',
#   'get',
#   'go',
#   'try',
#   'get',
#   'stay',
#   'have',
#   'see',
#   'see',
#   'have',
#   'get',
#   'get',
#   'turn',
#   'get',
#   'get'],
#  'own': ['tickets!', 'death,', 'house,', 'to'],
#  'tickets!': ['They'],
#  'pay': ['me', 'a'],
#  'from': ['the',
#   'your',
#   'this',
#   'the',
#   'a',
#   'a',
#   'this',
#   '1630',
#   'that!',
#   'last',
#   'a',
#   'commingling',
#   'a',
#   'across',
#   'eight',
#   'around',
#   'underneath'],
#  'last': ['time',
#   'night',
#   'night.',
#   'meal',
#   'few',
#   'night,',
#   'week.',
#   'night',
#   'good'],
#  'time': ['I', 'I', 'together', 'passes,', 'he'],
#  '’em': ['tickets.”', 'in', 'on', 'separate.', 'in.', 'out.', 'see'],
#  'Why': ['are',
#   'don’t',
#   'two?',
#   'would',
#   'don’t',
#   'are',
#   'are',
#   'don’t',
#   'is',
#   'are',
#   'are',
#   'is',
#   'can’t',
#   'are'],
#  'friends': ['so', 'single', 'that'],
#  'so': ['annoying?',
#   'we',
#   'that',
#   'sick',
#   'special,',
#   'much,',
#   'I',
#   'you',
#   'hypno-phonified',
#   'important',
#   'I',
#   'anxious',
#   'many',
#   'we',
#   'easily,',
#   'welcoming.',
#   'much',
#   'far.',
#   'don’t',
#   'often',
#   'funny',
#   'as',
#   'dearly,',
#   'nonsensically',
#   'pointless,',
#   'irrational,',
#   'time-consuming,'],
#  'annoying?': ['The'],
#  'The': ['people',
#   'greatest',
#   'meal',
#   'hot',
#   'bun',
#   'vendor',
#   'buffet',
#   'cars',
#   'phones',
#   'Maasai',
#   'other',
#   'human',
#   'door',
#   'female',
#   'female',
#   'female',
#   'husband,',
#   'male',
#   'little',
#   'way',
#   'baby’s',
#   'deal',
#   'Shawshank',
#   'cup'],
#  'people': ['you',
#   'worked',
#   'even',
#   'that',
#   'is',
#   'still',
#   'text',
#   'on',
#   'still',
#   'with',
#   'phones,',
#   'ask',
#   'around',
#   'are',
#   'walk',
#   'coming'],
#  'chosen': ['to'],
#  'be': ['with',
#   'out.”',
#   'out',
#   'gettin’',
#   'anywhere.',
#   'anywhere',
#   'honest.',
#   'up',
#   'here.',
#   'my',
#   'going',
#   'great.”',
#   'going',
#   'on',
#   'a',
#   'standing',
#   'helpful',
#   'a',
#   'close',
#   'all',
#   'a',
#   'pathetic',
#   'meaningless',
#   'a',
#   'a',
#   'discussing',
#   'out',
#   '“Bed',
#   'what',
#   'in',
#   'careful'],
#  'in': ['life.',
#   'a',
#   'the',
#   'your',
#   'life,',
#   'the',
#   'the',
#   'fact,',
#   'the',
#   'New',
#   'the',
#   'life:',
#   'New',
#   'food',
#   'that',
#   'a',
#   'Vegas',
#   'the',
#   'the',
#   'an',
#   'the',
#   'the',
#   'advance.',
#   'the',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'fear',
#   'touch',
#   'this',
#   'their',
#   'there,',
#   'the',
#   'the',
#   'so',
#   'the',
#   'any',
#   'the',
#   '“e-mail”?',
#   'the',
#   'embarrassing',
#   'your',
#   'New',
#   'here,',
#   'a',
#   'there,',
#   'love',
#   'life,',
#   'the',
#   'there.”',
#   'exchange',
#   'your',
#   'a',
#   'the',
#   'our',
#   'the',
#   'my',
#   'my',
#   'your',
#   'your',
#   'anything.',
#   'restaurants',
#   'front',
#   'a',
#   'life.',
#   'Afghanistan',
#   'all',
#   'the',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my',
#   'my',
#   'my',
#   'my',
#   'this,',
#   'every',
#   'marriage.',
#   'handy',
#   'the',
#   'my',
#   'the',
#   'a',
#   'that',
#   'this',
#   'a',
#   'marriage',
#   'marriage!',
#   'a',
#   'the',
#   'your',
#   'his',
#   'that',
#   'like',
#   'a',
#   'bizarre',
#   'the',
#   'fashion',
#   'the',
#   'it,',
#   'place',
#   'every',
#   'it,',
#   'case',
#   'here.',
#   'the',
#   'the',
#   'the',
#   'a',
#   'to',
#   'the',
#   'the'],
#  'It': ['makes',
#   'was',
#   'coulda',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'just',
#   'will',
#   'reminds',
#   'says',
#   'was'],
#  'makes': ['no', 'me', 'no', 'it', '♪\n♪'],
#  'no': ['sense.',
#   'phone?',
#   'commercial.',
#   'text.',
#   'way',
#   'shave,',
#   'sense.',
#   'excuse,',
#   'explanation.',
#   'single',
#   'one',
#   'problem.',
#   'one'],
#  'sense.': ['You’d', 'If'],
#  'You’d': ['get', 'have'],
#  'rid': ['of'],
#  'second…': ['if'],
#  'if': ['it',
#   'you',
#   'they…',
#   'you',
#   'I’m',
#   'I',
#   'I',
#   'it',
#   'you’re',
#   'no',
#   'he',
#   'they',
#   'you'],
#  'it': ['wasn’t',
#   'out',
#   'is',
#   'by',
#   'may',
#   'here.',
#   'myself,',
#   'with',
#   'so',
#   'was',
#   'suck?',
#   'great?',
#   'sucked.”',
#   'suck?',
#   'sucks.”',
#   'worse?',
#   'out.',
#   'in',
#   'with',
#   'too',
#   'seems',
#   'comes',
#   'comes',
#   'took',
#   'is.',
#   'from',
#   'was',
#   'back.',
#   'back.',
#   'back.',
#   'a',
#   'as',
#   'from',
#   'anymore.',
#   'is.',
#   'up',
#   'to',
#   'in',
#   'slips',
#   'back.',
#   'up',
#   'a',
#   'ends',
#   'says!',
#   'makes',
#   'easier',
#   'is”',
#   'to',
#   'is',
#   'is.”',
#   'is”',
#   'is.”',
#   'is',
#   'is.”',
#   'he',
#   'to',
#   'was',
#   'a',
#   'here.”',
#   'on',
#   'will',
#   'up',
#   'was',
#   'like',
#   'every',
#   'was',
#   'is',
#   'in',
#   'come…',
#   'in',
#   'doesn’t',
#   'could',
#   'is.',
#   'out',
#   'down.',
#   'roll',
#   'to',
#   'up?'],
#  'wasn’t': ['even'],
#  'even': ['a',
#   'give',
#   'see',
#   'move',
#   'walk.',
#   'know',
#   'use',
#   'longer',
#   'in',
#   'know',
#   'know',
#   'think',
#   'listening',
#   'aware',
#   'make'],
#  'bigger': ['pain'],
#  'pain': ['in'],
#  'ass': ['to', 'where', 'is'],
#  'find': ['new', 'my', 'the', 'their', '♪\n♪'],
#  'learn': ['about', 'in', 'anything'],
#  'annoying': ['problems', 'in'],
#  'problems': ['that', 'and', 'of'],
#  'that': ['they',
#   'feeling',
#   'we',
#   'because',
#   'everyone’s',
#   'your',
#   'different.',
#   'place.”',
#   'food?”',
#   'book,',
#   'was…',
#   'great?”',
#   'great.',
#   'hot',
#   'new',
#   'sucks.”',
#   '“sucks”',
#   'are',
#   'a',
#   'happened',
#   'dark',
#   'lab',
#   'you',
#   'battery',
#   'doesn’t',
#   'makes',
#   'day.',
#   'word,',
#   'we',
#   'we',
#   'add',
#   'you',
#   'was.',
#   'like',
#   'the',
#   'could',
#   'can’t',
#   'person',
#   'commercial?',
#   'we',
#   'their',
#   'seems',
#   'fill',
#   'with',
#   'he',
#   'anymore.',
#   'I',
#   'works',
#   'comes',
#   'bad',
#   'person.',
#   'will',
#   'thing',
#   'little',
#   'after',
#   'I',
#   'number.',
#   'flea',
#   'option.',
#   'I’m',
#   'woman.',
#   'may',
#   'big',
#   'I',
#   'every',
#   'I',
#   'one?',
#   'I',
#   'I',
#   'in',
#   'women',
#   'I’d',
#   'I',
#   'Lollipop',
#   'their',
#   'in',
#   'thought',
#   'level,',
#   'took',
#   'car',
#   'you',
#   'person',
#   'room.',
#   'is',
#   'the',
#   'are',
#   'play.',
#   'it',
#   'he',
#   'moment',
#   'threw',
#   'dark,',
#   'have',
#   'our',
#   'fires',
#   'is',
#   'defines',
#   'work.',
#   'are',
#   'big',
#   'you'],
#  'they': ['never',
#   'open',
#   'are!',
#   'are.',
#   'invented',
#   'must’ve',
#   'can’t',
#   'weren’t',
#   'put',
#   'gave',
#   'tell',
#   'give',
#   'hear:',
#   'do',
#   'stand',
#   'can’t',
#   'make?',
#   'always',
#   'have',
#   'say,',
#   'were',
#   'here?',
#   'were',
#   'love',
#   'done',
#   'cinch'],
#  'never': ['do',
#   'go',
#   'meet.',
#   'mind.”',
#   'touch',
#   'marry',
#   'has',
#   'heard',
#   'heard',
#   'any',
#   'stop',
#   'as'],
#  'anything': ['about…', 'anymore.', 'I'],
#  'about…': ['…change'],
#  '…change': ['the'],
#  'names': ['and', 'on'],
#  'numbers': ['in'],
#  'phone,': ['delete', '’cause', 'it'],
#  'delete': ['the'],
#  'old': ['contacts.', 'people', 'people'],
#  'contacts.': ['“Ah,'],
#  '“Ah,': ['the', 'uh,'],
#  'hell': ['with',
#   'outta',
#   'you’re',
#   'outta',
#   'is',
#   'you',
#   'is',
#   'up.”',
#   'else',
#   'outta'],
#  'it.': ['I’ll',
#   'Now,',
#   'He',
#   'Wouldn’t',
#   'We’re',
#   'We’re',
#   'It’s',
#   'I’ve',
#   'It’s',
#   'That…',
#   'Give',
#   '“Text',
#   'Don’t',
#   'I',
#   'I',
#   'I',
#   'It’s',
#   'Sometimes,',
#   'Forget',
#   'It’s',
#   '“You',
#   'Or',
#   'Or',
#   'If',
#   'He’s',
#   'He',
#   'He',
#   'Sometimes,',
#   'We',
#   'We',
#   'That’s',
#   'And',
#   'The',
#   'Oh,',
#   '“Jerry,',
#   'It’s',
#   'Thanks',
#   'Good'],
#  'I’ll': ['ride',
#   'talk',
#   'handle',
#   'tell',
#   'be',
#   'answer.',
#   'see',
#   'Google',
#   'just',
#   'tell',
#   'bring',
#   'work'],
#  'ride': ['it', 'around'],
#  'these': ['idiots.',
#   'plates.',
#   'necessary',
#   'phones',
#   'terms',
#   'humans.',
#   'portable,',
#   'bathrooms',
#   'bathrooms.',
#   'things.',
#   'instincts'],
#  'idiots.': ['It’s'],
#  'It’s': ['the',
#   'all',
#   'okay.',
#   'too',
#   'not',
#   'supposed',
#   'like',
#   'a',
#   'here.',
#   'here.',
#   'a',
#   'half',
#   'over.',
#   'antiquated.',
#   'fun',
#   'got',
#   'fast.',
#   'efficient.',
#   'the',
#   'not',
#   'beastly!',
#   'hyena',
#   'my',
#   'relaxing.',
#   'not',
#   'all',
#   'blowin’',
#   'two',
#   'a',
#   'risky.',
#   'rest,',
#   'just',
#   'a',
#   'also',
#   'the',
#   'a',
#   'you'],
#  'same': ['meals,',
#   'thing.',
#   'shape',
#   'nutrition',
#   'data',
#   'impression.',
#   'room,',
#   'bed,',
#   'stuff',
#   'guy,'],
#  'meals,': ['holidays,'],
#  'holidays,': ['and'],
#  'movies': ['anyway.', 'the'],
#  'anyway.': ['What’s', 'Check', 'Forty-eight,'],
#  'What’s': ['the', 'this'],
#  'difference': ['who'],
#  'who': ['I’m', 'had', 'are', 'I', 'incidentally', 'I'],
#  'with?”': ['“Just'],
#  '“Just': ['wanna', 'send'],
#  'wanna': ['be',
#   'get',
#   'talk',
#   'get',
#   'text,',
#   'know',
#   'remember',
#   'go',
#   'do',
#   'do',
#   'take',
#   'check',
#   'grow.',
#   'change.',
#   'do',
#   'be',
#   'be',
#   'grip!”',
#   'be'],
#  'out.”': ['This', 'Well…', 'You’re'],
#  'This': ['is',
#   'is',
#   'could',
#   'is,',
#   'is',
#   'is',
#   'move.',
#   'is',
#   'is,',
#   'doesn’t',
#   'thing',
#   'thing'],
#  'out.': ['People',
#   '“We',
#   'Let’s',
#   'We',
#   '“This',
#   'It',
#   'A',
#   'You',
#   'That’s',
#   'Their',
#   'What’s'],
#  'People': ['talk', 'do', 'are', 'are', 'like'],
#  'talk': ['about',
#   'a',
#   'to',
#   'to',
#   'or',
#   'about.',
#   'like',
#   'like',
#   'like',
#   'in'],
#  'goin’': ['out.', 'in', 'under.', 'with'],
#  '“We': ['should', 'can’t'],
#  'should': ['go', 'hear'],
#  'go': ['out.',
#   'out.',
#   'out.”',
#   'over',
#   'to',
#   'see',
#   'to',
#   'in,',
#   'stale,',
#   'ahead',
#   'dead',
#   'back',
#   'up',
#   'in',
#   'in',
#   'for',
#   'to',
#   'to',
#   'fight',
#   'back',
#   'into',
#   'into'],
#  'Let’s': ['go',
#   'go',
#   'talk',
#   'make',
#   'see',
#   'get',
#   'change',
#   'fight',
#   'use',
#   'fight',
#   'let'],
#  'We': ['never',
#   'love',
#   'live',
#   'can’t',
#   'couldn’t',
#   'saw',
#   'were',
#   'had',
#   'had',
#   'had',
#   'are',
#   'don’t',
#   'call',
#   'don’t',
#   'can',
#   'wanna',
#   'like',
#   'like',
#   'gotta',
#   'didn’t',
#   'don’t',
#   'tend',
#   'live',
#   'like',
#   'make',
#   'also',
#   'have',
#   'Saw',
#   'Had',
#   'raise',
#   'talk',
#   'don’t',
#   'can’t',
#   'saw',
#   'just',
#   'did',
#   'gotta',
#   'gotta',
#   'gotta',
#   'want',
#   'can’t',
#   'want',
#   'don’t'],
#  'Well…': ['this'],
#  'Now,': ['the', 'you', 'who', 'instead', 'I', 'in'],
#  'good': ['thing',
#   'as',
#   'subject.',
#   'one',
#   'idea?',
#   'time.',
#   'question,',
#   'year'],
#  'thing': ['about',
#   'this',
#   'that',
#   'your',
#   'anymore.',
#   'last',
#   'totally',
#   'I',
#   'the',
#   'is…',
#   'needs'],
#  'being': ['out', 'in', 'on', 'a'],
#  'long.': ['Just'],
#  'Just': ['long', 'keep', 'a'],
#  'long': ['enough', 'it', 'as'],
#  'enough': ['to'],
#  'next': ['feeling,', 'text,'],
#  'feeling,': ['which'],
#  'which': ['you’re', 'I'],
#  'get.': ['And', 'I’ll'],
#  'And': ['that',
#   'so…',
#   'I',
#   'everybody',
#   'in',
#   'they',
#   'the',
#   'let’s',
#   'when',
#   'by',
#   'I',
#   'don’t',
#   'women',
#   'then',
#   'you’re',
#   'I',
#   'I’m',
#   'then',
#   'then',
#   'we',
#   'I’m',
#   'then',
#   'again,',
#   'I'],
#  'feeling': ['is,'],
#  'is,': ['“I', 'in', '“Well,', 'uh,', 'uh…', 'you’re'],
#  'gettin’': ['back.”', 'closer?'],
#  'back.”': ['After', '“I', '“Who'],
#  'After': ['all', 'two'],
#  'work': ['you', 'out', 'for', 'out,', 'my'],
#  'put': ['into', 'together', '’em', 'people', 'Uber', 'it'],
#  'getting': ['your', 'on', 'it?', 'it?', 'smarter.', 'messages'],
#  'where': ['it', 'they', 'it', 'it'],
#  'only': ['halfway', 'two', 'reason', 'get', 'imagine', 'possibly'],
#  'halfway': ['through'],
#  'through': ['this', 'life', 'a', 'their', 'a', 'sand', 'a'],
#  'nightmare': ['at'],
#  'point.': ['Wherever', 'We’re'],
#  'Wherever': ['you'],
#  'are,': ['really,'],
#  'really,': ['anywhere'],
#  'life,': ['at', 'everyone’s', 'and', 'I', 'we'],
#  'point,': ['you', 'you'],
#  'outta': ['there.', 'here', 'my', 'here.'],
#  'there.': ['You’re', 'If', 'Nobody’s', 'It'],
#  'You’re': ['at',
#   'at',
#   'out,',
#   'on',
#   'making',
#   'such',
#   'playing',
#   'sleeping.',
#   'goddamn',
#   'goin’',
#   'poppin’'],
#  'work;': ['you'],
#  'home.': ['You’re', '“I’m', 'But'],
#  'working': ['all', 'model', 'on', 'anymore.'],
#  'week.': ['I', '“I’ll'],
#  'it’s': ['late.',
#   'great.”',
#   'called',
#   'coming.',
#   'gonna',
#   'goin’',
#   'very',
#   'in',
#   'probably',
#   'a',
#   'a',
#   'better.',
#   'like',
#   'scary.',
#   'supposed',
#   'a'],
#  'late.': ['“I'],
#  'up.”': ['“I', '“I’m'],
#  'airport.”': ['“When'],
#  'plane?”': ['Plane'],
#  'Plane': ['takes', 'lands.'],
#  'takes': ['off.', 'two', '♪\n♪'],
#  'off.': ['“When’s', 'We', 'What…'],
#  '“When’s': ['the'],
#  'plane': ['gonna', 'out'],
#  'land?”': ['Plane'],
#  'lands.': ['“Why'],
#  'open': ['the', 'a', 'the', 'my'],
#  'door': ['so', 'to', 'opens', 'open.'],
#  'out?”': ['Nobody'],
#  'Nobody': ['wants', 'likes', 'would'],
#  'wants': ['to', 'to'],
#  'anywhere.': ['Nobody'],
#  'likes': ['anything.', 'the'],
#  'anything.': ['We’re', 'I’m', 'I'],
#  'We’re': ['cranky,',
#   'going',
#   'gonna',
#   'gonna',
#   'gonna',
#   'so',
#   'still',
#   'picture-addicted.',
#   'sittin’',
#   'goin’'],
#  'cranky,': ['we’re'],
#  'we’re': ['irritable,', 'dealing', 'doing', 'cooking', 'all', 'gonna'],
#  'irritable,': ['and'],
#  'by': ['constantly', 'the', 'the', 'itself,', 'the', 'the', 'the'],
#  'constantly': ['changing'],
#  'changing': ['locations.'],
#  'locations.': ['And'],
#  'so…': ['we'],
#  'come': ['up',
#   'on.',
#   'out',
#   'up',
#   'up',
#   'out.',
#   'in',
#   'out…',
#   'in',
#   'and',
#   'running'],
#  'up': ['with',
#   'here,',
#   'strangers',
#   'here',
#   'to',
#   'to',
#   'to,',
#   'a',
#   'to',
#   'to',
#   'much',
#   'another',
#   'you',
#   'to',
#   'in',
#   'in',
#   'after',
#   'the',
#   'in',
#   'tight'],
#  'things': ['like', 'we', 'are', 'I’ve', 'to', 'that', 'I', 'like', 'and'],
#  'like': ['this,',
#   'it?”',
#   'the',
#   'great',
#   'taking',
#   'a',
#   'an',
#   'a',
#   'wrapping',
#   'I’m',
#   'a',
#   'Moses',
#   'your',
#   'a',
#   'a',
#   'that',
#   'it.',
#   'two',
#   'to',
#   'somebody',
#   'a',
#   'floor',
#   '“e-mail”?',
#   'we’re',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'cleaning',
#   'a',
#   'it’s',
#   'this',
#   'it',
#   'to',
#   'this…',
#   'doing',
#   'something',
#   'you?',
#   'being',
#   'to',
#   'your',
#   'this',
#   'this…',
#   'that',
#   'this…',
#   'that…',
#   'to',
#   'that.',
#   'my',
#   'this.',
#   'you',
#   'to',
#   'to',
#   'to',
#   'if',
#   'racks',
#   'they',
#   'he’s'],
#  'this,': ['what', 'would', 'too.'],
#  'what': ['we’re',
#   'this',
#   'I’ve',
#   'I’ve',
#   'the',
#   'I’m',
#   'you',
#   'the',
#   'I',
#   'you',
#   'microfraction',
#   'this',
#   'that',
#   'it',
#   'do',
#   'we',
#   'it',
#   'it',
#   'it',
#   'it',
#   'and',
#   'it',
#   'the',
#   'if',
#   'would',
#   'you',
#   'I',
#   'I',
#   'you’re',
#   'marriage',
#   'an',
#   'I',
#   'the',
#   'it’s',
#   'the',
#   'you',
#   'the',
#   'you'],
#  'doing': ['right', 'this', 'this.”', 'this'],
#  'made-up,': ['bogus,'],
#  'bogus,': ['hyped-up,'],
#  'hyped-up,': ['not-necessary'],
#  'not-necessary': ['special'],
#  'event.': ['That’s', 'Thank'],
#  'That’s': ['what',
#   'why',
#   'another',
#   'the',
#   'how',
#   'why',
#   'why',
#   'a',
#   'not',
#   'it.',
#   'what',
#   'all.”',
#   'Wiffle',
#   'why',
#   'when',
#   'not',
#   'the',
#   'okay.',
#   'kind',
#   'the',
#   'what',
#   'what'],
#  'is.': ['That', 'You’ll', 'I', 'Don’t', 'It’s', 'It’s'],
#  'That': ['a',
#   'place',
#   'was',
#   'was',
#   'was',
#   'doesn’t',
#   'makes',
#   'looks',
#   'is'],
#  'lot': ['of',
#   'of',
#   'and',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'like',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'worked': ['very', 'out'],
#  'hard': ['to', 'part.'],
#  'together': ['so', 'because', 'here.', 'without'],
#  'could': ['all',
#   'be',
#   'be',
#   'it',
#   'we',
#   'speak.',
#   'take',
#   'get',
#   'talk',
#   'text',
#   'get',
#   'result',
#   'happen',
#   'potentially',
#   'have',
#   'kill',
#   'say',
#   'also',
#   'only'],
#  'kill': ['some', 'you', 'you.”', 'you'],
#  'time.': ['That’s', 'Does', 'I', 'Just…', 'I’ll', 'It’s'],
#  'why': ['I’m', 'the', 'it’s', 'I’m', 'don’t', 'I'],
#  'had': ['nothing',
#   'a',
#   'toast!',
#   'orange',
#   'to',
#   'shredded',
#   'to',
#   'all',
#   'it',
#   'some',
#   'married',
#   'the',
#   'to',
#   'a'],
#  'nothing': ['to', 'but', 'to', 'the', 'kicks'],
#  'either,': ['by'],
#  'way.': ['I', 'Not'],
#  'tell': ['you',
#   'everyone',
#   'ya',
#   'you',
#   'you',
#   'me!',
#   'me!”',
#   'us',
#   'ya',
#   'you.'],
#  'that.': ['You', 'What', 'Give', 'I-I', 'That’s', 'You', 'We'],
# ...
#  'he': ['love',
#   'died',
#   'loved.”',
#   'would',
#   'does',
#   'comes',
#   'has',
#   'got',
#   'freezes',
#   'meets',
#   'makes',
#   'takes',
#   'won’t'],
#  'it?': ['You', 'There', 'There', 'You', 'Except,'],
#  'it.”': ['“You.”', 'Being'],
#  '“You.”': ['You'],
#  'single': ['you', 'friends.', 'guys.', 'guys', 'day', 'man,'],
#  'out?': ['“You.'],
#  '“You.': ['Wouldn’t'],
#  'he?': ['He'],
#  'place.”': ['“Did'],
#  'it?”': ['“I'],
#  'care': ['for', 'what', 'that'],
#  'myself,': ['but', 'half'],
#  'but': ['you…”',
#   'they',
#   'kind',
#   'don’t',
#   'it’s',
#   'empty,',
#   'he’s',
#   'cannot',
#   'that',
#   'it'],
#  'you…”': ['I'],
#  'looking': ['for', 'at'],
#  'bad.': ['“How’s', 'How'],
#  '“How’s': ['that'],
#  'food?”': ['“It’s'],
#  'bad.”': ['“That'],
#  '“That': ['sounds'],
#  'sounds': ['great.', 'great.'],
#  'over': ['there', 'with.”', 'it.', 'the', 'the'],
#  'there': ['and', 'an', 'any', 'never', 'at', 'since'],
#  'with.”': ['“Wanna'],
#  '“Wanna': ['hear'],
#  'specials?”': ['“No.'],
#  '“No.': ['If', 'Nor'],
#  'they’re': ['so', 'handed', 'allowed'],
#  'menu.': ['I’m'],
#  'interested': ['in'],
#  'food': ['that’s', 'orgy', 'for', 'thing', 'or'],
#  'that’s': ['auditioning', 'a', 'it.', 'a', 'no', 'what', 'what'],
#  'auditioning': ['to'],
#  'team.”': ['I'],
#  'talkin’': ['about.', 'on', 'ended', 'about', 'to'],
#  'about.': ['“We’re', 'You'],
#  '“We’re': ['gonna', 'comin’', 'not'],
#  'pan-sear': ['it.'],
#  'herb-crust': ['it.'],
#  'drizzle': ['it', 'it!'],
#  'reduction': ['of'],
#  'somethin’': ['else.”', 'that', 'to'],
#  'else.”': ['Stop'],
#  'Stop': ['drizzling.'],
#  'drizzling.': ['We'],
#  'can’t': ['take',
#   'even',
#   'go',
#   'find',
#   'even',
#   'do',
#   'either.',
#   'show',
#   'hold',
#   'get',
#   'keep',
#   'get',
#   'wait',
#   'hang',
#   'do',
#   'ask,',
#   'believe',
#   'say',
#   'say',
#   'do',
#   'they'],
#  'take': ['the',
#   'two',
#   'back',
#   'the',
#   'the',
#   'a',
#   'a',
#   'you',
#   '‘Movies',
#   '‘Details',
#   'that',
#   'a'],
#  'drizzling': ['anymore!'],
#  'anymore!': ['It’s'],
#  'drizzling!': ['Maybe'],
#  'Maybe': ['if', 'we’ll', 'I', 'I’ll', 'I’ll'],
#  'reduce': ['it'],
#  'much,': ['you'],
#  'wouldn’t': ['have'],
#  'it!': ['The', 'Text!”', 'He’s', 'We'],
#  'meal': ['takes', 'wish'],
#  'two': ['and',
#   'ratings',
#   'days',
#   'tablets',
#   'seconds,',
#   'free',
#   'buttons:',
#   'younger',
#   'octaves',
#   'octaves.',
#   'people…',
#   'people'],
#  'half': ['hours.', 'as', 'myself,', 'phone.', 'years', 'hours'],
#  'hours.': ['Your'],
#  'hurtin’': ['by'],
#  'end': ['of', 'of', 'with', 'of'],
#  'bowl': ['of'],
#  'Lucky': ['Charms'],
#  'Charms': ['and'],
#  'Pepsi': ['anyway.'],
#  'Check': ['always'],
#  'always': ['comes',
#   'wanted',
#   'wonder',
#   'have',
#   'push',
#   'find',
#   'in',
#   'are.',
#   'say,',
#   'have'],
#  'comes': ['in', 'in…', 'in,', 'in.', 'out', 'home,'],
#  'book,': ['the'],
#  'little': ['story',
#   'bit',
#   'bitch',
#   'lunch',
#   'bite',
#   'ghosty',
#   'different,',
#   'shook',
#   'lighter',
#   'move',
#   'world…',
#   'perspective',
#   'edge',
#   'more',
#   'bitey,',
#   'shoe',
#   'PowerPoint',
#   'bit'],
#  'story': ['of'],
#  'bill.': ['Yeah,'],
#  'here’s': ['the', 'what'],
#  'story.': ['Once', 'You’re'],
#  'Once': ['upon', 'they'],
#  'upon': ['a'],
#  'time,': ['you', 'on'],
#  'rib.': ['That’s'],
#  'street': ['afterwards', 'all', 'like'],
#  'afterwards': ['with'],
#  '“I-I': ['didn’t'],
#  'think': ['that',
#   'it',
#   'the',
#   'Uber',
#   'about',
#   'you’re',
#   'we’re',
#   'this',
#   'that',
#   'every',
#   'I’ll',
#   'that',
#   'I',
#   'that',
#   'that',
#   'is,',
#   'we',
#   'babies'],
#  'was…': ['Was', 'Was'],
#  'Was': ['that', 'there'],
#  'great?”': ['Everyone'],
#  'Everyone': ['says'],
#  'says': ['“great.”', '“hospital”'],
#  '“great.”': ['“Yeah,'],
#  'think?”': ['“It'],
#  '“It': ['sucked,', 'is', 'is', 'is'],
#  'sucked,': ['right?'],
#  'right?': ['That'],
#  'place': ['sucks.”', 'than', 'you', 'to', 'in', 'in', 'in', 'between'],
#  'sucks.”': ['A', '“Oh,', '“I'],
#  'places': ['just'],
#  'suck!': ['Then'],
#  'Then': ['you', 'I'],
#  'baseball': ['game.'],
#  'game.': ['You', 'I'],
#  'hot': ['dog.', 'dog', 'dog'],
#  'dog.': ['The'],
#  'dog': ['is',
#   'every',
#   'to',
#   'do',
#   'food',
#   'judgment.',
#   'does',
#   'leash',
#   'pulls'],
#  'cold.': ['The'],
#  'bun': ['is'],
#  'toasted.': ['The'],
#  'vendor': ['is'],
#  'ex-con': ['in'],
#  'work-release': ['program.'],
#  'program.': ['You'],
#  'every': ['time.',
#   'restaurant',
#   'three',
#   'night',
#   'single',
#   'argument',
#   'second.',
#   'five',
#   'move'],
#  'Does': ['it…', 'it', 'anyone'],
#  'it…': ['Does'],
#  'suck?': ['Yes.', 'It’s'],
#  'Yes.': ['Is', 'That’s'],
#  'Is': ['it', 'that', 'that', 'anyone…', 'there', 'that'],
#  'great?': ['Yes.'],
#  'close': ['they', 'together'],
#  'are!': ['“Sucks”'],
#  'ratings': ['people'],
#  'give': ['to', 'him', 'me', 'you', 'you', 'our', 'you', 'you', 'yourself'],
#  'anymore.': ['“Hey,', 'I', 'Your', '“How', 'Also,', '“How', 'I', 'This'],
#  '“Hey,': ['let’s', 'are', 'you', 'Jerry,', 'this', 'Bob,'],
#  'let’s': ['go', 'make'],
#  'movie.': ['I'],
#  'heard': ['it’s', 'it', 'the', 'that?', 'anyone', 'my', 'someone'],
#  'great.”': ['“Really?', '“I', 'I'],
#  '“Really?': ['I'],
#  'sucked.”': ['“How'],
#  'supposed': ['to', 'to'],
#  'beginning': ['is'],
#  'great,': ['and'],
#  'then': ['after', 'no', 'the', 'all', 'she', 'time'],
#  'that,': ['it', 'too.', 'it', 'Alex.', 'when'],
#  '“Oh,': ['that', 'we’re', 'I', 'my', 'we’ll', 'okay.'],
#  'know.': ['It', 'Is', 'I', 'Ladies,'],
#  'coulda': ['been'],
#  'say': ['that',
#   'to',
#   'air',
#   'those',
#   'that',
#   'things',
#   'no.',
#   'then?”',
#   'this.',
#   'that.',
#   'that.”',
#   'I',
#   'it.',
#   '♪\n♪'],
#  '“sucks”': ['and'],
#  'exact': ['same'],
#  'ice': ['cream', 'cream', 'cream'],
#  'cream': ['cone.', 'falls', 'on', 'and'],
#  'cone.': ['Walking'],
#  'Walking': ['down'],
#  'down': ['the', 'to', 'at', 'the', 'a', 'the', 'eight', 'another'],
#  'street,': ['the', 'tell'],
#  'falls': ['off'],
#  'off': ['the', 'for', 'the', 'a', 'a', 'camera', 'all', 'her', 'to'],
#  'top': ['of', 'of'],
#  'cone,': ['hits'],
#  'hits': ['the'],
#  'pavement.': ['Sucks.'],
#  'Sucks.': ['What'],
#  'say?': ['“Great.”'],
#  '“Great.”': ['Food‘s'],
#  'Food‘s': ['a'],
#  'subject.': ['Let’s'],
#  'bit': ['more', 'of', 'before'],
#  'more': ['about', 'time.', 'detail', 'money'],
#  'this.': ['‘Cause', 'You', '“That’s', 'She', 'I', 'Baby'],
#  '‘Cause': ['we', 'I', 'the'],
#  'Vegas': ['a'],
#  'couple': ['months', 'of'],
#  'months': ['ago.'],
#  'ago.': ['And'],
#  'everybody': ['goes,', 'would…'],
#  'goes,': ['“Jerry,', '“It’s'],
#  'buffet.': ['They', 'Oh,'],
#  'on.': ['You', 'We', 'You’re', 'It'],
#  'whatever': ['you', 'you', 'the', 'happens,', 'the'],
#  'buffet.”': ['What', 'Start'],
#  'idea': ['of'],
#  'buffet?': ['“Well,'],
#  '“Well,': ['things', 'I', 'I’ll', 'it', 'at', 'I'],
#  'make': ['it', 'the', 'sure', 'them', 'ourselves', 'a', 'you', 'that', 'the'],
#  'worse?': ['Why'],
#  'already': ['struggling', 'know.', 'seen.'],
#  'struggling': ['with', 'to', 'to'],
#  'portion': ['control…'],
#  'control…': ['…into'],
#  '…into': ['some'],
#  'kind': ['of', 'of', 'of', 'of'],
#  'debauched,': ['Caligula'],
#  'Caligula': ['food'],
#  'orgy': ['of'],
#  'unlimited': ['human'],
#  'consumption?': ['Let’s'],
#  'entrance': ['a'],
#  'chocolate-syrup': ['water'],
#  'water': ['park', 'in'],
#  'park': ['slide.”'],
#  'slide.”': ['The'],
#  'buffet': ['is'],
#  'Petco': ['and'],
#  'letting': ['your'],
#  'shopping.': ['You'],
#  'him': ['your'],
#  'wallet': ['in'],
#  'parking': ['lot'],
#  'go,': ['“Why',
#   '“All',
#   '“Hey,',
#   '“Fantastic.',
#   '‘Oh,',
#   '‘Oh,',
#   '“Both.',
#   '“You'],
#  'in,': ['get', 'too.', 'but', 'but'],
#  'think…': ['is', 'about', 'I', 'You'],
#  'amount': ['of', 'of'],
#  'you?': ['Use', 'I', 'What', 'Mom,'],
#  'Use': ['your'],
#  'judgment.': ['I’m'],
#  'wait': ['in', 'for', 'for'],
#  'car.': ['Leave', 'One'],
#  'Leave': ['the'],
#  'window': ['open'],
#  'crack': ['so'],
#  'breathe.”': ['People'],
#  'well': ['in'],
#  'unsupervised': ['eating'],
#  'environment.': ['Nobody'],
#  'walk': ['into', 'around.', 'around', 'into', 'in,'],
#  'say,': ['“I’ll',
#   '“Eat',
#   '“Why',
#   '‘Oh',
#   '‘Oh,',
#   '“Do',
#   '“I',
#   '“You’re',
#   '“I’m'],
#  '“I’ll': ['have', 'take', 'take'],
#  'yogurt': ['parfait,'],
#  'parfait,': ['sparerib,'],
#  'sparerib,': ['meat'],
#  'meat': ['pie,'],
#  'pie,': ['crab'],
#  'crab': ['leg,'],
#  'leg,': ['four'],
#  'four': ['cookies,', 'miles'],
#  'cookies,': ['and'],
#  'egg-white': ['omelet.”'],
#  'omelet.”': ['People'],
#  'building': ['death-row'],
#  'death-row': ['last'],
#  'wish': ['lists', 'I'],
#  'lists': ['on'],
#  'plates.': ['It’s'],
#  'perfect': ['working'],
#  'model': ['of', 'from'],
#  'emotional': ['problems'],
#  'personal': ['difficulties.', 'life.'],
#  'difficulties.': ['They', 'He’s'],
#  'around.': ['They', 'Then', 'Who’s', 'Like,', 'And'],
#  'kinda': ['hold'],
#  'hold': ['it', 'things,'],
#  '“This': ['is', 'is'],
#  'with.': ['It’s'],
#  'salad': ['with'],
#  'scoop': ['of'],
#  'unresolved': ['issues'],
#  'issues': ['I’m', 'quite'],
#  'trying': ['to', 'to', 'to', 'to'],
#  'Start': ['accosting'],
#  'accosting': ['strangers.'],
#  'strangers.': ['“Excuse'],
#  '“Excuse': ['me.'],
#  'Where': ['did', 'did'],
#  'that?': ['What', 'I', 'Is', 'Or', 'And', 'How’d'],
#  'caramelized': ['chicken'],
#  'chicken': ['leg?'],
#  'leg?': ['I'],
#  'try': ['that.'],
#  'Give': ['me', 'it', 'it', 'me', 'me'],
#  'yours.': ['You'],
#  'are.': ['You', 'The'],
#  'more.': ['Come'],
#  'on!”': ['Let’s…'],
#  'Let’s…': ['Please.'],
#  'Please.': ['Please.', 'Please'],
#  'Please': ['stay'],
#  'stay': ['with', 'in', 'together'],
#  'group': ['as'],
#  'can.': ['We’re'],
#  'exhibits.': ['I'],
#  'any': ['stragglers.', 'other', 'similarity', 'other', 'guy', 'Scotch'],
#  'stragglers.': ['But'],
#  'when': ['I',
#   'the',
#   'the',
#   'I',
#   'we',
#   'one',
#   'you',
#   'you’re',
#   'it’s',
#   'the',
#   'the',
#   'you’re',
#   'you',
#   'this',
#   'he',
#   'I’m'],
#  'kid,': ['the', 'ambulance.'],
#  'biggest': ['food'],
#  'happened': ['to', 'there?'],
#  'me…': ['When'],
#  'When': ['they', 'that', 'you’re', 'I', 'my', 'I’m'],
#  'invented': ['the'],
#  'Pop-Tart,': ['the'],
#  'back': ['of', 'to', 'some', 'to', 'from', 'basically'],
#  'head': ['blew', 'over'],
#  'blew': ['right', 'clear'],
#  'couldn’t': ['comprehend'],
#  'comprehend': ['the'],
#  'Pop-Tart!': ['It'],
#  'advanced!': ['We'],
#  'supermarket.': ['It'],
#  'alien': ['spaceship.'],
#  'spaceship.': ['We'],
#  'chimps': ['in'],
#  'dirt,': ['playing'],
#  'playing': ['with', 'paintball'],
#  'sticks.': ['Just…'],
#  'Just…': ['…grunting,', 'just'],
#  '…grunting,': ['pointing.'],
#  'pointing.': ['“Pop-Tart'],
#  '“Pop-Tart': ['is'],
#  'here.”': ['Think', 'I', '“Want', 'The'],
#  'Think': ['back', 'We'],
#  'Pop-Tart': ['came', 'is'],
#  'came': ['out.', 'back'],
#  '’60s.': ['We'],
#  'toast!': ['We'],
#  'orange': ['juice,', 'jumpsuit'],
#  'juice,': ['frozen'],
#  'frozen': ['decades', 'smiles'],
#  'decades': ['in'],
#  'advance.': ['You'],
#  'hack': ['away'],
#  'away': ['at', '♪\n♪'],
#  'knife!': ['It'],
#  'murder': ['to'],
#  'drops': ['of'],
#  'liquidity': ['in'],
#  'morning.': ['We'],
#  'shredded': ['wheat.'],
#  'wheat.': ['It'],
#  'wrapping': ['your'],
#  'lips': ['around', 'and'],
#  'around': ['a',
#   'in.',
#   'and',
#   'somebody',
#   'the',
#   'the',
#   'my',
#   'the',
#   'the',
#   'the',
#   'your'],
#  'woodchipper.': ['You’d'],
#  'breakfast,': ['you'],
#  'days': ['off'],
#  'scars': ['to'],
#  'heal': ['so'],
#  'speak.': ['My'],
#  'mom': ['made'],
#  'made': ['Cream', 'a', 'of', 'me.'],
#  'Cream': ['of'],
#  'Wheat.': ['She'],
#  'She': ['didn’t', 'may', 'had', 'was', 'finished'],
#  'recipe.': ['“Mom,'],
#  '“Mom,': ['the'],
#  'dish': ['is'],
#  'critical.': ['You’re'],
#  'making': ['it'],
#  'thick!': ['I'],
#  'move': ['my', 'they', 'on', 'on.', 'he', 'forward'],
#  'little-kid': ['spoon'],
#  'spoon': ['in'],
#  'bowl!': ['I’m'],
#  'seven.': ['I'],
#  'rowing': ['in'],
#  'hull': ['of'],
#  'Greek': ['slave'],
#  'slave': ['ship.'],
#  'ship.': ['That'],
#  'breakfast?”': ['And'],
#  'midst': ['of'],
#  'dark': ['and'],
#  'hopeless': ['moment,'],
#  'moment,': ['the'],
#  'Kellogg’s': ['Pop-Tarts', 'and'],
#  'Pop-Tarts': ['suddenly'],
#  'suddenly': ['appeared'],
#  'appeared': ['out'],
#  'Battle': ['Creek,'],
#  'Creek,': ['Michigan,'],
#  'Michigan,': ['which,'],
#  'which,': ['as'],
#  'cereal': ['fans', 'Silicon'],
#  'fans': ['know,'],
#  'know,': ['is', 'but…', 'step', 'everybody’s', 'first', 'I'],
#  'corporate': ['headquarters'],
#  'headquarters': ['of'],
#  'town': ['I'],
#  'wanted': ['to', 'to', 'it', 'to'],
#  'visit…': ['because'],
#  'seems': ['like', 'to'],
#  'Silicon': ['Valley…'],
#  'Valley…': ['of'],
#  'breakfast': ['super'],
#  'super': ['scientists…'],
#  'scientists…': ['conceiving'],
#  'conceiving': ['of'],
#  'frosted,': ['fruit-filled,'],
#  'fruit-filled,': ['heatable'],
#  'heatable': ['rectangles'],
#  'rectangles': ['in'],
#  'shape': ['as'],
#  'box': ['it', 'it', 'over'],
#  'in…': ['and'],
#  'nutrition': ['as'],
#  'took': ['to', 'place', 'place'],
#  'invent,': ['but'],
#  'must’ve': ['come'],
#  'lab': ['like'],
#  'Moses': ['with'],
#  'tablets': ['of'],
#  'Ten': ['Commandments.'],
#  'Commandments.': ['“The'],
#  '“The': ['Pop-Tart', 'air'],
#  'here!': ['Two'],
#  'Two': ['in', 'slots'],
#  'packet!': ['Two'],
#  'slots': ['in'],
#  'toaster!': ['Let’s'],
#  'ya': ['screw', 'to', 'it’s', 'see'],
#  'screw': ['this'],
#  'up!': ['Why', 'A', 'I’m'],
#  'two?': ['One’s'],
#  'One’s': ['not'],
#  'enough.': ['Three’s'],
#  'Three’s': ['too'],
#  'many.': ['And'],
#  'stale,': ['’cause'],
#  '’cause': ['they', 'the', 'we…'],
#  'weren’t': ['ever'],
#  'ever': ['fresh.”', 'see', 'forget', 'see'],
#  'fresh.”': ['What'],
#  'else': ['is', 'I’ve', 'say', 'we'],
#  'besides': ['everything?'],
#  'everything?': ['What'],
#  'device': ['dictatorship'],
#  'dictatorship': ['that'],
#  'under,': ['cowering'],
#  'cowering': ['in'],
#  'fear': ['from'],
#  'phone?': ['“My', 'I', 'What', 'I'],
#  'phone!': ['Where’s'],
#  'Where’s': ['my'],
#  'phone.': ['It’s…',
#   'It’s',
#   'That’s',
#   'That’s',
#   'The',
#   'We',
#   'Nobody’s',
#   'Once',
#   'One'],
#  'It’s…': ['Oh,'],
#  'phone': ['is', 'to', 'battery', 'so', 'because', 'is'],
#  'didn’t…': ['I'],
#  'moved': ['it'],
#  'pocket': ['to'],
#  'pocket.': ['I'],
#  'second.': ['I’m', 'He'],
#  'really': ['close.', 'the', 'remember', 'fun.'],
#  'Phew.': ['You'],
#  'hypno-phonified': ['at'],
#  'hand': ['your', 'button-clicker.'],
#  'somebody': ['to', 'coming', 'you', 'going,', 'that'],
#  'them': ['something.', 'tomorrow.”', 'operates', 'up.', 'to', 'staring'],
#  'something.': ['After'],
#  'seconds,': ['you'],
#  '“All': ['right.'],
#  'right.': ['Okay,', 'I’m', 'Let’s', 'There’s'],
#  'Okay,': ['give'],
#  'back.': ['Give', 'You', 'I', '“I'],
#  'That…': ['that’s', 'that’s'],
#  'completely': ['off-the-grid'],
#  'off-the-grid': ['right'],
#  'now.”': ['When', 'You'],
#  'battery': ['gets', 'gets'],
#  'gets': ['low…', 'down'],
#  'low…': ['you'],
#  'whole': ['body’s', 'thing,', 'thing.', 'thing'],
#  'body’s': ['runnin’'],
#  'runnin’': ['out'],
#  'power,': ['don’t'],
#  'just…': ['I-I', '…bumbling', 'You'],
#  'I-I': ['feel', 'can’t'],
#  'tired': ['when'],
#  'ten': ['or'],
#  'five.': ['I'],
#  'walk.': ['“You', 'I', 'My'],
#  'guys': ['go', 'play', 'here'],
#  'ahead': ['without'],
#  'without': ['me.', 'your', 'somebody', 'anesthesia.', 'saying'],
#  'charger.”': ['A'],
#  'call': ['comes', 'it', 'it'],
#  'in.': ['“Listen,', 'I', 'We', 'We', 'For', 'He’s'],
#  '“Listen,': ['I'],
#  'left': ['out', 'over,', 'side', 'or'],
#  'said.': ['If'],
#  'dead': ['on'],
#  'everyone': ['I', 'he'],
#  'tomorrow.”': ['“Well,'],
#  'touch': ['with', 'in'],
#  'Jerry.': ['That’s'],
#  'phone’s': ['so', 'the'],
#  'important': ['to'],
#  'important,': ['you', 'the'],
#  'know.”': ['Really?'],
#  'Really?': ['They'],
#  'seem': ['very', 'to'],
#  'way': ['you', 'to', 'back,', 'out…', 'I', 'down'],
#  'scroll': ['through'],
#  'contact': ['list', 'but'],
#  'list': ['like'],
#  'gay': ['French'],
#  'French': ['king.'],
#  'king.': ['“Who'],
#  '“Who': ['pleases', 'was'],
#  'pleases': ['me'],
#  'Who': ['shall', 'shall', 'the', 'designed', 'leads'],
#  'shall': ['I', 'I'],
#  'favor?': ['Who'],
#  'delete?”': ['We'],
#  'separating': ['from'],
#  'part': ['of'],
#  'us.': ['Now,', 'We', 'That'],
#  'access': ['to'],
#  'information': ['do', 'from', 'but', 'system'],
#  'have?': ['What'],
#  'remember.': ['What’ll'],
#  'What’ll': ['you'],
#  'pictures?': ['Are'],
#  'Are': ['you', 'these', 'you'],
#  'describe': ['what'],
#  'saw?': ['That'],
#  'anybody': ['that'],
#  'called': ['an'],
#  'iPhone.': ['It’s'],
#  'complete': ['individual.', 'stop!', 'this'],
#  ...}

# %%
generate_sentence(jerry_dict)
# Out:
# 'Marriage you’re in the end. You can get this point. We’re goin’ under. You’re goddamn?'
